# %%
# %matplotlib inline
# -*- coding: utf-8 -*-
"""
Exemple simple de MNIST avec PyTorch
Exemple avec nn.Conv2d et F.cross_entropy
Production de métriques avec graphes
Fonction entrainer
"""
import torch
torch.manual_seed(0) # Pour résultats reproductibles

# Fonction J d'entropie croisée
import torch.nn.functional as F
fonction_cout = F.cross_entropy

def taux_bonnes_predictions(lot_Y_predictions, lot_Y):
    predictions_categorie = torch.argmax(lot_Y_predictions, dim=1)
    return (predictions_categorie == lot_Y).float().mean()

from torch import nn
# Définition de l'architecture du RNA

modele = nn.Sequential(
    nn.Conv2d(1,16,3),
    nn.ReLU(),
    nn.Conv2d(16,32,3),
    nn.ReLU(),
    nn.Flatten(),
    nn.Linear(24*24*32, 10)
)
    
from torch import optim
optimiseur = optim.SGD(modele.parameters(), lr=0.01)

# Chargement des données de MNIST
import pickle, gzip
fichier_donnees = gzip.open(r"mnist.pkl.gz", 'rb')
((donnees_ent_X, donnees_ent_Y),(donnees_valid_X, donnees_valid_Y),(donnees_test_X,donnees_test_Y)) = pickle.load(fichier_donnees, encoding="latin-1")
fichier_donnees.close()

# Conversion des données en type toch.Tensor
import torch
donnees_ent_X,donnees_ent_Y,donnees_valid_X,donnees_valid_Y,donnees_test_X,donnees_test_Y  = map(torch.tensor,
    (donnees_ent_X.reshape((-1,1,28,28)),donnees_ent_Y,donnees_valid_X.reshape((-1,1,28,28)),donnees_valid_Y,donnees_test_X.reshape((-1,1,28,28)),donnees_test_Y))

# Création des objets DataLoader pour itérer par lot
from torch.utils.data import TensorDataset
from torch.utils.data import DataLoader
ds_ent = TensorDataset(donnees_ent_X, donnees_ent_Y)
dl_ent = DataLoader(ds_ent, batch_size=100, shuffle=True)
ds_valid = TensorDataset(donnees_valid_X,donnees_valid_Y)
dl_valid = DataLoader(ds_valid, batch_size=100)

def entrainer(modele, dl_ent, dl_valid, optimiseur, nb_epochs=10):

    # Listes pour les métriques par epoch
    liste_cout_moyen_ent = []
    liste_taux_moyen_ent = []
    liste_cout_moyen_valid = []
    liste_taux_moyen_valid = []
    
    # Boucle d'apprentissage
    for epoch in range(nb_epochs):
        cout_total_ent = 0 # pour cumuler les couts par mini-lot
        taux_bonnes_predictions_ent = 0 # pour cumuler les taux par mini-lot
        modele.train() # Pour certains types de couches (nn.BatchNorm2d, nn.Dropout, ...)
        
        # Boucle d'apprentissage par mini-lot pour une epoch
        for lot_X, lot_Y in dl_ent:
            optimiseur.zero_grad() # Remettre les dérivées à zéro
            lot_Y_predictions = modele(lot_X) # Appel de la méthode forward
            cout = fonction_cout(lot_Y_predictions, lot_Y)
            cout.backward() # Calcul des gradiants par rétropropagation
            with torch.no_grad():
                cout_total_ent +=cout
                taux_bonnes_predictions_ent += taux_bonnes_predictions(lot_Y_predictions, lot_Y)
            optimiseur.step() # Mise à jour des paramètres
        # Calculer les moyennes par mini-lot
        with torch.no_grad():
            cout_moyen_ent = cout_total_ent/len(dl_ent)
            taux_moyen_ent = taux_bonnes_predictions_ent/len(dl_ent)
       
        modele.eval() # Pour certains types de couches (nn.BatchNorm2d, nn.Dropout, ...)
        with torch.no_grad():
            cout_valid = sum(fonction_cout(modele(lot_valid_X), lot_valid_Y) for lot_valid_X, lot_valid_Y in dl_valid)
            taux_bons_valid = sum(taux_bonnes_predictions(modele(lot_valid_X), lot_valid_Y) for lot_valid_X, lot_valid_Y in dl_valid)
        cout_moyen_valid = cout_valid/len(dl_valid)
        taux_moyen_valid = taux_bons_valid/len(dl_valid)
        print(f'-------- > epoch {epoch+1}:  coût moyen entraînement = {cout_moyen_ent}')
        print(f'-------- > epoch {epoch+1}:  taux moyen entraînement = {taux_moyen_ent}')
        print(f'-------- > epoch {epoch+1}:  coût moyen validation = {cout_moyen_valid}')
        print(f'-------- > epoch {epoch+1}:  taux moyen validation = {taux_moyen_valid}')
    
        liste_cout_moyen_ent.append(cout_moyen_ent)
        liste_taux_moyen_ent.append(taux_moyen_ent)
        liste_cout_moyen_valid.append(cout_moyen_valid)
        liste_taux_moyen_valid.append(taux_moyen_valid)
    
    # Affichage du graphique d'évolution des métriques par epoch
    import numpy as np
    import matplotlib.pyplot as plt
    plt.plot(np.arange(0,nb_epochs),liste_cout_moyen_ent,label='Erreur entraînement')
    plt.plot(np.arange(0,nb_epochs),liste_cout_moyen_valid,label='Erreur validation')
    plt.title("Evolution du coût")
    plt.xlabel('epoch')
    plt.ylabel('moyenne par observation')
    plt.legend(loc='upper center')
    plt.show()
        
    plt.plot(np.arange(0,nb_epochs),liste_taux_moyen_ent,label='Taux bonnes réponses entraînement')
    plt.plot(np.arange(0,nb_epochs),liste_taux_moyen_valid,label='Taux bonnes réponses validation')
    plt.title("Evolution du taux")
    plt.xlabel('epoch')
    plt.ylabel('moyenne par observation')
    plt.legend(loc='upper center')
    plt.show()

entrainer(modele, dl_ent, dl_valid, optimiseur, nb_epochs=30)
# Out:
# -------- > epoch 1:  coût moyen entraînement = 0.6776726841926575
# -------- > epoch 1:  taux moyen entraînement = 0.8181402683258057
# -------- > epoch 1:  coût moyen validation = 0.3085939288139343
# -------- > epoch 1:  taux moyen validation = 0.9126999378204346
# -------- > epoch 2:  coût moyen entraînement = 0.32810187339782715
# -------- > epoch 2:  taux moyen entraînement = 0.9046206474304199
# -------- > epoch 2:  coût moyen validation = 0.27954840660095215
# -------- > epoch 2:  taux moyen validation = 0.9200998544692993
# -------- > epoch 3:  coût moyen entraînement = 0.295859158039093
# -------- > epoch 3:  taux moyen entraînement = 0.9143204689025879
# -------- > epoch 3:  coût moyen validation = 0.25443318486213684
# -------- > epoch 3:  taux moyen validation = 0.9294000267982483
# -------- > epoch 4:  coût moyen entraînement = 0.2672252953052521
# -------- > epoch 4:  taux moyen entraînement = 0.923781156539917
# -------- > epoch 4:  coût moyen validation = 0.2284909039735794
# -------- > epoch 4:  taux moyen validation = 0.9350999593734741
# -------- > epoch 5:  coût moyen entraînement = 0.23411861062049866
# -------- > epoch 5:  taux moyen entraînement = 0.9337605237960815
# -------- > epoch 5:  coût moyen validation = 0.20023372769355774
# -------- > epoch 5:  taux moyen validation = 0.9465000629425049
# -------- > epoch 6:  coût moyen entraînement = 0.1984255164861679
# -------- > epoch 6:  taux moyen entraînement = 0.9445209503173828
# -------- > epoch 6:  coût moyen validation = 0.16537748277187347
# -------- > epoch 6:  taux moyen validation = 0.9577001333236694
# -------- > epoch 7:  coût moyen entraînement = 0.164685919880867
# -------- > epoch 7:  taux moyen entraînement = 0.9538413286209106
# -------- > epoch 7:  coût moyen validation = 0.1443236768245697
# -------- > epoch 7:  taux moyen validation = 0.9637001752853394
# -------- > epoch 8:  coût moyen entraînement = 0.13670842349529266
# -------- > epoch 8:  taux moyen entraînement = 0.9618613123893738
# -------- > epoch 8:  coût moyen validation = 0.1201825737953186
# -------- > epoch 8:  taux moyen validation = 0.971000075340271
# -------- > epoch 9:  coût moyen entraînement = 0.11577300727367401
# -------- > epoch 9:  taux moyen entraînement = 0.9682008624076843
# -------- > epoch 9:  coût moyen validation = 0.10635652393102646
# -------- > epoch 9:  taux moyen validation = 0.9738999009132385
# -------- > epoch 10:  coût moyen entraînement = 0.10168442130088806
# -------- > epoch 10:  taux moyen entraînement = 0.971821665763855
# -------- > epoch 10:  coût moyen validation = 0.09577426314353943
# -------- > epoch 10:  taux moyen validation = 0.9768999218940735
# -------- > epoch 11:  coût moyen entraînement = 0.09056611359119415
# -------- > epoch 11:  taux moyen entraînement = 0.9748007655143738
# -------- > epoch 11:  coût moyen validation = 0.08953645080327988
# -------- > epoch 11:  taux moyen validation = 0.9784000515937805
# -------- > epoch 12:  coût moyen entraînement = 0.08159384876489639
# -------- > epoch 12:  taux moyen entraînement = 0.9771602749824524
# -------- > epoch 12:  coût moyen validation = 0.08434775471687317
# -------- > epoch 12:  taux moyen validation = 0.9785001873970032
# -------- > epoch 13:  coût moyen entraînement = 0.07509937137365341
# -------- > epoch 13:  taux moyen entraînement = 0.9789806008338928
# -------- > epoch 13:  coût moyen validation = 0.0861058309674263
# -------- > epoch 13:  taux moyen validation = 0.9782001376152039
# -------- > epoch 14:  coût moyen entraînement = 0.06986358016729355
# -------- > epoch 14:  taux moyen entraînement = 0.9805203676223755
# -------- > epoch 14:  coût moyen validation = 0.08189539611339569
# -------- > epoch 14:  taux moyen validation = 0.9794001579284668
# -------- > epoch 15:  coût moyen entraînement = 0.06505157798528671
# -------- > epoch 15:  taux moyen entraînement = 0.9818602800369263
# -------- > epoch 15:  coût moyen validation = 0.07634270191192627
# -------- > epoch 15:  taux moyen validation = 0.9812000393867493
# -------- > epoch 16:  coût moyen entraînement = 0.061602845788002014
# -------- > epoch 16:  taux moyen entraînement = 0.9826000332832336
# -------- > epoch 16:  coût moyen validation = 0.07092712074518204
# -------- > epoch 16:  taux moyen validation = 0.9827002882957458
# -------- > epoch 17:  coût moyen entraînement = 0.05852191522717476
# -------- > epoch 17:  taux moyen entraînement = 0.9836602210998535
# -------- > epoch 17:  coût moyen validation = 0.0729372501373291
# -------- > epoch 17:  taux moyen validation = 0.9815003275871277
# -------- > epoch 18:  coût moyen entraînement = 0.05561289191246033
# -------- > epoch 18:  taux moyen entraînement = 0.9842806458473206
# -------- > epoch 18:  coût moyen validation = 0.0699031800031662
# -------- > epoch 18:  taux moyen validation = 0.9813002943992615
# -------- > epoch 19:  coût moyen entraînement = 0.05282287299633026
# -------- > epoch 19:  taux moyen entraînement = 0.9848403930664062
# -------- > epoch 19:  coût moyen validation = 0.07085251063108444
# -------- > epoch 19:  taux moyen validation = 0.9816003441810608
# -------- > epoch 20:  coût moyen entraînement = 0.05039943754673004
# -------- > epoch 20:  taux moyen entraînement = 0.9856799244880676
# -------- > epoch 20:  coût moyen validation = 0.07629036158323288
# -------- > epoch 20:  taux moyen validation = 0.9795000553131104
# -------- > epoch 21:  coût moyen entraînement = 0.048363182693719864
# -------- > epoch 21:  taux moyen entraînement = 0.9862002730369568
# -------- > epoch 21:  coût moyen validation = 0.06907043606042862
# -------- > epoch 21:  taux moyen validation = 0.9812003374099731
# -------- > epoch 22:  coût moyen entraînement = 0.04647388681769371
# -------- > epoch 22:  taux moyen entraînement = 0.9865599274635315
# -------- > epoch 22:  coût moyen validation = 0.0650593638420105
# -------- > epoch 22:  taux moyen validation = 0.9826001524925232
# -------- > epoch 23:  coût moyen entraînement = 0.04443248733878136
# -------- > epoch 23:  taux moyen entraînement = 0.9874203205108643
# -------- > epoch 23:  coût moyen validation = 0.06567317992448807
# -------- > epoch 23:  taux moyen validation = 0.9828002452850342
# -------- > epoch 24:  coût moyen entraînement = 0.04297753423452377
# -------- > epoch 24:  taux moyen entraînement = 0.9872400164604187
# -------- > epoch 24:  coût moyen validation = 0.0651092678308487
# -------- > epoch 24:  taux moyen validation = 0.9829999804496765
# -------- > epoch 25:  coût moyen entraînement = 0.041107602417469025
# -------- > epoch 25:  taux moyen entraînement = 0.9879997968673706
# -------- > epoch 25:  coût moyen validation = 0.06649469584226608
# -------- > epoch 25:  taux moyen validation = 0.982900083065033
# -------- > epoch 26:  coût moyen entraînement = 0.03977791592478752
# -------- > epoch 26:  taux moyen entraînement = 0.9884597063064575
# -------- > epoch 26:  coût moyen validation = 0.06405322253704071
# -------- > epoch 26:  taux moyen validation = 0.9834001064300537
# -------- > epoch 27:  coût moyen entraînement = 0.03828701004385948
# -------- > epoch 27:  taux moyen entraînement = 0.9888595938682556
# -------- > epoch 27:  coût moyen validation = 0.06634775549173355
# -------- > epoch 27:  taux moyen validation = 0.981200098991394
# -------- > epoch 28:  coût moyen entraînement = 0.036817584186792374
# -------- > epoch 28:  taux moyen entraînement = 0.9894593954086304
# -------- > epoch 28:  coût moyen validation = 0.064745232462883
# -------- > epoch 28:  taux moyen validation = 0.9820998907089233
# -------- > epoch 29:  coût moyen entraînement = 0.035777654498815536
# -------- > epoch 29:  taux moyen entraînement = 0.9896396398544312
# -------- > epoch 29:  coût moyen validation = 0.06529445946216583
# -------- > epoch 29:  taux moyen validation = 0.9822002649307251
# -------- > epoch 30:  coût moyen entraînement = 0.03468639403581619
# -------- > epoch 30:  taux moyen entraînement = 0.98993980884552
# -------- > epoch 30:  coût moyen validation = 0.06281469762325287
# -------- > epoch 30:  taux moyen validation = 0.9823001027107239
