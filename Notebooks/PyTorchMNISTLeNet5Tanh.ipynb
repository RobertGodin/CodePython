# %%
# %matplotlib inline
# -*- coding: utf-8 -*-
"""
Exemple MNIST avec RNA semblable à LeNet-5 (LeCun et al.)
"""
import torch
torch.manual_seed(0) # Pour résultats reproductibles

# Fonction J d'entropie croisée
import torch.nn.functional as F
fonction_cout = F.cross_entropy

def taux_bonnes_predictions(lot_Y_predictions, lot_Y):
    predictions_categorie = torch.argmax(lot_Y_predictions, dim=1)
    return (predictions_categorie == lot_Y).float().mean()

from torch import nn
# Définition de l'architecture du RNA

modele = torch.nn.Sequential(
    nn.Conv2d(1, 6, kernel_size=5, padding=2), nn.Tanh(), #(N, 1, 28, 28) -> (N, 6, 28, 28)
    nn.AvgPool2d(kernel_size=2, stride=2), #(N, 6, 28, 28) -> (N, 6, 14, 14)
    nn.Conv2d(6, 16, kernel_size=5), nn.Tanh(), #(N, 6, 14, 14) -> (N, 16, 10, 10)
    nn.AvgPool2d(kernel_size=2, stride=2), #(N, 16, 10, 10) -> (N, 16, 5, 5)
    nn.Flatten(), #(N, 16, 5, 5) -> (N, 400)
    nn.Linear(16 * 5 * 5, 120), nn.Tanh(), #(N, 400) -> (N, 120)
    nn.Linear(120, 84), nn.Tanh(), #(N, 120) -> (N, 84)
    nn.Linear(84, 10)) #(N, 84) -> (N, 10)

from torch import optim
optimiseur = optim.SGD(modele.parameters(), lr=0.5)

import torchvision
import torchvision.transforms as transforms

#Chargement des données
ds = torchvision.datasets.MNIST(root = "./data", train = True, download = True, transform = transforms.ToTensor())
ds_ent, ds_valid = torch.utils.data.random_split(ds, [50000, 10000])
ds_test = torchvision.datasets.MNIST(root = "./data", train = False, download = True, transform = transforms.ToTensor())

#Création du DataLoader avec le dataset
dl_ent = torch.utils.data.DataLoader(ds_ent, batch_size=100, shuffle = True)
dl_valid = torch.utils.data.DataLoader(ds_valid, batch_size=100)

def entrainer(modele, dl_ent, dl_valid, optimiseur, nb_epochs=10):

    # Listes pour les métriques par epoch
    liste_cout_moyen_ent = []
    liste_taux_moyen_ent = []
    liste_cout_moyen_valid = []
    liste_taux_moyen_valid = []
    
    # Boucle d'apprentissage
    for epoch in range(nb_epochs):
        cout_total_ent = 0 # pour cumuler les couts par mini-lot
        taux_bonnes_predictions_ent = 0 # pour cumuler les taux par mini-lot
        modele.train() # Pour certains types de couches (nn.BatchNorm2d, nn.Dropout, ...)
        
        # Boucle d'apprentissage par mini-lot pour une epoch
        for lot_X, lot_Y in dl_ent:
            optimiseur.zero_grad() # Remettre les dérivées à zéro
            lot_Y_predictions = modele(lot_X) # Appel de la méthode forward
            cout = fonction_cout(lot_Y_predictions, lot_Y)
            cout.backward() # Calcul des gradiants par rétropropagation
            with torch.no_grad():
                cout_total_ent +=cout
                taux_bonnes_predictions_ent += taux_bonnes_predictions(lot_Y_predictions, lot_Y)
            optimiseur.step() # Mise à jour des paramètres
        # Calculer les moyennes par mini-lot
        with torch.no_grad():
            cout_moyen_ent = cout_total_ent/len(dl_ent)
            taux_moyen_ent = taux_bonnes_predictions_ent/len(dl_ent)
       
        modele.eval() # Pour certains types de couches (nn.BatchNorm2d, nn.Dropout, ...)
        with torch.no_grad():
            cout_valid = sum(fonction_cout(modele(lot_valid_X), lot_valid_Y) for lot_valid_X, lot_valid_Y in dl_valid)
            taux_bons_valid = sum(taux_bonnes_predictions(modele(lot_valid_X), lot_valid_Y) for lot_valid_X, lot_valid_Y in dl_valid)
        cout_moyen_valid = cout_valid/len(dl_valid)
        taux_moyen_valid = taux_bons_valid/len(dl_valid)
        print(f'-------- > epoch {epoch+1}:  coût moyen entraînement = {cout_moyen_ent}')
        print(f'-------- > epoch {epoch+1}:  taux moyen entraînement = {taux_moyen_ent}')
        print(f'-------- > epoch {epoch+1}:  coût moyen validation = {cout_moyen_valid}')
        print(f'-------- > epoch {epoch+1}:  taux moyen validation = {taux_moyen_valid}')
    
        liste_cout_moyen_ent.append(cout_moyen_ent)
        liste_taux_moyen_ent.append(taux_moyen_ent)
        liste_cout_moyen_valid.append(cout_moyen_valid)
        liste_taux_moyen_valid.append(taux_moyen_valid)
    
    # Affichage du graphique d'évolution des métriques par epoch
    import numpy as np
    import matplotlib.pyplot as plt
    plt.plot(np.arange(0,nb_epochs),liste_cout_moyen_ent,label='Erreur entraînement')
    plt.plot(np.arange(0,nb_epochs),liste_cout_moyen_valid,label='Erreur validation')
    plt.title("Evolution du coût")
    plt.xlabel('epoch')
    plt.ylabel('moyenne par observation')
    plt.legend(loc='upper center')
    plt.show()
        
    plt.plot(np.arange(0,nb_epochs),liste_taux_moyen_ent,label='Taux bonnes réponses entraînement')
    plt.plot(np.arange(0,nb_epochs),liste_taux_moyen_valid,label='Taux bonnes réponses validation')
    plt.title("Evolution du taux")
    plt.xlabel('epoch')
    plt.ylabel('moyenne par observation')
    plt.legend(loc='lower center')
    plt.show()

entrainer(modele, dl_ent, dl_valid, optimiseur, nb_epochs=30)
# Out:
# -------- > epoch 1:  coût moyen entraînement = 0.3201104402542114
# -------- > epoch 1:  taux moyen entraînement = 0.899880588054657
# -------- > epoch 1:  coût moyen validation = 0.12023136764764786
# -------- > epoch 1:  taux moyen validation = 0.9632999897003174
# -------- > epoch 2:  coût moyen entraînement = 0.0899624302983284
# -------- > epoch 2:  taux moyen entraînement = 0.9726806879043579
# -------- > epoch 2:  coût moyen validation = 0.0664469450712204
# -------- > epoch 2:  taux moyen validation = 0.9790002703666687
# -------- > epoch 3:  coût moyen entraînement = 0.05960821360349655
# -------- > epoch 3:  taux moyen entraînement = 0.9819605946540833
# -------- > epoch 3:  coût moyen validation = 0.056973520666360855
# -------- > epoch 3:  taux moyen validation = 0.9822004437446594
# -------- > epoch 4:  coût moyen entraînement = 0.04354242607951164
# -------- > epoch 4:  taux moyen entraînement = 0.9864604473114014
# -------- > epoch 4:  coût moyen validation = 0.049242082983255386
# -------- > epoch 4:  taux moyen validation = 0.9846003651618958
# -------- > epoch 5:  coût moyen entraînement = 0.034657593816518784
# -------- > epoch 5:  taux moyen entraînement = 0.9893795847892761
# -------- > epoch 5:  coût moyen validation = 0.05474698171019554
# -------- > epoch 5:  taux moyen validation = 0.9827001094818115
# -------- > epoch 6:  coût moyen entraînement = 0.027630841359496117
# -------- > epoch 6:  taux moyen entraînement = 0.9912991523742676
# -------- > epoch 6:  coût moyen validation = 0.044231198728084564
# -------- > epoch 6:  taux moyen validation = 0.9865001440048218
# -------- > epoch 7:  coût moyen entraînement = 0.022114329040050507
# -------- > epoch 7:  taux moyen entraînement = 0.9930996298789978
# -------- > epoch 7:  coût moyen validation = 0.043319955468177795
# -------- > epoch 7:  taux moyen validation = 0.9873001575469971
# -------- > epoch 8:  coût moyen entraînement = 0.016415324062108994
# -------- > epoch 8:  taux moyen entraînement = 0.9952991604804993
# -------- > epoch 8:  coût moyen validation = 0.04254459962248802
# -------- > epoch 8:  taux moyen validation = 0.987500011920929
# -------- > epoch 9:  coût moyen entraînement = 0.01308459509164095
# -------- > epoch 9:  taux moyen entraînement = 0.9960193634033203
# -------- > epoch 9:  coût moyen validation = 0.04283011332154274
# -------- > epoch 9:  taux moyen validation = 0.9876999855041504
# -------- > epoch 10:  coût moyen entraînement = 0.010858799330890179
# -------- > epoch 10:  taux moyen entraînement = 0.9967992901802063
# -------- > epoch 10:  coût moyen validation = 0.03985263779759407
# -------- > epoch 10:  taux moyen validation = 0.9890003204345703
# -------- > epoch 11:  coût moyen entraînement = 0.007378159556537867
# -------- > epoch 11:  taux moyen entraînement = 0.9981993436813354
# -------- > epoch 11:  coût moyen validation = 0.040001824498176575
# -------- > epoch 11:  taux moyen validation = 0.9889000654220581
# -------- > epoch 12:  coût moyen entraînement = 0.005774612072855234
# -------- > epoch 12:  taux moyen entraînement = 0.9984395503997803
# -------- > epoch 12:  coût moyen validation = 0.041751403361558914
# -------- > epoch 12:  taux moyen validation = 0.9883001446723938
# -------- > epoch 13:  coût moyen entraînement = 0.005108865909278393
# -------- > epoch 13:  taux moyen entraînement = 0.9986995458602905
# -------- > epoch 13:  coût moyen validation = 0.04273074120283127
# -------- > epoch 13:  taux moyen validation = 0.9895002245903015
# -------- > epoch 14:  coût moyen entraînement = 0.00390995480120182
# -------- > epoch 14:  taux moyen entraînement = 0.9991397857666016
# -------- > epoch 14:  coût moyen validation = 0.04067158326506615
# -------- > epoch 14:  taux moyen validation = 0.9895002245903015
# -------- > epoch 15:  coût moyen entraînement = 0.003275101538747549
# -------- > epoch 15:  taux moyen entraînement = 0.9992198348045349
# -------- > epoch 15:  coût moyen validation = 0.041503194719552994
# -------- > epoch 15:  taux moyen validation = 0.9889001250267029
# -------- > epoch 16:  coût moyen entraînement = 0.0022021732293069363
# -------- > epoch 16:  taux moyen entraînement = 0.9996397495269775
# -------- > epoch 16:  coût moyen validation = 0.041986171156167984
# -------- > epoch 16:  taux moyen validation = 0.989200234413147
# -------- > epoch 17:  coût moyen entraînement = 0.001954904990270734
# -------- > epoch 17:  taux moyen entraînement = 0.9995997548103333
# -------- > epoch 17:  coût moyen validation = 0.04035276919603348
# -------- > epoch 17:  taux moyen validation = 0.9898000955581665
# -------- > epoch 18:  coût moyen entraînement = 0.0014257262228056788
# -------- > epoch 18:  taux moyen entraînement = 0.9998598694801331
# -------- > epoch 18:  coût moyen validation = 0.04065864533185959
# -------- > epoch 18:  taux moyen validation = 0.9903000593185425
# -------- > epoch 19:  coût moyen entraînement = 0.001395678031258285
# -------- > epoch 19:  taux moyen entraînement = 0.9997199773788452
# -------- > epoch 19:  coût moyen validation = 0.041951730847358704
# -------- > epoch 19:  taux moyen validation = 0.9899002313613892
# -------- > epoch 20:  coût moyen entraînement = 0.0009582618367858231
# -------- > epoch 20:  taux moyen entraînement = 0.9998599886894226
# -------- > epoch 20:  coût moyen validation = 0.041554588824510574
# -------- > epoch 20:  taux moyen validation = 0.9897001385688782
# -------- > epoch 21:  coût moyen entraînement = 0.0008046910515986383
# -------- > epoch 21:  taux moyen entraînement = 0.9999199509620667
# -------- > epoch 21:  coût moyen validation = 0.04078643396496773
# -------- > epoch 21:  taux moyen validation = 0.9901000261306763
# -------- > epoch 22:  coût moyen entraînement = 0.0006417116965167224
# -------- > epoch 22:  taux moyen entraînement = 0.9999599456787109
# -------- > epoch 22:  coût moyen validation = 0.04148080199956894
# -------- > epoch 22:  taux moyen validation = 0.9900000691413879
# -------- > epoch 23:  coût moyen entraînement = 0.0005492651253007352
# -------- > epoch 23:  taux moyen entraînement = 0.9999799728393555
# -------- > epoch 23:  coût moyen validation = 0.04131337255239487
# -------- > epoch 23:  taux moyen validation = 0.9898000359535217
# -------- > epoch 24:  coût moyen entraînement = 0.00048235751455649734
# -------- > epoch 24:  taux moyen entraînement = 1.0
# -------- > epoch 24:  coût moyen validation = 0.04166403412818909
# -------- > epoch 24:  taux moyen validation = 0.9900000691413879
# -------- > epoch 25:  coût moyen entraînement = 0.0004227327590342611
# -------- > epoch 25:  taux moyen entraînement = 1.0
# -------- > epoch 25:  coût moyen validation = 0.04223527014255524
# -------- > epoch 25:  taux moyen validation = 0.9899001121520996
# -------- > epoch 26:  coût moyen entraînement = 0.00039419502718374133
# -------- > epoch 26:  taux moyen entraînement = 1.0
# -------- > epoch 26:  coût moyen validation = 0.042016834020614624
# -------- > epoch 26:  taux moyen validation = 0.9899000525474548
# -------- > epoch 27:  coût moyen entraînement = 0.0003668600111268461
# -------- > epoch 27:  taux moyen entraînement = 1.0
# -------- > epoch 27:  coût moyen validation = 0.042514607310295105
# -------- > epoch 27:  taux moyen validation = 0.9899000525474548
# -------- > epoch 28:  coût moyen entraînement = 0.00033912507933564484
# -------- > epoch 28:  taux moyen entraînement = 1.0
# -------- > epoch 28:  coût moyen validation = 0.042894087731838226
# -------- > epoch 28:  taux moyen validation = 0.9901999831199646
# -------- > epoch 29:  coût moyen entraînement = 0.00031902751652523875
# -------- > epoch 29:  taux moyen entraînement = 1.0
# -------- > epoch 29:  coût moyen validation = 0.043041810393333435
# -------- > epoch 29:  taux moyen validation = 0.9899000525474548
# -------- > epoch 30:  coût moyen entraînement = 0.0002997355768457055
# -------- > epoch 30:  taux moyen entraînement = 1.0
# -------- > epoch 30:  coût moyen validation = 0.043096818029880524
# -------- > epoch 30:  taux moyen validation = 0.9898000955581665

# %%
X = torch.randn(size=(1, 1, 28, 28), dtype=torch.float32)
for une_couche in modele:
    X = une_couche(X)
    print('Type de couche:',une_couche.__class__.__name__,'  Forme de sortie:',X.shape)
# Out:
# Type de couche: Conv2d   Forme de sortie: torch.Size([1, 6, 28, 28])
# Type de couche: Tanh   Forme de sortie: torch.Size([1, 6, 28, 28])
# Type de couche: AvgPool2d   Forme de sortie: torch.Size([1, 6, 14, 14])
# Type de couche: Conv2d   Forme de sortie: torch.Size([1, 16, 10, 10])
# Type de couche: Tanh   Forme de sortie: torch.Size([1, 16, 10, 10])
# Type de couche: AvgPool2d   Forme de sortie: torch.Size([1, 16, 5, 5])
# Type de couche: Flatten   Forme de sortie: torch.Size([1, 400])
# Type de couche: Linear   Forme de sortie: torch.Size([1, 120])
# Type de couche: Tanh   Forme de sortie: torch.Size([1, 120])
# Type de couche: Linear   Forme de sortie: torch.Size([1, 84])
# Type de couche: Tanh   Forme de sortie: torch.Size([1, 84])
# Type de couche: Linear   Forme de sortie: torch.Size([1, 10])

# %%
optimiseur = optim.SGD(modele.parameters(), lr=0.001)
entrainer(modele, dl_ent, dl_valid, optimiseur, nb_epochs=10)
# Out:
# -------- > epoch 1:  coût moyen entraînement = 0.03446153923869133
# -------- > epoch 1:  taux moyen entraînement = 0.9897797107696533
# -------- > epoch 1:  coût moyen validation = 0.047925323247909546
# -------- > epoch 1:  taux moyen validation = 0.9848001599311829
# -------- > epoch 2:  coût moyen entraînement = 0.032589782029390335
# -------- > epoch 2:  taux moyen entraînement = 0.9904400706291199
# -------- > epoch 2:  coût moyen validation = 0.046702370047569275
# -------- > epoch 2:  taux moyen validation = 0.9857003092765808
# -------- > epoch 3:  coût moyen entraînement = 0.03162141516804695
# -------- > epoch 3:  taux moyen entraînement = 0.9906794428825378
# -------- > epoch 3:  coût moyen validation = 0.04602151736617088
# -------- > epoch 3:  taux moyen validation = 0.985900342464447
# -------- > epoch 4:  coût moyen entraînement = 0.031067242845892906
# -------- > epoch 4:  taux moyen entraînement = 0.9907993078231812
# -------- > epoch 4:  coût moyen validation = 0.04559771716594696
# -------- > epoch 4:  taux moyen validation = 0.986000120639801
# -------- > epoch 5:  coût moyen entraînement = 0.030719542875885963
# -------- > epoch 5:  taux moyen entraînement = 0.9911195635795593
# -------- > epoch 5:  coût moyen validation = 0.045308489352464676
# -------- > epoch 5:  taux moyen validation = 0.9856002330780029
# -------- > epoch 6:  coût moyen entraînement = 0.03048531711101532
# -------- > epoch 6:  taux moyen entraînement = 0.9911195039749146
# -------- > epoch 6:  coût moyen validation = 0.045095715671777725
# -------- > epoch 6:  taux moyen validation = 0.9860002994537354
# -------- > epoch 7:  coût moyen entraînement = 0.030320992693305016
# -------- > epoch 7:  taux moyen entraînement = 0.9912799000740051
# -------- > epoch 7:  coût moyen validation = 0.04492877423763275
# -------- > epoch 7:  taux moyen validation = 0.9861002564430237
# -------- > epoch 8:  coût moyen entraînement = 0.03019868955016136
# -------- > epoch 8:  taux moyen entraînement = 0.9912192821502686
# -------- > epoch 8:  coût moyen validation = 0.04479596018791199
# -------- > epoch 8:  taux moyen validation = 0.9860002398490906
# -------- > epoch 9:  coût moyen entraînement = 0.030104702338576317
# -------- > epoch 9:  taux moyen entraînement = 0.9911995530128479
# -------- > epoch 9:  coût moyen validation = 0.04468608275055885
# -------- > epoch 9:  taux moyen validation = 0.9860002398490906
# -------- > epoch 10:  coût moyen entraînement = 0.03002971224486828
# -------- > epoch 10:  taux moyen entraînement = 0.9911995530128479
# -------- > epoch 10:  coût moyen validation = 0.04458840936422348
# -------- > epoch 10:  taux moyen validation = 0.9860002398490906
