# %%
# %matplotlib inline
# -*- coding: utf-8 -*-
"""
Exercice: FashionMNIST avec PyTorch
Exemple avec nn.Sequential et F.cross_entropy
Production de métriques avec graphes
Fonction entrainer
"""
import torch
torch.manual_seed(0) # Pour résultats reproductibles

# Fonction J d'entropie croisée
import torch.nn.functional as F
fonction_cout = F.cross_entropy

def taux_bonnes_predictions(lot_Y_predictions, lot_Y):
    predictions_categorie = torch.argmax(lot_Y_predictions, dim=1)
    return (predictions_categorie == lot_Y).float().mean()

from torch import nn
# Définition de l'architecture du RNA

class BlocResNetSimple(nn.Module):
    def __init__(self, nb_f):
        super().__init__()

        self.conv1 = nn.Conv2d(nb_f, nb_f, kernel_size=3, stride=1, padding=1, bias=False) 
        self.bn1 = nn.BatchNorm2d(nb_f)    
        self.relu = nn.ReLU(inplace=True)
        self.conv2 = nn.Conv2d(nb_f, nb_f, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(nb_f)    

    def forward(self, lot_X):
        lot_Y_predictions = self.conv1(lot_X)
        lot_Y_predictions = self.bn1(lot_Y_predictions)
        lot_Y_predictions = F.relu(lot_Y_predictions)
        lot_Y_predictions = self.conv2(lot_Y_predictions)
        lot_Y_predictions = self.bn2(lot_Y_predictions)
        lot_Y_predictions = lot_Y_predictions + lot_X
        lot_Y_predictions = F.relu(lot_Y_predictions)
        return lot_Y_predictions 

modele = nn.Sequential(
    nn.Conv2d(1,8,3,2,1),
    nn.BatchNorm2d(8),
    nn.ReLU(),
    BlocResNetSimple(8),
    nn.Conv2d(8,16,3,2,1),
    nn.BatchNorm2d(16),
    nn.ReLU(),    
    BlocResNetSimple(16),
    nn.Conv2d(16,32,3,2,1),
    nn.BatchNorm2d(32),
    nn.ReLU(),    
    BlocResNetSimple(32),
    nn.Conv2d(32,16,3,2,1),
    nn.BatchNorm2d(16),
    nn.ReLU(),
    nn.Conv2d(16,10,3,2,1),
    nn.BatchNorm2d(10),
    nn.ReLU(),
    nn.Flatten()
)
class LeNet(nn.Module):
    def __init__(self):
        super(LeNet, self).__init__()
        self.cnn_model = nn.Sequential(
            nn.Conv2d(1, 6, kernel_size = 5), #(N, 1, 28, 28) -> (N, 6, 24, 24)
            nn.Tanh(),
            nn.AvgPool2d(2, stride = 2), #(N, 6, 24, 24) -> (N, 6, 12, 12)
            
            nn.Conv2d(6, 16, kernel_size = 5), #(N, 6, 12, 12) -> (N, 6, 8, 8)
            nn.Tanh(),
            nn.AvgPool2d(2, stride = 2)) #(N, 6, 8, 8) -> (N, 16, 4, 4)
    
        self.fc_model = nn.Sequential(
            nn.Linear(256, 120), # (N, 256) -> (N, 120)
            nn.Tanh(),
            nn.Linear(120, 84), # (N, 120) -> (N, 84)
            nn.Tanh(),
            nn.Linear(84, 10))  # (N, 84)  -> (N, 10))
            
    def forward(self, x):
        #print(x.shape)
        x = self.cnn_model(x)
        #print(x.shape)
        #print(x)
        x = x.view(x.size(0), -1)
        #print(x.shape)
        x = self.fc_model(x)
        #print(x.shape)
        return x
    
modele = LeNet()

net = torch.nn.Sequential(
    nn.Conv2d(1, 6, kernel_size=5, padding=2), nn.Sigmoid(),
    nn.AvgPool2d(kernel_size=2, stride=2),
    nn.Conv2d(6, 16, kernel_size=5), nn.Sigmoid(),
    nn.AvgPool2d(kernel_size=2, stride=2),
    nn.Flatten(),
    nn.Linear(16 * 5 * 5, 120), nn.Sigmoid(),
    nn.Linear(120, 84), nn.Sigmoid(),
    nn.Linear(84, 10))








from torch import optim
optimiseur = optim.SGD(modele.parameters(), lr=0.01, momentum=0.9)

import torchvision
import torchvision.transforms as transforms

#Chargement des données
ds = torchvision.datasets.FashionMNIST(root = "./data", train = True, download = True, transform = transforms.ToTensor())
ds_ent, ds_valid = torch.utils.data.random_split(ds, [50000, 10000])
ds_test = torchvision.datasets.FashionMNIST(root = "./data", train = False, download = True, transform = transforms.ToTensor())

#Création du DataLoader avec le dataset
dl_ent = torch.utils.data.DataLoader(ds_ent, batch_size=100, shuffle = True)
dl_valid = torch.utils.data.DataLoader(ds_valid, batch_size=100)

def entrainer(modele, dl_ent, dl_valid, optimiseur, nb_epochs=10):

    # Listes pour les métriques par epoch
    liste_cout_moyen_ent = []
    liste_taux_moyen_ent = []
    liste_cout_moyen_valid = []
    liste_taux_moyen_valid = []
    
    # Boucle d'apprentissage
    for epoch in range(nb_epochs):
        cout_total_ent = 0 # pour cumuler les couts par mini-lot
        taux_bonnes_predictions_ent = 0 # pour cumuler les taux par mini-lot
        modele.train() # Pour certains types de couches (nn.BatchNorm2d, nn.Dropout, ...)
        
        # Boucle d'apprentissage par mini-lot pour une epoch
        for lot_X, lot_Y in dl_ent:
            optimiseur.zero_grad() # Remettre les dérivées à zéro
            lot_Y_predictions = modele(lot_X) # Appel de la méthode forward
            cout = fonction_cout(lot_Y_predictions, lot_Y)
            cout.backward() # Calcul des gradiants par rétropropagation
            with torch.no_grad():
                cout_total_ent +=cout
                taux_bonnes_predictions_ent += taux_bonnes_predictions(lot_Y_predictions, lot_Y)
            optimiseur.step() # Mise à jour des paramètres
        # Calculer les moyennes par mini-lot
        with torch.no_grad():
            cout_moyen_ent = cout_total_ent/len(dl_ent)
            taux_moyen_ent = taux_bonnes_predictions_ent/len(dl_ent)
       
        modele.eval() # Pour certains types de couches (nn.BatchNorm2d, nn.Dropout, ...)
        with torch.no_grad():
            cout_valid = sum(fonction_cout(modele(lot_valid_X), lot_valid_Y) for lot_valid_X, lot_valid_Y in dl_valid)
            taux_bons_valid = sum(taux_bonnes_predictions(modele(lot_valid_X), lot_valid_Y) for lot_valid_X, lot_valid_Y in dl_valid)
        cout_moyen_valid = cout_valid/len(dl_valid)
        taux_moyen_valid = taux_bons_valid/len(dl_valid)
        print(f'-------- > epoch {epoch+1}:  coût moyen entraînement = {cout_moyen_ent}')
        print(f'-------- > epoch {epoch+1}:  taux moyen entraînement = {taux_moyen_ent}')
        print(f'-------- > epoch {epoch+1}:  coût moyen validation = {cout_moyen_valid}')
        print(f'-------- > epoch {epoch+1}:  taux moyen validation = {taux_moyen_valid}')
    
        liste_cout_moyen_ent.append(cout_moyen_ent)
        liste_taux_moyen_ent.append(taux_moyen_ent)
        liste_cout_moyen_valid.append(cout_moyen_valid)
        liste_taux_moyen_valid.append(taux_moyen_valid)
    
    # Affichage du graphique d'évolution des métriques par epoch
    import numpy as np
    import matplotlib.pyplot as plt
    plt.plot(np.arange(0,nb_epochs),liste_cout_moyen_ent,label='Erreur entraînement')
    plt.plot(np.arange(0,nb_epochs),liste_cout_moyen_valid,label='Erreur validation')
    plt.title("Evolution du coût")
    plt.xlabel('epoch')
    plt.ylabel('moyenne par observation')
    plt.legend(loc='upper center')
    plt.show()
        
    plt.plot(np.arange(0,nb_epochs),liste_taux_moyen_ent,label='Taux bonnes réponses entraînement')
    plt.plot(np.arange(0,nb_epochs),liste_taux_moyen_valid,label='Taux bonnes réponses validation')
    plt.title("Evolution du taux")
    plt.xlabel('epoch')
    plt.ylabel('moyenne par observation')
    plt.legend(loc='lower center')
    plt.show()

entrainer(modele, dl_ent, dl_valid, optimiseur, nb_epochs=30)
# Out:
# -------- > epoch 1:  coût moyen entraînement = 1.0007028579711914
# -------- > epoch 1:  taux moyen entraînement = 0.6294198632240295
# -------- > epoch 1:  coût moyen validation = 0.6418712735176086
# -------- > epoch 1:  taux moyen validation = 0.744499921798706
# -------- > epoch 2:  coût moyen entraînement = 0.5677383542060852
# -------- > epoch 2:  taux moyen entraînement = 0.7830990552902222
# -------- > epoch 2:  coût moyen validation = 0.5334283113479614
# -------- > epoch 2:  taux moyen validation = 0.7995998859405518
# -------- > epoch 3:  coût moyen entraînement = 0.48412632942199707
# -------- > epoch 3:  taux moyen entraînement = 0.8221595287322998
# -------- > epoch 3:  coût moyen validation = 0.4741276502609253
# -------- > epoch 3:  taux moyen validation = 0.824199914932251
# -------- > epoch 4:  coût moyen entraînement = 0.43615850806236267
# -------- > epoch 4:  taux moyen entraînement = 0.8407997488975525
# -------- > epoch 4:  coût moyen validation = 0.42715710401535034
# -------- > epoch 4:  taux moyen validation = 0.8413001298904419
# -------- > epoch 5:  coût moyen entraînement = 0.4050375819206238
# -------- > epoch 5:  taux moyen entraînement = 0.852219820022583
# -------- > epoch 5:  coût moyen validation = 0.40248990058898926
# -------- > epoch 5:  taux moyen validation = 0.8516998291015625
# -------- > epoch 6:  coût moyen entraînement = 0.3815831243991852
# -------- > epoch 6:  taux moyen entraînement = 0.8609195351600647
# -------- > epoch 6:  coût moyen validation = 0.4095073640346527
# -------- > epoch 6:  taux moyen validation = 0.8482000231742859
# -------- > epoch 7:  coût moyen entraînement = 0.36454787850379944
# -------- > epoch 7:  taux moyen entraînement = 0.8678803443908691
# -------- > epoch 7:  coût moyen validation = 0.36380091309547424
# -------- > epoch 7:  taux moyen validation = 0.8647000193595886
# -------- > epoch 8:  coût moyen entraînement = 0.34987732768058777
# -------- > epoch 8:  taux moyen entraînement = 0.8728803396224976
# -------- > epoch 8:  coût moyen validation = 0.3754537105560303
# -------- > epoch 8:  taux moyen validation = 0.8579001426696777
# -------- > epoch 9:  coût moyen entraînement = 0.3382469713687897
# -------- > epoch 9:  taux moyen entraînement = 0.8759999871253967
# -------- > epoch 9:  coût moyen validation = 0.3577769100666046
# -------- > epoch 9:  taux moyen validation = 0.8683002591133118
# -------- > epoch 10:  coût moyen entraînement = 0.32746410369873047
# -------- > epoch 10:  taux moyen entraînement = 0.8796002268791199
# -------- > epoch 10:  coût moyen validation = 0.34265923500061035
# -------- > epoch 10:  taux moyen validation = 0.8742998242378235
# -------- > epoch 11:  coût moyen entraînement = 0.3184695541858673
# -------- > epoch 11:  taux moyen entraînement = 0.8818202018737793
# -------- > epoch 11:  coût moyen validation = 0.33266541361808777
# -------- > epoch 11:  taux moyen validation = 0.881399929523468
# -------- > epoch 12:  coût moyen entraînement = 0.3088645339012146
# -------- > epoch 12:  taux moyen entraînement = 0.8873409628868103
# -------- > epoch 12:  coût moyen validation = 0.33524981141090393
# -------- > epoch 12:  taux moyen validation = 0.8735001087188721
# -------- > epoch 13:  coût moyen entraînement = 0.30200421810150146
# -------- > epoch 13:  taux moyen entraînement = 0.8886603116989136
# -------- > epoch 13:  coût moyen validation = 0.32557761669158936
# -------- > epoch 13:  taux moyen validation = 0.8773002624511719
# -------- > epoch 14:  coût moyen entraînement = 0.2941114008426666
# -------- > epoch 14:  taux moyen entraînement = 0.8910006284713745
# -------- > epoch 14:  coût moyen validation = 0.3194144666194916
# -------- > epoch 14:  taux moyen validation = 0.8806999921798706
# -------- > epoch 15:  coût moyen entraînement = 0.28899815678596497
# -------- > epoch 15:  taux moyen entraînement = 0.8934006690979004
# -------- > epoch 15:  coût moyen validation = 0.30965471267700195
# -------- > epoch 15:  taux moyen validation = 0.883400022983551
# -------- > epoch 16:  coût moyen entraînement = 0.2827504277229309
# -------- > epoch 16:  taux moyen entraînement = 0.8961209654808044
# -------- > epoch 16:  coût moyen validation = 0.3315141797065735
# -------- > epoch 16:  taux moyen validation = 0.8766999244689941
# -------- > epoch 17:  coût moyen entraînement = 0.2769545316696167
# -------- > epoch 17:  taux moyen entraînement = 0.8978206515312195
# -------- > epoch 17:  coût moyen validation = 0.31614989042282104
# -------- > epoch 17:  taux moyen validation = 0.8823999166488647
# -------- > epoch 18:  coût moyen entraînement = 0.26984983682632446
# -------- > epoch 18:  taux moyen entraînement = 0.8996003270149231
# -------- > epoch 18:  coût moyen validation = 0.29889586567878723
# -------- > epoch 18:  taux moyen validation = 0.8882002234458923
# -------- > epoch 19:  coût moyen entraînement = 0.26421529054641724
# -------- > epoch 19:  taux moyen entraînement = 0.9025405049324036
# -------- > epoch 19:  coût moyen validation = 0.3220369219779968
# -------- > epoch 19:  taux moyen validation = 0.8822999596595764
# -------- > epoch 20:  coût moyen entraînement = 0.25903385877609253
# -------- > epoch 20:  taux moyen entraînement = 0.9046809673309326
# -------- > epoch 20:  coût moyen validation = 0.31634798645973206
# -------- > epoch 20:  taux moyen validation = 0.8815999627113342
# -------- > epoch 21:  coût moyen entraînement = 0.2538047730922699
# -------- > epoch 21:  taux moyen entraînement = 0.905200719833374
# -------- > epoch 21:  coût moyen validation = 0.28712227940559387
# -------- > epoch 21:  taux moyen validation = 0.8920000195503235
# -------- > epoch 22:  coût moyen entraînement = 0.2511802315711975
# -------- > epoch 22:  taux moyen entraînement = 0.907360851764679
# -------- > epoch 22:  coût moyen validation = 0.2985056936740875
# -------- > epoch 22:  taux moyen validation = 0.8899999856948853
# -------- > epoch 23:  coût moyen entraînement = 0.24743692576885223
# -------- > epoch 23:  taux moyen entraînement = 0.9076412320137024
# -------- > epoch 23:  coût moyen validation = 0.28958314657211304
# -------- > epoch 23:  taux moyen validation = 0.8922999501228333
# -------- > epoch 24:  coût moyen entraînement = 0.24421599507331848
# -------- > epoch 24:  taux moyen entraînement = 0.909220814704895
# -------- > epoch 24:  coût moyen validation = 0.28470832109451294
# -------- > epoch 24:  taux moyen validation = 0.8930002450942993
# -------- > epoch 25:  coût moyen entraînement = 0.23684610426425934
# -------- > epoch 25:  taux moyen entraînement = 0.9123208522796631
# -------- > epoch 25:  coût moyen validation = 0.2794881761074066
# -------- > epoch 25:  taux moyen validation = 0.8964999914169312
# -------- > epoch 26:  coût moyen entraînement = 0.2331915944814682
# -------- > epoch 26:  taux moyen entraînement = 0.9151009321212769
# -------- > epoch 26:  coût moyen validation = 0.31575772166252136
# -------- > epoch 26:  taux moyen validation = 0.8869999051094055
# -------- > epoch 27:  coût moyen entraînement = 0.2300553172826767
# -------- > epoch 27:  taux moyen entraînement = 0.9153811931610107
# -------- > epoch 27:  coût moyen validation = 0.29374000430107117
# -------- > epoch 27:  taux moyen validation = 0.8926999568939209
# -------- > epoch 28:  coût moyen entraînement = 0.227657750248909
# -------- > epoch 28:  taux moyen entraînement = 0.9168010354042053
# -------- > epoch 28:  coût moyen validation = 0.29526934027671814
# -------- > epoch 28:  taux moyen validation = 0.8896002173423767
# -------- > epoch 29:  coût moyen entraînement = 0.22154930233955383
# -------- > epoch 29:  taux moyen entraînement = 0.9183411598205566
# -------- > epoch 29:  coût moyen validation = 0.29765069484710693
# -------- > epoch 29:  taux moyen validation = 0.8908001780509949
# -------- > epoch 30:  coût moyen entraînement = 0.21992920339107513
# -------- > epoch 30:  taux moyen entraînement = 0.9178804159164429
# -------- > epoch 30:  coût moyen validation = 0.29890555143356323
# -------- > epoch 30:  taux moyen validation = 0.8894999027252197
