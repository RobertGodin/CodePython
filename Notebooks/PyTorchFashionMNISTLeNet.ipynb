# %%
# %matplotlib inline
# -*- coding: utf-8 -*-
"""
Exemple FashionMNIST avec réseau LeNet (LeCun et al.)
"""
import torch
torch.manual_seed(0) # Pour résultats reproductibles

# Fonction J d'entropie croisée
import torch.nn.functional as F
fonction_cout = F.cross_entropy

def taux_bonnes_predictions(lot_Y_predictions, lot_Y):
    predictions_categorie = torch.argmax(lot_Y_predictions, dim=1)
    return (predictions_categorie == lot_Y).float().mean()

from torch import nn
# Définition de l'architecture du RNA

modele = torch.nn.Sequential(
    nn.Conv2d(1, 6, kernel_size=5, padding=2), nn.Sigmoid(), #(N, 1, 28, 28) -> (N, 6, 28, 28)
    nn.AvgPool2d(kernel_size=2, stride=2), #(N, 6, 28, 28) -> (N, 6, 14, 14)
    nn.Conv2d(6, 16, kernel_size=5), nn.Sigmoid(), #(N, 6, 14, 14) -> (N, 16, 10, 10)
    nn.AvgPool2d(kernel_size=2, stride=2), #(N, 16, 10, 10) -> (N, 16, 5, 5)
    nn.Flatten(), #(N, 16, 5, 5) -> (N, 400)
    nn.Linear(16 * 5 * 5, 120), nn.Sigmoid(), #(N, 400) -> (N, 120)
    nn.Linear(120, 84), nn.Sigmoid(), #(N, 120) -> (N, 84)
    nn.Linear(84, 10)) #(N, 84) -> (N, 10)

from torch import optim
optimiseur = optim.SGD(modele.parameters(), lr=0.5)

import torchvision
import torchvision.transforms as transforms

#Chargement des données
ds = torchvision.datasets.FashionMNIST(root = "./data", train = True, download = True, transform = transforms.ToTensor())
ds_ent, ds_valid = torch.utils.data.random_split(ds, [50000, 10000])
ds_test = torchvision.datasets.FashionMNIST(root = "./data", train = False, download = True, transform = transforms.ToTensor())

#Création du DataLoader avec le dataset
dl_ent = torch.utils.data.DataLoader(ds_ent, batch_size=100, shuffle = True)
dl_valid = torch.utils.data.DataLoader(ds_valid, batch_size=100)

def entrainer(modele, dl_ent, dl_valid, optimiseur, nb_epochs=10):

    # Listes pour les métriques par epoch
    liste_cout_moyen_ent = []
    liste_taux_moyen_ent = []
    liste_cout_moyen_valid = []
    liste_taux_moyen_valid = []
    
    # Boucle d'apprentissage
    for epoch in range(nb_epochs):
        cout_total_ent = 0 # pour cumuler les couts par mini-lot
        taux_bonnes_predictions_ent = 0 # pour cumuler les taux par mini-lot
        modele.train() # Pour certains types de couches (nn.BatchNorm2d, nn.Dropout, ...)
        
        # Boucle d'apprentissage par mini-lot pour une epoch
        for lot_X, lot_Y in dl_ent:
            optimiseur.zero_grad() # Remettre les dérivées à zéro
            lot_Y_predictions = modele(lot_X) # Appel de la méthode forward
            cout = fonction_cout(lot_Y_predictions, lot_Y)
            cout.backward() # Calcul des gradiants par rétropropagation
            with torch.no_grad():
                cout_total_ent +=cout
                taux_bonnes_predictions_ent += taux_bonnes_predictions(lot_Y_predictions, lot_Y)
            optimiseur.step() # Mise à jour des paramètres
        # Calculer les moyennes par mini-lot
        with torch.no_grad():
            cout_moyen_ent = cout_total_ent/len(dl_ent)
            taux_moyen_ent = taux_bonnes_predictions_ent/len(dl_ent)
       
        modele.eval() # Pour certains types de couches (nn.BatchNorm2d, nn.Dropout, ...)
        with torch.no_grad():
            cout_valid = sum(fonction_cout(modele(lot_valid_X), lot_valid_Y) for lot_valid_X, lot_valid_Y in dl_valid)
            taux_bons_valid = sum(taux_bonnes_predictions(modele(lot_valid_X), lot_valid_Y) for lot_valid_X, lot_valid_Y in dl_valid)
        cout_moyen_valid = cout_valid/len(dl_valid)
        taux_moyen_valid = taux_bons_valid/len(dl_valid)
        print(f'-------- > epoch {epoch+1}:  coût moyen entraînement = {cout_moyen_ent}')
        print(f'-------- > epoch {epoch+1}:  taux moyen entraînement = {taux_moyen_ent}')
        print(f'-------- > epoch {epoch+1}:  coût moyen validation = {cout_moyen_valid}')
        print(f'-------- > epoch {epoch+1}:  taux moyen validation = {taux_moyen_valid}')
    
        liste_cout_moyen_ent.append(cout_moyen_ent)
        liste_taux_moyen_ent.append(taux_moyen_ent)
        liste_cout_moyen_valid.append(cout_moyen_valid)
        liste_taux_moyen_valid.append(taux_moyen_valid)
    
    # Affichage du graphique d'évolution des métriques par epoch
    import numpy as np
    import matplotlib.pyplot as plt
    plt.plot(np.arange(0,nb_epochs),liste_cout_moyen_ent,label='Erreur entraînement')
    plt.plot(np.arange(0,nb_epochs),liste_cout_moyen_valid,label='Erreur validation')
    plt.title("Evolution du coût")
    plt.xlabel('epoch')
    plt.ylabel('moyenne par observation')
    plt.legend(loc='upper center')
    plt.show()
        
    plt.plot(np.arange(0,nb_epochs),liste_taux_moyen_ent,label='Taux bonnes réponses entraînement')
    plt.plot(np.arange(0,nb_epochs),liste_taux_moyen_valid,label='Taux bonnes réponses validation')
    plt.title("Evolution du taux")
    plt.xlabel('epoch')
    plt.ylabel('moyenne par observation')
    plt.legend(loc='lower center')
    plt.show()

entrainer(modele, dl_ent, dl_valid, optimiseur, nb_epochs=50)
# Out:
# -------- > epoch 1:  coût moyen entraînement = 2.314098834991455
# -------- > epoch 1:  taux moyen entraînement = 0.10136005282402039
# -------- > epoch 1:  coût moyen validation = 2.3048486709594727
# -------- > epoch 1:  taux moyen validation = 0.10300002247095108
# -------- > epoch 2:  coût moyen entraînement = 2.305255174636841
# -------- > epoch 2:  taux moyen entraînement = 0.09838005155324936
# -------- > epoch 2:  coût moyen validation = 2.3056650161743164
# -------- > epoch 2:  taux moyen validation = 0.09839998185634613
# -------- > epoch 3:  coût moyen entraînement = 2.304183006286621
# -------- > epoch 3:  taux moyen entraînement = 0.09982005506753922
# -------- > epoch 3:  coût moyen validation = 2.3034470081329346
# -------- > epoch 3:  taux moyen validation = 0.10419999808073044
# -------- > epoch 4:  coût moyen entraînement = 2.3037972450256348
# -------- > epoch 4:  taux moyen entraînement = 0.10168007016181946
# -------- > epoch 4:  coût moyen validation = 2.304100513458252
# -------- > epoch 4:  taux moyen validation = 0.09839998185634613
# -------- > epoch 5:  coût moyen entraînement = 2.30387282371521
# -------- > epoch 5:  taux moyen entraînement = 0.09952004998922348
# -------- > epoch 5:  coût moyen validation = 2.302279233932495
# -------- > epoch 5:  taux moyen validation = 0.09960000962018967
# -------- > epoch 6:  coût moyen entraînement = 2.3024065494537354
# -------- > epoch 6:  taux moyen entraînement = 0.10352004319429398
# -------- > epoch 6:  coût moyen validation = 2.300558090209961
# -------- > epoch 6:  taux moyen validation = 0.09839998185634613
# -------- > epoch 7:  coût moyen entraînement = 2.045058488845825
# -------- > epoch 7:  taux moyen entraînement = 0.2152198851108551
# -------- > epoch 7:  coût moyen validation = 1.3970907926559448
# -------- > epoch 7:  taux moyen validation = 0.43019992113113403
# -------- > epoch 8:  coût moyen entraînement = 1.1250660419464111
# -------- > epoch 8:  taux moyen entraînement = 0.54006028175354
# -------- > epoch 8:  coût moyen validation = 0.9802407026290894
# -------- > epoch 8:  taux moyen validation = 0.6321998834609985
# -------- > epoch 9:  coût moyen entraînement = 0.870387077331543
# -------- > epoch 9:  taux moyen entraînement = 0.660140335559845
# -------- > epoch 9:  coût moyen validation = 0.8091842532157898
# -------- > epoch 9:  taux moyen validation = 0.6908999085426331
# -------- > epoch 10:  coût moyen entraînement = 0.7546364665031433
# -------- > epoch 10:  taux moyen entraînement = 0.7082197666168213
# -------- > epoch 10:  coût moyen validation = 0.7107300758361816
# -------- > epoch 10:  taux moyen validation = 0.722300112247467
# -------- > epoch 11:  coût moyen entraînement = 0.6578516364097595
# -------- > epoch 11:  taux moyen entraînement = 0.7436000108718872
# -------- > epoch 11:  coût moyen validation = 0.662116527557373
# -------- > epoch 11:  taux moyen validation = 0.7387999892234802
# -------- > epoch 12:  coût moyen entraînement = 0.6047276854515076
# -------- > epoch 12:  taux moyen entraînement = 0.7636998891830444
# -------- > epoch 12:  coût moyen validation = 0.5787004232406616
# -------- > epoch 12:  taux moyen validation = 0.7793999314308167
# -------- > epoch 13:  coût moyen entraînement = 0.5666885375976562
# -------- > epoch 13:  taux moyen entraînement = 0.778599739074707
# -------- > epoch 13:  coût moyen validation = 0.531790554523468
# -------- > epoch 13:  taux moyen validation = 0.8050998449325562
# -------- > epoch 14:  coût moyen entraînement = 0.5312348008155823
# -------- > epoch 14:  taux moyen entraînement = 0.7951791286468506
# -------- > epoch 14:  coût moyen validation = 0.5362337827682495
# -------- > epoch 14:  taux moyen validation = 0.7994000315666199
# -------- > epoch 15:  coût moyen entraînement = 0.5017836689949036
# -------- > epoch 15:  taux moyen entraînement = 0.8090195655822754
# -------- > epoch 15:  coût moyen validation = 0.48249998688697815
# -------- > epoch 15:  taux moyen validation = 0.8244999647140503
# -------- > epoch 16:  coût moyen entraînement = 0.4763009250164032
# -------- > epoch 16:  taux moyen entraînement = 0.8202994465827942
# -------- > epoch 16:  coût moyen validation = 0.46039292216300964
# -------- > epoch 16:  taux moyen validation = 0.8325002193450928
# -------- > epoch 17:  coût moyen entraînement = 0.4559127688407898
# -------- > epoch 17:  taux moyen entraînement = 0.8285190463066101
# -------- > epoch 17:  coût moyen validation = 0.4962177574634552
# -------- > epoch 17:  taux moyen validation = 0.8142997622489929
# -------- > epoch 18:  coût moyen entraînement = 0.43768784403800964
# -------- > epoch 18:  taux moyen entraînement = 0.8373396992683411
# -------- > epoch 18:  coût moyen validation = 0.4162640869617462
# -------- > epoch 18:  taux moyen validation = 0.847899854183197
# -------- > epoch 19:  coût moyen entraînement = 0.42260250449180603
# -------- > epoch 19:  taux moyen entraînement = 0.8414795994758606
# -------- > epoch 19:  coût moyen validation = 0.4217064678668976
# -------- > epoch 19:  taux moyen validation = 0.8481999039649963
# -------- > epoch 20:  coût moyen entraînement = 0.4129513204097748
# -------- > epoch 20:  taux moyen entraînement = 0.8465797901153564
# -------- > epoch 20:  coût moyen validation = 0.39303433895111084
# -------- > epoch 20:  taux moyen validation = 0.8565999865531921
# -------- > epoch 21:  coût moyen entraînement = 0.4000755548477173
# -------- > epoch 21:  taux moyen entraînement = 0.8512389659881592
# -------- > epoch 21:  coût moyen validation = 0.431303471326828
# -------- > epoch 21:  taux moyen validation = 0.8374999761581421
# -------- > epoch 22:  coût moyen entraînement = 0.39235183596611023
# -------- > epoch 22:  taux moyen entraînement = 0.8535397052764893
# -------- > epoch 22:  coût moyen validation = 0.3965410590171814
# -------- > epoch 22:  taux moyen validation = 0.8533000349998474
# -------- > epoch 23:  coût moyen entraînement = 0.3828076124191284
# -------- > epoch 23:  taux moyen entraînement = 0.8587595820426941
# -------- > epoch 23:  coût moyen validation = 0.3690339922904968
# -------- > epoch 23:  taux moyen validation = 0.8630001544952393
# -------- > epoch 24:  coût moyen entraînement = 0.3725726008415222
# -------- > epoch 24:  taux moyen entraînement = 0.8626195788383484
# -------- > epoch 24:  coût moyen validation = 0.3796325922012329
# -------- > epoch 24:  taux moyen validation = 0.859299898147583
# -------- > epoch 25:  coût moyen entraînement = 0.3649059236049652
# -------- > epoch 25:  taux moyen entraînement = 0.8645200729370117
# -------- > epoch 25:  coût moyen validation = 0.36619773507118225
# -------- > epoch 25:  taux moyen validation = 0.8643001317977905
# -------- > epoch 26:  coût moyen entraînement = 0.35987165570259094
# -------- > epoch 26:  taux moyen entraînement = 0.8665996789932251
# -------- > epoch 26:  coût moyen validation = 0.3738562762737274
# -------- > epoch 26:  taux moyen validation = 0.8659000992774963
# -------- > epoch 27:  coût moyen entraînement = 0.3529316484928131
# -------- > epoch 27:  taux moyen entraînement = 0.869139552116394
# -------- > epoch 27:  coût moyen validation = 0.3583879768848419
# -------- > epoch 27:  taux moyen validation = 0.8696998357772827
# -------- > epoch 28:  coût moyen entraînement = 0.34700512886047363
# -------- > epoch 28:  taux moyen entraînement = 0.8713399171829224
# -------- > epoch 28:  coût moyen validation = 0.36017733812332153
# -------- > epoch 28:  taux moyen validation = 0.8688000440597534
# -------- > epoch 29:  coût moyen entraînement = 0.34179913997650146
# -------- > epoch 29:  taux moyen entraînement = 0.8726401329040527
# -------- > epoch 29:  coût moyen validation = 0.4364938735961914
# -------- > epoch 29:  taux moyen validation = 0.835599958896637
# -------- > epoch 30:  coût moyen entraînement = 0.33533960580825806
# -------- > epoch 30:  taux moyen entraînement = 0.8753799200057983
# -------- > epoch 30:  coût moyen validation = 0.35203033685684204
# -------- > epoch 30:  taux moyen validation = 0.8690998554229736
# -------- > epoch 31:  coût moyen entraînement = 0.33145982027053833
# -------- > epoch 31:  taux moyen entraînement = 0.8757002353668213
# -------- > epoch 31:  coût moyen validation = 0.3501438498497009
# -------- > epoch 31:  taux moyen validation = 0.8721001148223877
# -------- > epoch 32:  coût moyen entraînement = 0.32757872343063354
# -------- > epoch 32:  taux moyen entraînement = 0.8767601847648621
# -------- > epoch 32:  coût moyen validation = 0.3602823317050934
# -------- > epoch 32:  taux moyen validation = 0.8669998049736023
# -------- > epoch 33:  coût moyen entraînement = 0.32396575808525085
# -------- > epoch 33:  taux moyen entraînement = 0.8785193562507629
# -------- > epoch 33:  coût moyen validation = 0.3396546542644501
# -------- > epoch 33:  taux moyen validation = 0.8709999322891235
# -------- > epoch 34:  coût moyen entraînement = 0.31742504239082336
# -------- > epoch 34:  taux moyen entraînement = 0.8809002041816711
# -------- > epoch 34:  coût moyen validation = 0.32049188017845154
# -------- > epoch 34:  taux moyen validation = 0.8829001784324646
# -------- > epoch 35:  coût moyen entraînement = 0.31410419940948486
# -------- > epoch 35:  taux moyen entraînement = 0.8823207020759583
# -------- > epoch 35:  coût moyen validation = 0.3308302164077759
# -------- > epoch 35:  taux moyen validation = 0.8759000897407532
# -------- > epoch 36:  coût moyen entraînement = 0.31174591183662415
# -------- > epoch 36:  taux moyen entraînement = 0.8835002183914185
# -------- > epoch 36:  coût moyen validation = 0.3154498040676117
# -------- > epoch 36:  taux moyen validation = 0.882800281047821
# -------- > epoch 37:  coût moyen entraînement = 0.30742499232292175
# -------- > epoch 37:  taux moyen entraînement = 0.8853604793548584
# -------- > epoch 37:  coût moyen validation = 0.3304150402545929
# -------- > epoch 37:  taux moyen validation = 0.8804000616073608
# -------- > epoch 38:  coût moyen entraînement = 0.3039897084236145
# -------- > epoch 38:  taux moyen entraînement = 0.8849805593490601
# -------- > epoch 38:  coût moyen validation = 0.30457213521003723
# -------- > epoch 38:  taux moyen validation = 0.8885002136230469
# -------- > epoch 39:  coût moyen entraînement = 0.2995140850543976
# -------- > epoch 39:  taux moyen entraînement = 0.8883405327796936
# -------- > epoch 39:  coût moyen validation = 0.3055681884288788
# -------- > epoch 39:  taux moyen validation = 0.887900173664093
# -------- > epoch 40:  coût moyen entraînement = 0.29676803946495056
# -------- > epoch 40:  taux moyen entraînement = 0.8888006806373596
# -------- > epoch 40:  coût moyen validation = 0.32205939292907715
# -------- > epoch 40:  taux moyen validation = 0.8834999203681946
# -------- > epoch 41:  coût moyen entraînement = 0.295309454202652
# -------- > epoch 41:  taux moyen entraînement = 0.8883609771728516
# -------- > epoch 41:  coût moyen validation = 0.3125968277454376
# -------- > epoch 41:  taux moyen validation = 0.8855999708175659
# -------- > epoch 42:  coût moyen entraînement = 0.29097267985343933
# -------- > epoch 42:  taux moyen entraînement = 0.8908807039260864
# -------- > epoch 42:  coût moyen validation = 0.30406785011291504
# -------- > epoch 42:  taux moyen validation = 0.8892998695373535
# -------- > epoch 43:  coût moyen entraînement = 0.2883687913417816
# -------- > epoch 43:  taux moyen entraînement = 0.8927004337310791
# -------- > epoch 43:  coût moyen validation = 0.3017868399620056
# -------- > epoch 43:  taux moyen validation = 0.892799973487854
# -------- > epoch 44:  coût moyen entraînement = 0.28456544876098633
# -------- > epoch 44:  taux moyen entraînement = 0.8932802081108093
# -------- > epoch 44:  coût moyen validation = 0.3122791349887848
# -------- > epoch 44:  taux moyen validation = 0.8864004611968994
# -------- > epoch 45:  coût moyen entraînement = 0.2843186557292938
# -------- > epoch 45:  taux moyen entraînement = 0.8943206667900085
# -------- > epoch 45:  coût moyen validation = 0.3149719536304474
# -------- > epoch 45:  taux moyen validation = 0.8842002153396606
# -------- > epoch 46:  coût moyen entraînement = 0.2810254693031311
# -------- > epoch 46:  taux moyen entraînement = 0.8935003876686096
# -------- > epoch 46:  coût moyen validation = 0.2954026758670807
# -------- > epoch 46:  taux moyen validation = 0.8931002616882324
# -------- > epoch 47:  coût moyen entraînement = 0.2786039113998413
# -------- > epoch 47:  taux moyen entraînement = 0.8952000737190247
# -------- > epoch 47:  coût moyen validation = 0.29231885075569153
# -------- > epoch 47:  taux moyen validation = 0.8918001055717468
# -------- > epoch 48:  coût moyen entraînement = 0.27536919713020325
# -------- > epoch 48:  taux moyen entraînement = 0.896120548248291
# -------- > epoch 48:  coût moyen validation = 0.29805460572242737
# -------- > epoch 48:  taux moyen validation = 0.8916001319885254
# -------- > epoch 49:  coût moyen entraînement = 0.27413782477378845
# -------- > epoch 49:  taux moyen entraînement = 0.8967811465263367
# -------- > epoch 49:  coût moyen validation = 0.315438449382782
# -------- > epoch 49:  taux moyen validation = 0.8871002197265625
# -------- > epoch 50:  coût moyen entraînement = 0.2696729898452759
# -------- > epoch 50:  taux moyen entraînement = 0.8984604477882385
# -------- > epoch 50:  coût moyen validation = 0.3139703869819641
# -------- > epoch 50:  taux moyen validation = 0.8817999362945557

# %%
X = torch.randn(size=(1, 1, 28, 28), dtype=torch.float32)
for une_couche in modele:
    X = une_couche(X)
    print('Type de couche:',une_couche.__class__.__name__,'  Forme de sortie:',X.shape)
# Out:
# Type de couche: Conv2d   Forme de sortie: torch.Size([1, 6, 28, 28])
# Type de couche: Sigmoid   Forme de sortie: torch.Size([1, 6, 28, 28])
# Type de couche: AvgPool2d   Forme de sortie: torch.Size([1, 6, 14, 14])
# Type de couche: Conv2d   Forme de sortie: torch.Size([1, 16, 10, 10])
# Type de couche: Sigmoid   Forme de sortie: torch.Size([1, 16, 10, 10])
# Type de couche: AvgPool2d   Forme de sortie: torch.Size([1, 16, 5, 5])
# Type de couche: Flatten   Forme de sortie: torch.Size([1, 400])
# Type de couche: Linear   Forme de sortie: torch.Size([1, 120])
# Type de couche: Sigmoid   Forme de sortie: torch.Size([1, 120])
# Type de couche: Linear   Forme de sortie: torch.Size([1, 84])
# Type de couche: Sigmoid   Forme de sortie: torch.Size([1, 84])
# Type de couche: Linear   Forme de sortie: torch.Size([1, 10])

# %%
optimiseur = optim.SGD(modele.parameters(), lr=0.001)
entrainer(modele, dl_ent, dl_valid, optimiseur, nb_epochs=10)
# Out:
# -------- > epoch 1:  coût moyen entraînement = 0.03446153923869133
# -------- > epoch 1:  taux moyen entraînement = 0.9897797107696533
# -------- > epoch 1:  coût moyen validation = 0.047925323247909546
# -------- > epoch 1:  taux moyen validation = 0.9848001599311829
# -------- > epoch 2:  coût moyen entraînement = 0.032589782029390335
# -------- > epoch 2:  taux moyen entraînement = 0.9904400706291199
# -------- > epoch 2:  coût moyen validation = 0.046702370047569275
# -------- > epoch 2:  taux moyen validation = 0.9857003092765808
# -------- > epoch 3:  coût moyen entraînement = 0.03162141516804695
# -------- > epoch 3:  taux moyen entraînement = 0.9906794428825378
# -------- > epoch 3:  coût moyen validation = 0.04602151736617088
# -------- > epoch 3:  taux moyen validation = 0.985900342464447
# -------- > epoch 4:  coût moyen entraînement = 0.031067242845892906
# -------- > epoch 4:  taux moyen entraînement = 0.9907993078231812
# -------- > epoch 4:  coût moyen validation = 0.04559771716594696
# -------- > epoch 4:  taux moyen validation = 0.986000120639801
# -------- > epoch 5:  coût moyen entraînement = 0.030719542875885963
# -------- > epoch 5:  taux moyen entraînement = 0.9911195635795593
# -------- > epoch 5:  coût moyen validation = 0.045308489352464676
# -------- > epoch 5:  taux moyen validation = 0.9856002330780029
# -------- > epoch 6:  coût moyen entraînement = 0.03048531711101532
# -------- > epoch 6:  taux moyen entraînement = 0.9911195039749146
# -------- > epoch 6:  coût moyen validation = 0.045095715671777725
# -------- > epoch 6:  taux moyen validation = 0.9860002994537354
# -------- > epoch 7:  coût moyen entraînement = 0.030320992693305016
# -------- > epoch 7:  taux moyen entraînement = 0.9912799000740051
# -------- > epoch 7:  coût moyen validation = 0.04492877423763275
# -------- > epoch 7:  taux moyen validation = 0.9861002564430237
# -------- > epoch 8:  coût moyen entraînement = 0.03019868955016136
# -------- > epoch 8:  taux moyen entraînement = 0.9912192821502686
# -------- > epoch 8:  coût moyen validation = 0.04479596018791199
# -------- > epoch 8:  taux moyen validation = 0.9860002398490906
# -------- > epoch 9:  coût moyen entraînement = 0.030104702338576317
# -------- > epoch 9:  taux moyen entraînement = 0.9911995530128479
# -------- > epoch 9:  coût moyen validation = 0.04468608275055885
# -------- > epoch 9:  taux moyen validation = 0.9860002398490906
# -------- > epoch 10:  coût moyen entraînement = 0.03002971224486828
# -------- > epoch 10:  taux moyen entraînement = 0.9911995530128479
# -------- > epoch 10:  coût moyen validation = 0.04458840936422348
# -------- > epoch 10:  taux moyen validation = 0.9860002398490906
