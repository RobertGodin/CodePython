# %%
# %matplotlib inline
# -*- coding: utf-8 -*-
"""
Exemple simple de MNIST avec PyTorch
Exemple avec nn.Conv2d et F.cross_entropy
Production de métriques avec graphes
Fonction entrainer
"""
import torch
torch.manual_seed(0) # Pour résultats reproductibles

# Fonction J d'entropie croisée
import torch.nn.functional as F
fonction_cout = F.cross_entropy

def taux_bonnes_predictions(lot_Y_predictions, lot_Y):
    predictions_categorie = torch.argmax(lot_Y_predictions, dim=1)
    return (predictions_categorie == lot_Y).float().mean()

from torch import nn
# Définition de l'architecture du RNA

modele = nn.Sequential(
    nn.Conv2d(1,32,3),
    nn.ReLU(),
    nn.Conv2d(32,16,3),
    nn.ReLU(),
    nn.Flatten(),
    nn.Linear(24*24*16, 10)
)
    
from torch import optim
optimiseur = optim.SGD(modele.parameters(), lr=0.01)

# Chargement des données de MNIST
import pickle, gzip
fichier_donnees = gzip.open(r"mnist.pkl.gz", 'rb')
((donnees_ent_X, donnees_ent_Y),(donnees_valid_X, donnees_valid_Y),(donnees_test_X,donnees_test_Y)) = pickle.load(fichier_donnees, encoding="latin-1")
fichier_donnees.close()

# Conversion des données en type toch.Tensor
import torch
donnees_ent_X,donnees_ent_Y,donnees_valid_X,donnees_valid_Y,donnees_test_X,donnees_test_Y  = map(torch.tensor,
    (donnees_ent_X.reshape((-1,1,28,28)),donnees_ent_Y,donnees_valid_X.reshape((-1,1,28,28)),donnees_valid_Y,donnees_test_X.reshape((-1,1,28,28)),donnees_test_Y))

# Création des objets DataLoader pour itérer par lot
from torch.utils.data import TensorDataset
from torch.utils.data import DataLoader
ds_ent = TensorDataset(donnees_ent_X, donnees_ent_Y)
dl_ent = DataLoader(ds_ent, batch_size=100, shuffle=True)
ds_valid = TensorDataset(donnees_valid_X,donnees_valid_Y)
dl_valid = DataLoader(ds_valid, batch_size=100)

def entrainer(modele, dl_ent, dl_valid, optimiseur, nb_epochs=10):

    # Listes pour les métriques par epoch
    liste_cout_moyen_ent = []
    liste_taux_moyen_ent = []
    liste_cout_moyen_valid = []
    liste_taux_moyen_valid = []
    
    # Boucle d'apprentissage
    for epoch in range(nb_epochs):
        cout_total_ent = 0 # pour cumuler les couts par mini-lot
        taux_bonnes_predictions_ent = 0 # pour cumuler les taux par mini-lot
        modele.train() # Pour certains types de couches (nn.BatchNorm2d, nn.Dropout, ...)
        
        # Boucle d'apprentissage par mini-lot pour une epoch
        for lot_X, lot_Y in dl_ent:
            optimiseur.zero_grad() # Remettre les dérivées à zéro
            lot_Y_predictions = modele(lot_X) # Appel de la méthode forward
            cout = fonction_cout(lot_Y_predictions, lot_Y)
            cout.backward() # Calcul des gradiants par rétropropagation
            with torch.no_grad():
                cout_total_ent +=cout
                taux_bonnes_predictions_ent += taux_bonnes_predictions(lot_Y_predictions, lot_Y)
            optimiseur.step() # Mise à jour des paramètres
        # Calculer les moyennes par mini-lot
        with torch.no_grad():
            cout_moyen_ent = cout_total_ent/len(dl_ent)
            taux_moyen_ent = taux_bonnes_predictions_ent/len(dl_ent)
       
        modele.eval() # Pour certains types de couches (nn.BatchNorm2d, nn.Dropout, ...)
        with torch.no_grad():
            cout_valid = sum(fonction_cout(modele(lot_valid_X), lot_valid_Y) for lot_valid_X, lot_valid_Y in dl_valid)
            taux_bons_valid = sum(taux_bonnes_predictions(modele(lot_valid_X), lot_valid_Y) for lot_valid_X, lot_valid_Y in dl_valid)
        cout_moyen_valid = cout_valid/len(dl_valid)
        taux_moyen_valid = taux_bons_valid/len(dl_valid)
        print(f'-------- > epoch {epoch+1}:  coût moyen entraînement = {cout_moyen_ent}')
        print(f'-------- > epoch {epoch+1}:  taux moyen entraînement = {taux_moyen_ent}')
        print(f'-------- > epoch {epoch+1}:  coût moyen validation = {cout_moyen_valid}')
        print(f'-------- > epoch {epoch+1}:  taux moyen validation = {taux_moyen_valid}')
    
        liste_cout_moyen_ent.append(cout_moyen_ent)
        liste_taux_moyen_ent.append(taux_moyen_ent)
        liste_cout_moyen_valid.append(cout_moyen_valid)
        liste_taux_moyen_valid.append(taux_moyen_valid)
    
    # Affichage du graphique d'évolution des métriques par epoch
    import numpy as np
    import matplotlib.pyplot as plt
    plt.plot(np.arange(0,nb_epochs),liste_cout_moyen_ent,label='Erreur entraînement')
    plt.plot(np.arange(0,nb_epochs),liste_cout_moyen_valid,label='Erreur validation')
    plt.title("Evolution du coût")
    plt.xlabel('epoch')
    plt.ylabel('moyenne par observation')
    plt.legend(loc='upper center')
    plt.show()
        
    plt.plot(np.arange(0,nb_epochs),liste_taux_moyen_ent,label='Taux bonnes réponses entraînement')
    plt.plot(np.arange(0,nb_epochs),liste_taux_moyen_valid,label='Taux bonnes réponses validation')
    plt.title("Evolution du taux")
    plt.xlabel('epoch')
    plt.ylabel('moyenne par observation')
    plt.legend(loc='upper center')
    plt.show()

entrainer(modele, dl_ent, dl_valid, optimiseur, nb_epochs=30)
# Out:
# -------- > epoch 1:  coût moyen entraînement = 0.6395615935325623
# -------- > epoch 1:  taux moyen entraînement = 0.8308802247047424
# -------- > epoch 1:  coût moyen validation = 0.34182068705558777
# -------- > epoch 1:  taux moyen validation = 0.9018999338150024
# -------- > epoch 2:  coût moyen entraînement = 0.33830082416534424
# -------- > epoch 2:  taux moyen entraînement = 0.9012807011604309
# -------- > epoch 2:  coût moyen validation = 0.31163010001182556
# -------- > epoch 2:  taux moyen validation = 0.9098999500274658
# -------- > epoch 3:  coût moyen entraînement = 0.3107055425643921
# -------- > epoch 3:  taux moyen entraînement = 0.9097204804420471
# -------- > epoch 3:  coût moyen validation = 0.27020400762557983
# -------- > epoch 3:  taux moyen validation = 0.9230998754501343
# -------- > epoch 4:  coût moyen entraînement = 0.28789085149765015
# -------- > epoch 4:  taux moyen entraînement = 0.9180006980895996
# -------- > epoch 4:  coût moyen validation = 0.2630469799041748
# -------- > epoch 4:  taux moyen validation = 0.9244998097419739
# -------- > epoch 5:  coût moyen entraînement = 0.2657875120639801
# -------- > epoch 5:  taux moyen entraînement = 0.9235210418701172
# -------- > epoch 5:  coût moyen validation = 0.25041624903678894
# -------- > epoch 5:  taux moyen validation = 0.9275000095367432
# -------- > epoch 6:  coût moyen entraînement = 0.23840269446372986
# -------- > epoch 6:  taux moyen entraînement = 0.9322409629821777
# -------- > epoch 6:  coût moyen validation = 0.20752005279064178
# -------- > epoch 6:  taux moyen validation = 0.9442999958992004
# -------- > epoch 7:  coût moyen entraînement = 0.2068343311548233
# -------- > epoch 7:  taux moyen entraînement = 0.9410211443901062
# -------- > epoch 7:  coût moyen validation = 0.17519603669643402
# -------- > epoch 7:  taux moyen validation = 0.9564999938011169
# -------- > epoch 8:  coût moyen entraînement = 0.17708414793014526
# -------- > epoch 8:  taux moyen entraînement = 0.9499009847640991
# -------- > epoch 8:  coût moyen validation = 0.15372087061405182
# -------- > epoch 8:  taux moyen validation = 0.9605000019073486
# -------- > epoch 9:  coût moyen entraînement = 0.15094292163848877
# -------- > epoch 9:  taux moyen entraînement = 0.9579409956932068
# -------- > epoch 9:  coût moyen validation = 0.13450951874256134
# -------- > epoch 9:  taux moyen validation = 0.9665003418922424
# -------- > epoch 10:  coût moyen entraînement = 0.12940959632396698
# -------- > epoch 10:  taux moyen entraînement = 0.9633209705352783
# -------- > epoch 10:  coût moyen validation = 0.11599263548851013
# -------- > epoch 10:  taux moyen validation = 0.9704001545906067
# -------- > epoch 11:  coût moyen entraînement = 0.11314976960420609
# -------- > epoch 11:  taux moyen entraînement = 0.9687003493309021
# -------- > epoch 11:  coût moyen validation = 0.10497455298900604
# -------- > epoch 11:  taux moyen validation = 0.9739000797271729
# -------- > epoch 12:  coût moyen entraînement = 0.10135795176029205
# -------- > epoch 12:  taux moyen entraînement = 0.9716204404830933
# -------- > epoch 12:  coût moyen validation = 0.09909763932228088
# -------- > epoch 12:  taux moyen validation = 0.9750999212265015
# -------- > epoch 13:  coût moyen entraînement = 0.09085442870855331
# -------- > epoch 13:  taux moyen entraînement = 0.9745208024978638
# -------- > epoch 13:  coût moyen validation = 0.09294992685317993
# -------- > epoch 13:  taux moyen validation = 0.9754000306129456
# -------- > epoch 14:  coût moyen entraînement = 0.08303654938936234
# -------- > epoch 14:  taux moyen entraînement = 0.9764005541801453
# -------- > epoch 14:  coût moyen validation = 0.09022737294435501
# -------- > epoch 14:  taux moyen validation = 0.9751999378204346
# -------- > epoch 15:  coût moyen entraînement = 0.07725179940462112
# -------- > epoch 15:  taux moyen entraînement = 0.9784006476402283
# -------- > epoch 15:  coût moyen validation = 0.08236822485923767
# -------- > epoch 15:  taux moyen validation = 0.9785001277923584
# -------- > epoch 16:  coût moyen entraînement = 0.07186248153448105
# -------- > epoch 16:  taux moyen entraînement = 0.979320228099823
# -------- > epoch 16:  coût moyen validation = 0.07933054119348526
# -------- > epoch 16:  taux moyen validation = 0.9790000915527344
# -------- > epoch 17:  coût moyen entraînement = 0.06769321858882904
# -------- > epoch 17:  taux moyen entraînement = 0.9809005856513977
# -------- > epoch 17:  coût moyen validation = 0.07613980025053024
# -------- > epoch 17:  taux moyen validation = 0.9789000153541565
# -------- > epoch 18:  coût moyen entraînement = 0.06364695727825165
# -------- > epoch 18:  taux moyen entraînement = 0.9815798401832581
# -------- > epoch 18:  coût moyen validation = 0.07809118926525116
# -------- > epoch 18:  taux moyen validation = 0.9805002808570862
# -------- > epoch 19:  coût moyen entraînement = 0.06084762513637543
# -------- > epoch 19:  taux moyen entraînement = 0.9831002950668335
# -------- > epoch 19:  coût moyen validation = 0.07342354953289032
# -------- > epoch 19:  taux moyen validation = 0.980400025844574
# -------- > epoch 20:  coût moyen entraînement = 0.05799553543329239
# -------- > epoch 20:  taux moyen entraînement = 0.9835598468780518
# -------- > epoch 20:  coût moyen validation = 0.0714501366019249
# -------- > epoch 20:  taux moyen validation = 0.9810001254081726
# -------- > epoch 21:  coût moyen entraînement = 0.05564308911561966
# -------- > epoch 21:  taux moyen entraînement = 0.9840999245643616
# -------- > epoch 21:  coût moyen validation = 0.07331327348947525
# -------- > epoch 21:  taux moyen validation = 0.9806001782417297
# -------- > epoch 22:  coût moyen entraînement = 0.053649842739105225
# -------- > epoch 22:  taux moyen entraînement = 0.9839798808097839
# -------- > epoch 22:  coût moyen validation = 0.07042805850505829
# -------- > epoch 22:  taux moyen validation = 0.9808002710342407
# -------- > epoch 23:  coût moyen entraînement = 0.05188269913196564
# -------- > epoch 23:  taux moyen entraînement = 0.9852402806282043
# -------- > epoch 23:  coût moyen validation = 0.07034626603126526
# -------- > epoch 23:  taux moyen validation = 0.9811000823974609
# -------- > epoch 24:  coût moyen entraînement = 0.04945826157927513
# -------- > epoch 24:  taux moyen entraînement = 0.985720157623291
# -------- > epoch 24:  coût moyen validation = 0.0675320029258728
# -------- > epoch 24:  taux moyen validation = 0.982100248336792
# -------- > epoch 25:  coût moyen entraînement = 0.04820967838168144
# -------- > epoch 25:  taux moyen entraînement = 0.9859800934791565
# -------- > epoch 25:  coût moyen validation = 0.06845413893461227
# -------- > epoch 25:  taux moyen validation = 0.9808000922203064
# -------- > epoch 26:  coût moyen entraînement = 0.046289920806884766
# -------- > epoch 26:  taux moyen entraînement = 0.9865598082542419
# -------- > epoch 26:  coût moyen validation = 0.06745196878910065
# -------- > epoch 26:  taux moyen validation = 0.9814000725746155
# -------- > epoch 27:  coût moyen entraînement = 0.044693347066640854
# -------- > epoch 27:  taux moyen entraînement = 0.9872201681137085
# -------- > epoch 27:  coût moyen validation = 0.06692586094141006
# -------- > epoch 27:  taux moyen validation = 0.982400119304657
# -------- > epoch 28:  coût moyen entraînement = 0.0436270572245121
# -------- > epoch 28:  taux moyen entraînement = 0.9872000217437744
# -------- > epoch 28:  coût moyen validation = 0.0718335434794426
# -------- > epoch 28:  taux moyen validation = 0.9808001518249512
# -------- > epoch 29:  coût moyen entraînement = 0.042379096150398254
# -------- > epoch 29:  taux moyen entraînement = 0.9874401092529297
# -------- > epoch 29:  coût moyen validation = 0.0645679160952568
# -------- > epoch 29:  taux moyen validation = 0.9828000664710999
# -------- > epoch 30:  coût moyen entraînement = 0.041063424199819565
# -------- > epoch 30:  taux moyen entraînement = 0.9880396127700806
# -------- > epoch 30:  coût moyen validation = 0.0645856037735939
# -------- > epoch 30:  taux moyen validation = 0.9832000732421875
