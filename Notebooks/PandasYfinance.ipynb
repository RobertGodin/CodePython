# %%
import yfinance as yf

msft = yf.Ticker("MSFT")
msft.info # Informations sur l'action
# Out:
# {'zip': '98052-6399',
#  'sector': 'Technology',
#  'fullTimeEmployees': 181000,
#  'longBusinessSummary': 'Microsoft Corporation develops, licenses, and supports software, services, devices, and solutions worldwide. Its Productivity and Business Processes segment offers Office, Exchange, SharePoint, Microsoft Teams, Office 365 Security and Compliance, and Skype for Business, as well as related Client Access Licenses (CAL); Skype, Outlook.com, OneDrive, and LinkedIn; and Dynamics 365, a set of cloud-based and on-premises business solutions for organizations and enterprise divisions. Its Intelligent Cloud segment licenses SQL, Windows Servers, Visual Studio, System Center, and related CALs; GitHub that provides a collaboration platform and code hosting service for developers; and Azure, a cloud platform. It also offers support services and Microsoft consulting services to assist customers in developing, deploying, and managing Microsoft server and desktop solutions; and training and certification on Microsoft products. Its More Personal Computing segment provides Windows original equipment manufacturer (OEM) licensing and other non-volume licensing of the Windows operating system; Windows Commercial, such as volume licensing of the Windows operating system, Windows cloud services, and other Windows commercial offerings; patent licensing; Windows Internet of Things; and MSN advertising. It also offers Surface, PC accessories, PCs, tablets, gaming and entertainment consoles, and other devices; Gaming, including Xbox hardware, and Xbox content and services; video games and third-party video game royalties; and Search, including Bing and Microsoft advertising. It sells its products through OEMs, distributors, and resellers; and directly through digital marketplaces, online stores, and retail stores. It has collaborations with Dynatrace, Inc., Morgan Stanley, Micro Focus, WPP plc, ACI Worldwide, Inc., and iCIMS, Inc., as well as strategic relationships with Avaya Holdings Corp. and wejo Limited. Microsoft Corporation was founded in 1975 and is based in Redmond, Washington.',
#  'city': 'Redmond',
#  'phone': '425 882 8080',
#  'state': 'WA',
#  'country': 'United States',
#  'companyOfficers': [],
#  'website': 'http://www.microsoft.com',
#  'maxAge': 1,
#  'address1': 'One Microsoft Way',
#  'industry': 'Software—Infrastructure',
#  'ebitdaMargins': 0.48648998,
#  'profitMargins': 0.38515,
#  'grossMargins': 0.68864995,
#  'operatingCashflow': 81945001984,
#  'revenueGrowth': 0.22,
#  'operatingMargins': 0.42143002,
#  'ebitda': 85745000448,
#  'targetLowPrice': 299.93,
#  'recommendationKey': 'buy',
#  'grossProfits': 115856000000,
#  'freeCashflow': 49819750400,
#  'targetMedianPrice': 364,
#  'currentPrice': 337.16,
#  'earningsGrowth': 0.489,
#  'currentRatio': 2.165,
#  'returnOnAssets': 0.14589,
#  'numberOfAnalystOpinions': 39,
#  'targetMeanPrice': 363.88,
#  'debtToEquity': 51.938,
#  'returnOnEquity': 0.49303,
#  'targetHighPrice': 410,
#  'totalCash': 130584002560,
#  'totalDebt': 78934999040,
#  'totalRevenue': 176250994688,
#  'totalCashPerShare': 17.393,
#  'financialCurrency': 'USD',
#  'revenuePerShare': 23.395,
#  'quickRatio': 1.961,
#  'recommendationMean': 1.7,
#  'exchange': 'NMS',
#  'shortName': 'Microsoft Corporation',
#  'longName': 'Microsoft Corporation',
#  'exchangeTimezoneName': 'America/New_York',
#  'exchangeTimezoneShortName': 'EST',
#  'isEsgPopulated': False,
#  'gmtOffSetMilliseconds': '-18000000',
#  'quoteType': 'EQUITY',
#  'symbol': 'MSFT',
#  'messageBoardId': 'finmb_21835',
#  'market': 'us_market',
#  'annualHoldingsTurnover': None,
#  'enterpriseToRevenue': 14.183,
#  'beta3Year': None,
#  'enterpriseToEbitda': 29.154,
#  '52WeekChange': 0.58903027,
#  'morningStarRiskRating': None,
#  'forwardEps': 10.53,
#  'revenueQuarterlyGrowth': None,
#  'sharesOutstanding': 7507979776,
#  'fundInceptionDate': None,
#  'annualReportExpenseRatio': None,
#  'totalAssets': None,
#  'bookValue': 20.242,
#  'sharesShort': 49332744,
#  'sharesPercentSharesOut': 0.0066000004,
#  'fundFamily': None,
#  'lastFiscalYearEnd': 1625011200,
#  'heldPercentInstitutions': 0.71779,
#  'netIncomeToCommon': 67882999808,
#  'trailingEps': 8.939,
#  'lastDividendValue': 0.62,
#  'SandP52WeekChange': 0.28814626,
#  'priceToBook': 16.656456,
#  'heldPercentInsiders': 0.00078,
#  'nextFiscalYearEnd': 1688083200,
#  'yield': None,
#  'mostRecentQuarter': 1632960000,
#  'shortRatio': 1.97,
#  'sharesShortPreviousMonthDate': 1632960000,
#  'floatShares': 7500172144,
#  'beta': 0.862337,
#  'enterpriseValue': 2499787882496,
#  'priceHint': 2,
#  'threeYearAverageReturn': None,
#  'lastSplitDate': 1045526400,
#  'lastSplitFactor': '2:1',
#  'legalType': None,
#  'lastDividendDate': 1637107200,
#  'morningStarOverallRating': None,
#  'earningsQuarterlyGrowth': 0.476,
#  'priceToSalesTrailing12Months': 14.362417,
#  'dateShortInterest': 1635465600,
#  'pegRatio': 2.23,
#  'ytdReturn': None,
#  'forwardPE': 32.018993,
#  'lastCapGain': None,
#  'shortPercentOfFloat': 0.0066000004,
#  'sharesShortPriorMonth': 47171313,
#  'impliedSharesOutstanding': None,
#  'category': None,
#  'fiveYearAverageReturn': None,
#  'previousClose': 339.83,
#  'regularMarketOpen': 337.05,
#  'twoHundredDayAverage': 274.3822,
#  'trailingAnnualDividendYield': 0.00676809,
#  'payoutRatio': 0.25059998,
#  'volume24Hr': None,
#  'regularMarketDayHigh': 339.45,
#  'navPrice': None,
#  'averageDailyVolume10Day': 21955360,
#  'regularMarketPreviousClose': 339.83,
#  'fiftyDayAverage': 311.9018,
#  'trailingAnnualDividendRate': 2.3,
#  'open': 337.05,
#  'toCurrency': None,
#  'averageVolume10days': 21955360,
#  'expireDate': None,
#  'algorithm': None,
#  'dividendRate': 2.48,
#  'exDividendDate': 1637107200,
#  'circulatingSupply': None,
#  'startDate': None,
#  'regularMarketDayLow': 333.56,
#  'currency': 'USD',
#  'trailingPE': 37.717865,
#  'regularMarketVolume': 22580665,
#  'lastMarket': None,
#  'maxSupply': None,
#  'openInterest': None,
#  'marketCap': 2531390390272,
#  'volumeAllCurrencies': None,
#  'strikePrice': None,
#  'averageVolume': 23476745,
#  'dayLow': 333.56,
#  'ask': 336.75,
#  'askSize': 800,
#  'volume': 22580665,
#  'fiftyTwoWeekHigh': 349.67,
#  'fromCurrency': None,
#  'fiveYearAvgDividendYield': 1.45,
#  'fiftyTwoWeekLow': 208.86,
#  'bid': 336.7,
#  'tradeable': False,
#  'dividendYield': 0.0073,
#  'bidSize': 900,
#  'dayHigh': 339.45,
#  'regularMarketPrice': 337.16,
#  'logo_url': 'https://logo.clearbit.com/microsoft.com'}

# %%
# period: periode visée jusqu'à la date d'aujourd'hui (1d, 5d, 1mo, 3mo, 6mo, 1y, 2y, 5y, 10y, ytd, max)
df_historique_msft = msft.history(period="max") # Chercher l'historique des prix de l'action
df_historique_msft.head()
# Out:
#                 Open      High       Low     Close      Volume  Dividends  \
# Date
# 1986-03-13  0.055898  0.064119  0.055898  0.061378  1031788800        0.0
# 1986-03-14  0.061378  0.064667  0.061378  0.063570   308160000        0.0
# 1986-03-17  0.063570  0.065215  0.063570  0.064667   133171200        0.0
# 1986-03-18  0.064667  0.065215  0.062474  0.063022    67766400        0.0
# 1986-03-19  0.063022  0.063570  0.061378  0.061926    47894400        0.0
#
#             Stock Splits
# Date
# 1986-03-13           0.0
# 1986-03-14           0.0
# 1986-03-17           0.0
# 1986-03-18           0.0
# 1986-03-19           0.0

# %%
type(df_historique_msft)
# Out:
# pandas.core.frame.DataFrame

# %%
df_historique_msft.tail()
# Out:
#                   Open        High         Low       Close    Volume  \
# Date
# 2021-11-17  338.940002  342.190002  338.000000  339.119995  19053400
# 2021-11-18  338.179993  342.450012  337.119995  341.269989  22463500
# 2021-11-19  342.640015  345.100006  342.200012  343.109985  21942200
# 2021-11-22  344.619995  349.670013  339.549988  339.829987  31031100
# 2021-11-23  337.049988  339.450012  333.559998  337.170013  22584323
#
#             Dividends  Stock Splits
# Date
# 2021-11-17       0.62           0.0
# 2021-11-18       0.00           0.0
# 2021-11-19       0.00           0.0
# 2021-11-22       0.00           0.0
# 2021-11-23       0.00           0.0

# %%
type(df_historique_msft.index)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
df_historique_msft.index
# Out:
# DatetimeIndex(['1986-03-13', '1986-03-14', '1986-03-17', '1986-03-18',
#                '1986-03-19', '1986-03-20', '1986-03-21', '1986-03-24',
#                '1986-03-25', '1986-03-26',
#                ...
#                '2021-11-10', '2021-11-11', '2021-11-12', '2021-11-15',
#                '2021-11-16', '2021-11-17', '2021-11-18', '2021-11-19',
#                '2021-11-22', '2021-11-23'],
#               dtype='datetime64[ns]', name='Date', length=9000, freq=None)

# %%
df_historique_msft.index[0]
# Out:
# Timestamp('1986-03-13 00:00:00')

# %%
type(df_historique_msft.index[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df_historique_msft.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits'], dtype='object')

# %%
df_historique_msft.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 9000 entries, 1986-03-13 to 2021-11-23
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Open          9000 non-null   float64
#  1   High          9000 non-null   float64
#  2   Low           9000 non-null   float64
#  3   Close         9000 non-null   float64
#  4   Volume        9000 non-null   int64
#  5   Dividends     9000 non-null   float64
#  6   Stock Splits  9000 non-null   float64
# dtypes: float64(6), int64(1)
# memory usage: 562.5 KB

# %%
df_historique_msft.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  9000.000000  9000.000000  9000.000000  9000.000000  9.000000e+03
# mean     33.774314    34.117381    33.429856    33.788998  5.896063e+07
# std      54.209902    54.706535    53.718099    54.253722  3.854679e+07
# min       0.055898     0.058090     0.055898     0.056994  2.304000e+06
# 25%       2.495693     2.524054     2.475964     2.500009  3.484440e+07
# 50%      18.837690    19.039084    18.623224    18.835478  5.224520e+07
# 75%      28.468657    28.960859    28.194368    28.591716  7.284270e+07
# max     344.619995   349.670013   342.200012   343.109985  1.031789e+09
#
#          Dividends  Stock Splits
# count  9000.000000   9000.000000
# mean      0.002446      0.001889
# std       0.042526      0.060066
# min       0.000000      0.000000
# 25%       0.000000      0.000000
# 50%       0.000000      0.000000
# 75%       0.000000      0.000000
# max       3.080000      2.000000

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
#
#                '2021-11-17 11:30:00-05:00', '2021-11-17 12:30:00-05:00',
#                '2021-11-17 13:30:00-05:00', '2021-11-17 14:30:00-05:00',
#                '2021-11-17 15:30:00-05:00', '2021-11-18 09:30:00-05:00',
#                '2021-11-18 10:30:00-05:00', '2021-11-18 11:30:00-05:00',
#                '2021-11-18 12:30:00-05:00', '2021-11-18 13:30:00-05:00',
#                '2021-11-18 14:30:00-05:00', '2021-11-18 15:30:00-05:00',
#                '2021-11-19 09:30:00-05:00', '2021-11-19 10:30:00-05:00',
#                '2021-11-19 11:30:00-05:00', '2021-11-19 12:30:00-05:00',
#                '2021-11-19 13:30:00-05:00', '2021-11-19 14:30:00-05:00',
#                '2021-11-19 15:30:00-05:00', '2021-11-22 09:30:00-05:00',
#                '2021-11-22 10:30:00-05:00', '2021-11-22 11:30:00-05:00',
#                '2021-11-22 12:30:00-05:00', '2021-11-22 13:30:00-05:00',
#                '2021-11-22 14:30:00-05:00', '2021-11-22 15:30:00-05:00',
#                '2021-11-23 09:30:00-05:00', '2021-11-23 10:30:00-05:00',
#                '2021-11-23 11:30:00-05:00', '2021-11-23 12:30:00-05:00',
#                '2021-11-23 13:30:00-05:00', '2021-11-23 14:30:00-05:00',
#                '2021-11-23 15:30:00-05:00', '2021-11-23 15:43:31-05:00'],
#               dtype='datetime64[ns, America/New_York]', name='Datetime', freq=None)

# %%
# Employer start et end plutôt que period
msft.history(start="2000-01-01", end="2001-01-01")
# Out:
#                  Open       High        Low      Close     Volume  Dividends  \
# Date
# 2000-01-03  37.050679  37.445255  35.354003  36.794205   53228400          0
# 2000-01-04  35.847224  36.971766  35.432920  35.551292   54119000          0
# 2000-01-05  35.077820  36.735040  34.525414  35.926159   64059600          0
# 2000-01-06  35.413195  35.945872  34.209738  34.722687   54976600          0
# 2000-01-07  34.288660  35.432931  33.874355  35.176456   62013600          0
# ...               ...        ...        ...        ...        ...        ...
# 2000-12-22  14.125825  14.875519  14.125825  14.658503  109551800          0
# 2000-12-26  14.796609  15.329287  14.480948  14.796609   66941600          0
# 2000-12-27  14.559859  14.776875  14.204740  14.658503   69003800          0
# 2000-12-28  14.244196  14.599315  13.849620  14.066637   77619200          0
# 2000-12-29  13.869343  14.461207  13.573411  13.691784   99977600          0
#
#             Stock Splits
# Date
# 2000-01-03             0
# 2000-01-04             0
# 2000-01-05             0
# 2000-01-06             0
# 2000-01-07             0
# ...                  ...
# 2000-12-22             0
# 2000-12-26             0
# 2000-12-27             0
# 2000-12-28             0
# 2000-12-29             0
#
# [252 rows x 7 columns]

# %%
# La fonction download permet aussi de charger des données historiques
df_hist_1990a2020 = yf.download("MSFT", start="1990-01-01", end="2020-01-01")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df_hist_1990a2020
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1990-01-02    0.605903    0.616319    0.598090    0.616319    0.389096
# 1990-01-03    0.621528    0.626736    0.614583    0.619792    0.391288
# 1990-01-04    0.619792    0.638889    0.616319    0.638021    0.402797
# 1990-01-05    0.635417    0.638889    0.621528    0.622396    0.392932
# 1990-01-08    0.621528    0.631944    0.614583    0.631944    0.398960
# ...                ...         ...         ...         ...         ...
# 2019-12-24  157.479996  157.710007  157.119995  157.380005  154.435730
# 2019-12-26  157.559998  158.729996  157.399994  158.669998  155.701599
# 2019-12-27  159.449997  159.550003  158.220001  158.960007  155.986160
# 2019-12-30  158.990005  159.020004  156.729996  157.589996  154.641769
# 2019-12-31  156.770004  157.770004  156.449997  157.699997  154.749741
#
#                Volume
# Date
# 1990-01-02   53035200
# 1990-01-03  113774400
# 1990-01-04  125740800
# 1990-01-05   69566400
# 1990-01-08   58982400
# ...               ...
# 2019-12-24    8989200
# 2019-12-26   14520600
# 2019-12-27   18412800
# 2019-12-30   16348400
# 2019-12-31   18369400
#
# [7559 rows x 6 columns]

# %%
# la fonction download permet de charger les données de plusieurs symboles à la fois
df_historique = yf.download("MSFT AAPL AMZN", start="2000-01-01", end="2010-01-01")
df_historique["Close"]
# Out:
# [*********************100%***********************]  3 of 3 completed
#                 AAPL        AMZN       MSFT
# Date
# 2000-01-03  0.999442   89.375000  58.281250
# 2000-01-04  0.915179   81.937500  56.312500
# 2000-01-05  0.928571   69.750000  56.906250
# 2000-01-06  0.848214   65.562500  55.000000
# 2000-01-07  0.888393   69.562500  55.718750
# ...              ...         ...        ...
# 2009-12-24  7.465714  138.470001  31.000000
# 2009-12-28  7.557500  139.309998  31.170000
# 2009-12-29  7.467857  139.410004  31.389999
# 2009-12-30  7.558571  136.490005  30.959999
# 2009-12-31  7.526071  134.520004  30.480000
#
# [2515 rows x 3 columns]

# %%
df_historique['Close'].plot()
plt.title("Prix fermeture")
plt.show()

# %%
fenetre_10=df_historique_msft['Close'].rolling(window = 10)
df_historique_msft['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
fenetre_10.mean().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# rolling() retourne un objet Rolling qui permet des opérations d'agrégation sur une fenêtre de données
# par défaut chacun des éléments est pondéré également
fenetre_10=df_historique_msft['2000-03-01': '2001-04-25']['Close'].rolling(window = 10)
df_historique_msft['2000-03-01': '2001-04-25']['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# Prend la moyenne de 10 valeurs à la fois
fenetre_10.mean().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_historique_msft['2000-03-01': '2001-04-25']['Close']
# Out:
# Date
# 2000-03-01    28.665937
# 2000-03-02    29.474819
# 2000-03-03    30.342899
# 2000-03-06    28.606760
# 2000-03-07    29.317009
#                 ...
# 2001-04-19    21.477564
# 2001-04-20    21.780594
# 2001-04-23    21.543844
# 2001-04-24    21.322889
# 2001-04-25    21.998396
# Name: Close, Length: 291, dtype: float64

# %%
from pandas.plotting import lag_plot
plt.figure()
# Affiche Yt+lag vs Yt
# Si lag=1 affiche serie[:-1] vs. serie[1:]
lag_plot(df_historique_msft['2000-03-01': '2001-04-25']['Close'],lag=1)
# Out:
# <AxesSubplot:xlabel='y(t)', ylabel='y(t + 1)'>

# %%
lag_plot(df_historique_msft['2000-03-01': '2001-04-25']['Close'], lag=5)
# Out:
# <AxesSubplot:xlabel='y(t)', ylabel='y(t + 5)'>

# %%
from pandas.plotting import autocorrelation_plot
plt.figure()
# La ligne pleine indique l'intervalle de confiance à 95%
# La ligne pointillée indique l'intervalle de confiance à 99%
autocorrelation_plot(df_historique_msft['2000-03-01': '2001-04-25']['Close'])
# Out:
# <AxesSubplot:xlabel='Lag', ylabel='Autocorrelation'>

# %%
# plot_acf() de statsmodel produit un graphique similaire
# le cône est un intervalle de confiance à 95%
from statsmodels.graphics.tsaplots import plot_acf
# Plot the acf function on the ts_data_load set
plot_acf(df_historique_msft['2000-03-01': '2001-04-25']['Close'])
plt.show()

# %%
# Import plot_pacf() function
from statsmodels.graphics.tsaplots import plot_pacf
# Plot the pacf function on the ts_data_load dataset
plot_pacf(df_historique_msft['2000-03-01': '2001-04-25']['Close'], lags=20)
plt.show()

# %%
tickers_list = ['AAPL', 'IBM', 'MSFT', 'WMT']

# Create placeholder for data
data = pd.DataFrame(columns=tickers_list)

# Fetch the data
for ticker in tickers_list:
    data[ticker] = yf.download(ticker, 
                               start_date,
                               end_date)['Adj Close']
    
# Print first 5 rows of the data
print(data.head())

# Plot all the close prices
data.plot(figsize=(10, 7))

# Show the legend
plt.legend()

# Define the label for the title of the figure
plt.title("Adjusted Close Price", fontsize=16)

# Define the labels for x-axis and y-axis
plt.ylabel('Price', fontsize=14)
plt.xlabel('Year', fontsize=14)

# Plot the grid lines
plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-106596dcb131> in <module>
#       2
#       3 # Create placeholder for data
# ----> 4 data = pd.DataFrame(columns=tickers_list)
#       5
#       6 # Fetch the data
#
# NameError: name 'pd' is not defined

# %%
# Documentation sur le site de yfinance
data = yf.download(  # or pdr.get_data_yahoo(...
        # tickers list or string as well
        tickers = "SPY AAPL MSFT",

        # use "period" instead of start/end
        # valid periods: 1d,5d,1mo,3mo,6mo,1y,2y,5y,10y,ytd,max
        # (optional, default is '1mo')
        period = "ytd",

        # fetch data by interval (including intraday if period < 60 days)
        # valid intervals: 1m,2m,5m,15m,30m,60m,90m,1h,1d,5d,1wk,1mo,3mo
        # (optional, default is '1d')
        interval = "1m",

        # group by ticker (to access via data['SPY'])
        # (optional, default is 'column')
        group_by = 'ticker',

        # adjust all OHLC automatically
        # (optional, default is False)
        auto_adjust = True,

        # download pre/post regular market hours data
        # (optional, default is False)
        prepost = True,

        # use threads for mass downloading? (True/False/Integer)
        # (optional, default is True)
        threads = True,

        # proxy URL scheme use use when downloading?
        # (optional, default is None)
        proxy = None
    )

# %%
msft.actions # Dividendes et fractionnements (splits)
# Out:
#             Dividends  Stock Splits
# Date
# 1987-09-21       0.00           2.0
# 1990-04-16       0.00           2.0
# 1991-06-27       0.00           1.5
# 1992-06-15       0.00           1.5
# 1994-05-23       0.00           2.0
# ...               ...           ...
# 2020-05-20       0.51           0.0
# 2020-08-19       0.51           0.0
# 2020-11-18       0.56           0.0
# 2021-02-17       0.56           0.0
# 2021-05-19       0.56           0.0
#
# [79 rows x 2 columns]

# %%
msft.dividends
# Out:
# Date
# 2003-02-19    0.08
# 2003-10-15    0.16
# 2004-08-23    0.08
# 2004-11-15    3.08
# 2005-02-15    0.08
#               ...
# 2020-05-20    0.51
# 2020-08-19    0.51
# 2020-11-18    0.56
# 2021-02-17    0.56
# 2021-05-19    0.56
# Name: Dividends, Length: 70, dtype: float64

# %%
msft.splits
# Out:
# Date
# 1987-09-21    2.0
# 1990-04-16    2.0
# 1991-06-27    1.5
# 1992-06-15    1.5
# 1994-05-23    2.0
# 1996-12-09    2.0
# 1998-02-23    2.0
# 1999-03-29    2.0
# 2003-02-18    2.0
# Name: Stock Splits, dtype: float64

# %%
msft.financials # Etats financiers
# Out:
#                                             2021-06-30      2020-06-30  \
# Research Development                     20716000000.0   19269000000.0
# Effect Of Accounting Charges                      None            None
# Income Before Tax                        71102000000.0   53036000000.0
# Minority Interest                                 None            None
# Net Income                               61271000000.0   44281000000.0
# Selling General Administrative           25224000000.0   24523000000.0
# Gross Profit                            115856000000.0   96937000000.0
# Ebit                                     69916000000.0   53145000000.0
# Operating Income                         69916000000.0   53145000000.0
# Other Operating Expenses                          None            None
# Interest Expense                         -2330000000.0   -2591000000.0
# Extraordinary Items                               None            None
# Non Recurring                                     None            None
# Other Items                                       None            None
# Income Tax Expense                        9831000000.0    8755000000.0
# Total Revenue                           168088000000.0  143015000000.0
# Total Operating Expenses                 98172000000.0   89870000000.0
# Cost Of Revenue                          52232000000.0   46078000000.0
# Total Other Income Expense Net            1186000000.0    -109000000.0
# Discontinued Operations                           None            None
# Net Income From Continuing Ops
shares Date Reported   % Out  \
# 0         Vanguard Group, Inc. (The)  610849992    2021-03-30  0.0813
# 1                     Blackrock Inc.  518649291    2021-03-30  0.0690
# 2           State Street Corporation  292575655    2021-03-30  0.0389
# 3                           FMR, LLC  217585928    2021-03-30  0.0290
# 4      Price (T.Rowe) Associates Inc  178824616    2021-03-30  0.0238
# 5      Geode Capital Management, LLC  120231394    2021-03-30  0.0160
# 6            Capital World Investors  112150578    2021-03-30  0.0149
# 7  Capital Research Global Investors   99286940    2021-03-30  0.0132
# 8    Capital International Investors   90228967    2021-03-30  0.0120
# 9         Northern Trust Corporation   89762724    2021-03-30  0.0119
#
#           Value
# 0  144020102613
# 1  122281943339
# 2   68980562179
# 3   51300234244
# 4   42161479714
# 5   28346955763
# 6   26441741775
# 7   23408881843
# 8   21273283549
# 9   21163357437

# %%
msft.balance_sheet
# Out:
#                                     2021-06-30    2020-06-30    2019-06-30  \
# Intangible Assets                 7.800000e+09  7.038000e+09  7.750000e+09
# Total Liab                        1.917910e+11  1.830070e+11  1.842260e+11
# Total Stockholder Equity          1.419880e+11  1.183040e+11  1.023300e+11
# Other Current Liab                5.261200e+10  4.600100e+10  4.586000e+10
# Total Assets                      3.337790e+11  3.013110e+11  2.865560e+11
# Common Stock                      8.311100e+10  8.055200e+10  7.852000e+10
# Other Current Assets              1.347100e+10  1.151700e+10  1.013300e+10
# Retained Earnings                 5.705500e+10  3.456600e+10  2.415000e+10
# Other Liab                        3.168100e+10  3.449200e+10  3.569900e+10
# Good Will                         4.971100e+10  4.335100e+10  4.202600e+10
# Treasury Stock                    1.822000e+09  3.186000e+09 -3.400000e+08
# Other Assets                      1.507500e+10  1.313800e+10  1.472300e+10
# Cash                              1.422400e+10  1.357600e+10  1.135600e+10
# Total Current Liabilities         8.865700e+10  7.231000e+10  6.942000e+10
# Deferred Long Term Asset Charges  7.181000e+09  6.405000e+09  7.536000e+09
# Short Long Term Debt              8.072000e+09  3.749000e+09  5.516000e+09
# Other Stockholder Equity          1.822000e+09  3.186000e+09 -3.400000e+08
# Property Plant Equipment          7.080300e+10  5.290400e+10  4.385600e+10
# Total Current Assets              1.844060e+11  1.819150e+11  1.755520e+11
# Long Term Investments             5.984000e+09  2.965000e+09  2.649000e+09
# Net Tangible Assets               8.447700e+10  6.791500e+10  5.255400e+10
# Short Term Investments            1.160320e+11  1.229160e+11  1.224760e+11
# Net Receivables                   3.804300e+10  3.201100e+10  2.952400e+10
# Long Term Debt                    5.007400e+10  5.957800e+10  6.666200e+10
# Inventory                         2.636000e+09  1.895000e+09  2.063000e+09
# Accounts Payable                  1.516300e+10  1.253000e+10  9.382000e+09
#
#                                     2018-06-30
# Intangible Assets                 8.053000e+09
# Total Liab                        1.761300e+11
# Total Stockholder Equity          8.271800e+10
# Other Current Liab                3.819500e+10
# Total Assets                      2.588480e+11
# Common Stock                      7.122300e+10
# Other Current Assets              6.855000e+09
# Retained Earnings                 1.368200e+10
# Other Liab                        3.570700e+10
# Good Will                         3.568300e+10
# Treasury Stock                   -2.187000e+09
# Other Assets                      7.442000e+09
# Cash                              1.194600e+10
# Total Current Liabilities         5.848800e+10
# Deferred Long Term Asset Charges  1.369000e+09
# Short Long Term Debt              3.998000e+09
# Other Stockholder Equity         -2.187000e+09
# Property Plant Equipment          3.614600e+10
# Total Current Assets              1.696620e+11
# Long Term Investments             1.862000e+09
# Net Tangible Assets               3.898200e+10
# Short Term Investments            1.217180e+11
# Net Receivables                   2.648100e+10
# Long Term Debt                    7.224200e+10
# Inventory                         2.662000e+09
# Accounts Payable                  8.617000e+09

# %%
msft.quarterly_balance_sheet
# Out:
#                                     2021-06-30    2021-03-31    2020-12-31  \
# Intangible Assets                 7.800000e+09  8.127000e+09  6.555000e+09
# Total Liab                        1.917910e+11  1.743740e+11  1.739010e+11
# Total Stockholder Equity          1.419880e+11  1.345050e+11  1.302360e+11
# Other Current Liab                5.261200e+10  4.006900e+10  3.992600e+10
# Total Assets                      3.337790e+11  3.088790e+11  3.041370e+11
# Common Stock                      8.311100e+10  8.230800e+10  8.189600e+10
# Other Current Assets              1.347100e+10  1.203400e+10  1.274800e+10
# Retained Earnings                 5.705500e+10  5.073500e+10  4.497300e+10
# Other Liab                        3.168100e+10  3.160100e+10  3.158500e+10
# Good Will                         4.971100e+10  4.969800e+10  4.421900e+10
# Treasury Stock                    1.822000e+09  1.462000e+09  3.367000e+09
# Other Assets                      1.507500e+10  1.442700e+10  1.356100e+10
# Cash                              1.422400e+10  1.370200e+10  1.443200e+10
# Total Current Liabilities         8.865700e+10  7.219300e+10  6.748600e+10
# Deferred Long Term Asset Charges  7.181000e+09           NaN           NaN
# Short Long Term Debt              8.072000e+09  8.051000e+09  5.387000e+09
# Other Stockholder Equity          1.822000e+09  1.462000e+09  3.367000e+09
# Property Plant Equipment          7.080300e+10  6.561800e+10  6.203500e+10
# Total Current Assets              1.844060e+11  1.656140e+11  1.739730e+11
# Long Term Investments             5.984000e+09  5.395000e+09  3.794000e+09
# Net Tangible Assets               8.447700e+10  7.668000e+10  7.946200e+10
# Short Term Investments            1.160320e+11  1.113110e+11  1.175570e+11
# Net Receivables                   3.804300e+10  2.632200e+10  2.731200e+10
# Long Term Debt                    5.007400e+10  5.000700e+10  5.513600e+10
# Inventory                         2.636000e+09  2.245000e+09  1.924000e+09
# Accounts Payable                  1.516300e+10  1.341200e+10  1.277000e+10
#
#                                     2020-09-30
# Intangible Assets                 6.923000e+09
# Total Liab                        1.776090e+11
# Total Stockholder Equity          1.233920e+11
# Other Current Liab                4.299600e+10
# Total Assets                      3.010010e+11
# Common Stock                      8.108900e+10
# Other Current Assets              1.357200e+10
# Retained Earnings                 3.919300e+10
# Other Liab                        3.317400e+10
# Good Will                         4.389000e+10
# Treasury Stock                    3.110000e+09
# Other Assets                      1.303400e+10
# Cash                              1.720500e+10
# Total Current Liabilities         7.005600e+10
# Deferred Long Term Asset Charges           NaN
# Short Long Term Debt              6.497000e+09
# Other Stockholder Equity          3.110000e+09
# Property Plant Equipment          5.697400e+10
# Total Current Assets              1.770770e+11
# Long Term Investments             3.103000e+09
# Net Tangible Assets               7.257900e+10
# Short Term Investments            1.207440e+11
# Net Receivables                   2.285100e+10
# Long Term Debt                    5.705500e+10
# Inventory                         2.705000e+09
# Accounts Payable                  1.250900e+10

# %%
msft.cashflow
# Out:
#                                              2021-06-30    2020-06-30  \
# Investments                                2.876000e+09  6.980000e+09
# Change To Liabilities                      7.431000e+09  5.230000e+09
# Total Cashflows From Investing Activities -2.757700e+10 -1.222300e+10
# Net Borrowings                            -3.750000e+09 -5.518000e+09
# Total Cash From Financing Activities      -4.848600e+10 -4.603100e+10
# Change To Operating Activities             1.160000e+09 -6.730000e+08
# Issuance Of Stock                          1.693000e+09  1.343000e+09
# Net Income                                 6.127100e+10  4.428100e+10
# Change In Cash                             6.480000e+08  2.220000e+09
# Repurchase Of Stock                       -2.738500e+10 -2.296800e+10
# Effect Of Exchange Rate                   -2.900000e+07 -2.010000e+08
# Total Cash From Operating Activities       7.674000e+10  6.067500e+10
# Depreciation                               1.090000e+10  1.230000e+10
# Other Cashflows From Investing Activities -9.220000e+08 -1.241000e+09
# Dividends Paid                            -1.652100e+10 -1.513700e+10
# Change To Inventory                       -7.370000e+08  1.680000e+08
# Change To Account Receivables             -6.481000e+09 -2.577000e+09
# Other Cashflows From Financing Activities -2.523000e+09 -3.751000e+09
# Change To Netincome                        5.505000e+09  5.577000e+09
# Capital Expenditures                      -2.062200e+10 -1.544100e+10
#
#                                              2019-06-30    2018-06-30
# Investments                                5.400000e+08  6.557000e+09
# Change To Liabilities                      4.694000e+09  7.070000e+09
# Total Cashflows From Investing Activities -1.577300e+10 -6.061000e+09
# Net Borrowings                            -4.000000e+09 -1.020100e+10
# Total Cash From Financing Activities      -3.688700e+10 -3.359000e+10
# Change To Operating Activities            -1.542000e+09 -4.590000e+08
# Issuance Of Stock                          1.142000e+09  1.002000e+09
# Net Income                                 3.924000e+10  1.657100e+10
# Change In Cash                            -5.900000e+08  4.283000e+09
# Repurchase Of Stock                       -1.954300e+10 -1.072100e+10
# Effect Of Exchange Rate                   -1.150000e+08  5.000000e+07
# Total Cash From Operating Activities       5.218500e+10  4.388400e+10
# Depreciation                               1.160000e+10  9.900000e+09
# Other Cashflows From Investing Activities -1.241000e+09 -9.800000e+07
# Dividends Paid                            -1.381100e+10 -1.269900e+10
# Change To Inventory                        5.970000e+08 -4.650000e+08
# Change To Account Receivables             -2.812000e+09 -3.862000e+09
# Other Cashflows From Financing Activities -6.750000e+08 -9.710000e+08
# Change To Netincome                       -2.521000e+09 -3.054000e+09
# Capital Expenditures                      -1.392500e+10 -1.163200e+10

# %%
msft.quarterly_cashflow
# Out:
#                                              2021-06-30    2021-03-31  \
# Investments                               -4.334000e+09  2.517000e+09
# Change To Liabilities                      1.301400e+10  3.600000e+08
# Total Cashflows From Investing Activities -1.085300e+10 -9.684000e+09
# Total Cash From Financing Activities      -1.137100e+10 -1.319200e+10
# Change To Operating Activities             7.990000e+08  1.305000e+09
# Issuance Of Stock                          4.500000e+08  3.960000e+08
# Net Income                                 1.645800e+10  1.545700e+10
# Change In Cash                             5.220000e+08 -7.300000e+08
# Repurchase Of Stock                       -7.177000e+09 -6.930000e+09
# Effect Of Exchange Rate                    3.600000e+07 -3.300000e+07
# Total Cash From Operating Activities       2.271000e+10  2.217900e+10
# Depreciation                               2.558000e+09  2.936000e+09
# Other Cashflows From Investing Activities  4.340000e+08  4.000000e+08
# Dividends Paid                            -4.214000e+09 -4.221000e+09
# Change To Inventory                       -3.880000e+08 -3.290000e+08
# Change To Account Receivables             -1.160600e+10  2.900000e+08
# Other Cashflows From Financing Activities -4.300000e+08 -1.937000e+09
# Change To Netincome                        1.907000e+09  1.086000e+09
# Capital Expenditures                      -6.452000e+09 -5.089000e+09
# Net Borrowings                                      NaN -5.000000e+08
#
#                                              2020-12-31    2020-09-30
# Investments                                2.593000e+09  2.100000e+09
# Change To Liabilities                     -3.194000e+09 -2.749000e+09
# Total Cashflows From Investing Activities -1.669000e+09 -5.371000e+09
# Total Cash From Financing Activities      -1.363400e+10 -1.028900e+10
# Change To Operating Activities             1.879000e+09 -2.823000e+09
# Issuance Of Stock                          3.020000e+08  5.450000e+08
# Net Income                                 1.546300e+10  1.389300e+10
# Change In Cash                            -2.773000e+09  3.629000e+09
# Repurchase Of Stock                       -6.535000e+09 -6.743000e+09
# Effect Of Exchange Rate                    1.400000e+07 -4.600000e+07
# Total Cash From Operating Activities       1.251600e+10  1.933500e+10
# Depreciation                               2.761000e+09  2.645000e+09
# Other Cashflows From Investing Activities  3.270000e+08 -2.083000e+09
# Dividends Paid                            -4.230000e+09 -3.856000e+09
# Change To Inventory                        7.880000e+08 -8.080000e+08
# Change To Account Receivables             -4.008000e+09  8.843000e+09
# Other Cashflows From Financing Activities  7.900000e+07 -2.350000e+08
# Change To Netincome                        1.195000e+09  1.317000e+09
# Capital Expenditures                      -4.174000e+09 -4.907000e+09
# Net Borrowings                            -3.250000e+09 -3.250000e+09

# %%
msft.earnings
# Out:
#            Revenue     Earnings
# Year
# 2018  110360000000  16571000000
# 2019  125843000000  39240000000
# 2020  143015000000  44281000000
# 2021  168088000000  61271000000

# %%
msft.quarterly_earnings
# Out:
#              Revenue     Earnings
# Quarter
# 3Q2020   37154000000  13893000000
# 4Q2020   43076000000  15463000000
# 1Q2021   41706000000  15457000000
# 2Q2021   46152000000  16458000000

# %%
msft.options
# Out:
# ('2021-08-13',
#  '2021-08-20',
#  '2021-08-27',
#  '2021-09-03',
#  '2021-09-10',
#  '2021-09-17',
#  '2021-09-24',
#  '2021-10-15',
#  '2021-11-19',
#  '2021-12-17',
#  '2022-01-21',
#  '2022-03-18',
#  '2022-06-17',
#  '2022-09-16',
#  '2023-01-20',
#  '2023-03-17',
#  '2023-06-16')

# %%
msft.sustainability
msft.recommendations
msft.calendar
# ISIN = International Securities Identification Number
msft.isin
msft.options
