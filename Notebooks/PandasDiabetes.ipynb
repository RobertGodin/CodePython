# %%
# Chargement des données de California Housing dans un DataFrame de Pandas

# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.datasets import load_diabetes

diabetes = load_diabetes(as_frame=True)

# %%
type(diabetes)
# Out:
# sklearn.utils.Bunch

# %%
print(diabetes.DESCR)
# Out:
# .. _diabetes_dataset:
#
# Diabetes dataset
# ----------------
#
# Ten baseline variables, age, sex, body mass index, average blood
# pressure, and six blood serum measurements were obtained for each of n =
# 442 diabetes patients, as well as the response of interest, a
# quantitative measure of disease progression one year after baseline.
#
# **Data Set Characteristics:**
#
#   :Number of Instances: 442
#
#   :Number of Attributes: First 10 columns are numeric predictive values
#
#   :Target: Column 11 is a quantitative measure of disease progression one year after baseline
#
#   :Attribute Information:
#       - age     age in years
#       - sex
#       - bmi     body mass index
#       - bp      average blood pressure
#       - s1      tc, T-Cells (a type of white blood cells)
#       - s2      ldl, low-density lipoproteins
#       - s3      hdl, high-density lipoproteins
#       - s4      tch, thyroid stimulating hormone
#       - s5      ltg, lamotrigine
# ...

# %%
df_diabetes = diabetes.frame
df_diabetes.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6  target
# 0 -0.002592  0.019908 -0.017646   151.0
# 1 -0.039493 -0.068330 -0.092204    75.0
# 2 -0.002592  0.002864 -0.025930   141.0
# 3  0.034309  0.022692 -0.009362   206.0
# 4 -0.002592 -0.031991 -0.046641   135.0

# %%
df_diabetes.tail()
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017282 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081414  0.083740  0.027809  0.173816
#
#            s4        s5        s6  target
# 437 -0.002592  0.031193  0.007207   178.0
# 438  0.034309 -0.018118  0.044485   104.0
# 439 -0.011080 -0.046879  0.015491   132.0
# 440  0.026560  0.044528 -0.025930   220.0
# 441 -0.039493 -0.004220  0.003064    57.0

# %%
df_diabetes.dtypes
# Out:
# age       float64
# sex       float64
# bmi       float64
# bp        float64
# s1        float64
# s2        float64
# s3        float64
# s4        float64
# s5        float64
# s6        float64
# target    float64
# dtype: object

# %%
df_diabetes.columns
# Out:
# Index(['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6',
#        'target'],
#       dtype='object')

# %%
df_diabetes.index
# Out:
# RangeIndex(start=0, stop=442, step=1)

# %%
df_diabetes.axes
# Out:
# [RangeIndex(start=0, stop=442, step=1),
#  Index(['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6',
#         'target'],
#        dtype='object')]

# %%
df_diabetes.count()
# Out:
# age       442
# sex       442
# bmi       442
# bp        442
# s1        442
# s2        442
# s3        442
# s4        442
# s5        442
# s6        442
# target    442
# dtype: int64

# %%
df_diabetes.mean()
# Out:
# age      -3.634285e-16
# sex       1.308343e-16
# bmi      -8.045349e-16
# bp        1.281655e-16
# s1       -8.835316e-17
# s2        1.327024e-16
# s3       -4.574646e-16
# s4        3.777301e-16
# s5       -3.830854e-16
# s6       -3.412882e-16
# target    1.521335e+02
# dtype: float64

# %%
df_diabetes.median()
# Out:
# age         0.005383
# sex        -0.044642
# bmi        -0.007284
# bp         -0.005671
# s1         -0.004321
# s2         -0.003819
# s3         -0.006584
# s4         -0.002592
# s5         -0.001948
# s6         -0.001078
# target    140.500000
# dtype: float64

# %%
df_diabetes.std()
# Out:
# age        0.047619
# sex        0.047619
# bmi        0.047619
# bp         0.047619
# s1         0.047619
# s2         0.047619
# s3         0.047619
# s4         0.047619
# s5         0.047619
# s6         0.047619
# target    77.093005
# dtype: float64

# %%
df_diabetes.min()
# Out:
# age       -0.107226
# sex       -0.044642
# bmi       -0.090275
# bp        -0.112400
# s1        -0.126781
# s2        -0.115613
# s3        -0.102307
# s4        -0.076395
# s5        -0.126097
# s6        -0.137767
# target    25.000000
# dtype: float64

# %%
df_diabetes.max()
# Out:
# age         0.110727
# sex         0.050680
# bmi         0.170555
# bp          0.132044
# s1          0.153914
# s2          0.198788
# s3          0.181179
# s4          0.185234
# s5          0.133599
# s6          0.135612
# target    346.000000
# dtype: float64

# %%
df_diabetes.sample(5)
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 385  0.023546  0.050680 -0.019140  0.049415 -0.063487 -0.061125  0.004460
# 55  -0.041840 -0.044642 -0.049318 -0.036656 -0.007073 -0.022608  0.085456
# 228 -0.052738 -0.044642 -0.012673 -0.060757 -0.000193  0.008081  0.011824
# 67   0.041708  0.050680 -0.014828 -0.017147 -0.005697  0.008394 -0.013948
# 196 -0.023677 -0.044642 -0.046085 -0.033214  0.032830  0.036264  0.037595
#
#            s4        s5        s6  target
# 385 -0.039493 -0.025952 -0.013504   219.0
# 55  -0.039493 -0.066488  0.007207   128.0
# 228 -0.002592 -0.027129 -0.050783   160.0
# 67  -0.001854 -0.011901  0.003064    97.0
# 196 -0.002592 -0.033249  0.011349    72.0

# %%
df_diabetes['age'].head()
# Out:
# 0    0.038076
# 1   -0.001882
# 2    0.085299
# 3   -0.089063
# 4    0.005383
# Name: age, dtype: float64

# %%
df_diabetes.age.head()
# Out:
# 0    0.038076
# 1   -0.001882
# 2    0.085299
# 3   -0.089063
# 4    0.005383
# Name: age, dtype: float64

# %%
df_diabetes.describe()
# Out:
#                 age           sex           bmi            bp            s1  \
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean  -3.634285e-16  1.308343e-16 -8.045349e-16  1.281655e-16 -8.835316e-17
# std    4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02
# min   -1.072256e-01 -4.464164e-02 -9.027530e-02 -1.123996e-01 -1.267807e-01
# 25%   -3.729927e-02 -4.464164e-02 -3.422907e-02 -3.665645e-02 -3.424784e-02
# 50%    5.383060e-03 -4.464164e-02 -7.283766e-03 -5.670611e-03 -4.320866e-03
# 75%    3.807591e-02  5.068012e-02  3.124802e-02  3.564384e-02  2.835801e-02
# max    1.107267e-01  5.068012e-02  1.705552e-01  1.320442e-01  1.539137e-01
#
#                  s2            s3            s4            s5            s6  \
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean   1.327024e-16 -4.574646e-16  3.777301e-16 -3.830854e-16 -3.412882e-16
# ...

# %%
import matplotlib.pyplot as plt
df_diabetes.hist(bins=20, figsize=(20,15))
plt.show()

# %%
df_diabetes.corr().round(2)
# Out:
#          age   sex   bmi    bp    s1    s2    s3    s4    s5    s6  target
# age     1.00  0.17  0.19  0.34  0.26  0.22 -0.08  0.20  0.27  0.30    0.19
# sex     0.17  1.00  0.09  0.24  0.04  0.14 -0.38  0.33  0.15  0.21    0.04
# bmi     0.19  0.09  1.00  0.40  0.25  0.26 -0.37  0.41  0.45  0.39    0.59
# bp      0.34  0.24  0.40  1.00  0.24  0.19 -0.18  0.26  0.39  0.39    0.44
# s1      0.26  0.04  0.25  0.24  1.00  0.90  0.05  0.54  0.52  0.33    0.21
# s2      0.22  0.14  0.26  0.19  0.90  1.00 -0.20  0.66  0.32  0.29    0.17
# s3     -0.08 -0.38 -0.37 -0.18  0.05 -0.20  1.00 -0.74 -0.40 -0.27   -0.39
# s4      0.20  0.33  0.41  0.26  0.54  0.66 -0.74  1.00  0.62  0.42    0.43
# s5      0.27  0.15  0.45  0.39  0.52  0.32 -0.40  0.62  1.00  0.46    0.57
# s6      0.30  0.21  0.39  0.39  0.33  0.29 -0.27  0.42  0.46  1.00    0.38
# target  0.19  0.04  0.59  0.44  0.21  0.17 -0.39  0.43  0.57  0.38    1.00

# %%
df_diabetes.assign(bmi_exp2 = np.square(df_diabetes['bmi'])).head(5)
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6  target  bmi_exp2
# 0 -0.002592  0.019908 -0.017646   151.0  0.003806
# 1 -0.039493 -0.068330 -0.092204    75.0  0.002650
# 2 -0.002592  0.002864 -0.025930   141.0  0.001976
# 3  0.034309  0.022692 -0.009362   206.0  0.000134
# 4 -0.002592 -0.031991 -0.046641   135.0  0.001324
