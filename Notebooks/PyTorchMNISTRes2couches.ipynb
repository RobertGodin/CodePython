# %%
# %matplotlib inline
# -*- coding: utf-8 -*-
"""
Exemple simple de MNIST avec PyTorch
Exemple ResBlock
"""
import torch
torch.manual_seed(0) # Pour résultats reproductibles

# Fonction J d'entropie croisée
import torch.nn.functional as F
fonction_cout = F.cross_entropy

def taux_bonnes_predictions(lot_Y_predictions, lot_Y):
    predictions_categorie = torch.argmax(lot_Y_predictions, dim=1)
    return (predictions_categorie == lot_Y).float().mean()

from torch import nn
# Définition de l'architecture du RNA

class ResBlock(nn.Module):
  def __init__(self, nb_f):
    super().__init__()
    
    self.conv1 = nn.Conv2d(nb_f, nb_f, kernel_size=3, stride=1, padding=1, bias=False) 
    self.bn1 = nn.BatchNorm2d(nb_f)    
    self.relu = nn.ReLU(inplace=True)
    self.conv2 = nn.Conv2d(nb_f, nb_f, kernel_size=3, stride=1, padding=1, bias=False)
    self.bn2 = nn.BatchNorm2d(nb_f)    

  def forward(self, lot_X):
    lot_Y_predictions = self.conv1(lot_X)
    lot_Y_predictions = self.bn1(lot_Y_predictions)
    lot_Y_predictions = self.relu(lot_Y_predictions)
    lot_Y_predictions = self.conv2(lot_Y_predictions)
    lot_Y_predictions = self.bn2(lot_Y_predictions)
    lot_Y_predictions = lot_Y_predictions + lot_X
    lot_Y_predictions = self.relu(lot_Y_predictions)
    return lot_Y_predictions 

modele = nn.Sequential(
    nn.Conv2d(1,16,3),
    nn.BatchNorm2d(16),
    nn.ReLU(),
    ResBlock(16),    
    nn.Conv2d(16,8,3),
    nn.BatchNorm2d(8),
    nn.ReLU(),
    ResBlock(8),
    nn.Flatten(),
    nn.Linear(24*24*8,10)
)

from torch import optim
optimiseur = optim.SGD(modele.parameters(), lr=0.01)

# Chargement des données de MNIST
import pickle, gzip
fichier_donnees = gzip.open(r"mnist.pkl.gz", 'rb')
((donnees_ent_X, donnees_ent_Y),(donnees_valid_X, donnees_valid_Y),(donnees_test_X,donnees_test_Y)) = pickle.load(fichier_donnees, encoding="latin-1")
fichier_donnees.close()

# Conversion des données en type toch.Tensor
import torch
donnees_ent_X,donnees_ent_Y,donnees_valid_X,donnees_valid_Y,donnees_test_X,donnees_test_Y  = map(torch.tensor,
    (donnees_ent_X.reshape((-1,1,28,28)),donnees_ent_Y,donnees_valid_X.reshape((-1,1,28,28)),donnees_valid_Y,donnees_test_X.reshape((-1,1,28,28)),donnees_test_Y))

# Création des objets DataLoader pour itérer par lot
from torch.utils.data import TensorDataset
from torch.utils.data import DataLoader
ds_ent = TensorDataset(donnees_ent_X, donnees_ent_Y)
dl_ent = DataLoader(ds_ent, batch_size=100, shuffle=True)
ds_valid = TensorDataset(donnees_valid_X,donnees_valid_Y)
dl_valid = DataLoader(ds_valid, batch_size=100)

def entrainer(modele, dl_ent, dl_valid, optimiseur, nb_epochs=10):

    # Listes pour les métriques par epoch
    liste_cout_moyen_ent = []
    liste_taux_moyen_ent = []
    liste_cout_moyen_valid = []
    liste_taux_moyen_valid = []
    
    # Boucle d'apprentissage
    for epoch in range(nb_epochs):
        cout_total_ent = 0 # pour cumuler les couts par mini-lot
        taux_bonnes_predictions_ent = 0 # pour cumuler les taux par mini-lot
        modele.train() # Pour certains types de couches (nn.BatchNorm2d, nn.Dropout, ...)
        
        # Boucle d'apprentissage par mini-lot pour une epoch
        for lot_X, lot_Y in dl_ent:
            optimiseur.zero_grad() # Remettre les dérivées à zéro
            lot_Y_predictions = modele(lot_X) # Appel de la méthode forward
            cout = fonction_cout(lot_Y_predictions, lot_Y)
            cout.backward() # Calcul des gradiants par rétropropagation
            with torch.no_grad():
                cout_total_ent +=cout
                taux_bonnes_predictions_ent += taux_bonnes_predictions(lot_Y_predictions, lot_Y)
            optimiseur.step() # Mise à jour des paramètres
        # Calculer les moyennes par mini-lot
        with torch.no_grad():
            cout_moyen_ent = cout_total_ent/len(dl_ent)
            taux_moyen_ent = taux_bonnes_predictions_ent/len(dl_ent)
       
        modele.eval() # Pour certains types de couches (nn.BatchNorm2d, nn.Dropout, ...)
        with torch.no_grad():
            cout_valid = sum(fonction_cout(modele(lot_valid_X), lot_valid_Y) for lot_valid_X, lot_valid_Y in dl_valid)
            taux_bons_valid = sum(taux_bonnes_predictions(modele(lot_valid_X), lot_valid_Y) for lot_valid_X, lot_valid_Y in dl_valid)
        cout_moyen_valid = cout_valid/len(dl_valid)
        taux_moyen_valid = taux_bons_valid/len(dl_valid)
        print(f'-------- > epoch {epoch+1}:  coût moyen entraînement = {cout_moyen_ent}')
        print(f'-------- > epoch {epoch+1}:  taux moyen entraînement = {taux_moyen_ent}')
        print(f'-------- > epoch {epoch+1}:  coût moyen validation = {cout_moyen_valid}')
        print(f'-------- > epoch {epoch+1}:  taux moyen validation = {taux_moyen_valid}')
    
        liste_cout_moyen_ent.append(cout_moyen_ent)
        liste_taux_moyen_ent.append(taux_moyen_ent)
        liste_cout_moyen_valid.append(cout_moyen_valid)
        liste_taux_moyen_valid.append(taux_moyen_valid)
    
    # Affichage du graphique d'évolution des métriques par epoch
    import numpy as np
    import matplotlib.pyplot as plt
    plt.plot(np.arange(0,nb_epochs),liste_cout_moyen_ent,label='Erreur entraînement')
    plt.plot(np.arange(0,nb_epochs),liste_cout_moyen_valid,label='Erreur validation')
    plt.title("Evolution du coût")
    plt.xlabel('epoch')
    plt.ylabel('moyenne par observation')
    plt.legend(loc='upper center')
    plt.show()
        
    plt.plot(np.arange(0,nb_epochs),liste_taux_moyen_ent,label='Taux bonnes réponses entraînement')
    plt.plot(np.arange(0,nb_epochs),liste_taux_moyen_valid,label='Taux bonnes réponses validation')
    plt.title("Evolution du taux")
    plt.xlabel('epoch')
    plt.ylabel('moyenne par observation')
    plt.legend(loc='upper center')
    plt.show()

entrainer(modele, dl_ent, dl_valid, optimiseur, nb_epochs=30)
# Out:
# -------- > epoch 1:  coût moyen entraînement = 0.1809774488210678
# -------- > epoch 1:  taux moyen entraînement = 0.9464006423950195
# -------- > epoch 1:  coût moyen validation = 0.07688676565885544
# -------- > epoch 1:  taux moyen validation = 0.977500319480896
# -------- > epoch 2:  coût moyen entraînement = 0.06332305818796158
# -------- > epoch 2:  taux moyen entraînement = 0.9809406995773315
# -------- > epoch 2:  coût moyen validation = 0.05825914442539215
# -------- > epoch 2:  taux moyen validation = 0.9846001267433167
# -------- > epoch 3:  coût moyen entraînement = 0.047482799738645554
# -------- > epoch 3:  taux moyen entraînement = 0.985120415687561
# -------- > epoch 3:  coût moyen validation = 0.04889915883541107
# -------- > epoch 3:  taux moyen validation = 0.9870998859405518
# -------- > epoch 4:  coût moyen entraînement = 0.038602981716394424
# -------- > epoch 4:  taux moyen entraînement = 0.9886793494224548
# -------- > epoch 4:  coût moyen validation = 0.05409383401274681
# -------- > epoch 4:  taux moyen validation = 0.9862001538276672
# -------- > epoch 5:  coût moyen entraînement = 0.03364505246281624
# -------- > epoch 5:  taux moyen entraînement = 0.9901599287986755
# -------- > epoch 5:  coût moyen validation = 0.049162015318870544
# -------- > epoch 5:  taux moyen validation = 0.986400306224823
# -------- > epoch 6:  coût moyen entraînement = 0.02931172400712967
# -------- > epoch 6:  taux moyen entraînement = 0.9907395839691162
# -------- > epoch 6:  coût moyen validation = 0.04388048127293587
# -------- > epoch 6:  taux moyen validation = 0.9871000051498413
# -------- > epoch 7:  coût moyen entraînement = 0.02567770518362522
# -------- > epoch 7:  taux moyen entraînement = 0.9924594163894653
# -------- > epoch 7:  coût moyen validation = 0.04467783495783806
# -------- > epoch 7:  taux moyen validation = 0.9879999756813049
# -------- > epoch 8:  coût moyen entraînement = 0.022965067997574806
# -------- > epoch 8:  taux moyen entraînement = 0.9934991002082825
# -------- > epoch 8:  coût moyen validation = 0.05052775889635086
# -------- > epoch 8:  taux moyen validation = 0.9865001440048218
# -------- > epoch 9:  coût moyen entraînement = 0.020231014117598534
# -------- > epoch 9:  taux moyen entraînement = 0.9943193793296814
# -------- > epoch 9:  coût moyen validation = 0.04876212775707245
# -------- > epoch 9:  taux moyen validation = 0.986599862575531
# -------- > epoch 10:  coût moyen entraînement = 0.01821000687777996
# -------- > epoch 10:  taux moyen entraînement = 0.9945395588874817
# -------- > epoch 10:  coût moyen validation = 0.04327581077814102
# -------- > epoch 10:  taux moyen validation = 0.9878000617027283
# -------- > epoch 11:  coût moyen entraînement = 0.016611753031611443
# -------- > epoch 11:  taux moyen entraînement = 0.995219349861145
# -------- > epoch 11:  coût moyen validation = 0.04883359745144844
# -------- > epoch 11:  taux moyen validation = 0.9868999719619751
# -------- > epoch 12:  coût moyen entraînement = 0.01460768561810255
# -------- > epoch 12:  taux moyen entraînement = 0.9962192177772522
# -------- > epoch 12:  coût moyen validation = 0.04198445379734039
# -------- > epoch 12:  taux moyen validation = 0.9887000322341919
# -------- > epoch 13:  coût moyen entraînement = 0.013175228610634804
# -------- > epoch 13:  taux moyen entraînement = 0.9965395927429199
# -------- > epoch 13:  coût moyen validation = 0.04421733692288399
# -------- > epoch 13:  taux moyen validation = 0.9886000752449036
# -------- > epoch 14:  coût moyen entraînement = 0.011919483542442322
# -------- > epoch 14:  taux moyen entraînement = 0.9969392418861389
# -------- > epoch 14:  coût moyen validation = 0.042673490941524506
# -------- > epoch 14:  taux moyen validation = 0.9886999726295471
# -------- > epoch 15:  coût moyen entraînement = 0.010982741601765156
# -------- > epoch 15:  taux moyen entraînement = 0.9974195957183838
# -------- > epoch 15:  coût moyen validation = 0.04060174897313118
# -------- > epoch 15:  taux moyen validation = 0.9894000291824341
# -------- > epoch 16:  coût moyen entraînement = 0.009852364659309387
# -------- > epoch 16:  taux moyen entraînement = 0.9980794191360474
# -------- > epoch 16:  coût moyen validation = 0.04462764412164688
# -------- > epoch 16:  taux moyen validation = 0.9881999492645264
# -------- > epoch 17:  coût moyen entraînement = 0.008988550864160061
# -------- > epoch 17:  taux moyen entraînement = 0.9982395172119141
# -------- > epoch 17:  coût moyen validation = 0.0789143294095993
# -------- > epoch 17:  taux moyen validation = 0.9802002906799316
# -------- > epoch 18:  coût moyen entraînement = 0.00801559817045927
# -------- > epoch 18:  taux moyen entraînement = 0.9985796213150024
# -------- > epoch 18:  coût moyen validation = 0.04383542388677597
# -------- > epoch 18:  taux moyen validation = 0.988800048828125
# -------- > epoch 19:  coût moyen entraînement = 0.007418870460242033
# -------- > epoch 19:  taux moyen entraînement = 0.9988394379615784
# -------- > epoch 19:  coût moyen validation = 0.04203084483742714
# -------- > epoch 19:  taux moyen validation = 0.9895000457763672
# -------- > epoch 20:  coût moyen entraînement = 0.006861111149191856
# -------- > epoch 20:  taux moyen entraînement = 0.9987996220588684
# -------- > epoch 20:  coût moyen validation = 0.04174244776368141
# -------- > epoch 20:  taux moyen validation = 0.9894000887870789
# -------- > epoch 21:  coût moyen entraînement = 0.0065917340107262135
# -------- > epoch 21:  taux moyen entraînement = 0.9988595843315125
# -------- > epoch 21:  coût moyen validation = 0.04266248643398285
# -------- > epoch 21:  taux moyen validation = 0.989300012588501
# -------- > epoch 22:  coût moyen entraînement = 0.005595956463366747
# -------- > epoch 22:  taux moyen entraînement = 0.9991196990013123
# -------- > epoch 22:  coût moyen validation = 0.047229837626218796
# -------- > epoch 22:  taux moyen validation = 0.988599956035614
# -------- > epoch 23:  coût moyen entraînement = 0.005104852840304375
# -------- > epoch 23:  taux moyen entraînement = 0.9995397925376892
# -------- > epoch 23:  coût moyen validation = 0.042445968836545944
# -------- > epoch 23:  taux moyen validation = 0.9891998767852783
# -------- > epoch 24:  coût moyen entraînement = 0.005235358141362667
# -------- > epoch 24:  taux moyen entraînement = 0.999339759349823
# -------- > epoch 24:  coût moyen validation = 0.040662191808223724
# -------- > epoch 24:  taux moyen validation = 0.9900999665260315
# -------- > epoch 25:  coût moyen entraînement = 0.004456859081983566
# -------- > epoch 25:  taux moyen entraînement = 0.9995197653770447
# -------- > epoch 25:  coût moyen validation = 0.041516900062561035
# -------- > epoch 25:  taux moyen validation = 0.9898999929428101
# -------- > epoch 26:  coût moyen entraînement = 0.0039472817443311214
# -------- > epoch 26:  taux moyen entraînement = 0.9997398853302002
# -------- > epoch 26:  coût moyen validation = 0.043140314519405365
# -------- > epoch 26:  taux moyen validation = 0.9893999695777893
# -------- > epoch 27:  coût moyen entraînement = 0.0036290420684963465
# -------- > epoch 27:  taux moyen entraînement = 0.9997599124908447
# -------- > epoch 27:  coût moyen validation = 0.041708312928676605
# -------- > epoch 27:  taux moyen validation = 0.9898998737335205
# -------- > epoch 28:  coût moyen entraînement = 0.0034329977352172136
# -------- > epoch 28:  taux moyen entraînement = 0.999799907207489
# -------- > epoch 28:  coût moyen validation = 0.04453793540596962
# -------- > epoch 28:  taux moyen validation = 0.9893999695777893
# -------- > epoch 29:  coût moyen entraînement = 0.0031242782715708017
# -------- > epoch 29:  taux moyen entraînement = 0.9998199343681335
# -------- > epoch 29:  coût moyen validation = 0.04464074224233627
# -------- > epoch 29:  taux moyen validation = 0.9897000789642334
# -------- > epoch 30:  coût moyen entraînement = 0.0029535668436437845
# -------- > epoch 30:  taux moyen entraînement = 0.9998999238014221
# -------- > epoch 30:  coût moyen validation = 0.042719241231679916
# -------- > epoch 30:  taux moyen validation = 0.9900000095367432
