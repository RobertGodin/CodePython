# %%
# %matplotlib inline
# -*- coding: utf-8 -*-
"""
Exemple de réseau de neuronne à propagation avant et rétropropagation de l'erreur pour l'apprentissage
Application aux données Iris
"""

import random
import numpy as np
np.random.seed(42) # pour reproduire les mêmes résultats
random.seed(42)
import matplotlib.pyplot as plt

def sigmoide(z):
    """Fonction sigmoide"""
    return 1.0/(1.0+np.exp(-z))

def derivee_sigmoide(z):
    """Dérivée de la fonction sigmoide"""
    return sigmoide(z)*(1-sigmoide(z))

def dJ_dz_final(activation_finale, y):
    """Dérivée de J par rapport à z pour la couche finale"""
    return (activation_finale-y)

class RNA(object):
    """ Un RNA est un réseau de neuronnes artificiel multi-couche.
    """
        
    def __init__(self, liste_nc):
        """ liste_nc[c] contient le nombre de neurones de la couche c, c = 0 ...nombre_couches-1
        la couche d'indice 0 est la couche d'entrée
        liste_nc[nombre_couches-1] doit correspondre au nombre de catégories des y (sortie)
        
        w[c] est la matrice des poids entre la couche c et c+1 (NB différent du livre à cause de l'indice 0)
        w[c][i,j] est le poids entre le neuronne i de la couche c+1 et j de la couche c
        i = 0 correspond au biais par convention
        les poids sont initialisés avec un nombre aléatoire selon une distribution N(0,1)
        """
        self.liste_nc = liste_nc
        self.nombre_couches = len(liste_nc)
        # Initialiser les matrices des poids w avec des valeurs aleatoires N(0,1)
        # NB w[c] correspond a la couche c+1
        self.w = [np.random.randn(x+1,y) for x, y in zip(liste_nc[:-1], liste_nc[1:])]

    def propagation_avant_w(self, activation):
        """
        Traiter une entrée par propagation avant
        
        activation: activation initiale qui correspond aux entrées (taille self.liste_nc[0])
        retourne l'activation de sortie après propagation avant"""
        
        for un_w in self.w:
            activation = np.vstack((np.ones(1),sigmoide(np.dot(un_w.transpose(),activation))))
        return activation

    def entrainer_par_mini_lot(self,donnees_entrainement,donnees_test,nombre_epochs,taille_mini_lot,eta):
        """
        Entrainer le RNA par mini-lots
        Affiche le nombre de bons résultats des donnees_test pour chaque epoch
        
        donnees_entrainement : liste de tuples (x,y) pour l'entrainement où
            x est un tableau de taille (liste_nc[0],1) où n est la taille des entrées
            y est un encodage bitmap de la catégorie en tableau de taille liste_nc[nombre_couches-1]
        donnees_test : liste de tuples (x,y) pour les tests
            x est un tableau de taille (liste_nc[0],1) où n est la taille des entrées
            y un int où 0<=y< nombre de catégories
        nombre_epochs : nombre de passe d'entrainement
        taille_mini_lot : la taille de chacun des mini-lots
        eta : vitesse d'apprentissage
        """
        n_test = len(donnees_test)
        n_ent = len(donnees_entrainement)
        self.liste_eqm_ent = []
        self.liste_ok_ent = []
        self.liste_eqm_test = []
        self.liste_ok_test = []
        
        for j in range(nombre_epochs):
            random.shuffle(donnees_entrainement)
            mini_lots = [donnees_entrainement[k:k+taille_mini_lot] for k in range(0, n_ent, taille_mini_lot)]
            # Entrainer un mimi-lot à la fois
            for mini_lot in mini_lots:
                # Initialiser les gradiants totaux à 0
                liste_dJ_dw = [np.zeros(w.shape) for w in self.w]
                for x, y in mini_lot:
                    dJ_dw_une_ligne = self.retropropagation_w(x, y)
                    # ajouter les gradiants d'une observation aux totaux partiels du lot
                    liste_dJ_dw = [dJ_dw+dJ_dw_1 for (dJ_dw, dJ_dw_1) in zip(liste_dJ_dw, dJ_dw_une_ligne)]
                # mettre à jour les paramètres du RNA avec les gradiants du lot    
                self.w = [w-(eta/len(mini_lot))*dw  for (w, dw) in zip(self.w, liste_dJ_dw)]
            
             # Calcul des métriques de performance
            eqm_ent,ok_ent = self.metriques(donnees_entrainement)
            eqm_test,ok_test = self.metriques(donnees_test)
            self.liste_eqm_ent.append(eqm_ent/n_ent)
            self.liste_ok_ent.append(ok_ent/n_ent)
            self.liste_eqm_test.append(eqm_test/n_test)
            self.liste_ok_test.append(ok_test/n_test)
            print("Epoch {0}: EQM entrainement: {1} Taux correct: {2}".format(j, eqm_ent/n_ent,ok_ent/n_ent))
            print("Epoch {0}: EQM test: {1} Taux correct: {2}".format(j, eqm_test/n_test,ok_test/n_test))

        # Affichage des graphiques d'évolution des performances par epoch
        plt.plot(np.arange(0,nombre_epochs),self.liste_eqm_ent,label='Eqm entraînement')
        plt.plot(np.arange(0,nombre_epochs),self.liste_eqm_test,label='Eqm test')
        plt.title("Erreur quadratique moyenne")
        plt.xlabel('epoch')
        plt.ylabel('erreur')
        plt.legend(loc='upper center')
        plt.show()

        plt.plot(np.arange(0,nombre_epochs),self.liste_ok_ent,label='Nb correct entraînement')
        plt.plot(np.arange(0,nombre_epochs),self.liste_ok_test,label='Nb correct test')
        plt.title("Taux de bonnes réponses")
        plt.xlabel('epoch')
        plt.ylabel('nb correct')
        plt.legend(loc='upper center')
        plt.show()
    
    def retropropagation_w(self, x, y):
        """Return a tuple ``(dJ_db, dJ_dw)`` representing the
        gradient for the cost function C_x.  ``dJ_db`` and
        ``dJ_dw`` are layer-by-layer lists of numpy arrays, similar
        to ``self.liste_biais`` and ``self.w``."""

        # propagation_avant avec stockage des activations pour la rétropropagation
        activation = np.vstack((np.ones(1),x)) # activation de la couche 0
        activation_par_couche = [np.vstack((np.ones(1),x))] # liste des activations couche par couche
        z_par_couche = [] # liste des z par couche
        for c in range(self.nombre_couches-1): # NB c part a 0
            z = np.dot(self.w[c].transpose(),activation)
            z_par_couche.append(z)
            activation = np.vstack((np.ones(1),sigmoide(z))) 
            activation_par_couche.append(activation)
            
        # retropropagation
        dJ_dw = [np.zeros(un_w.shape) for un_w in self.w]
        dJ_dz = dJ_dz_final(activation_par_couche[self.nombre_couches-1][1:], y)
        dJ_dw[self.nombre_couches-2] = np.dot(activation_par_couche[self.nombre_couches-2],dJ_dz.transpose())
        # itérer de la couche nc-2 à la couche 1
        for c in range(self.nombre_couches-2,0,-1):
            z = z_par_couche[c-1] # NB z_par_couche[c-1] correspond à z de la couche c
            dJ_dz = np.dot(self.w[c][1:], dJ_dz) * derivee_sigmoide(z) # dérivée pour zi pour la couche c
            dJ_dw[c-1] = np.dot(activation_par_couche[c-1], dJ_dz.transpose())
        return dJ_dw
    
    def metriques(self, donnees):
        """Retourne le nombre de bons résultats
        Choisit l'indice de la classe dont l'activation est la plus grande"""
        erreur_quadratique = 0
        nb_correct = 0
        for (x,y) in donnees:
            resultat_propagation = self.propagation_avant_w(np.vstack((np.ones(1),x)))[1:]
            erreur_quadratique += sum((resultat_propagation-y)**2)
            classe_predite = np.argmax(resultat_propagation)
            if y[classe_predite] == 1:
                nb_correct+=1
        return (erreur_quadratique,nb_correct)



# Charger les données de Iris
from sklearn import datasets
iris = datasets.load_iris()
iris_X = iris.data[:,:2] # les deux colonnes longueur et largeur de sépale
iris_y = iris.target
iris_y_setosa = (iris_y==0).astype(np.int) # setosa ou non

def diviser_ent_test(donnees, proportion):
    """ Diviser aléatoirement les données en deux groupes, entrainement et test
    proportion : proportion des données de test"""
    random.shuffle(donnees)
    taille_test = int(len(donnees) * proportion)
    return donnees[:taille_test],donnees[taille_test:]

def bitmap2(classe):
    """ Representer l'entier de classe par un vecteur bitmap (10,1) 
    classe : entier entre 0 et 9 qui représente la classe de l'observation"""
    e = np.zeros((2, 1))
    e[classe] = 1.0
    return e
    
donnees=[(np.reshape(iris_X[i], (2, 1)),bitmap2(iris_y_setosa[i])) for i in range(len(iris_X))]
donnees_test,donnees_ent=diviser_ent_test(donnees, 0.5)

un_rna = RNA([2,5,2])
un_rna.entrainer_par_mini_lot(donnees_ent,donnees_test,100,10,0.1)
# Out:
# Epoch 0: EQM entrainement: [0.52438064] Taux correct: 0.44
# Epoch 0: EQM test: [0.54945603] Taux correct: 0.36
# Epoch 1: EQM entrainement: [0.40491429] Taux correct: 0.6266666666666667
# Epoch 1: EQM test: [0.38577679] Taux correct: 0.7066666666666667
# Epoch 2: EQM entrainement: [0.37208344] Taux correct: 0.7333333333333333
# Epoch 2: EQM test: [0.35789225] Taux correct: 0.76
# Epoch 3: EQM entrainement: [0.35432015] Taux correct: 0.6266666666666667
# Epoch 3: EQM test: [0.32748624] Taux correct: 0.7066666666666667
# Epoch 4: EQM entrainement: [0.3426639] Taux correct: 0.6266666666666667
# Epoch 4: EQM test: [0.31526511] Taux correct: 0.7066666666666667
# Epoch 5: EQM entrainement: [0.33685096] Taux correct: 0.8933333333333333
# Epoch 5: EQM test: [0.32531143] Taux correct: 0.8666666666666667
# Epoch 6: EQM entrainement: [0.32589667] Taux correct: 0.64
# Epoch 6: EQM test: [0.29773651] Taux correct: 0.72
# Epoch 7: EQM entrainement: [0.30965062] Taux correct: 0.7066666666666667
# Epoch 7: EQM test: [0.28675538] Taux correct: 0.72
# Epoch 8: EQM entrainement: [0.2969804] Taux correct: 0.8666666666666667
# Epoch 8: EQM test: [0.28174338] Taux correct: 0.84
# Epoch 9: EQM entrainement: [0.28745009] Taux correct: 0.7866666666666666
# Epoch 9: EQM test: [0.26824868] Taux correct: 0.7866666666666666
# Epoch 10: EQM entrainement: [0.27981079] Taux correct: 0.7466666666666667
# Epoch 10: EQM test: [0.25944846] Taux correct: 0.7866666666666666
# Epoch 11: EQM entrainement: [0.26473045] Taux correct: 0.8933333333333333
# Epoch 11: EQM test: [0.24954878] Taux correct: 0.8533333333333334
# Epoch 12: EQM entrainement: [0.2728255] Taux correct: 0.7466666666666667
# Epoch 12: EQM test: [0.24956359] Taux correct: 0.7466666666666667
# Epoch 13: EQM entrainement: [0.25113825] Taux correct: 1.0
# Epoch 13: EQM test: [0.24743279] Taux correct: 0.9733333333333334
# Epoch 14: EQM entrainement: [0.23327189] Taux correct: 0.9066666666666666
# Epoch 14: EQM test: [0.22244009] Taux correct: 0.9066666666666666
# Epoch 15: EQM entrainement: [0.2404602] Taux correct: 0.8133333333333334
# Epoch 15: EQM test: [0.22385899] Taux correct: 0.8
# Epoch 16: EQM entrainement: [0.22164851] Taux correct: 0.8933333333333333
# Epoch 16: EQM test: [0.20925763] Taux correct: 0.8933333333333333
# Epoch 17: EQM entrainement: [0.22510651] Taux correct: 1.0
# Epoch 17: EQM test: [0.23082834] Taux correct: 0.9733333333333334
# Epoch 18: EQM entrainement: [0.20687953] Taux correct: 0.8933333333333333
# Epoch 18: EQM test: [0.19712473] Taux correct: 0.8933333333333333
# Epoch 19: EQM entrainement: [0.18588106] Taux correct: 1.0
# Epoch 19: EQM test: [0.18463793] Taux correct: 0.9733333333333334
# Epoch 20: EQM entrainement: [0.17613407] Taux correct: 0.9866666666666667
# Epoch 20: EQM test: [0.17446932] Taux correct: 0.9733333333333334
# Epoch 21: EQM entrainement: [0.18355934] Taux correct: 0.92
# Epoch 21: EQM test: [0.1776004] Taux correct: 0.9066666666666666
# Epoch 22: EQM entrainement: [0.17934162] Taux correct: 0.9066666666666666
# Epoch 22: EQM test: [0.1739768] Taux correct: 0.9066666666666666
# Epoch 23: EQM entrainement: [0.1538205] Taux correct: 0.9866666666666667
# Epoch 23: EQM test: [0.15448048] Taux correct: 0.9733333333333334
# Epoch 24: EQM entrainement: [0.14696879] Taux correct: 0.9866666666666667
# Epoch 24: EQM test: [0.14859546] Taux correct: 0.9733333333333334
# Epoch 25: EQM entrainement: [0.15172146] Taux correct: 0.9466666666666667
# Epoch 25: EQM test: [0.15161421] Taux correct: 0.9333333333333333
# Epoch 26: EQM entrainement: [0.14662146] Taux correct: 0.9466666666666667
# Epoch 26: EQM test: [0.14711156] Taux correct: 0.9333333333333333
# Epoch 27: EQM entrainement: [0.1276592] Taux correct: 1.0
# Epoch 27: EQM test: [0.1318142] Taux correct: 0.9733333333333334
# Epoch 28: EQM entrainement: [0.12051877] Taux correct: 1.0
# Epoch 28: EQM test: [0.12608156] Taux correct: 0.9733333333333334
# Epoch 29: EQM entrainement: [0.11433482] Taux correct: 1.0
# Epoch 29: EQM test: [0.12116981] Taux correct: 0.9866666666666667
# Epoch 30: EQM entrainement: [0.11084703] Taux correct: 1.0
# Epoch 30: EQM test: [0.11752699] Taux correct: 0.9733333333333334
# Epoch 31: EQM entrainement: [0.10373011] Taux correct: 1.0
# Epoch 31: EQM test: [0.1122001] Taux correct: 0.9866666666666667
# Epoch 32: EQM entrainement: [0.14484739] Taux correct: 0.96
# Epoch 32: EQM test: [0.16187327] Taux correct: 0.9333333333333333
# Epoch 33: EQM entrainement: [0.10042494] Taux correct: 1.0
# Epoch 33: EQM test: [0.10883744] Taux correct: 0.9733333333333334
# Epoch 34: EQM entrainement: [0.09429766] Taux correct: 1.0
# Epoch 34: EQM test: [0.10579364] Taux correct: 0.9866666666666667
# Epoch 35: EQM entrainement: [0.09227771] Taux correct: 1.0
# Epoch 35: EQM test: [0.10198282] Taux correct: 0.9733333333333334
# Epoch 36: EQM entrainement: [0.10813059] Taux correct: 0.9466666666666667
# Epoch 36: EQM test: [0.11678579] Taux correct: 0.96
# Epoch 37: EQM entrainement: [0.08291727] Taux correct: 1.0
# Epoch 37: EQM test: [0.09379719] Taux correct: 0.9733333333333334
# Epoch 38: EQM entrainement: [0.07723913] Taux correct: 1.0
# Epoch 38: EQM test: [0.08881853] Taux correct: 0.9866666666666667
# Epoch 39: EQM entrainement: [0.0798697] Taux correct: 1.0
# Epoch 39: EQM test: [0.09147691] Taux correct: 0.9733333333333334
# Epoch 40: EQM entrainement: [0.07132128] Taux correct: 1.0
# Epoch 40: EQM test: [0.08383143] Taux correct: 0.9866666666666667
# Epoch 41: EQM entrainement: [0.06834699] Taux correct: 1.0
# Epoch 41: EQM test: [0.08190948] Taux correct: 0.9866666666666667
# Epoch 42: EQM entrainement: [0.06787863] Taux correct: 1.0
# Epoch 42: EQM test: [0.08116229] Taux correct: 0.9866666666666667
# Epoch 43: EQM entrainement: [0.07298516] Taux correct: 1.0
# Epoch 43: EQM test: [0.08765353] Taux correct: 0.9733333333333334
# Epoch 44: EQM entrainement: [0.07192043] Taux correct: 0.9866666666666667
# Epoch 44: EQM test: [0.08693789] Taux correct: 0.9733333333333334
# Epoch 45: EQM entrainement: [0.05898113] Taux correct: 1.0
# Epoch 45: EQM test: [0.07340619] Taux correct: 0.9866666666666667
# Epoch 46: EQM entrainement: [0.06804907] Taux correct: 0.9866666666666667
# Epoch 46: EQM test: [0.08334337] Taux correct: 0.9733333333333334
# Epoch 47: EQM entrainement: [0.05639049] Taux correct: 1.0
# Epoch 47: EQM test: [0.07153674] Taux correct: 0.9866666666666667
# Epoch 48: EQM entrainement: [0.05927051] Taux correct: 1.0
# Epoch 48: EQM test: [0.07466009] Taux correct: 0.9733333333333334
# Epoch 49: EQM entrainement: [0.05099183] Taux correct: 1.0
# Epoch 49: EQM test: [0.06677306] Taux correct: 0.9866666666666667
# Epoch 50: EQM entrainement: [0.04812275] Taux correct: 1.0
# Epoch 50: EQM test: [0.06391023] Taux correct: 0.9866666666666667
# Epoch 51: EQM entrainement: [0.06230189] Taux correct: 0.9866666666666667
# Epoch 51: EQM test: [0.07860407] Taux correct: 0.9733333333333334
# Epoch 52: EQM entrainement: [0.04870567] Taux correct: 1.0
# Epoch 52: EQM test: [0.06470683] Taux correct: 0.9733333333333334
# Epoch 53: EQM entrainement: [0.05826624] Taux correct: 0.9866666666666667
# Epoch 53: EQM test: [0.07521199] Taux correct: 0.9733333333333334
# Epoch 54: EQM entrainement: [0.04747028] Taux correct: 1.0
# Epoch 54: EQM test: [0.06467789] Taux correct: 0.9733333333333334
# Epoch 55: EQM entrainement: [0.0415818] Taux correct: 1.0
# Epoch 55: EQM test: [0.05825403] Taux correct: 0.9866666666666667
# Epoch 56: EQM entrainement: [0.03892464] Taux correct: 1.0
# Epoch 56: EQM test: [0.05599358] Taux correct: 0.9866666666666667
# Epoch 57: EQM entrainement: [0.04321978] Taux correct: 1.0
# Epoch 57: EQM test: [0.05994507] Taux correct: 0.9733333333333334
# Epoch 58: EQM entrainement: [0.03818714] Taux correct: 1.0
# Epoch 58: EQM test: [0.05530831] Taux correct: 0.9866666666666667
# Epoch 59: EQM entrainement: [0.0412736] Taux correct: 1.0
# Epoch 59: EQM test: [0.05970881] Taux correct: 0.9733333333333334
# Epoch 60: EQM entrainement: [0.03480454] Taux correct: 1.0
# Epoch 60: EQM test: [0.05246357] Taux correct: 0.9866666666666667
# Epoch 61: EQM entrainement: [0.033716] Taux correct: 1.0
# Epoch 61: EQM test: [0.05218682] Taux correct: 0.9866666666666667
# Epoch 62: EQM entrainement: [0.0322043] Taux correct: 1.0
# Epoch 62: EQM test: [0.05040578] Taux correct: 0.9866666666666667
# Epoch 63: EQM entrainement: [0.03211446] Taux correct: 1.0
# Epoch 63: EQM test: [0.05094988] Taux correct: 0.9866666666666667
# Epoch 64: EQM entrainement: [0.03161364] Taux correct: 1.0
# Epoch 64: EQM test: [0.05067562] Taux correct: 0.9866666666666667
# Epoch 65: EQM entrainement: [0.04854418] Taux correct: 0.9866666666666667
# Epoch 65: EQM test: [0.0683564] Taux correct: 0.9733333333333334
# Epoch 66: EQM entrainement: [0.03436125] Taux correct: 1.0
# Epoch 66: EQM test: [0.05217259] Taux correct: 0.9733333333333334
# Epoch 67: EQM entrainement: [0.02815511] Taux correct: 1.0
# Epoch 67: EQM test: [0.0474843] Taux correct: 0.9866666666666667
# Epoch 68: EQM entrainement: [0.03080659] Taux correct: 1.0
# Epoch 68: EQM test: [0.04905209] Taux correct: 0.9733333333333334
# Epoch 69: EQM entrainement: [0.03209299] Taux correct: 1.0
# Epoch 69: EQM test: [0.05237429] Taux correct: 0.9866666666666667
# Epoch 70: EQM entrainement: [0.02688591] Taux correct: 1.0
# Epoch 70: EQM test: [0.04689237] Taux correct: 0.9866666666666667
# Epoch 71: EQM entrainement: [0.02680521] Taux correct: 1.0
# Epoch 71: EQM test: [0.04702338] Taux correct: 0.9866666666666667
# Epoch 72: EQM entrainement: [0.02486759] Taux correct: 1.0
# Epoch 72: EQM test: [0.04427723] Taux correct: 0.9866666666666667
# Epoch 73: EQM entrainement: [0.02451514] Taux correct: 1.0
# Epoch 73: EQM test: [0.04476197] Taux correct: 0.9866666666666667
# Epoch 74: EQM entrainement: [0.02445984] Taux correct: 1.0
# Epoch 74: EQM test: [0.04494613] Taux correct: 0.9866666666666667
# Epoch 75: EQM entrainement: [0.02298095] Taux correct: 1.0
# Epoch 75: EQM test: [0.04336489] Taux correct: 0.9866666666666667
# Epoch 76: EQM entrainement: [0.02218272] Taux correct: 1.0
# Epoch 76: EQM test: [0.04247313] Taux correct: 0.9866666666666667
# Epoch 77: EQM entrainement: [0.02676038] Taux correct: 1.0
# Epoch 77: EQM test: [0.04811075] Taux correct: 0.9866666666666667
# Epoch 78: EQM entrainement: [0.02318301] Taux correct: 1.0
# Epoch 78: EQM test: [0.04434533] Taux correct: 0.9866666666666667
# Epoch 79: EQM entrainement: [0.03178193] Taux correct: 1.0
# Epoch 79: EQM test: [0.05366032] Taux correct: 0.9733333333333334
# Epoch 80: EQM entrainement: [0.02022905] Taux correct: 1.0
# Epoch 80: EQM test: [0.04084086] Taux correct: 0.9866666666666667
# Epoch 81: EQM entrainement: [0.01993187] Taux correct: 1.0
# Epoch 81: EQM test: [0.04044873] Taux correct: 0.9866666666666667
# Epoch 82: EQM entrainement: [0.01983753] Taux correct: 1.0
# Epoch 82: EQM test: [0.040286] Taux correct: 0.9866666666666667
# Epoch 83: EQM entrainement: [0.0189769] Taux correct: 1.0
# Epoch 83: EQM test: [0.03980575] Taux correct: 0.9866666666666667
# Epoch 84: EQM entrainement: [0.02120166] Taux correct: 1.0
# Epoch 84: EQM test: [0.04313655] Taux correct: 0.9866666666666667
# Epoch 85: EQM entrainement: [0.02004223] Taux correct: 1.0
# Epoch 85: EQM test: [0.04032308] Taux correct: 0.9866666666666667
# Epoch 86: EQM entrainement: [0.01767414] Taux correct: 1.0
# Epoch 86: EQM test: [0.03891274] Taux correct: 0.9866666666666667
# Epoch 87: EQM entrainement: [0.0173343] Taux correct: 1.0
# Epoch 87: EQM test: [0.03876165] Taux correct: 0.9866666666666667
# Epoch 88: EQM entrainement: [0.01738978] Taux correct: 1.0
# Epoch 88: EQM test: [0.03919455] Taux correct: 0.9866666666666667
# Epoch 89: EQM entrainement: [0.02002166] Taux correct: 1.0
# Epoch 89: EQM test: [0.04032322] Taux correct: 0.9733333333333334
# Epoch 90: EQM entrainement: [0.01637091] Taux correct: 1.0
# Epoch 90: EQM test: [0.03781145] Taux correct: 0.9866666666666667
# Epoch 91: EQM entrainement: [0.019827] Taux correct: 1.0
# Epoch 91: EQM test: [0.04258926] Taux correct: 0.9866666666666667
# Epoch 92: EQM entrainement: [0.01883446] Taux correct: 1.0
# Epoch 92: EQM test: [0.03940536] Taux correct: 0.9866666666666667
# Epoch 93: EQM entrainement: [0.01557867] Taux correct: 1.0
# Epoch 93: EQM test: [0.03777187] Taux correct: 0.9866666666666667
# Epoch 94: EQM entrainement: [0.01535826] Taux correct: 1.0
# Epoch 94: EQM test: [0.03766294] Taux correct: 0.9866666666666667
# Epoch 95: EQM entrainement: [0.01566243] Taux correct: 1.0
# Epoch 95: EQM test: [0.03705915] Taux correct: 0.9866666666666667
# Epoch 96: EQM entrainement: [0.01629083] Taux correct: 1.0
# Epoch 96: EQM test: [0.03748125] Taux correct: 0.9866666666666667
# Epoch 97: EQM entrainement: [0.0168914] Taux correct: 1.0
# Epoch 97: EQM test: [0.03999896] Taux correct: 0.9866666666666667
# Epoch 98: EQM entrainement: [0.01731939] Taux correct: 1.0
# Epoch 98: EQM test: [0.04059959] Taux correct: 0.9866666666666667
# Epoch 99: EQM entrainement: [0.01371004] Taux correct: 1.0
# Epoch 99: EQM test: [0.03616941] Taux correct: 0.9866666666666667
