# %%
# -*- coding: utf-8 -*-
# %matplotlib inline
import numpy as np
import random
import matplotlib.pyplot as plt
import matplotlib as mpl

def afficher_grille(grille):
    """ Afficher les cases de la grille.
    grille : tableau 2d de cases qui correspondent aux états du monde
    """
    largeur, hauteur = grille.shape
    plt.figure(figsize=(largeur, hauteur))
    im = plt.imshow(grille,interpolation='none',cmap = mpl.cm.binary)
    ax = plt.gca()
    # Graduation majeure pour les axes
    ax.set_xticks(np.arange(0, largeur, 1))
    ax.set_yticks(np.arange(0, hauteur, 1))
    # Etiquettes de graduation
    ax.set_xticklabels(np.arange(0, largeur, 1));
    ax.set_yticklabels(np.arange(0, hauteur, 1));
    # Graduations mineures
    ax.set_xticks(np.arange(-.5, largeur, 1), minor=True);
    ax.set_yticks(np.arange(-.5, hauteur, 1), minor=True);

    # Quadrillage pour délimiter les pixels
    ax.grid(which='minor', linestyle='-', linewidth=2)

    for i in range(largeur):
        for j in range(hauteur):
            text = ax.text(j, i,round(grille[i, j],2),ha="center", va="center")
            
    plt.show()

gamma = 1 # taux d'escompte
taille_grille = 4
recompense = -1
etats_terminaux = [[0,0], [taille_grille-1, taille_grille-1]]
actions = [[-1, 0], [1, 0], [0, 1], [0, -1]]
nombre_iterations = 1000

def p(s,a):
    """ Retourne l'état suivant s_prime et la récompense r"""
    if s in etats_terminaux:
        return s, 0
    s_prime = np.array(s) + np.array(a)
    r = recompense
    # si débordement de grille retour à l'état s
    if -1 in s_prime or taille_grille in s_prime:
        s_prime = s
    return s_prime, r

etats = [[i, j] for i in range(taille_grille) for j in range(taille_grille)]

def calculer_v_par_iteration_en_place(etats,actions,nombre_iterations,gamma):
    """ Calcul de la récompense moyenne anticipée pour la politique aléatoire
    par itération de l'équation de Bellman pour v 
    version en place """
    v = np.zeros((taille_grille, taille_grille)) 
    print("v initial")
    afficher_grille(v)
    
    for i in range(nombre_iterations):
        delta = 0
        for etat in etats :
            copie_v=v[etat[0],etat[1]]
            moyenne_v=0
            for action in actions:
                s_prime,r = p(etat,action)
                moyenne_v += 1/len(actions)* (r + gamma * v[s_prime[0],s_prime[1]])
            v[etat[0],etat[1]]=moyenne_v
            delta =max(delta,abs(moyenne_v-copie_v))
        if i in [0,1,2,10]:
            print("delta:", delta, "iteration:",i)
            afficher_grille(v)
        if(delta < 0.001):
            print("delta:", delta, "iteration:",i)
            afficher_grille(v)
            break
            
calculer_v_par_iteration_en_place(etats,actions,nombre_iterations,1)
# Out:
# v initial
# delta: 1.8984375 iteration: 0
# delta: 1.724609375 iteration: 1
# delta: 1.472412109375 iteration: 2
# delta: 0.8183112404493045 iteration: 10
# delta: 0.0009689367250516057 iteration: 87

# %%
def vorace(etat,pi,pi1,gamma,v):
    """ Trouver meilleure politique pour un état """
    q_values=np.zeros(len(actions))
    for idx,action in enumerate(actions):
        s_prime,r = p(etat,action)
        q_values[idx] += 1/4* (r + gamma * v[s_prime[0],s_prime[1]])
    # Find the index of the action for which the q_value is 
    idx=q_values.argmax()
    pi[etat[0],etat[1]]=idx 
    if(idx == 0):
        pi1[etat[0],etat[1]]='h'
    elif(idx == 1):
        pi1[etat[0],etat[1]]='b'
    elif(idx == 2):
        pi1[etat[0],etat[1]]='d'
    elif(idx == 3):
        pi1[etat[0],etat[1]]='g'
        
def ameliorer_pi_vorace(pi, pi1,gamma,v):
    politique_stable = True
    for etat in etats:
        old = pi[etat].copy()
        # Greedify policy for state
        vorace(etat,pi,pi1,gamma,v)
        if not np.array_equal(pi[etat], old):
            politique_stable = False
    print(pi)
    print(pi1)
    return pi, pi1, politique_stable
        
pi = np.ones((taille_grille,taille_grille))/4
pi1 = np.chararray((taille_grille, taille_grille))
pi1[:] = 'a'

def calculer_v_et_pi(etats,actions,nombre_iterations,gamma):
    """ Calcul de la récompense moyenne anticipée pour la politique aléatoire
    par itération de l'équation de Bellman pour v 
    version en place """
    v = np.zeros((taille_grille, taille_grille)) 
    print("v initial")
    afficher_grille(v)
    
    pi = np.ones((taille_grille,taille_grille))/4
    pi1 = np.chararray((taille_grille, taille_grille))
    pi1[:] = 'a'
    
    for i in range(nombre_iterations):
        delta = 0
        for etat in etats :
            copie_v=v[etat[0],etat[1]]
            moyenne_v=0
            for action in actions:
                s_prime,r = p(etat,action)
                moyenne_v += 1/len(actions)* (r + gamma * v[s_prime[0],s_prime[1]])
            v[etat[0],etat[1]]=moyenne_v
            delta =max(delta,abs(moyenne_v-copie_v))
        
        ameliorer_pi_vorace(pi, pi1,gamma,v)
        if i in [0,1,2,10]:
            print("delta:", delta, "iteration:",i)
            afficher_grille(v)
        if(delta < 0.001):
            print("delta:", delta, "iteration:",i)
            afficher_grille(v)
            break
            
calculer_v_et_pi(etats,actions,nombre_iterations,1)
# Out:
# v initial
# [[0. 3. 3. 3.]
#  [0. 0. 0. 0.]
#  [0. 3. 0. 1.]
#  [0. 3. 2. 0.]]
# [[b'h' b'g' b'g' b'g']
#  [b'h' b'h' b'h' b'h']
#  [b'h' b'g' b'h' b'b']
#  [b'h' b'g' b'd' b'h']]
# delta: 1.8984375 iteration: 0
# [[0. 3. 3. 3.]
#  [0. 0. 0. 0.]
#  [0. 3. 1. 1.]
#  [0. 3. 2. 0.]]
# [[b'h' b'g' b'g' b'g']
#  [b'h' b'h' b'h' b'h']
#  [b'h' b'g' b'b' b'b']
#  [b'h' b'g' b'd' b'h']]
# delta: 1.724609375 iteration: 1
# [[0. 3. 3. 3.]
#  [0. 0. 0. 0.]
#  [0. 3. 1. 1.]
#  [0. 3. 2. 0.]]
# [[b'h' b'g' b'g' b'g']
#  [b'h' b'h' b'h' b'h']
#  [b'h' b'g' b'b' b'b']
#  [b'h' b'g' b'd' b'h']]
# delta: 1.472412109375 iteration: 2
# [[0. 3. 3. 3.]
#  [0. 0. 0. 1.]
#  [0. 3. 1. 1.]
#  [0. 2. 2. 0.]]
# [[b'h' b'g' b'g' b'g']
#  [b'h' b'h' b'h' b'b']
#  [b'h' b'g' b'b' b'b']
#  [b'h' b'd' b'd' b'h']]
# [[0. 3. 3. 3.]
#  [0. 0. 3. 1.]
#  [0. 0. 1. 1.]
#  [0. 2. 2. 0.]]
# [[b'h' b'g' b'g' b'g']
#  [b'h' b'h' b'g' b'b']
#  [b'h' b'h' b'b' b'b']
#  [b'h' b'd' b'd' b'h']]
# [[0. 3. 3. 3.]
#  [0. 0. 3. 1.]
#  [0. 0. 1. 1.]
#  [0. 2. 2. 0.]]
# [[b'h' b'g' b'g' b'g']
#  [b'h' b'h' b'g' b'b']
#  [b'h' b'h' b'b' b'b']
#  [b'h' b'd' b'd' b'h']]
# [[0. 3. 3. 3.]
#  [0. 0. 3. 1.]
#  [0. 0. 1. 1.]
#  [0. 2. 2. 0.]]
# [[b'h' b'g' b'g' b'g']
#  [b'h' b'h' b'g' b'b']
#  [b'h' b'h' b'b' b'b']
#  [b'h' b'd' b'd' b'h']]
# [[0. 3. 3. 3.]
#  [0. 0. 3. 1.]
#  [0. 0. 1. 1.]
#  [0. 2. 2. 0.]]
# [[b'h' b'g' b'g' b'g']
#  [b'h' b'h' b'g' b'b']
#  [b'h' b'h' b'b' b'b']
#  [b'h' b'd' b'd' b'h']]
# [[0. 3. 3. 3.]
#  [0. 0. 3. 1.]
#  [0. 0. 1. 1.]
#  [0. 2. 2. 0.]]
# [[b'h' b'g' b'g' b'g']
#  [b'h' b'h' b'g' b'b']
#  [b'h' b'h' b'b' b'b']
#  [b'h' b'd' b'd' b'h']]
# [[0. 3. 3. 3.]
#  [0. 0. 3. 1.]
#  [0. 0. 1. 1.]
#  [0. 2. 2. 0.]]
# [[b'h' b'g' b'g' b'g']
#  [b'h' b'h' b'g' b'b']
#  [b'h' b'h' b'b' b'b']
#  [b'h' b'd' b'd' b'h']]
# [[0. 3. 3. 3.]
#  [0. 0. 3. 1.]
#  [0. 0. 1. 1.]
#  [0. 2. 2. 0.]]
# [[b'h' b'g' b'g' b'g']
#  [b'h' b'h' b'g' b'b']
#  [b'h' b'h' b'b' b'b']
#  [b'h' b'd' b'd' b'h']]
# delta: 0.8183112404493045 iteration: 10
# [[0. 3. 3. 3.]
#  [0. 0. 3. 1.]
#  [0. 0. 2. 1.]
#  [0. 2. 2. 0.]]
# [[b'h' b'g' b'g' b'g']
#  [b'h' b'h' b'g' b'b']
#  [b'h' b'h' b'd' b'b']
#  [b'h' b'd' b'd' b'h']]
# [[0. 3. 3. 3.]
#  [0. 0. 3. 1.]
#  [0. 0. 2. 1.]
#  [0. 2. 2. 0.]]
# [[b'h' b'g' b'g' b'g']
#  [b'h' b'h' b'g' b'b']
#  [b'h' b'h' b'd' b'b']
#  [b'h' b'd' b'd' b'h']]
# [[0. 3. 3. 3.]
#  [0. 0. 3. 1.]
#  [0. 0. 1. 1.]
#  [0. 2. 2. 0.]]
# [[b'h' b'g' b'g' b'g']
#  [b'h' b'h' b'g' b'b']
#  [b'h' b'h' b'b' b'b']
#  [b'h' b'd' b'd' b'h']]
# [[0. 3. 3. 3.]
#  [0. 0. 3. 1.]
#  [0. 0. 1. 1.]
#  [0. 2. 2. 0.]]
# [[b'h' b'g' b'g' b'g']
#  [b'h' b'h' b'g' b'b']
#  [b'h' b'h' b'b' b'b']
#  [b'h' b'd' b'd' b'h']]
# [[0. 3. 3. 3.]
#  [0. 0. 3. 1.]
#  [0. 0. 1. 1.]
#  [0. 2. 2. 0.]]
# [[b'h' b'g' b'g' b'g']
#  [b'h' b'h' b'g' b'b']
#  [b'h' b'h' b'b' b'b']
#  [b'h' b'd' b'd' b'h']]
# [[0. 3. 3. 3.]
#  [0. 0. 3. 1.]
#  [0. 0. 1. 1.]
#  [0. 2. 2. 0.]]
# [[b'h' b'g' b'g' b'g']
#  [b'h' b'h' b'g' b'b']
#  [b'h' b'h' b'b' b'b']
#  [b'h' b'd' b'd' b'h']]
# [[0. 3. 3. 3.]
#  [0. 3. 3. 1.]
#  [0. 0. 1. 1.]
#  [0. 2. 2. 0.]]
# [[b'h' b'g' b'g' b'g']
#  [b'h' b'g' b'g' b'b']
#  [b'h' b'h' b'b' b'b']
#  [b'h' b'd' b'd' b'h']]
# [[0. 3. 3. 3.]
#  [0. 0. 3. 1.]
#  [0. 0. 1. 1.]
#  [0. 2. 2. 0.]]
# [[b'h' b'g' b'g' b'g']
#  [b'h' b'h' b'g' b'b']
#  [b'h' b'h' b'b' b'b']
#  [b'h' b'd' b'd' b'h']]
# [[0. 3. 3. 3.]
#  [0. 0. 3. 1.]
#  [0. 0. 1. 1.]
#  [0. 2. 2. 0.]]
# [[b'h' b'g' b'g' b'g']
#  [b'h' b'h' b'g' b'b']
#  [b'h' b'h' b'b' b'b']
#  [b'h' b'd' b'd' b'h']]
# [[0. 3. 3. 3.]
#  [0. 0. 3. 1.]
#  [0. 0. 1. 1.]
#  [0. 2. 2. 0.]]
# [[b'h' b'g' b'g' b'g']
#  [b'h' b'h' b'g' b'b']
#  [b'h' b'h' b'b' b'b']
#  [b'h' b'd' b'd' b'h']]
# [[0. 3. 3. 3.]
#  [0. 0. 3. 1.]
#  [0. 0. 1. 1.]
#  [0. 2. 2. 0.]]
# [[b'h' b'g' b'g' b'g']
#  [b'h' b'h' b'g' b'b']
#  [b'h' b'h' b'b' b'b']
#  [b'h' b'd' b'd' b'h']]
# [[0. 3. 3. 3.]
#  [0. 0. 3. 1.]
#  [0. 0. 1. 1.]
#  [0. 2. 2. 0.]]
# [[b'h' b'g' b'g' b'g']
#  [b'h' b'h' b'g' b'b']
#  [b'h' b'h' b'b' b'b']
#  [b'h' b'd' b'd' b'h']]
# [[0. 3. 3. 3.]
#  [0. 0. 3. 1.]
#  [0. 0. 1. 1.]
#  [0. 2. 2. 0.]]
# [[b'h' b'g' b'g' b'g']
#  [b'h' b'h' b'g' b'b']
#  [b'h' b'h' b'b' b'b']
#  [b'h' b'd' b'd' b'h']]
# [[0. 3. 3. 3.]
#  [0. 0. 3. 1.]
#  [0. 0. 1. 1.]
#  [0. 2. 2. 0.]]
# [[b'h' b'g' b'g' b'g']
#  [b'h' b'h' b'g' b'b']
#  [b'h' b'h' b'b' b'b']
#  [b'h' b'd' b'd' b'h']]
# [[0. 3. 3. 3.]
#  [0. 3. 3. 1.]
#  [0. 0. 1. 1.]
#  [0. 2. 2. 0.]]
# [[b'h' b'g' b'g' b'g']
#  [b'h' b'g' b'g' b'b']
#  [b'h' b'h' b'b' b'b']
#  [b'h' b'd' b'd' b'h']]
# [[0. 3. 3. 3.]
#  [0. 0. 3. 1.]
#  [0. 0. 1. 1.]
#  [0. 2. 2. 0.]]
# [[b'h' b'g' b'g' b'g']
#  [b'h' b'h' b'g' b'b']
#  [b'h' b'h' b'b' b'b']
#  [b'h' b'd' b'd' b'h']]
# [[0. 3. 3. 3.]
#  [0. 0. 3. 1.]
#  [0. 0. 1. 1.]
#  [0. 2. 2. 0.]]
# [[b'h' b'g' b'g' b'g']
#  [b'h' b'h' b'g' b'b']
#  [b'h' b'h' b'b' b'b']
#  [b'h' b'd' b'd' b'h']]
# [[0. 3. 3. 3.]
#  [0. 0. 3. 1.]
#  [0. 0. 1. 1.]
#  [0. 2. 2. 0.]]
# [[b'h' b'g' b'g' b'g']
#  [b'h' b'h' b'g' b'b']
#  [b'h' b'h' b'b' b'b']
#  [b'h' b'd' b'd' b'h']]
# [[0. 3. 3. 3.]
#  [0. 0. 3. 1.]
#  [0. 0. 2. 1.]
#  [0. 2. 2. 0.]]
# [[b'h' b'g' b'g' b'g']
#  [b'h' b'h' b'g' b'b']
#  [b'h' b'h' b'd' b'b']
#  [b'h' b'd' b'd' b'h']]
# [[0. 3. 3. 3.]
#  [0. 0. 3. 1.]
#  [0. 0. 1. 1.]
#  [0. 2. 2. 0.]]
# [[b'h' b'g' b'g' b'g']
#  [b'h' b'h' b'g' b'b']
#  [b'h' b'h' b'b' b'b']
#  [b'h' b'd' b'd' b'h']]
# [[0. 3. 3. 3.]
#  [0. 0. 3. 1.]
#  [0. 0. 1. 1.]
#  [0. 2. 2. 0.]]
# [[b'h' b'g' b'g' b'g']
#  [b'h' b'h' b'g' b'b']
#  [b'h' b'h' b'b' b'b']
#  [b'h' b'd' b'd' b'h']]
# [[0. 3. 3. 3.]
#  [0. 0. 3. 1.]
#  [0. 0. 1. 1.]
#  [0. 2. 2. 0.]]
# [[b'h' b'g' b'g' b'g']
#  [b'h' b'h' b'g' b'b']
#  [b'h' b'h' b'b' b'b']
#  [b'h' b'd' b'd' b'h']]
# [[0. 3. 3. 3.]
#  [0. 0. 3. 1.]
#  [0. 0. 1. 1.]
#  [0. 2. 2. 0.]]
# [[b'h' b'g' b'g' b'g']
#  [b'h' b'h' b'g' b'b']
#  [b'h' b'h' b'b' b'b']
#  [b'h' b'd' b'd' b'h']]
# [[0. 3. 3. 3.]
#  [0. 0. 3. 1.]
#  [0. 0. 1. 1.]
#  [0. 2. 2. 0.]]
# [[b'h' b'g' b'g' b'g']
#  [b'h' b'h' b'g' b'b']
#  [b'h' b'h' b'b' b'b']
#  [b'h' b'd' b'd' b'h']]
# [[0. 3. 3. 3.]
#  [0. 0. 3. 1.]
#  [0. 0. 1. 1.]
#  [0. 2. 2. 0.]]
# [[b'h' b'g' b'g' b'g']
#  [b'h' b'h' b'g' b'b']
#  [b'h' b'h' b'b' b'b']
#  [b'h' b'd' b'd' b'h']]
# [[0. 3. 3. 3.]
#  [0. 3. 3. 1.]
#  [0. 0. 1. 1.]
#  [0. 2. 2. 0.]]
# [[b'h' b'g' b'g' b'g']
#  [b'h' b'g' b'g' b'b']
#  [b'h' b'h' b'b' b'b']
#  [b'h' b'd' b'd' b'h']]
# [[0. 3. 3. 3.]
#  [0. 3. 3. 1.]
#  [0. 0. 1. 1.]
#  [0. 2. 2. 0.]]
# [[b'h' b'g' b'g' b'g']
#  [b'h' b'g' b'g' b'b']
#  [b'h' b'h' b'b' b'b']
#  [b'h' b'd' b'd' b'h']]
# [[0. 3. 3. 3.]
#  [0. 3. 3. 1.]
#  [0. 0. 1. 1.]
#  [0. 2. 2. 0.]]
# [[b'h' b'g' b'g' b'g']
#  [b'h' b'g' b'g' b'b']
#  [b'h' b'h' b'b' b'b']
#  [b'h' b'd' b'd' b'h']]
# [[0. 3. 3. 3.]
#  [0. 0. 3. 1.]
#  [0. 0. 1. 1.]
#  [0. 2. 2. 0.]]
# [[b'h' b'g' b'g' b'g']
#  [b'h' b'h' b'g' b'b']
#  [b'h' b'h' b'b' b'b']
#  [b'h' b'd' b'd' b'h']]
# [[0. 3. 3. 3.]
#  [0. 0. 3. 1.]
#  [0. 0. 1. 1.]
#  [0. 2. 2. 0.]]
# [[b'h' b'g' b'g' b'g']
#  [b'h' b'h' b'g' b'b']
#  [b'h' b'h' b'b' b'b']
#  [b'h' b'd' b'd' b'h']]
# [[0. 3. 3. 3.]
#  [0. 0. 3. 1.]
#  [0. 0. 1. 1.]
#  [0. 2. 2. 0.]]
# [[b'h' b'g' b'g' b'g']
#  [b'h' b'h' b'g' b'b']
#  [b'h' b'h' b'b' b'b']
#  [b'h' b'd' b'd' b'h']]
# [[0. 3. 3. 3.]
#  [0. 0. 3. 1.]
#  [0. 0. 1. 1.]
#  [0. 2. 2. 0.]]
# [[b'h' b'g' b'g' b'g']
#  [b'h' b'h' b'g' b'b']
#  [b'h' b'h' b'b' b'b']
#  [b'h' b'd' b'd' b'h']]
# [[0. 3. 3. 3.]
#  [0. 3. 3. 1.]
#  [0. 0. 1. 1.]
#  [0. 2. 2. 0.]]
# [[b'h' b'g' b'g' b'g']
#  [b'h' b'g' b'g' b'b']
#  [b'h' b'h' b'b' b'b']
#  [b'h' b'd' b'd' b'h']]
# [[0. 3. 3. 3.]
#  [0. 0. 3. 1.]
#  [0. 0. 1. 1.]
#  [0. 2. 2. 0.]]
# [[b'h' b'g' b'g' b'g']
#  [b'h' b'h' b'g' b'b']
#  [b'h' b'h' b'b' b'b']
#  [b'h' b'd' b'd' b'h']]
# [[0. 3. 3. 3.]
#  [0. 0. 3. 1.]
#  [0. 0. 1. 1.]
#  [0. 2. 2. 0.]]
# [[b'h' b'g' b'g' b'g']
#  [b'h' b'h' b'g' b'b']
#  [b'h' b'h' b'b' b'b']
#  [b'h' b'd' b'd' b'h']]
# [[0. 3. 3. 3.]
#  [0. 0. 3. 1.]
#  [0. 0. 1. 1.]
#  [0. 2. 2. 0.]]
# [[b'h' b'g' b'g' b'g']
#  [b'h' b'h' b'g' b'b']
#  [b'h' b'h' b'b' b'b']
#  [b'h' b'd' b'd' b'h']]
# [[0. 3. 3. 3.]
#  [0. 0. 3. 1.]
#  [0. 0. 1. 1.]
#  [0. 2. 2. 0.]]
# [[b'h' b'g' b'g' b'g']
#  [b'h' b'h' b'g' b'b']
#  [b'h' b'h' b'b' b'b']
#  [b'h' b'd' b'd' b'h']]
# [[0. 3. 3. 3.]
#  [0. 0. 3. 1.]
#  [0. 0. 1. 1.]
#  [0. 2. 2. 0.]]
# [[b'h' b'g' b'g' b'g']
#  [b'h' b'h' b'g' b'b']
#  [b'h' b'h' b'b' b'b']
#  [b'h' b'd' b'd' b'h']]
# [[0. 3. 3. 3.]
#  [0. 3. 3. 1.]
#  [0. 0. 1. 1.]
#  [0. 2. 2. 0.]]
# [[b'h' b'g' b'g' b'g']
#  [b'h' b'g' b'g' b'b']
#  [b'h' b'h' b'b' b'b']
#  [b'h' b'd' b'd' b'h']]
# [[0. 3. 3. 3.]
#  [0. 3. 3. 1.]
#  [0. 0. 1. 1.]
#  [0. 2. 2. 0.]]
# [[b'h' b'g' b'g' b'g']
#  [b'h' b'g' b'g' b'b']
#  [b'h' b'h' b'b' b'b']
#  [b'h' b'd' b'd' b'h']]
# [[0. 3. 3. 3.]
#  [0. 0. 3. 1.]
#  [0. 0. 2. 1.]
#  [0. 2. 2. 0.]]
# [[b'h' b'g' b'g' b'g']
#  [b'h' b'h' b'g' b'b']
#  [b'h' b'h' b'd' b'b']
#  [b'h' b'd' b'd' b'h']]
# [[0. 3. 3. 3.]
#  [0. 0. 3. 1.]
#  [0. 0. 1. 1.]
#  [0. 2. 2. 0.]]
# [[b'h' b'g' b'g' b'g']
#  [b'h' b'h' b'g' b'b']
#  [b'h' b'h' b'b' b'b']
#  [b'h' b'd' b'd' b'h']]
# [[0. 3. 3. 3.]
#  [0. 0. 3. 1.]
#  [0. 0. 1. 1.]
#  [0. 2. 2. 0.]]
# [[b'h' b'g' b'g' b'g']
#  [b'h' b'h' b'g' b'b']
#  [b'h' b'h' b'b' b'b']
#  [b'h' b'd' b'd' b'h']]
# [[0. 3. 3. 3.]
#  [0. 0. 3. 1.]
#  [0. 0. 1. 1.]
#  [0. 2. 2. 0.]]
# [[b'h' b'g' b'g' b'g']
#  [b'h' b'h' b'g' b'b']
#  [b'h' b'h' b'b' b'b']
#  [b'h' b'd' b'd' b'h']]
# [[0. 3. 3. 3.]
#  [0. 0. 3. 1.]
#  [0. 0. 1. 1.]
#  [0. 2. 2. 0.]]
# [[b'h' b'g' b'g' b'g']
#  [b'h' b'h' b'g' b'b']
#  [b'h' b'h' b'b' b'b']
#  [b'h' b'd' b'd' b'h']]
# [[0. 3. 3. 3.]
#  [0. 0. 3. 1.]
#  [0. 0. 2. 1.]
#  [0. 2. 2. 0.]]
# [[b'h' b'g' b'g' b'g']
#  [b'h' b'h' b'g' b'b']
#  [b'h' b'h' b'd' b'b']
#  [b'h' b'd' b'd' b'h']]
# [[0. 3. 3. 3.]
#  [0. 0. 3. 1.]
#  [0. 0. 2. 1.]
#  [0. 2. 2. 0.]]
# [[b'h' b'g' b'g' b'g']
#  [b'h' b'h' b'g' b'b']
#  [b'h' b'h' b'd' b'b']
#  [b'h' b'd' b'd' b'h']]
# [[0. 3. 3. 3.]
#  [0. 0. 3. 1.]
#  [0. 0. 1. 1.]
#  [0. 2. 2. 0.]]
# [[b'h' b'g' b'g' b'g']
#  [b'h' b'h' b'g' b'b']
#  [b'h' b'h' b'b' b'b']
#  [b'h' b'd' b'd' b'h']]
# [[0. 3. 3. 3.]
#  [0. 3. 3. 1.]
#  [0. 0. 1. 1.]
#  [0. 2. 2. 0.]]
# [[b'h' b'g' b'g' b'g']
#  [b'h' b'g' b'g' b'b']
#  [b'h' b'h' b'b' b'b']
#  [b'h' b'd' b'd' b'h']]
# [[0. 3. 3. 3.]
#  [0. 0. 3. 1.]
#  [0. 0. 1. 1.]
#  [0. 2. 2. 0.]]
# [[b'h' b'g' b'g' b'g']
#  [b'h' b'h' b'g' b'b']
#  [b'h' b'h' b'b' b'b']
#  [b'h' b'd' b'd' b'h']]
# [[0. 3. 3. 3.]
#  [0. 0. 3. 1.]
#  [0. 0. 1. 1.]
#  [0. 2. 2. 0.]]
# [[b'h' b'g' b'g' b'g']
#  [b'h' b'h' b'g' b'b']
#  [b'h' b'h' b'b' b'b']
#  [b'h' b'd' b'd' b'h']]
# [[0. 3. 3. 3.]
#  [0. 0. 3. 1.]
#  [0. 0. 1. 1.]
#  [0. 2. 2. 0.]]
# [[b'h' b'g' b'g' b'g']
#  [b'h' b'h' b'g' b'b']
#  [b'h' b'h' b'b' b'b']
#  [b'h' b'd' b'd' b'h']]
# [[0. 3. 3. 3.]
#  [0. 0. 3. 1.]
#  [0. 0. 2. 1.]
#  [0. 2. 2. 0.]]
# [[b'h' b'g' b'g' b'g']
#  [b'h' b'h' b'g' b'b']
#  [b'h' b'h' b'd' b'b']
#  [b'h' b'd' b'd' b'h']]
# [[0. 3. 3. 3.]
#  [0. 0. 3. 1.]
#  [0. 0. 1. 1.]
#  [0. 2. 2. 0.]]
# [[b'h' b'g' b'g' b'g']
#  [b'h' b'h' b'g' b'b']
#  [b'h' b'h' b'b' b'b']
#  [b'h' b'd' b'd' b'h']]
# [[0. 3. 3. 3.]
#  [0. 0. 3. 1.]
#  [0. 0. 2. 1.]
#  [0. 2. 2. 0.]]
# [[b'h' b'g' b'g' b'g']
#  [b'h' b'h' b'g' b'b']
#  [b'h' b'h' b'd' b'b']
#  [b'h' b'd' b'd' b'h']]
# [[0. 3. 3. 3.]
#  [0. 0. 3. 1.]
#  [0. 0. 2. 1.]
#  [0. 2. 2. 0.]]
# [[b'h' b'g' b'g' b'g']
#  [b'h' b'h' b'g' b'b']
#  [b'h' b'h' b'd' b'b']
#  [b'h' b'd' b'd' b'h']]
# [[0. 3. 3. 3.]
#  [0. 0. 3. 1.]
#  [0. 0. 2. 1.]
#  [0. 2. 2. 0.]]
# [[b'h' b'g' b'g' b'g']
#  [b'h' b'h' b'g' b'b']
#  [b'h' b'h' b'd' b'b']
#  [b'h' b'd' b'd' b'h']]
# [[0. 3. 3. 3.]
#  [0. 0. 3. 1.]
#  [0. 0. 2. 1.]
#  [0. 2. 2. 0.]]
# [[b'h' b'g' b'g' b'g']
#  [b'h' b'h' b'g' b'b']
#  [b'h' b'h' b'd' b'b']
#  [b'h' b'd' b'd' b'h']]
# [[0. 3. 3. 3.]
#  [0. 0. 3. 1.]
#  [0. 0. 2. 1.]
#  [0. 2. 2. 0.]]
# [[b'h' b'g' b'g' b'g']
#  [b'h' b'h' b'g' b'b']
#  [b'h' b'h' b'd' b'b']
#  [b'h' b'd' b'd' b'h']]
# [[0. 3. 3. 3.]
#  [0. 0. 3. 1.]
#  [0. 0. 2. 1.]
#  [0. 2. 2. 0.]]
# [[b'h' b'g' b'g' b'g']
#  [b'h' b'h' b'g' b'b']
#  [b'h' b'h' b'd' b'b']
#  [b'h' b'd' b'd' b'h']]
# [[0. 3. 3. 3.]
#  [0. 0. 3. 1.]
#  [0. 0. 2. 1.]
#  [0. 2. 2. 0.]]
# [[b'h' b'g' b'g' b'g']
#  [b'h' b'h' b'g' b'b']
#  [b'h' b'h' b'd' b'b']
#  [b'h' b'd' b'd' b'h']]
# [[0. 3. 3. 3.]
#  [0. 0. 3. 1.]
#  [0. 0. 2. 1.]
#  [0. 2. 2. 0.]]
# [[b'h' b'g' b'g' b'g']
#  [b'h' b'h' b'g' b'b']
#  [b'h' b'h' b'd' b'b']
#  [b'h' b'd' b'd' b'h']]
# [[0. 3. 3. 3.]
#  [0. 0. 3. 1.]
#  [0. 0. 1. 1.]
#  [0. 2. 2. 0.]]
# [[b'h' b'g' b'g' b'g']
#  [b'h' b'h' b'g' b'b']
#  [b'h' b'h' b'b' b'b']
#  [b'h' b'd' b'd' b'h']]
# [[0. 3. 3. 3.]
#  [0. 0. 3. 1.]
#  [0. 0. 1. 1.]
#  [0. 2. 2. 0.]]
# [[b'h' b'g' b'g' b'g']
#  [b'h' b'h' b'g' b'b']
#  [b'h' b'h' b'b' b'b']
#  [b'h' b'd' b'd' b'h']]
# [[0. 3. 3. 3.]
#  [0. 0. 3. 1.]
#  [0. 0. 1. 1.]
#  [0. 2. 2. 0.]]
# [[b'h' b'g' b'g' b'g']
#  [b'h' b'h' b'g' b'b']
#  [b'h' b'h' b'b' b'b']
#  [b'h' b'd' b'd' b'h']]
# [[0. 3. 3. 3.]
#  [0. 0. 3. 1.]
#  [0. 0. 1. 1.]
#  [0. 2. 2. 0.]]
# [[b'h' b'g' b'g' b'g']
#  [b'h' b'h' b'g' b'b']
#  [b'h' b'h' b'b' b'b']
#  [b'h' b'd' b'd' b'h']]
# [[0. 3. 3. 3.]
#  [0. 0. 3. 1.]
#  [0. 0. 2. 1.]
#  [0. 2. 2. 0.]]
# [[b'h' b'g' b'g' b'g']
#  [b'h' b'h' b'g' b'b']
#  [b'h' b'h' b'd' b'b']
#  [b'h' b'd' b'd' b'h']]
# [[0. 3. 3. 3.]
#  [0. 0. 3. 1.]
#  [0. 0. 2. 1.]
#  [0. 2. 2. 0.]]
# [[b'h' b'g' b'g' b'g']
#  [b'h' b'h' b'g' b'b']
#  [b'h' b'h' b'd' b'b']
#  [b'h' b'd' b'd' b'h']]
# [[0. 3. 3. 3.]
#  [0. 0. 3. 1.]
#  [0. 0. 2. 1.]
#  [0. 2. 2. 0.]]
# [[b'h' b'g' b'g' b'g']
#  [b'h' b'h' b'g' b'b']
#  [b'h' b'h' b'd' b'b']
#  [b'h' b'd' b'd' b'h']]
# [[0. 3. 3. 3.]
#  [0. 0. 3. 1.]
#  [0. 0. 1. 1.]
#  [0. 2. 2. 0.]]
# [[b'h' b'g' b'g' b'g']
#  [b'h' b'h' b'g' b'b']
#  [b'h' b'h' b'b' b'b']
#  [b'h' b'd' b'd' b'h']]
# [[0. 3. 3. 3.]
#  [0. 0. 3. 1.]
#  [0. 0. 1. 1.]
#  [0. 2. 2. 0.]]
# [[b'h' b'g' b'g' b'g']
#  [b'h' b'h' b'g' b'b']
#  [b'h' b'h' b'b' b'b']
#  [b'h' b'd' b'd' b'h']]
# [[0. 3. 3. 3.]
#  [0. 0. 3. 1.]
#  [0. 0. 1. 1.]
#  [0. 2. 2. 0.]]
# [[b'h' b'g' b'g' b'g']
#  [b'h' b'h' b'g' b'b']
#  [b'h' b'h' b'b' b'b']
#  [b'h' b'd' b'd' b'h']]
# [[0. 3. 3. 3.]
#  [0. 0. 3. 1.]
#  [0. 0. 1. 1.]
#  [0. 2. 2. 0.]]
# [[b'h' b'g' b'g' b'g']
#  [b'h' b'h' b'g' b'b']
#  [b'h' b'h' b'b' b'b']
#  [b'h' b'd' b'd' b'h']]
# [[0. 3. 3. 3.]
#  [0. 0. 3. 1.]
#  [0. 0. 1. 1.]
#  [0. 2. 2. 0.]]
# [[b'h' b'g' b'g' b'g']
#  [b'h' b'h' b'g' b'b']
#  [b'h' b'h' b'b' b'b']
#  [b'h' b'd' b'd' b'h']]
# [[0. 3. 3. 3.]
#  [0. 0. 3. 1.]
#  [0. 0. 1. 1.]
#  [0. 2. 2. 0.]]
# [[b'h' b'g' b'g' b'g']
#  [b'h' b'h' b'g' b'b']
#  [b'h' b'h' b'b' b'b']
#  [b'h' b'd' b'd' b'h']]
# [[0. 3. 3. 3.]
#  [0. 0. 3. 1.]
#  [0. 0. 2. 1.]
#  [0. 2. 2. 0.]]
# [[b'h' b'g' b'g' b'g']
#  [b'h' b'h' b'g' b'b']
#  [b'h' b'h' b'd' b'b']
#  [b'h' b'd' b'd' b'h']]
# [[0. 3. 3. 3.]
#  [0. 0. 3. 1.]
#  [0. 0. 1. 1.]
#  [0. 2. 2. 0.]]
# [[b'h' b'g' b'g' b'g']
#  [b'h' b'h' b'g' b'b']
#  [b'h' b'h' b'b' b'b']
#  [b'h' b'd' b'd' b'h']]
# delta: 0.0009689367250516057 iteration: 87

# %%
nombre_iterations = 1000
pi = np.ones((gridSize,gridSize))/4
pi1 = np.chararray((gridSize, gridSize))
pi1[:] = 'a'

# %%
def policy_iteration(gamma, theta):
    valueMap = np.zeros((gridSize, gridSize))
    pi = np.ones((gridSize,gridSize))/4
    pi1 = np.chararray((gridSize, gridSize))
    pi1[:] = 'a'
    policy_stable = False
    print("here")
    while not policy_stable:
        valueMap = policy_evaluate(states,actions,gamma,valueMap)
        pi,pi1, policy_stable = improve_policy(pi,pi1,  gamma,valueMap)
    return valueMap, pi,pi1

theta=0.1
valueMap, pi,pi1 = policy_iteration(gamma, theta)

# %%
def calculer_v_une_iteration(etats,actions,nombre_iterations,gamma,v):
    """Une itération de l'équation de Bellman pour v """

    copie_v=np.copy(v)
    for etat in etats :
        moyenne_v=0
        for action in actions:
            s_prime,r = p(etat,action)
            moyenne_v += 1/len(actions)* (r + gamma * v[s_prime[0],s_prime[1]])
        copie_v[etat[0],etat[1]]=moyenne_v 
    v = np.copy(copie_v)
    return v
