# %%
# %matplotlib inline
# -*- coding: utf-8 -*-
"""
Exemple de MNIST avec PyTorch
Exemple avec connexion distante (BlocResSimple)
"""
import torch
torch.manual_seed(0) # Pour résultats reproductibles

# Fonction J d'entropie croisée
import torch.nn.functional as F
fonction_cout = F.cross_entropy

def taux_bonnes_predictions(lot_Y_predictions, lot_Y):
    predictions_categorie = torch.argmax(lot_Y_predictions, dim=1)
    return (predictions_categorie == lot_Y).float().mean()

from torch import nn
# Définition de l'architecture du RNA

class BlocResSimple(nn.Module):
    def __init__(self, nb_f):
        super().__init__()
        self.convolution = nn.Conv2d(nb_f, nb_f, kernel_size=3, stride=1, padding=1) 
        self.normalisation = nn.BatchNorm2d(nb_f)    

    def forward(self, lot_X):
        lot_Y_predictions = self.convolution(lot_X)
        lot_Y_predictions = self.normalisation(lot_Y_predictions)
        lot_Y_predictions = F.relu(lot_Y_predictions)
        return lot_Y_predictions+lot_X

modele = nn.Sequential(
    nn.Conv2d(1,8,3),
    nn.BatchNorm2d(8),
    nn.ReLU(),
    BlocResSimple(8),
    BlocResSimple(8),
    nn.Conv2d(8,16,3),
    nn.BatchNorm2d(16),
    nn.ReLU(),    
    BlocResSimple(16),
    BlocResSimple(16),
    nn.Conv2d(16,32,3),
    nn.BatchNorm2d(32),
    nn.ReLU(),    
    BlocResSimple(32),
    BlocResSimple(32),
    nn.Conv2d(32,16,3),
    nn.BatchNorm2d(16),
    nn.ReLU(),    
    BlocResSimple(16),
    BlocResSimple(16),    
    nn.Flatten(),
    nn.Linear(20*20*16,10)
)

from torch import optim
optimiseur = optim.SGD(modele.parameters(), lr=0.01)

# Chargement des données de MNIST
import pickle, gzip
fichier_donnees = gzip.open(r"mnist.pkl.gz", 'rb')
((donnees_ent_X, donnees_ent_Y),(donnees_valid_X, donnees_valid_Y),(donnees_test_X,donnees_test_Y)) = pickle.load(fichier_donnees, encoding="latin-1")
fichier_donnees.close()

# Conversion des données en type toch.Tensor
import torch
donnees_ent_X,donnees_ent_Y,donnees_valid_X,donnees_valid_Y,donnees_test_X,donnees_test_Y  = map(torch.tensor,
    (donnees_ent_X.reshape((-1,1,28,28)),donnees_ent_Y,donnees_valid_X.reshape((-1,1,28,28)),donnees_valid_Y,donnees_test_X.reshape((-1,1,28,28)),donnees_test_Y))

# Création des objets DataLoader pour itérer par lot
from torch.utils.data import TensorDataset
from torch.utils.data import DataLoader
ds_ent = TensorDataset(donnees_ent_X, donnees_ent_Y)
dl_ent = DataLoader(ds_ent, batch_size=100, shuffle=True)
ds_valid = TensorDataset(donnees_valid_X,donnees_valid_Y)
dl_valid = DataLoader(ds_valid, batch_size=100)

def entrainer(modele, dl_ent, dl_valid, optimiseur, nb_epochs=10):

    # Listes pour les métriques par epoch
    liste_cout_moyen_ent = []
    liste_taux_moyen_ent = []
    liste_cout_moyen_valid = []
    liste_taux_moyen_valid = []
    
    # Boucle d'apprentissage
    for epoch in range(nb_epochs):
        cout_total_ent = 0 # pour cumuler les couts par mini-lot
        taux_bonnes_predictions_ent = 0 # pour cumuler les taux par mini-lot
        modele.train() # Pour certains types de couches (nn.BatchNorm2d, nn.Dropout, ...)
        
        # Boucle d'apprentissage par mini-lot pour une epoch
        for lot_X, lot_Y in dl_ent:
            optimiseur.zero_grad() # Remettre les dérivées à zéro
            lot_Y_predictions = modele(lot_X) # Appel de la méthode forward
            cout = fonction_cout(lot_Y_predictions, lot_Y)
            cout.backward() # Calcul des gradiants par rétropropagation
            with torch.no_grad():
                cout_total_ent +=cout
                taux_bonnes_predictions_ent += taux_bonnes_predictions(lot_Y_predictions, lot_Y)
            optimiseur.step() # Mise à jour des paramètres
        # Calculer les moyennes par mini-lot
        with torch.no_grad():
            cout_moyen_ent = cout_total_ent/len(dl_ent)
            taux_moyen_ent = taux_bonnes_predictions_ent/len(dl_ent)
       
        modele.eval() # Pour certains types de couches (nn.BatchNorm2d, nn.Dropout, ...)
        with torch.no_grad():
            cout_valid = sum(fonction_cout(modele(lot_valid_X), lot_valid_Y) for lot_valid_X, lot_valid_Y in dl_valid)
            taux_bons_valid = sum(taux_bonnes_predictions(modele(lot_valid_X), lot_valid_Y) for lot_valid_X, lot_valid_Y in dl_valid)
        cout_moyen_valid = cout_valid/len(dl_valid)
        taux_moyen_valid = taux_bons_valid/len(dl_valid)
        print(f'-------- > epoch {epoch+1}:  coût moyen entraînement = {cout_moyen_ent}')
        print(f'-------- > epoch {epoch+1}:  taux moyen entraînement = {taux_moyen_ent}')
        print(f'-------- > epoch {epoch+1}:  coût moyen validation = {cout_moyen_valid}')
        print(f'-------- > epoch {epoch+1}:  taux moyen validation = {taux_moyen_valid}')
    
        liste_cout_moyen_ent.append(cout_moyen_ent)
        liste_taux_moyen_ent.append(taux_moyen_ent)
        liste_cout_moyen_valid.append(cout_moyen_valid)
        liste_taux_moyen_valid.append(taux_moyen_valid)
    
    # Affichage du graphique d'évolution des métriques par epoch
    import numpy as np
    import matplotlib.pyplot as plt
    plt.plot(np.arange(0,nb_epochs),liste_cout_moyen_ent,label='Erreur entraînement')
    plt.plot(np.arange(0,nb_epochs),liste_cout_moyen_valid,label='Erreur validation')
    plt.title("Evolution du coût")
    plt.xlabel('epoch')
    plt.ylabel('moyenne par observation')
    plt.legend(loc='upper center')
    plt.show()
        
    plt.plot(np.arange(0,nb_epochs),liste_taux_moyen_ent,label='Taux bonnes réponses entraînement')
    plt.plot(np.arange(0,nb_epochs),liste_taux_moyen_valid,label='Taux bonnes réponses validation')
    plt.title("Evolution du taux")
    plt.xlabel('epoch')
    plt.ylabel('moyenne par observation')
    plt.legend(loc='center')
    plt.show()

entrainer(modele, dl_ent, dl_valid, optimiseur, nb_epochs=30)
# Out:
# -------- > epoch 1:  coût moyen entraînement = 0.4052720069885254
# -------- > epoch 1:  taux moyen entraînement = 0.933241069316864
# -------- > epoch 1:  coût moyen validation = 0.06936285644769669
# -------- > epoch 1:  taux moyen validation = 0.9788002967834473
# -------- > epoch 2:  coût moyen entraînement = 0.05470890551805496
# -------- > epoch 2:  taux moyen entraînement = 0.9825796484947205
# -------- > epoch 2:  coût moyen validation = 0.06047781556844711
# -------- > epoch 2:  taux moyen validation = 0.9817999005317688
# -------- > epoch 3:  coût moyen entraînement = 0.039101555943489075
# -------- > epoch 3:  taux moyen entraînement = 0.9875991344451904
# -------- > epoch 3:  coût moyen validation = 0.05300130322575569
# -------- > epoch 3:  taux moyen validation = 0.9846999645233154
# -------- > epoch 4:  coût moyen entraînement = 0.030004918575286865
# -------- > epoch 4:  taux moyen entraînement = 0.9909597039222717
# -------- > epoch 4:  coût moyen validation = 0.048898328095674515
# -------- > epoch 4:  taux moyen validation = 0.9861997961997986
# -------- > epoch 5:  coût moyen entraînement = 0.024673504754900932
# -------- > epoch 5:  taux moyen entraînement = 0.9927995800971985
# -------- > epoch 5:  coût moyen validation = 0.0451442189514637
# -------- > epoch 5:  taux moyen validation = 0.9875998497009277
# -------- > epoch 6:  coût moyen entraînement = 0.01982041820883751
# -------- > epoch 6:  taux moyen entraînement = 0.9940393567085266
# -------- > epoch 6:  coût moyen validation = 0.041121721267700195
# -------- > epoch 6:  taux moyen validation = 0.9869001507759094
# -------- > epoch 7:  coût moyen entraînement = 0.017044633626937866
# -------- > epoch 7:  taux moyen entraînement = 0.9949192404747009
# -------- > epoch 7:  coût moyen validation = 0.04046584665775299
# -------- > epoch 7:  taux moyen validation = 0.988800048828125
# -------- > epoch 8:  coût moyen entraînement = 0.01313947606831789
# -------- > epoch 8:  taux moyen entraînement = 0.9962393641471863
# -------- > epoch 8:  coût moyen validation = 0.03999108076095581
# -------- > epoch 8:  taux moyen validation = 0.9886999726295471
# -------- > epoch 9:  coût moyen entraînement = 0.011429019272327423
# -------- > epoch 9:  taux moyen entraînement = 0.9969794154167175
# -------- > epoch 9:  coût moyen validation = 0.24285441637039185
# -------- > epoch 9:  taux moyen validation = 0.932900071144104
# -------- > epoch 10:  coût moyen entraînement = 0.009287698194384575
# -------- > epoch 10:  taux moyen entraînement = 0.9976391792297363
# -------- > epoch 10:  coût moyen validation = 0.042338598519563675
# -------- > epoch 10:  taux moyen validation = 0.9879000782966614
# -------- > epoch 11:  coût moyen entraînement = 0.007474030368030071
# -------- > epoch 11:  taux moyen entraînement = 0.998199462890625
# -------- > epoch 11:  coût moyen validation = 0.041923943907022476
# -------- > epoch 11:  taux moyen validation = 0.9879001379013062
# -------- > epoch 12:  coût moyen entraînement = 0.005945494398474693
# -------- > epoch 12:  taux moyen entraînement = 0.9987795948982239
# -------- > epoch 12:  coût moyen validation = 0.040934666991233826
# -------- > epoch 12:  taux moyen validation = 0.9884999990463257
# -------- > epoch 13:  coût moyen entraînement = 0.0047654034569859505
# -------- > epoch 13:  taux moyen entraînement = 0.9993798136711121
# -------- > epoch 13:  coût moyen validation = 0.03716797009110451
# -------- > epoch 13:  taux moyen validation = 0.9894000887870789
# -------- > epoch 14:  coût moyen entraînement = 0.003979320637881756
# -------- > epoch 14:  taux moyen entraînement = 0.999459981918335
# -------- > epoch 14:  coût moyen validation = 0.036245137453079224
# -------- > epoch 14:  taux moyen validation = 0.9902999401092529
# -------- > epoch 15:  coût moyen entraînement = 0.0035199755802750587
# -------- > epoch 15:  taux moyen entraînement = 0.9995999336242676
# -------- > epoch 15:  coût moyen validation = 0.036351900547742844
# -------- > epoch 15:  taux moyen validation = 0.9907997846603394
# -------- > epoch 16:  coût moyen entraînement = 0.002651551738381386
# -------- > epoch 16:  taux moyen entraînement = 0.9997398853302002
# -------- > epoch 16:  coût moyen validation = 0.036300964653491974
# -------- > epoch 16:  taux moyen validation = 0.9904999732971191
# -------- > epoch 17:  coût moyen entraînement = 0.00235164538025856
# -------- > epoch 17:  taux moyen entraînement = 0.9999200105667114
# -------- > epoch 17:  coût moyen validation = 0.037322573363780975
# -------- > epoch 17:  taux moyen validation = 0.9901998043060303
# -------- > epoch 18:  coût moyen entraînement = 0.002153016161173582
# -------- > epoch 18:  taux moyen entraînement = 0.9998399019241333
# -------- > epoch 18:  coût moyen validation = 0.0388290211558342
# -------- > epoch 18:  taux moyen validation = 0.9897998571395874
# -------- > epoch 19:  coût moyen entraînement = 0.0018933709943667054
# -------- > epoch 19:  taux moyen entraînement = 0.9999200701713562
# -------- > epoch 19:  coût moyen validation = 0.0387420617043972
# -------- > epoch 19:  taux moyen validation = 0.9902999401092529
# -------- > epoch 20:  coût moyen entraînement = 0.0016578197246417403
# -------- > epoch 20:  taux moyen entraînement = 0.9999799728393555
# -------- > epoch 20:  coût moyen validation = 0.036074116826057434
# -------- > epoch 20:  taux moyen validation = 0.990199863910675
# -------- > epoch 21:  coût moyen entraînement = 0.001471384079195559
# -------- > epoch 21:  taux moyen entraînement = 1.0
# -------- > epoch 21:  coût moyen validation = 0.03965814784169197
# -------- > epoch 21:  taux moyen validation = 0.9896998405456543
# -------- > epoch 22:  coût moyen entraînement = 0.0013362698955461383
# -------- > epoch 22:  taux moyen entraînement = 1.0
# -------- > epoch 22:  coût moyen validation = 0.03911975771188736
# -------- > epoch 22:  taux moyen validation = 0.9906999468803406
# -------- > epoch 23:  coût moyen entraînement = 0.0012745739659294486
# -------- > epoch 23:  taux moyen entraînement = 0.9999799728393555
# -------- > epoch 23:  coût moyen validation = 0.04001699015498161
# -------- > epoch 23:  taux moyen validation = 0.9895998239517212
# -------- > epoch 24:  coût moyen entraînement = 0.0011167586781084538
# -------- > epoch 24:  taux moyen entraînement = 1.0
# -------- > epoch 24:  coût moyen validation = 0.03946486860513687
# -------- > epoch 24:  taux moyen validation = 0.9901998043060303
# -------- > epoch 25:  coût moyen entraînement = 0.001070082071237266
# -------- > epoch 25:  taux moyen entraînement = 1.0
# -------- > epoch 25:  coût moyen validation = 0.03911072760820389
# -------- > epoch 25:  taux moyen validation = 0.9900999665260315
# -------- > epoch 26:  coût moyen entraînement = 0.0010173134505748749
# -------- > epoch 26:  taux moyen entraînement = 1.0
# -------- > epoch 26:  coût moyen validation = 0.040324583649635315
# -------- > epoch 26:  taux moyen validation = 0.9903998374938965
# -------- > epoch 27:  coût moyen entraînement = 0.0009012556402012706
# -------- > epoch 27:  taux moyen entraînement = 1.0
# -------- > epoch 27:  coût moyen validation = 0.039288561791181564
# -------- > epoch 27:  taux moyen validation = 0.990399956703186
# -------- > epoch 28:  coût moyen entraînement = 0.0008915193029679358
# -------- > epoch 28:  taux moyen entraînement = 1.0
# -------- > epoch 28:  coût moyen validation = 0.04066194221377373
# -------- > epoch 28:  taux moyen validation = 0.9903998374938965
# -------- > epoch 29:  coût moyen entraînement = 0.0008129040361382067
# -------- > epoch 29:  taux moyen entraînement = 1.0
# -------- > epoch 29:  coût moyen validation = 0.039834629744291306
# -------- > epoch 29:  taux moyen validation = 0.9907998442649841
# -------- > epoch 30:  coût moyen entraînement = 0.0007908460102044046
# -------- > epoch 30:  taux moyen entraînement = 1.0
# -------- > epoch 30:  coût moyen validation = 0.04050632566213608
# -------- > epoch 30:  taux moyen validation = 0.9902998208999634
