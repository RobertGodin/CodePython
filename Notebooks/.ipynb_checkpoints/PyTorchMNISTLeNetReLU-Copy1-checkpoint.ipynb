# %%
# %matplotlib inline
# -*- coding: utf-8 -*-
"""
Exemple MNIST avec réseau LeNet (LeCun et al.)
"""
import torch
torch.manual_seed(0) # Pour résultats reproductibles

# Fonction J d'entropie croisée
import torch.nn.functional as F
fonction_cout = F.cross_entropy

def taux_bonnes_predictions(lot_Y_predictions, lot_Y):
    predictions_categorie = torch.argmax(lot_Y_predictions, dim=1)
    return (predictions_categorie == lot_Y).float().mean()

from torch import nn
# Définition de l'architecture du RNA

modele = torch.nn.Sequential(
    nn.Conv2d(1, 6, kernel_size=5, padding=2), nn.ReLU(), #(N, 1, 28, 28) -> (N, 6, 28, 28)
    nn.AvgPool2d(kernel_size=2, stride=2), #(N, 6, 28, 28) -> (N, 6, 14, 14)
    nn.Conv2d(6, 16, kernel_size=5), nn.ReLU(), #(N, 6, 14, 14) -> (N, 16, 10, 10)
    nn.AvgPool2d(kernel_size=2, stride=2), #(N, 16, 10, 10) -> (N, 16, 5, 5)
    nn.Flatten(), #(N, 16, 5, 5) -> (N, 400)
    nn.Linear(16 * 5 * 5, 120), nn.ReLU(), #(N, 400) -> (N, 120)
    nn.Linear(120, 84), nn.ReLU(), #(N, 120) -> (N, 84)
    nn.Linear(84, 10)) #(N, 84) -> (N, 10)

from torch import optim
optimiseur = optim.SGD(modele.parameters(), lr=0.5)

import torchvision
import torchvision.transforms as transforms

#Chargement des données
ds = torchvision.datasets.FashionMNIST(root = "./data", train = True, download = True, transform = transforms.ToTensor())
ds_ent, ds_valid = torch.utils.data.random_split(ds, [50000, 10000])
ds_test = torchvision.datasets.FashionMNIST(root = "./data", train = False, download = True, transform = transforms.ToTensor())

#Création du DataLoader avec le dataset
dl_ent = torch.utils.data.DataLoader(ds_ent, batch_size=100, shuffle = True)
dl_valid = torch.utils.data.DataLoader(ds_valid, batch_size=100)

def entrainer(modele, dl_ent, dl_valid, optimiseur, nb_epochs=10):

    # Listes pour les métriques par epoch
    liste_cout_moyen_ent = []
    liste_taux_moyen_ent = []
    liste_cout_moyen_valid = []
    liste_taux_moyen_valid = []
    
    # Boucle d'apprentissage
    for epoch in range(nb_epochs):
        cout_total_ent = 0 # pour cumuler les couts par mini-lot
        taux_bonnes_predictions_ent = 0 # pour cumuler les taux par mini-lot
        modele.train() # Pour certains types de couches (nn.BatchNorm2d, nn.Dropout, ...)
        
        # Boucle d'apprentissage par mini-lot pour une epoch
        for lot_X, lot_Y in dl_ent:
            optimiseur.zero_grad() # Remettre les dérivées à zéro
            lot_Y_predictions = modele(lot_X) # Appel de la méthode forward
            cout = fonction_cout(lot_Y_predictions, lot_Y)
            cout.backward() # Calcul des gradiants par rétropropagation
            with torch.no_grad():
                cout_total_ent +=cout
                taux_bonnes_predictions_ent += taux_bonnes_predictions(lot_Y_predictions, lot_Y)
            optimiseur.step() # Mise à jour des paramètres
        # Calculer les moyennes par mini-lot
        with torch.no_grad():
            cout_moyen_ent = cout_total_ent/len(dl_ent)
            taux_moyen_ent = taux_bonnes_predictions_ent/len(dl_ent)
       
        modele.eval() # Pour certains types de couches (nn.BatchNorm2d, nn.Dropout, ...)
        with torch.no_grad():
            cout_valid = sum(fonction_cout(modele(lot_valid_X), lot_valid_Y) for lot_valid_X, lot_valid_Y in dl_valid)
            taux_bons_valid = sum(taux_bonnes_predictions(modele(lot_valid_X), lot_valid_Y) for lot_valid_X, lot_valid_Y in dl_valid)
        cout_moyen_valid = cout_valid/len(dl_valid)
        taux_moyen_valid = taux_bons_valid/len(dl_valid)
        print(f'-------- > epoch {epoch+1}:  coût moyen entraînement = {cout_moyen_ent}')
        print(f'-------- > epoch {epoch+1}:  taux moyen entraînement = {taux_moyen_ent}')
        print(f'-------- > epoch {epoch+1}:  coût moyen validation = {cout_moyen_valid}')
        print(f'-------- > epoch {epoch+1}:  taux moyen validation = {taux_moyen_valid}')
    
        liste_cout_moyen_ent.append(cout_moyen_ent)
        liste_taux_moyen_ent.append(taux_moyen_ent)
        liste_cout_moyen_valid.append(cout_moyen_valid)
        liste_taux_moyen_valid.append(taux_moyen_valid)
    
    # Affichage du graphique d'évolution des métriques par epoch
    import numpy as np
    import matplotlib.pyplot as plt
    plt.plot(np.arange(0,nb_epochs),liste_cout_moyen_ent,label='Erreur entraînement')
    plt.plot(np.arange(0,nb_epochs),liste_cout_moyen_valid,label='Erreur validation')
    plt.title("Evolution du coût")
    plt.xlabel('epoch')
    plt.ylabel('moyenne par observation')
    plt.legend(loc='upper center')
    plt.show()
        
    plt.plot(np.arange(0,nb_epochs),liste_taux_moyen_ent,label='Taux bonnes réponses entraînement')
    plt.plot(np.arange(0,nb_epochs),liste_taux_moyen_valid,label='Taux bonnes réponses validation')
    plt.title("Evolution du taux")
    plt.xlabel('epoch')
    plt.ylabel('moyenne par observation')
    plt.legend(loc='lower center')
    plt.show()

entrainer(modele, dl_ent, dl_valid, optimiseur, nb_epochs=50)
# Out:
# -------- > epoch 1:  coût moyen entraînement = 1.1740190982818604
# -------- > epoch 1:  taux moyen entraînement = 0.5482801198959351
# -------- > epoch 1:  coût moyen validation = 0.5081219673156738
# -------- > epoch 1:  taux moyen validation = 0.7974002361297607
# -------- > epoch 2:  coût moyen entraînement = 0.4879923462867737
# -------- > epoch 2:  taux moyen entraînement = 0.8124793767929077
# -------- > epoch 2:  coût moyen validation = 0.489827960729599
# -------- > epoch 2:  taux moyen validation = 0.820900022983551
# -------- > epoch 3:  coût moyen entraînement = 0.41118350625038147
# -------- > epoch 3:  taux moyen entraînement = 0.8442996144294739
# -------- > epoch 3:  coût moyen validation = 0.3732175827026367
# -------- > epoch 3:  taux moyen validation = 0.8638999462127686
# -------- > epoch 4:  coût moyen entraînement = 0.37108197808265686
# -------- > epoch 4:  taux moyen entraînement = 0.8599001169204712
# -------- > epoch 4:  coût moyen validation = 0.36247894167900085
# -------- > epoch 4:  taux moyen validation = 0.8678998351097107
# -------- > epoch 5:  coût moyen entraînement = 0.34826159477233887
# -------- > epoch 5:  taux moyen entraînement = 0.8680598139762878
# -------- > epoch 5:  coût moyen validation = 0.3833504617214203
# -------- > epoch 5:  taux moyen validation = 0.8532999157905579
# -------- > epoch 6:  coût moyen entraînement = 0.33269089460372925
# -------- > epoch 6:  taux moyen entraînement = 0.8736403584480286
# -------- > epoch 6:  coût moyen validation = 0.3312956690788269
# -------- > epoch 6:  taux moyen validation = 0.8782000541687012
# -------- > epoch 7:  coût moyen entraînement = 0.31748640537261963
# -------- > epoch 7:  taux moyen entraînement = 0.8799408078193665
# -------- > epoch 7:  coût moyen validation = 0.34325528144836426
# -------- > epoch 7:  taux moyen validation = 0.8716998100280762
# -------- > epoch 8:  coût moyen entraînement = 0.3084203898906708
# -------- > epoch 8:  taux moyen entraînement = 0.8820599913597107
# -------- > epoch 8:  coût moyen validation = 0.34588924050331116
# -------- > epoch 8:  taux moyen validation = 0.8765000104904175
# -------- > epoch 9:  coût moyen entraînement = 0.2975665330886841
# -------- > epoch 9:  taux moyen entraînement = 0.8860204219818115
# -------- > epoch 9:  coût moyen validation = 0.3687373697757721
# -------- > epoch 9:  taux moyen validation = 0.8620001077651978
# -------- > epoch 10:  coût moyen entraînement = 0.28733107447624207
# -------- > epoch 10:  taux moyen entraînement = 0.8900404572486877
# -------- > epoch 10:  coût moyen validation = 0.31913891434669495
# -------- > epoch 10:  taux moyen validation = 0.8823999762535095
# -------- > epoch 11:  coût moyen entraînement = 0.2801593542098999
# -------- > epoch 11:  taux moyen entraînement = 0.8942406177520752
# -------- > epoch 11:  coût moyen validation = 0.31559857726097107
# -------- > epoch 11:  taux moyen validation = 0.8839999437332153
# -------- > epoch 12:  coût moyen entraînement = 0.27223941683769226
# -------- > epoch 12:  taux moyen entraînement = 0.8956803679466248
# -------- > epoch 12:  coût moyen validation = 0.3113783001899719
# -------- > epoch 12:  taux moyen validation = 0.8862999081611633
# -------- > epoch 13:  coût moyen entraînement = 0.26644518971443176
# -------- > epoch 13:  taux moyen entraînement = 0.8977606296539307
# -------- > epoch 13:  coût moyen validation = 0.3186711370944977
# -------- > epoch 13:  taux moyen validation = 0.8901000022888184
# -------- > epoch 14:  coût moyen entraînement = 0.2569546401500702
# -------- > epoch 14:  taux moyen entraînement = 0.9018006324768066
# -------- > epoch 14:  coût moyen validation = 0.32264789938926697
# -------- > epoch 14:  taux moyen validation = 0.8863999247550964
# -------- > epoch 15:  coût moyen entraînement = 0.25421395897865295
# -------- > epoch 15:  taux moyen entraînement = 0.9019008874893188
# -------- > epoch 15:  coût moyen validation = 0.33150091767311096
# -------- > epoch 15:  taux moyen validation = 0.8815997838973999
# -------- > epoch 16:  coût moyen entraînement = 0.2464333325624466
# -------- > epoch 16:  taux moyen entraînement = 0.9053806066513062
# -------- > epoch 16:  coût moyen validation = 0.3177036941051483
# -------- > epoch 16:  taux moyen validation = 0.8895001411437988
# -------- > epoch 17:  coût moyen entraînement = 0.24308748543262482
# -------- > epoch 17:  taux moyen entraînement = 0.9077215790748596
# -------- > epoch 17:  coût moyen validation = 0.3319658041000366
# -------- > epoch 17:  taux moyen validation = 0.8854999542236328
# -------- > epoch 18:  coût moyen entraînement = 0.2352646142244339
# -------- > epoch 18:  taux moyen entraînement = 0.9101811647415161
# -------- > epoch 18:  coût moyen validation = 0.3162156045436859
# -------- > epoch 18:  taux moyen validation = 0.8941001296043396
# -------- > epoch 19:  coût moyen entraînement = 0.23209252953529358
# -------- > epoch 19:  taux moyen entraînement = 0.9109209775924683
# -------- > epoch 19:  coût moyen validation = 0.3371303081512451
# -------- > epoch 19:  taux moyen validation = 0.8805999755859375
# -------- > epoch 20:  coût moyen entraînement = 0.2297745943069458
# -------- > epoch 20:  taux moyen entraînement = 0.910540759563446
# -------- > epoch 20:  coût moyen validation = 0.3225112557411194
# -------- > epoch 20:  taux moyen validation = 0.890700101852417
# -------- > epoch 21:  coût moyen entraînement = 0.22496788203716278
# -------- > epoch 21:  taux moyen entraînement = 0.9130805730819702
# -------- > epoch 21:  coût moyen validation = 0.37814339995384216
# -------- > epoch 21:  taux moyen validation = 0.8686999678611755
# -------- > epoch 22:  coût moyen entraînement = 0.21994438767433167
# -------- > epoch 22:  taux moyen entraînement = 0.9158211350440979
# -------- > epoch 22:  coût moyen validation = 0.3231324255466461
# -------- > epoch 22:  taux moyen validation = 0.890800416469574
# -------- > epoch 23:  coût moyen entraînement = 0.21758103370666504
# -------- > epoch 23:  taux moyen entraînement = 0.9175404906272888
# -------- > epoch 23:  coût moyen validation = 0.34452536702156067
# -------- > epoch 23:  taux moyen validation = 0.891299843788147
# -------- > epoch 24:  coût moyen entraînement = 0.2177053540945053
# -------- > epoch 24:  taux moyen entraînement = 0.9164610505104065
# -------- > epoch 24:  coût moyen validation = 0.3654598891735077
# -------- > epoch 24:  taux moyen validation = 0.886699914932251
# -------- > epoch 25:  coût moyen entraînement = 0.20923306047916412
# -------- > epoch 25:  taux moyen entraînement = 0.9203807711601257
# -------- > epoch 25:  coût moyen validation = 0.32841968536376953
# -------- > epoch 25:  taux moyen validation = 0.8957000970840454
# -------- > epoch 26:  coût moyen entraînement = 0.20465987920761108
# -------- > epoch 26:  taux moyen entraînement = 0.92112135887146
# -------- > epoch 26:  coût moyen validation = 0.36306217312812805
# -------- > epoch 26:  taux moyen validation = 0.8905001282691956
# -------- > epoch 27:  coût moyen entraînement = 0.19970163702964783
# -------- > epoch 27:  taux moyen entraînement = 0.9235813617706299
# -------- > epoch 27:  coût moyen validation = 0.3996203541755676
# -------- > epoch 27:  taux moyen validation = 0.8729000091552734
# -------- > epoch 28:  coût moyen entraînement = 0.19495567679405212
# -------- > epoch 28:  taux moyen entraînement = 0.9249011278152466
# -------- > epoch 28:  coût moyen validation = 0.36903902888298035
# -------- > epoch 28:  taux moyen validation = 0.8871003985404968
# -------- > epoch 29:  coût moyen entraînement = 0.19833572208881378
# -------- > epoch 29:  taux moyen entraînement = 0.9227809309959412
# -------- > epoch 29:  coût moyen validation = 0.4287244379520416
# -------- > epoch 29:  taux moyen validation = 0.8715999722480774
# -------- > epoch 30:  coût moyen entraînement = 0.19068022072315216
# -------- > epoch 30:  taux moyen entraînement = 0.9262005686759949
# -------- > epoch 30:  coût moyen validation = 0.3806149363517761
# -------- > epoch 30:  taux moyen validation = 0.8884000182151794
# -------- > epoch 31:  coût moyen entraînement = 0.19487068057060242
# -------- > epoch 31:  taux moyen entraînement = 0.9244412183761597
# -------- > epoch 31:  coût moyen validation = 0.3966630697250366
# -------- > epoch 31:  taux moyen validation = 0.88319993019104
# -------- > epoch 32:  coût moyen entraînement = 0.18843702971935272
# -------- > epoch 32:  taux moyen entraînement = 0.9266412258148193
# -------- > epoch 32:  coût moyen validation = 0.4508149325847626
# -------- > epoch 32:  taux moyen validation = 0.8734999299049377
# -------- > epoch 33:  coût moyen entraînement = 0.1894257813692093
# -------- > epoch 33:  taux moyen entraînement = 0.9273614287376404
# -------- > epoch 33:  coût moyen validation = 0.367035835981369
# -------- > epoch 33:  taux moyen validation = 0.8938999772071838
# -------- > epoch 34:  coût moyen entraînement = 0.1882702261209488
# -------- > epoch 34:  taux moyen entraînement = 0.927401065826416
# -------- > epoch 34:  coût moyen validation = 0.35473576188087463
# -------- > epoch 34:  taux moyen validation = 0.8955001831054688
# -------- > epoch 35:  coût moyen entraînement = 0.18168579041957855
# -------- > epoch 35:  taux moyen entraînement = 0.9312810301780701
# -------- > epoch 35:  coût moyen validation = 0.37522202730178833
# -------- > epoch 35:  taux moyen validation = 0.8885001540184021
# -------- > epoch 36:  coût moyen entraînement = 0.18169590830802917
# -------- > epoch 36:  taux moyen entraînement = 0.9302411675453186
# -------- > epoch 36:  coût moyen validation = 0.38292500376701355
# -------- > epoch 36:  taux moyen validation = 0.8921999931335449
# -------- > epoch 37:  coût moyen entraînement = 0.17580515146255493
# -------- > epoch 37:  taux moyen entraînement = 0.9304614067077637
# -------- > epoch 37:  coût moyen validation = 0.4199756383895874
# -------- > epoch 37:  taux moyen validation = 0.8934999108314514
# -------- > epoch 38:  coût moyen entraînement = 0.1747664511203766
# -------- > epoch 38:  taux moyen entraînement = 0.9325212240219116
# -------- > epoch 38:  coût moyen validation = 0.389600932598114
# -------- > epoch 38:  taux moyen validation = 0.8920001983642578
# -------- > epoch 39:  coût moyen entraînement = 0.17467258870601654
# -------- > epoch 39:  taux moyen entraînement = 0.9313206076622009
# -------- > epoch 39:  coût moyen validation = 0.40955811738967896
# -------- > epoch 39:  taux moyen validation = 0.8940001130104065
# -------- > epoch 40:  coût moyen entraînement = 0.1747014820575714
# -------- > epoch 40:  taux moyen entraînement = 0.9336810111999512
# -------- > epoch 40:  coût moyen validation = 0.40147170424461365
# -------- > epoch 40:  taux moyen validation = 0.8922001719474792
# -------- > epoch 41:  coût moyen entraînement = 0.1765228509902954
# -------- > epoch 41:  taux moyen entraînement = 0.9317208528518677
# -------- > epoch 41:  coût moyen validation = 0.414730042219162
# -------- > epoch 41:  taux moyen validation = 0.8928002715110779
# -------- > epoch 42:  coût moyen entraînement = 0.16375716030597687
# -------- > epoch 42:  taux moyen entraînement = 0.9365809559822083
# -------- > epoch 42:  coût moyen validation = 0.3922007381916046
# -------- > epoch 42:  taux moyen validation = 0.8940999507904053
# -------- > epoch 43:  coût moyen entraînement = 0.1729377657175064
# -------- > epoch 43:  taux moyen entraînement = 0.9341608285903931
# -------- > epoch 43:  coût moyen validation = 0.39575740694999695
# -------- > epoch 43:  taux moyen validation = 0.8928999304771423
# -------- > epoch 44:  coût moyen entraînement = 0.16134415566921234
# -------- > epoch 44:  taux moyen entraînement = 0.93784099817276
# -------- > epoch 44:  coût moyen validation = 0.43665313720703125
# -------- > epoch 44:  taux moyen validation = 0.8909999132156372
# -------- > epoch 45:  coût moyen entraînement = 0.1618189662694931
# -------- > epoch 45:  taux moyen entraînement = 0.9372806549072266
# -------- > epoch 45:  coût moyen validation = 0.4107622504234314
# -------- > epoch 45:  taux moyen validation = 0.8980000019073486
# -------- > epoch 46:  coût moyen entraînement = 0.161215677857399
# -------- > epoch 46:  taux moyen entraînement = 0.9374414682388306
# -------- > epoch 46:  coût moyen validation = 0.409952849149704
# -------- > epoch 46:  taux moyen validation = 0.8941999673843384
# -------- > epoch 47:  coût moyen entraînement = 0.17164355516433716
# -------- > epoch 47:  taux moyen entraînement = 0.9356208443641663
# -------- > epoch 47:  coût moyen validation = 0.41853126883506775
# -------- > epoch 47:  taux moyen validation = 0.8931002020835876
# -------- > epoch 48:  coût moyen entraînement = 0.16301682591438293
# -------- > epoch 48:  taux moyen entraînement = 0.9385213255882263
# -------- > epoch 48:  coût moyen validation = 0.42900413274765015
# -------- > epoch 48:  taux moyen validation = 0.8938000202178955
# -------- > epoch 49:  coût moyen entraînement = 0.1568216234445572
# -------- > epoch 49:  taux moyen entraînement = 0.9396411180496216
# -------- > epoch 49:  coût moyen validation = 0.4491725265979767
# -------- > epoch 49:  taux moyen validation = 0.8880001902580261
# -------- > epoch 50:  coût moyen entraînement = 0.1538676768541336
# -------- > epoch 50:  taux moyen entraînement = 0.9411607980728149
# -------- > epoch 50:  coût moyen validation = 0.44422751665115356
# -------- > epoch 50:  taux moyen validation = 0.8927002549171448

# %%
X = torch.randn(size=(1, 1, 28, 28), dtype=torch.float32)
for une_couche in modele:
    X = une_couche(X)
    print('Type de couche:',une_couche.__class__.__name__,'  Forme de sortie:',X.shape)
# Out:
# Type de couche: Conv2d   Forme de sortie: torch.Size([1, 6, 28, 28])
# Type de couche: ReLU   Forme de sortie: torch.Size([1, 6, 28, 28])
# Type de couche: AvgPool2d   Forme de sortie: torch.Size([1, 6, 14, 14])
# Type de couche: Conv2d   Forme de sortie: torch.Size([1, 16, 10, 10])
# Type de couche: ReLU   Forme de sortie: torch.Size([1, 16, 10, 10])
# Type de couche: AvgPool2d   Forme de sortie: torch.Size([1, 16, 5, 5])
# Type de couche: Flatten   Forme de sortie: torch.Size([1, 400])
# Type de couche: Linear   Forme de sortie: torch.Size([1, 120])
# Type de couche: ReLU   Forme de sortie: torch.Size([1, 120])
# Type de couche: Linear   Forme de sortie: torch.Size([1, 84])
# Type de couche: ReLU   Forme de sortie: torch.Size([1, 84])
# Type de couche: Linear   Forme de sortie: torch.Size([1, 10])

# %%
optimiseur = optim.SGD(modele.parameters(), lr=0.001)
entrainer(modele, dl_ent, dl_valid, optimiseur, nb_epochs=10)
# Out:
# -------- > epoch 1:  coût moyen entraînement = 1.593276647327002e-05
# -------- > epoch 1:  taux moyen entraînement = 1.0
# -------- > epoch 1:  coût moyen validation = 0.06867596507072449
# -------- > epoch 1:  taux moyen validation = 0.9902999997138977
# -------- > epoch 2:  coût moyen entraînement = 1.5930625522742048e-05
# -------- > epoch 2:  taux moyen entraînement = 1.0
# -------- > epoch 2:  coût moyen validation = 0.06867687404155731
# -------- > epoch 2:  taux moyen validation = 0.9902999997138977
# -------- > epoch 3:  coût moyen entraînement = 1.5928484572214074e-05
# -------- > epoch 3:  taux moyen entraînement = 1.0
# -------- > epoch 3:  coût moyen validation = 0.06867781281471252
# -------- > epoch 3:  taux moyen validation = 0.9902999997138977
# -------- > epoch 4:  coût moyen entraînement = 1.5926325431792066e-05
# -------- > epoch 4:  taux moyen entraînement = 1.0
# -------- > epoch 4:  coût moyen validation = 0.06867871433496475
# -------- > epoch 4:  taux moyen validation = 0.9902999997138977
# -------- > epoch 5:  coût moyen entraînement = 1.5924242688925005e-05
# -------- > epoch 5:  taux moyen entraînement = 1.0
# -------- > epoch 5:  coût moyen validation = 0.06867961585521698
# -------- > epoch 5:  taux moyen validation = 0.9902999997138977
# -------- > epoch 6:  coût moyen entraînement = 1.592209628142882e-05
# -------- > epoch 6:  taux moyen entraînement = 1.0
# -------- > epoch 6:  coût moyen validation = 0.06868049502372742
# -------- > epoch 6:  taux moyen validation = 0.9902999997138977
# -------- > epoch 7:  coût moyen entraînement = 1.5920018995529972e-05
# -------- > epoch 7:  taux moyen entraînement = 1.0
# -------- > epoch 7:  coût moyen validation = 0.06868138909339905
# -------- > epoch 7:  taux moyen validation = 0.9902999997138977
# -------- > epoch 8:  coût moyen entraînement = 1.5917912605800666e-05
# -------- > epoch 8:  taux moyen entraînement = 1.0
# -------- > epoch 8:  coût moyen validation = 0.06868227571249008
# -------- > epoch 8:  taux moyen validation = 0.9902999997138977
# -------- > epoch 9:  coût moyen entraînement = 1.5915771655272692e-05
# -------- > epoch 9:  taux moyen entraînement = 1.0
# -------- > epoch 9:  coût moyen validation = 0.06868316978216171
# -------- > epoch 9:  taux moyen validation = 0.9902999997138977
# -------- > epoch 10:  coût moyen entraînement = 1.5913679817458615e-05
# -------- > epoch 10:  taux moyen entraînement = 1.0
# -------- > epoch 10:  coût moyen validation = 0.06868407875299454
# -------- > epoch 10:  taux moyen validation = 0.9902999997138977
