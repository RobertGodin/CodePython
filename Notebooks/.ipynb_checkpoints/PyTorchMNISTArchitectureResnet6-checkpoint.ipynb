# %%
# %matplotlib inline
# -*- coding: utf-8 -*-
"""
Exemple de MNIST avec PyTorch
Exemple avec ResNet18
"""
import torch
torch.manual_seed(0) # Pour résultats reproductibles

# Fonction J d'entropie croisée
import torch.nn.functional as F
fonction_cout = F.cross_entropy

def taux_bonnes_predictions(lot_Y_predictions, lot_Y):
    predictions_categorie = torch.argmax(lot_Y_predictions, dim=1)
    return (predictions_categorie == lot_Y).float().mean()

from torch import nn
# Définition de l'architecture du RNA

class BlocResiduel2d(nn.Module):
    def __init__(self, nb_canaux_in, nb_canaux_out,pas=1):
        super().__init__()
        self.conv1 = nn.Conv2d(nb_canaux_in, nb_canaux_out,kernel_size=3, padding=1, stride=pas)
        self.conv2 = nn.Conv2d(nb_canaux_out, nb_canaux_out,kernel_size=3, padding=1)
        if nb_canaux_in <> nb_canaux_out:
            self.conv3 = nn.Conv2d(nb_canaux_in, nb_canaux_out,kernel_size=1, stride=pas)
        self.bn1 = nn.BatchNorm2d(nb_canaux_out)
        self.bn2 = nn.BatchNorm2d(nb_canaux_out)
        self.relu = nn.ReLU(inplace=True)

    def forward(self, lot_X):
        lot_Y_predictions = F.relu(self.bn1(self.conv1(lot_X)))
        lot_Y_predictions = self.bn2(self.conv2(Y))
        if nb_canaux_in <> nb_canaux_out:
            lot_X = self.conv3(lot_X)
        lot_Y_predictions += lot_X
        return F.relu(lot_Y_predictions)

modele_resnet18 = nn.Sequential(nn.Conv2d(1, 64, kernel_size=7, stride=2, padding=3), # ->(N,64,112,112)
                   nn.BatchNorm2d(64), nn.ReLU(), # ->(N,64,112,112)
                   nn.MaxPool2d(kernel_size=3, stride=2, padding=1),# ->(N,64,56,56)
                   BlocResiduel2d(64,64), BlocResiduel2d(64,64) ,# ->(N,64,56,56)
                   BlocResiduel2d(64,128,2), BlocResiduel2d(128,128),# ->(N,128,28,28)
                   BlocResiduel2d(128,256,2), BlocResiduel2d(256,256),# ->(N,256,256,14)
                   BlocResiduel2d(256,512,2), BlocResiduel2d(512,512),# ->(N,512,512,7)
                   nn.AdaptiveMaxPool2d((1,1)), nn.Flatten(), nn.Linear(512,10)
                  )

from torch import optim
optimiseur = optim.SGD(modele.parameters(), lr=0.01)

# Chargement des données de MNIST
import pickle, gzip
fichier_donnees = gzip.open(r"mnist.pkl.gz", 'rb')
((donnees_ent_X, donnees_ent_Y),(donnees_valid_X, donnees_valid_Y),(donnees_test_X,donnees_test_Y)) = pickle.load(fichier_donnees, encoding="latin-1")
fichier_donnees.close()

# Conversion des données en type toch.Tensor
import torch
donnees_ent_X,donnees_ent_Y,donnees_valid_X,donnees_valid_Y,donnees_test_X,donnees_test_Y  = map(torch.tensor,
    (donnees_ent_X.reshape((-1,1,28,28)),donnees_ent_Y,donnees_valid_X.reshape((-1,1,28,28)),donnees_valid_Y,donnees_test_X.reshape((-1,1,28,28)),donnees_test_Y))

# Création des objets DataLoader pour itérer par lot
from torch.utils.data import TensorDataset
from torch.utils.data import DataLoader
ds_ent = TensorDataset(donnees_ent_X, donnees_ent_Y)
dl_ent = DataLoader(ds_ent, batch_size=100, shuffle=True)
ds_valid = TensorDataset(donnees_valid_X,donnees_valid_Y)
dl_valid = DataLoader(ds_valid, batch_size=100)

def entrainer(modele, dl_ent, dl_valid, optimiseur, nb_epochs=10):

    # Listes pour les métriques par epoch
    liste_cout_moyen_ent = []
    liste_taux_moyen_ent = []
    liste_cout_moyen_valid = []
    liste_taux_moyen_valid = []
    
    # Boucle d'apprentissage
    for epoch in range(nb_epochs):
        cout_total_ent = 0 # pour cumuler les couts par mini-lot
        taux_bonnes_predictions_ent = 0 # pour cumuler les taux par mini-lot
        modele.train() # Pour certains types de couches (nn.BatchNorm2d, nn.Dropout, ...)
        
        # Boucle d'apprentissage par mini-lot pour une epoch
        for lot_X, lot_Y in dl_ent:
            optimiseur.zero_grad() # Remettre les dérivées à zéro
            lot_Y_predictions = modele(lot_X) # Appel de la méthode forward
            cout = fonction_cout(lot_Y_predictions, lot_Y)
            cout.backward() # Calcul des gradiants par rétropropagation
            with torch.no_grad():
                cout_total_ent +=cout
                taux_bonnes_predictions_ent += taux_bonnes_predictions(lot_Y_predictions, lot_Y)
            optimiseur.step() # Mise à jour des paramètres
            # scheduler.step()
        # Calculer les moyennes par mini-lot
        with torch.no_grad():
            cout_moyen_ent = cout_total_ent/len(dl_ent)
            taux_moyen_ent = taux_bonnes_predictions_ent/len(dl_ent)
       
        modele.eval() # Pour certains types de couches (nn.BatchNorm2d, nn.Dropout, ...)
        with torch.no_grad():
            cout_valid = sum(fonction_cout(modele(lot_valid_X), lot_valid_Y) for lot_valid_X, lot_valid_Y in dl_valid)
            taux_bons_valid = sum(taux_bonnes_predictions(modele(lot_valid_X), lot_valid_Y) for lot_valid_X, lot_valid_Y in dl_valid)
        cout_moyen_valid = cout_valid/len(dl_valid)
        taux_moyen_valid = taux_bons_valid/len(dl_valid)
        print(f'-------- > epoch {epoch+1}:  coût moyen entraînement = {cout_moyen_ent}')
        print(f'-------- > epoch {epoch+1}:  taux moyen entraînement = {taux_moyen_ent}')
        print(f'-------- > epoch {epoch+1}:  coût moyen validation = {cout_moyen_valid}')
        print(f'-------- > epoch {epoch+1}:  taux moyen validation = {taux_moyen_valid}')
    
        liste_cout_moyen_ent.append(cout_moyen_ent)
        liste_taux_moyen_ent.append(taux_moyen_ent)
        liste_cout_moyen_valid.append(cout_moyen_valid)
        liste_taux_moyen_valid.append(taux_moyen_valid)
    
    # Affichage du graphique d'évolution des métriques par epoch
    import numpy as np
    import matplotlib.pyplot as plt
    plt.plot(np.arange(0,nb_epochs),liste_cout_moyen_ent,label='Erreur entraînement')
    plt.plot(np.arange(0,nb_epochs),liste_cout_moyen_valid,label='Erreur validation')
    plt.title("Evolution du coût")
    plt.xlabel('epoch')
    plt.ylabel('moyenne par observation')
    plt.legend(loc='upper center')
    plt.show()
        
    plt.plot(np.arange(0,nb_epochs),liste_taux_moyen_ent,label='Taux bonnes réponses entraînement')
    plt.plot(np.arange(0,nb_epochs),liste_taux_moyen_valid,label='Taux bonnes réponses validation')
    plt.title("Evolution du taux")
    plt.xlabel('epoch')
    plt.ylabel('moyenne par observation')
    plt.legend(loc='center')
    plt.show()

entrainer(modele, dl_ent, dl_valid, optimiseur, nb_epochs=30)
# Out:
# -------- > epoch 1:  coût moyen entraînement = 0.616504967212677
# -------- > epoch 1:  taux moyen entraînement = 0.8994606733322144
# -------- > epoch 1:  coût moyen validation = 0.2995222210884094
# -------- > epoch 1:  taux moyen validation = 0.9686001539230347
# -------- > epoch 2:  coût moyen entraînement = 0.2762918770313263
# -------- > epoch 2:  taux moyen entraînement = 0.9675804972648621
# -------- > epoch 2:  coût moyen validation = 0.18591147661209106
# -------- > epoch 2:  taux moyen validation = 0.9772001504898071
# -------- > epoch 3:  coût moyen entraînement = 0.18874883651733398
# -------- > epoch 3:  taux moyen entraînement = 0.9758408665657043
# -------- > epoch 3:  coût moyen validation = 0.14867576956748962
# -------- > epoch 3:  taux moyen validation = 0.9793000817298889
# -------- > epoch 4:  coût moyen entraînement = 0.1441245675086975
# -------- > epoch 4:  taux moyen entraînement = 0.9814799427986145
# -------- > epoch 4:  coût moyen validation = 0.11245747655630112
# -------- > epoch 4:  taux moyen validation = 0.9813001751899719
# -------- > epoch 5:  coût moyen entraînement = 0.11648250371217728
# -------- > epoch 5:  taux moyen entraînement = 0.9843800067901611
# -------- > epoch 5:  coût moyen validation = 0.09659308195114136
# -------- > epoch 5:  taux moyen validation = 0.9843000769615173
# -------- > epoch 6:  coût moyen entraînement = 0.09883227199316025
# -------- > epoch 6:  taux moyen entraînement = 0.9868794679641724
# -------- > epoch 6:  coût moyen validation = 0.08980190008878708
# -------- > epoch 6:  taux moyen validation = 0.9849002361297607
# -------- > epoch 7:  coût moyen entraînement = 0.08402654528617859
# -------- > epoch 7:  taux moyen entraînement = 0.9883801937103271
# -------- > epoch 7:  coût moyen validation = 0.07529249787330627
# -------- > epoch 7:  taux moyen validation = 0.9853001236915588
# -------- > epoch 8:  coût moyen entraînement = 0.07318460941314697
# -------- > epoch 8:  taux moyen entraînement = 0.9902798533439636
# -------- > epoch 8:  coût moyen validation = 0.07048358768224716
# -------- > epoch 8:  taux moyen validation = 0.9871000647544861
# -------- > epoch 9:  coût moyen entraînement = 0.06449326872825623
# -------- > epoch 9:  taux moyen entraînement = 0.9919394254684448
# -------- > epoch 9:  coût moyen validation = 0.07111753523349762
# -------- > epoch 9:  taux moyen validation = 0.9853002429008484
# -------- > epoch 10:  coût moyen entraînement = 0.05851811543107033
# -------- > epoch 10:  taux moyen entraînement = 0.9922993183135986
# -------- > epoch 10:  coût moyen validation = 0.06358707696199417
# -------- > epoch 10:  taux moyen validation = 0.9874003529548645
# -------- > epoch 11:  coût moyen entraînement = 0.05123716592788696
# -------- > epoch 11:  taux moyen entraînement = 0.99383944272995
# -------- > epoch 11:  coût moyen validation = 0.06099320948123932
# -------- > epoch 11:  taux moyen validation = 0.9876001477241516
# -------- > epoch 12:  coût moyen entraînement = 0.04825873672962189
# -------- > epoch 12:  taux moyen entraînement = 0.9942993521690369
# -------- > epoch 12:  coût moyen validation = 0.05879206210374832
# -------- > epoch 12:  taux moyen validation = 0.9879001379013062
# -------- > epoch 13:  coût moyen entraînement = 0.042403675615787506
# -------- > epoch 13:  taux moyen entraînement = 0.9951595067977905
# -------- > epoch 13:  coût moyen validation = 0.05599223077297211
# -------- > epoch 13:  taux moyen validation = 0.987800121307373
# -------- > epoch 14:  coût moyen entraînement = 0.0389152429997921
# -------- > epoch 14:  taux moyen entraînement = 0.9960593581199646
# -------- > epoch 14:  coût moyen validation = 0.05412549152970314
# -------- > epoch 14:  taux moyen validation = 0.9885001182556152
# -------- > epoch 15:  coût moyen entraînement = 0.03596082702279091
# -------- > epoch 15:  taux moyen entraînement = 0.9963592886924744
# -------- > epoch 15:  coût moyen validation = 0.05338860675692558
# -------- > epoch 15:  taux moyen validation = 0.9883001446723938
# -------- > epoch 16:  coût moyen entraînement = 0.03403376042842865
# -------- > epoch 16:  taux moyen entraînement = 0.9964995980262756
# -------- > epoch 16:  coût moyen validation = 0.05410056933760643
# -------- > epoch 16:  taux moyen validation = 0.9871000647544861
# -------- > epoch 17:  coût moyen entraînement = 0.029750781133770943
# -------- > epoch 17:  taux moyen entraînement = 0.9971793293952942
# -------- > epoch 17:  coût moyen validation = 0.05253790691494942
# -------- > epoch 17:  taux moyen validation = 0.9873000979423523
# -------- > epoch 18:  coût moyen entraînement = 0.028926482424139977
# -------- > epoch 18:  taux moyen entraînement = 0.9972794651985168
# -------- > epoch 18:  coût moyen validation = 0.049869686365127563
# -------- > epoch 18:  taux moyen validation = 0.9876000881195068
# -------- > epoch 19:  coût moyen entraînement = 0.02582431770861149
# -------- > epoch 19:  taux moyen entraînement = 0.997959554195404
# -------- > epoch 19:  coût moyen validation = 0.05096420273184776
# -------- > epoch 19:  taux moyen validation = 0.9877000451087952
# -------- > epoch 20:  coût moyen entraînement = 0.025925131514668465
# -------- > epoch 20:  taux moyen entraînement = 0.9977594614028931
# -------- > epoch 20:  coût moyen validation = 0.048950690776109695
# -------- > epoch 20:  taux moyen validation = 0.9886001348495483
# -------- > epoch 21:  coût moyen entraînement = 0.023389311507344246
# -------- > epoch 21:  taux moyen entraînement = 0.9980793595314026
# -------- > epoch 21:  coût moyen validation = 0.04818858951330185
# -------- > epoch 21:  taux moyen validation = 0.9880001544952393
# -------- > epoch 22:  coût moyen entraînement = 0.02156943455338478
# -------- > epoch 22:  taux moyen entraînement = 0.9984592199325562
# -------- > epoch 22:  coût moyen validation = 0.048011016100645065
# -------- > epoch 22:  taux moyen validation = 0.9887001514434814
# -------- > epoch 23:  coût moyen entraînement = 0.01995258778333664
# -------- > epoch 23:  taux moyen entraînement = 0.9988194704055786
# -------- > epoch 23:  coût moyen validation = 0.046096719801425934
# -------- > epoch 23:  taux moyen validation = 0.9882000684738159
# -------- > epoch 24:  coût moyen entraînement = 0.019783247262239456
# -------- > epoch 24:  taux moyen entraînement = 0.9984995722770691
# -------- > epoch 24:  coût moyen validation = 0.05127228796482086
# -------- > epoch 24:  taux moyen validation = 0.9876002669334412
# -------- > epoch 25:  coût moyen entraînement = 0.018857130780816078
# -------- > epoch 25:  taux moyen entraînement = 0.9985995888710022
# -------- > epoch 25:  coût moyen validation = 0.04640450328588486
# -------- > epoch 25:  taux moyen validation = 0.9881001114845276
# -------- > epoch 26:  coût moyen entraînement = 0.018230276182293892
# -------- > epoch 26:  taux moyen entraînement = 0.9983596205711365
# -------- > epoch 26:  coût moyen validation = 0.048035696148872375
# -------- > epoch 26:  taux moyen validation = 0.9876000881195068
# -------- > epoch 27:  coût moyen entraînement = 0.017583606764674187
# -------- > epoch 27:  taux moyen entraînement = 0.9987795948982239
# -------- > epoch 27:  coût moyen validation = 0.04705749452114105
# -------- > epoch 27:  taux moyen validation = 0.9884001016616821
# -------- > epoch 28:  coût moyen entraînement = 0.015824398025870323
# -------- > epoch 28:  taux moyen entraînement = 0.9990596771240234
# -------- > epoch 28:  coût moyen validation = 0.04460565000772476
# -------- > epoch 28:  taux moyen validation = 0.9887000322341919
# -------- > epoch 29:  coût moyen entraînement = 0.01572229154407978
# -------- > epoch 29:  taux moyen entraînement = 0.9989597797393799
# -------- > epoch 29:  coût moyen validation = 0.043304022401571274
# -------- > epoch 29:  taux moyen validation = 0.9886000752449036
# -------- > epoch 30:  coût moyen entraînement = 0.014772875234484673
# -------- > epoch 30:  taux moyen entraînement = 0.9991597533226013
# -------- > epoch 30:  coût moyen validation = 0.044150520116090775
# -------- > epoch 30:  taux moyen validation = 0.9891000390052795
