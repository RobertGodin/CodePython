# %%
# %matplotlib inline
# -*- coding: utf-8 -*-
"""
Exemple simple de MNIST avec PyTorch
Exemple avec nn.Conv2d et F.cross_entropy
Production de métriques avec graphes
Fonction entrainer
"""
import torch
torch.manual_seed(0) # Pour résultats reproductibles

# Fonction J d'entropie croisée
import torch.nn.functional as F
fonction_cout = F.cross_entropy

def taux_bonnes_predictions(lot_Y_predictions, lot_Y):
    predictions_categorie = torch.argmax(lot_Y_predictions, dim=1)
    return (predictions_categorie == lot_Y).float().mean()

from torch import nn
# Définition de l'architecture du RNA

modele = nn.Sequential(
    nn.Conv2d(1,32,3,padding=1),
    nn.BatchNorm2d(32),
    nn.ReLU(),
    nn.MaxPool2d(2),
    nn.Conv2d(32,16,3),
    nn.BatchNorm2d(16),
    nn.ReLU(),
    nn.MaxPool2d(2),
    nn.Flatten(),
    nn.Linear(6*6*16,10)
)
    
from torch import optim
optimiseur = optim.SGD(modele.parameters(), lr=0.01)

# Chargement des données de MNIST
import pickle, gzip
fichier_donnees = gzip.open(r"mnist.pkl.gz", 'rb')
((donnees_ent_X, donnees_ent_Y),(donnees_valid_X, donnees_valid_Y),(donnees_test_X,donnees_test_Y)) = pickle.load(fichier_donnees, encoding="latin-1")
fichier_donnees.close()

# Conversion des données en type toch.Tensor
import torch
donnees_ent_X,donnees_ent_Y,donnees_valid_X,donnees_valid_Y,donnees_test_X,donnees_test_Y  = map(torch.tensor,
    (donnees_ent_X.reshape((-1,1,28,28)),donnees_ent_Y,donnees_valid_X.reshape((-1,1,28,28)),donnees_valid_Y,donnees_test_X.reshape((-1,1,28,28)),donnees_test_Y))

# Création des objets DataLoader pour itérer par lot
from torch.utils.data import TensorDataset
from torch.utils.data import DataLoader
ds_ent = TensorDataset(donnees_ent_X, donnees_ent_Y)
dl_ent = DataLoader(ds_ent, batch_size=100, shuffle=True)
ds_valid = TensorDataset(donnees_valid_X,donnees_valid_Y)
dl_valid = DataLoader(ds_valid, batch_size=100)

def entrainer(modele, dl_ent, dl_valid, optimiseur, nb_epochs=10):

    # Listes pour les métriques par epoch
    liste_cout_moyen_ent = []
    liste_taux_moyen_ent = []
    liste_cout_moyen_valid = []
    liste_taux_moyen_valid = []
    
    # Boucle d'apprentissage
    for epoch in range(nb_epochs):
        cout_total_ent = 0 # pour cumuler les couts par mini-lot
        taux_bonnes_predictions_ent = 0 # pour cumuler les taux par mini-lot
        modele.train() # Pour certains types de couches (nn.BatchNorm2d, nn.Dropout, ...)
        
        # Boucle d'apprentissage par mini-lot pour une epoch
        for lot_X, lot_Y in dl_ent:
            optimiseur.zero_grad() # Remettre les dérivées à zéro
            lot_Y_predictions = modele(lot_X) # Appel de la méthode forward
            cout = fonction_cout(lot_Y_predictions, lot_Y)
            cout.backward() # Calcul des gradiants par rétropropagation
            with torch.no_grad():
                cout_total_ent +=cout
                taux_bonnes_predictions_ent += taux_bonnes_predictions(lot_Y_predictions, lot_Y)
            optimiseur.step() # Mise à jour des paramètres
        # Calculer les moyennes par mini-lot
        with torch.no_grad():
            cout_moyen_ent = cout_total_ent/len(dl_ent)
            taux_moyen_ent = taux_bonnes_predictions_ent/len(dl_ent)
       
        modele.eval() # Pour certains types de couches (nn.BatchNorm2d, nn.Dropout, ...)
        with torch.no_grad():
            cout_valid = sum(fonction_cout(modele(lot_valid_X), lot_valid_Y) for lot_valid_X, lot_valid_Y in dl_valid)
            taux_bons_valid = sum(taux_bonnes_predictions(modele(lot_valid_X), lot_valid_Y) for lot_valid_X, lot_valid_Y in dl_valid)
        cout_moyen_valid = cout_valid/len(dl_valid)
        taux_moyen_valid = taux_bons_valid/len(dl_valid)
        print(f'-------- > epoch {epoch+1}:  coût moyen entraînement = {cout_moyen_ent}')
        print(f'-------- > epoch {epoch+1}:  taux moyen entraînement = {taux_moyen_ent}')
        print(f'-------- > epoch {epoch+1}:  coût moyen validation = {cout_moyen_valid}')
        print(f'-------- > epoch {epoch+1}:  taux moyen validation = {taux_moyen_valid}')
    
        liste_cout_moyen_ent.append(cout_moyen_ent)
        liste_taux_moyen_ent.append(taux_moyen_ent)
        liste_cout_moyen_valid.append(cout_moyen_valid)
        liste_taux_moyen_valid.append(taux_moyen_valid)
    
    # Affichage du graphique d'évolution des métriques par epoch
    import numpy as np
    import matplotlib.pyplot as plt
    plt.plot(np.arange(0,nb_epochs),liste_cout_moyen_ent,label='Erreur entraînement')
    plt.plot(np.arange(0,nb_epochs),liste_cout_moyen_valid,label='Erreur validation')
    plt.title("Evolution du coût")
    plt.xlabel('epoch')
    plt.ylabel('moyenne par observation')
    plt.legend(loc='upper center')
    plt.show()
        
    plt.plot(np.arange(0,nb_epochs),liste_taux_moyen_ent,label='Taux bonnes réponses entraînement')
    plt.plot(np.arange(0,nb_epochs),liste_taux_moyen_valid,label='Taux bonnes réponses validation')
    plt.title("Evolution du taux")
    plt.xlabel('epoch')
    plt.ylabel('moyenne par observation')
    plt.legend(loc='upper center')
    plt.show()

entrainer(modele, dl_ent, dl_valid, optimiseur, nb_epochs=30)
# Out:
# -------- > epoch 1:  coût moyen entraînement = 0.353189617395401
# -------- > epoch 1:  taux moyen entraînement = 0.917620837688446
# -------- > epoch 1:  coût moyen validation = 0.13826604187488556
# -------- > epoch 1:  taux moyen validation = 0.9649999737739563
# -------- > epoch 2:  coût moyen entraînement = 0.12468832731246948
# -------- > epoch 2:  taux moyen entraînement = 0.9673210978507996
# -------- > epoch 2:  coût moyen validation = 0.09843507409095764
# -------- > epoch 2:  taux moyen validation = 0.9734001755714417
# -------- > epoch 3:  coût moyen entraînement = 0.09568416327238083
# -------- > epoch 3:  taux moyen entraînement = 0.9735211730003357
# -------- > epoch 3:  coût moyen validation = 0.08203668892383575
# -------- > epoch 3:  taux moyen validation = 0.9782000780105591
# -------- > epoch 4:  coût moyen entraînement = 0.08034036308526993
# -------- > epoch 4:  taux moyen entraînement = 0.9778603315353394
# -------- > epoch 4:  coût moyen validation = 0.073768250644207
# -------- > epoch 4:  taux moyen validation = 0.9797002673149109
# -------- > epoch 5:  coût moyen entraînement = 0.07062552869319916
# -------- > epoch 5:  taux moyen entraînement = 0.9806810617446899
# -------- > epoch 5:  coût moyen validation = 0.06857240945100784
# -------- > epoch 5:  taux moyen validation = 0.9810001254081726
# -------- > epoch 6:  coût moyen entraînement = 0.06399087607860565
# -------- > epoch 6:  taux moyen entraînement = 0.9817202687263489
# -------- > epoch 6:  coût moyen validation = 0.06687457859516144
# -------- > epoch 6:  taux moyen validation = 0.9811001420021057
# -------- > epoch 7:  coût moyen entraînement = 0.05884881690144539
# -------- > epoch 7:  taux moyen entraînement = 0.9834805130958557
# -------- > epoch 7:  coût moyen validation = 0.060899768024683
# -------- > epoch 7:  taux moyen validation = 0.9824000597000122
# -------- > epoch 8:  coût moyen entraînement = 0.05490477755665779
# -------- > epoch 8:  taux moyen entraînement = 0.9846600294113159
# -------- > epoch 8:  coût moyen validation = 0.05801498517394066
# -------- > epoch 8:  taux moyen validation = 0.984499990940094
# -------- > epoch 9:  coût moyen entraînement = 0.051200319081544876
# -------- > epoch 9:  taux moyen entraînement = 0.9853399991989136
# -------- > epoch 9:  coût moyen validation = 0.0546901673078537
# -------- > epoch 9:  taux moyen validation = 0.9846998453140259
# -------- > epoch 10:  coût moyen entraînement = 0.04830252379179001
# -------- > epoch 10:  taux moyen entraînement = 0.9862599968910217
# -------- > epoch 10:  coût moyen validation = 0.05395204946398735
# -------- > epoch 10:  taux moyen validation = 0.9853000640869141
# -------- > epoch 11:  coût moyen entraînement = 0.045881956815719604
# -------- > epoch 11:  taux moyen entraînement = 0.9870800971984863
# -------- > epoch 11:  coût moyen validation = 0.052878085523843765
# -------- > epoch 11:  taux moyen validation = 0.9843000769615173
# -------- > epoch 12:  coût moyen entraînement = 0.04353082552552223
# -------- > epoch 12:  taux moyen entraînement = 0.9875404238700867
# -------- > epoch 12:  coût moyen validation = 0.05173168703913689
# -------- > epoch 12:  taux moyen validation = 0.9857000708580017
# -------- > epoch 13:  coût moyen entraînement = 0.04139452055096626
# -------- > epoch 13:  taux moyen entraînement = 0.9883801937103271
# -------- > epoch 13:  coût moyen validation = 0.055973440408706665
# -------- > epoch 13:  taux moyen validation = 0.983700156211853
# -------- > epoch 14:  coût moyen entraînement = 0.039316561073064804
# -------- > epoch 14:  taux moyen entraînement = 0.9890201091766357
# -------- > epoch 14:  coût moyen validation = 0.049963463097810745
# -------- > epoch 14:  taux moyen validation = 0.9859000444412231
# -------- > epoch 15:  coût moyen entraînement = 0.03818070515990257
# -------- > epoch 15:  taux moyen entraînement = 0.9889394044876099
# -------- > epoch 15:  coût moyen validation = 0.0480649434030056
# -------- > epoch 15:  taux moyen validation = 0.9858998656272888
# -------- > epoch 16:  coût moyen entraînement = 0.036735132336616516
# -------- > epoch 16:  taux moyen entraînement = 0.989599347114563
# -------- > epoch 16:  coût moyen validation = 0.0486438162624836
# -------- > epoch 16:  taux moyen validation = 0.9854000806808472
# -------- > epoch 17:  coût moyen entraînement = 0.03568211570382118
# -------- > epoch 17:  taux moyen entraînement = 0.9901798367500305
# -------- > epoch 17:  coût moyen validation = 0.047735705971717834
# -------- > epoch 17:  taux moyen validation = 0.9862000942230225
# -------- > epoch 18:  coût moyen entraînement = 0.03420776128768921
# -------- > epoch 18:  taux moyen entraînement = 0.9904195070266724
# -------- > epoch 18:  coût moyen validation = 0.049094706773757935
# -------- > epoch 18:  taux moyen validation = 0.9858998656272888
# -------- > epoch 19:  coût moyen entraînement = 0.03275208920240402
# -------- > epoch 19:  taux moyen entraînement = 0.9911590814590454
# -------- > epoch 19:  coût moyen validation = 0.04691606014966965
# -------- > epoch 19:  taux moyen validation = 0.9872000813484192
# -------- > epoch 20:  coût moyen entraînement = 0.03190263360738754
# -------- > epoch 20:  taux moyen entraînement = 0.9911792874336243
# -------- > epoch 20:  coût moyen validation = 0.053706225007772446
# -------- > epoch 20:  taux moyen validation = 0.9846000075340271
# -------- > epoch 21:  coût moyen entraînement = 0.030877888202667236
# -------- > epoch 21:  taux moyen entraînement = 0.9916591048240662
# -------- > epoch 21:  coût moyen validation = 0.04659423977136612
# -------- > epoch 21:  taux moyen validation = 0.986599862575531
# -------- > epoch 22:  coût moyen entraînement = 0.029857557266950607
# -------- > epoch 22:  taux moyen entraînement = 0.9918792843818665
# -------- > epoch 22:  coût moyen validation = 0.049332551658153534
# -------- > epoch 22:  taux moyen validation = 0.9854001402854919
# -------- > epoch 23:  coût moyen entraînement = 0.02925635501742363
# -------- > epoch 23:  taux moyen entraînement = 0.9920795559883118
# -------- > epoch 23:  coût moyen validation = 0.04661400243639946
# -------- > epoch 23:  taux moyen validation = 0.9864000082015991
# -------- > epoch 24:  coût moyen entraînement = 0.028104672208428383
# -------- > epoch 24:  taux moyen entraînement = 0.9923991560935974
# -------- > epoch 24:  coût moyen validation = 0.0450054407119751
# -------- > epoch 24:  taux moyen validation = 0.9866001605987549
# -------- > epoch 25:  coût moyen entraînement = 0.027339855208992958
# -------- > epoch 25:  taux moyen entraînement = 0.9922592043876648
# -------- > epoch 25:  coût moyen validation = 0.04889126867055893
# -------- > epoch 25:  taux moyen validation = 0.9861000180244446
# -------- > epoch 26:  coût moyen entraînement = 0.026394156739115715
# -------- > epoch 26:  taux moyen entraînement = 0.9929391145706177
# -------- > epoch 26:  coût moyen validation = 0.04636475443840027
# -------- > epoch 26:  taux moyen validation = 0.9868000149726868
# -------- > epoch 27:  coût moyen entraînement = 0.025582946836948395
# -------- > epoch 27:  taux moyen entraînement = 0.9930997490882874
# -------- > epoch 27:  coût moyen validation = 0.04566839709877968
# -------- > epoch 27:  taux moyen validation = 0.9870998859405518
# -------- > epoch 28:  coût moyen entraînement = 0.02509271539747715
# -------- > epoch 28:  taux moyen entraînement = 0.9933590292930603
# -------- > epoch 28:  coût moyen validation = 0.04862409457564354
# -------- > epoch 28:  taux moyen validation = 0.9860000014305115
# -------- > epoch 29:  coût moyen entraînement = 0.024606812745332718
# -------- > epoch 29:  taux moyen entraînement = 0.9932996034622192
# -------- > epoch 29:  coût moyen validation = 0.05006580799818039
# -------- > epoch 29:  taux moyen validation = 0.9857000708580017
# -------- > epoch 30:  coût moyen entraînement = 0.023853832855820656
# -------- > epoch 30:  taux moyen entraînement = 0.9936994314193726
# -------- > epoch 30:  coût moyen validation = 0.048367954790592194
# -------- > epoch 30:  taux moyen validation = 0.9858001470565796
