# %%
# %matplotlib inline
# -*- coding: utf-8 -*-
"""
Exemple simple de MNIST avec PyTorch
Exemple avec nn.Conv2d et F.cross_entropy
Production de métriques avec graphes
Fonction entrainer
"""
import torch
torch.manual_seed(0) # Pour résultats reproductibles

# Fonction J d'entropie croisée
import torch.nn.functional as F
fonction_cout = F.cross_entropy

def taux_bonnes_predictions(lot_Y_predictions, lot_Y):
    predictions_categorie = torch.argmax(lot_Y_predictions, dim=1)
    return (predictions_categorie == lot_Y).float().mean()

from torch import nn
# Définition de l'architecture du RNA

modele = nn.Sequential(
    nn.Conv2d(1,5,3), # 1 canal, 5 filtres, dimension 3 par 3
    nn.ReLU(),
    nn.Flatten(),
    nn.Linear(26*26*5, 10)
)
    
from torch import optim
optimiseur = optim.SGD(modele.parameters(), lr=0.01)

# Chargement des données de MNIST
import pickle, gzip
fichier_donnees = gzip.open(r"mnist.pkl.gz", 'rb')
((donnees_ent_X, donnees_ent_Y),(donnees_valid_X, donnees_valid_Y),(donnees_test_X,donnees_test_Y)) = pickle.load(fichier_donnees, encoding="latin-1")
fichier_donnees.close()

# Conversion des données en type toch.Tensor
import torch
donnees_ent_X,donnees_ent_Y,donnees_valid_X,donnees_valid_Y,donnees_test_X,donnees_test_Y  = map(torch.tensor,
    (donnees_ent_X.reshape((-1,1,28,28)),donnees_ent_Y,donnees_valid_X.reshape((-1,1,28,28)),donnees_valid_Y,donnees_test_X.reshape((-1,1,28,28)),donnees_test_Y))

# Création des objets DataLoader pour itérer par lot
from torch.utils.data import TensorDataset
from torch.utils.data import DataLoader
ds_ent = TensorDataset(donnees_ent_X, donnees_ent_Y)
dl_ent = DataLoader(ds_ent, batch_size=100, shuffle=True)
ds_valid = TensorDataset(donnees_valid_X,donnees_valid_Y)
dl_valid = DataLoader(ds_valid, batch_size=100)

def entrainer(modele, dl_ent, dl_valid, optimiseur, nb_epochs=10):

    # Listes pour les métriques par epoch
    liste_cout_moyen_ent = []
    liste_taux_moyen_ent = []
    liste_cout_moyen_valid = []
    liste_taux_moyen_valid = []
    
    # Boucle d'apprentissage
    for epoch in range(nb_epochs):
        cout_total_ent = 0 # pour cumuler les couts par mini-lot
        taux_bonnes_predictions_ent = 0 # pour cumuler les taux par mini-lot
        modele.train() # Pour certains types de couches (nn.BatchNorm2d, nn.Dropout, ...)
        
        # Boucle d'apprentissage par mini-lot pour une epoch
        for lot_X, lot_Y in dl_ent:
            optimiseur.zero_grad() # Remettre les dérivées à zéro
            lot_Y_predictions = modele(lot_X) # Appel de la méthode forward
            cout = fonction_cout(lot_Y_predictions, lot_Y)
            cout.backward() # Calcul des gradiants par rétropropagation
            with torch.no_grad():
                cout_total_ent +=cout
                taux_bonnes_predictions_ent += taux_bonnes_predictions(lot_Y_predictions, lot_Y)
            optimiseur.step() # Mise à jour des paramètres
        # Calculer les moyennes par mini-lot
        with torch.no_grad():
            cout_moyen_ent = cout_total_ent/len(dl_ent)
            taux_moyen_ent = taux_bonnes_predictions_ent/len(dl_ent)
       
        modele.eval() # Pour certains types de couches (nn.BatchNorm2d, nn.Dropout, ...)
        with torch.no_grad():
            cout_valid = sum(fonction_cout(modele(lot_valid_X), lot_valid_Y) for lot_valid_X, lot_valid_Y in dl_valid)
            taux_bons_valid = sum(taux_bonnes_predictions(modele(lot_valid_X), lot_valid_Y) for lot_valid_X, lot_valid_Y in dl_valid)
        cout_moyen_valid = cout_valid/len(dl_valid)
        taux_moyen_valid = taux_bons_valid/len(dl_valid)
        print(f'-------- > epoch {epoch+1}:  coût moyen entraînement = {cout_moyen_ent}')
        print(f'-------- > epoch {epoch+1}:  taux moyen entraînement = {taux_moyen_ent}')
        print(f'-------- > epoch {epoch+1}:  coût moyen validation = {cout_moyen_valid}')
        print(f'-------- > epoch {epoch+1}:  taux moyen validation = {taux_moyen_valid}')
    
        liste_cout_moyen_ent.append(cout_moyen_ent)
        liste_taux_moyen_ent.append(taux_moyen_ent)
        liste_cout_moyen_valid.append(cout_moyen_valid)
        liste_taux_moyen_valid.append(taux_moyen_valid)
    
    # Affichage du graphique d'évolution des métriques par epoch
    import numpy as np
    import matplotlib.pyplot as plt
    plt.plot(np.arange(0,nb_epochs),liste_cout_moyen_ent,label='Erreur entraînement')
    plt.plot(np.arange(0,nb_epochs),liste_cout_moyen_valid,label='Erreur validation')
    plt.title("Evolution du coût")
    plt.xlabel('epoch')
    plt.ylabel('moyenne par observation')
    plt.legend(loc='upper center')
    plt.show()
        
    plt.plot(np.arange(0,nb_epochs),liste_taux_moyen_ent,label='Taux bonnes réponses entraînement')
    plt.plot(np.arange(0,nb_epochs),liste_taux_moyen_valid,label='Taux bonnes réponses validation')
    plt.title("Evolution du taux")
    plt.xlabel('epoch')
    plt.ylabel('moyenne par observation')
    plt.legend(loc='upper center')
    plt.show()

entrainer(modele, dl_ent, dl_valid, optimiseur, nb_epochs=50)
# Out:
# -------- > epoch 1:  coût moyen entraînement = 0.7985090017318726
# -------- > epoch 1:  taux moyen entraînement = 0.8034403920173645
# -------- > epoch 1:  coût moyen validation = 0.34092238545417786
# -------- > epoch 1:  taux moyen validation = 0.904900074005127
# -------- > epoch 2:  coût moyen entraînement = 0.3504854142665863
# -------- > epoch 2:  taux moyen entraînement = 0.8982011675834656
# -------- > epoch 2:  coût moyen validation = 0.3037739396095276
# -------- > epoch 2:  taux moyen validation = 0.9130000472068787
# -------- > epoch 3:  coût moyen entraînement = 0.32058441638946533
# -------- > epoch 3:  taux moyen entraînement = 0.9074209332466125
# -------- > epoch 3:  coût moyen validation = 0.2861383259296417
# -------- > epoch 3:  taux moyen validation = 0.9170998930931091
# -------- > epoch 4:  coût moyen entraînement = 0.3062206208705902
# -------- > epoch 4:  taux moyen entraînement = 0.911281168460846
# -------- > epoch 4:  coût moyen validation = 0.2776552736759186
# -------- > epoch 4:  taux moyen validation = 0.9185000061988831
# -------- > epoch 5:  coût moyen entraînement = 0.29717206954956055
# -------- > epoch 5:  taux moyen entraînement = 0.9152811765670776
# -------- > epoch 5:  coût moyen validation = 0.27717524766921997
# -------- > epoch 5:  taux moyen validation = 0.9205001592636108
# -------- > epoch 6:  coût moyen entraînement = 0.2891697883605957
# -------- > epoch 6:  taux moyen entraînement = 0.9173204302787781
# -------- > epoch 6:  coût moyen validation = 0.26781052350997925
# -------- > epoch 6:  taux moyen validation = 0.9230998754501343
# -------- > epoch 7:  coût moyen entraînement = 0.28338295221328735
# -------- > epoch 7:  taux moyen entraînement = 0.9191805124282837
# -------- > epoch 7:  coût moyen validation = 0.2628074884414673
# -------- > epoch 7:  taux moyen validation = 0.9246999621391296
# -------- > epoch 8:  coût moyen entraînement = 0.27763447165489197
# -------- > epoch 8:  taux moyen entraînement = 0.921521008014679
# -------- > epoch 8:  coût moyen validation = 0.25782284140586853
# -------- > epoch 8:  taux moyen validation = 0.928300142288208
# -------- > epoch 9:  coût moyen entraînement = 0.27212217450141907
# -------- > epoch 9:  taux moyen entraînement = 0.9225409626960754
# -------- > epoch 9:  coût moyen validation = 0.25243815779685974
# -------- > epoch 9:  taux moyen validation = 0.9289000034332275
# -------- > epoch 10:  coût moyen entraînement = 0.26670363545417786
# -------- > epoch 10:  taux moyen entraînement = 0.9256010055541992
# -------- > epoch 10:  coût moyen validation = 0.2454252988100052
# -------- > epoch 10:  taux moyen validation = 0.9307003021240234
# -------- > epoch 11:  coût moyen entraînement = 0.2613447308540344
# -------- > epoch 11:  taux moyen entraînement = 0.9258809685707092
# -------- > epoch 11:  coût moyen validation = 0.2401180863380432
# -------- > epoch 11:  taux moyen validation = 0.9336001873016357
# -------- > epoch 12:  coût moyen entraînement = 0.2558749318122864
# -------- > epoch 12:  taux moyen entraînement = 0.9277008771896362
# -------- > epoch 12:  coût moyen validation = 0.23752669990062714
# -------- > epoch 12:  taux moyen validation = 0.9332001209259033
# -------- > epoch 13:  coût moyen entraînement = 0.24996745586395264
# -------- > epoch 13:  taux moyen entraînement = 0.930560827255249
# -------- > epoch 13:  coût moyen validation = 0.2338455766439438
# -------- > epoch 13:  taux moyen validation = 0.9355999827384949
# -------- > epoch 14:  coût moyen entraînement = 0.24410480260849
# -------- > epoch 14:  taux moyen entraînement = 0.931441068649292
# -------- > epoch 14:  coût moyen validation = 0.2306903451681137
# -------- > epoch 14:  taux moyen validation = 0.9372000098228455
# -------- > epoch 15:  coût moyen entraînement = 0.2375129759311676
# -------- > epoch 15:  taux moyen entraînement = 0.9333006143569946
# -------- > epoch 15:  coût moyen validation = 0.22212448716163635
# -------- > epoch 15:  taux moyen validation = 0.939799964427948
# -------- > epoch 16:  coût moyen entraînement = 0.23039458692073822
# -------- > epoch 16:  taux moyen entraînement = 0.9354012608528137
# -------- > epoch 16:  coût moyen validation = 0.21391496062278748
# -------- > epoch 16:  taux moyen validation = 0.9431000351905823
# -------- > epoch 17:  coût moyen entraînement = 0.22366011142730713
# -------- > epoch 17:  taux moyen entraînement = 0.937980592250824
# -------- > epoch 17:  coût moyen validation = 0.2095315307378769
# -------- > epoch 17:  taux moyen validation = 0.9469999670982361
# -------- > epoch 18:  coût moyen entraînement = 0.21660557389259338
# -------- > epoch 18:  taux moyen entraînement = 0.9389210343360901
# -------- > epoch 18:  coût moyen validation = 0.20168833434581757
# -------- > epoch 18:  taux moyen validation = 0.9458000063896179
# -------- > epoch 19:  coût moyen entraînement = 0.20907917618751526
# -------- > epoch 19:  taux moyen entraînement = 0.9416213631629944
# -------- > epoch 19:  coût moyen validation = 0.197072371840477
# -------- > epoch 19:  taux moyen validation = 0.9498001933097839
# -------- > epoch 20:  coût moyen entraînement = 0.20228587090969086
# -------- > epoch 20:  taux moyen entraînement = 0.9432615041732788
# -------- > epoch 20:  coût moyen validation = 0.192887082695961
# -------- > epoch 20:  taux moyen validation = 0.9505999684333801
# -------- > epoch 21:  coût moyen entraînement = 0.19534848630428314
# -------- > epoch 21:  taux moyen entraînement = 0.9451212882995605
# -------- > epoch 21:  coût moyen validation = 0.18164123594760895
# -------- > epoch 21:  taux moyen validation = 0.9531001448631287
# -------- > epoch 22:  coût moyen entraînement = 0.18818069994449615
# -------- > epoch 22:  taux moyen entraînement = 0.9477608799934387
# -------- > epoch 22:  coût moyen validation = 0.17741069197654724
# -------- > epoch 22:  taux moyen validation = 0.9550001621246338
# -------- > epoch 23:  coût moyen entraînement = 0.18185313045978546
# -------- > epoch 23:  taux moyen entraînement = 0.949140727519989
# -------- > epoch 23:  coût moyen validation = 0.17433702945709229
# -------- > epoch 23:  taux moyen validation = 0.9564000964164734
# -------- > epoch 24:  coût moyen entraînement = 0.17530259490013123
# -------- > epoch 24:  taux moyen entraînement = 0.9510610699653625
# -------- > epoch 24:  coût moyen validation = 0.17021840810775757
# -------- > epoch 24:  taux moyen validation = 0.957099974155426
# -------- > epoch 25:  coût moyen entraînement = 0.16963280737400055
# -------- > epoch 25:  taux moyen entraînement = 0.9530407786369324
# -------- > epoch 25:  coût moyen validation = 0.16324016451835632
# -------- > epoch 25:  taux moyen validation = 0.9575999975204468
# -------- > epoch 26:  coût moyen entraînement = 0.16399799287319183
# -------- > epoch 26:  taux moyen entraînement = 0.9544614553451538
# -------- > epoch 26:  coût moyen validation = 0.16142922639846802
# -------- > epoch 26:  taux moyen validation = 0.9589999318122864
# -------- > epoch 27:  coût moyen entraînement = 0.15841946005821228
# -------- > epoch 27:  taux moyen entraînement = 0.9561407566070557
# -------- > epoch 27:  coût moyen validation = 0.15611940622329712
# -------- > epoch 27:  taux moyen validation = 0.9600999355316162
# -------- > epoch 28:  coût moyen entraînement = 0.1530943363904953
# -------- > epoch 28:  taux moyen entraînement = 0.9578409790992737
# -------- > epoch 28:  coût moyen validation = 0.15364399552345276
# -------- > epoch 28:  taux moyen validation = 0.962399959564209
# -------- > epoch 29:  coût moyen entraînement = 0.1489723175764084
# -------- > epoch 29:  taux moyen entraînement = 0.9583008289337158
# -------- > epoch 29:  coût moyen validation = 0.14720438420772552
# -------- > epoch 29:  taux moyen validation = 0.9627999663352966
# -------- > epoch 30:  coût moyen entraînement = 0.14430716633796692
# -------- > epoch 30:  taux moyen entraînement = 0.9597809910774231
# -------- > epoch 30:  coût moyen validation = 0.14792661368846893
# -------- > epoch 30:  taux moyen validation = 0.9612999558448792
# -------- > epoch 31:  coût moyen entraînement = 0.14039377868175507
# -------- > epoch 31:  taux moyen entraînement = 0.9617612957954407
# -------- > epoch 31:  coût moyen validation = 0.14034207165241241
# -------- > epoch 31:  taux moyen validation = 0.9633001685142517
# -------- > epoch 32:  coût moyen entraînement = 0.13645094633102417
# -------- > epoch 32:  taux moyen entraînement = 0.9623610973358154
# -------- > epoch 32:  coût moyen validation = 0.14073224365711212
# -------- > epoch 32:  taux moyen validation = 0.964400053024292
# -------- > epoch 33:  coût moyen entraînement = 0.13312998414039612
# -------- > epoch 33:  taux moyen entraînement = 0.9635410308837891
# -------- > epoch 33:  coût moyen validation = 0.13532869517803192
# -------- > epoch 33:  taux moyen validation = 0.965700089931488
# -------- > epoch 34:  coût moyen entraînement = 0.1295611709356308
# -------- > epoch 34:  taux moyen entraînement = 0.9643407464027405
# -------- > epoch 34:  coût moyen validation = 0.13207270205020905
# -------- > epoch 34:  taux moyen validation = 0.966900110244751
# -------- > epoch 35:  coût moyen entraînement = 0.12676915526390076
# -------- > epoch 35:  taux moyen entraînement = 0.9649607539176941
# -------- > epoch 35:  coût moyen validation = 0.13208329677581787
# -------- > epoch 35:  taux moyen validation = 0.9655001163482666
# -------- > epoch 36:  coût moyen entraînement = 0.12355504930019379
# -------- > epoch 36:  taux moyen entraînement = 0.9655807614326477
# -------- > epoch 36:  coût moyen validation = 0.1302378624677658
# -------- > epoch 36:  taux moyen validation = 0.9669000506401062
# -------- > epoch 37:  coût moyen entraînement = 0.12070433795452118
# -------- > epoch 37:  taux moyen entraînement = 0.966140866279602
# -------- > epoch 37:  coût moyen validation = 0.12696032226085663
# -------- > epoch 37:  taux moyen validation = 0.96809983253479
# -------- > epoch 38:  coût moyen entraînement = 0.11806894838809967
# -------- > epoch 38:  taux moyen entraînement = 0.9672209620475769
# -------- > epoch 38:  coût moyen validation = 0.12422047555446625
# -------- > epoch 38:  taux moyen validation = 0.9681998491287231
# -------- > epoch 39:  coût moyen entraînement = 0.1158677339553833
# -------- > epoch 39:  taux moyen entraînement = 0.9679807424545288
# -------- > epoch 39:  coût moyen validation = 0.12652626633644104
# -------- > epoch 39:  taux moyen validation = 0.9671999216079712
# -------- > epoch 40:  coût moyen entraînement = 0.11298119276762009
# -------- > epoch 40:  taux moyen entraînement = 0.9685811400413513
# -------- > epoch 40:  coût moyen validation = 0.12082390487194061
# -------- > epoch 40:  taux moyen validation = 0.9690000414848328
# -------- > epoch 41:  coût moyen entraînement = 0.11115659773349762
# -------- > epoch 41:  taux moyen entraînement = 0.9687413573265076
# -------- > epoch 41:  coût moyen validation = 0.12080250680446625
# -------- > epoch 41:  taux moyen validation = 0.9695999622344971
# -------- > epoch 42:  coût moyen entraînement = 0.10909340530633926
# -------- > epoch 42:  taux moyen entraînement = 0.9696414470672607
# -------- > epoch 42:  coût moyen validation = 0.11970192193984985
# -------- > epoch 42:  taux moyen validation = 0.9693998098373413
# -------- > epoch 43:  coût moyen entraînement = 0.10732817649841309
# -------- > epoch 43:  taux moyen entraînement = 0.9701808094978333
# -------- > epoch 43:  coût moyen validation = 0.11658164858818054
# -------- > epoch 43:  taux moyen validation = 0.9696998596191406
# -------- > epoch 44:  coût moyen entraînement = 0.10520157217979431
# -------- > epoch 44:  taux moyen entraînement = 0.9709407687187195
# -------- > epoch 44:  coût moyen validation = 0.11624796688556671
# -------- > epoch 44:  taux moyen validation = 0.971099853515625
# -------- > epoch 45:  coût moyen entraînement = 0.1032896563410759
# -------- > epoch 45:  taux moyen entraînement = 0.9711411595344543
# -------- > epoch 45:  coût moyen validation = 0.11633341014385223
# -------- > epoch 45:  taux moyen validation = 0.9706999063491821
# -------- > epoch 46:  coût moyen entraînement = 0.10183122754096985
# -------- > epoch 46:  taux moyen entraînement = 0.9721009135246277
# -------- > epoch 46:  coût moyen validation = 0.11402487754821777
# -------- > epoch 46:  taux moyen validation = 0.971500039100647
# -------- > epoch 47:  coût moyen entraînement = 0.10001954436302185
# -------- > epoch 47:  taux moyen entraînement = 0.9726406931877136
# -------- > epoch 47:  coût moyen validation = 0.11351899057626724
# -------- > epoch 47:  taux moyen validation = 0.9704999327659607
# -------- > epoch 48:  coût moyen entraînement = 0.09844493865966797
# -------- > epoch 48:  taux moyen entraînement = 0.9725408554077148
# -------- > epoch 48:  coût moyen validation = 0.11348159611225128
# -------- > epoch 48:  taux moyen validation = 0.9701998829841614
# -------- > epoch 49:  coût moyen entraînement = 0.09735164046287537
# -------- > epoch 49:  taux moyen entraînement = 0.972801148891449
# -------- > epoch 49:  coût moyen validation = 0.11091980338096619
# -------- > epoch 49:  taux moyen validation = 0.9718000888824463
# -------- > epoch 50:  coût moyen entraînement = 0.0959709957242012
# -------- > epoch 50:  taux moyen entraînement = 0.9735004901885986
# -------- > epoch 50:  coût moyen validation = 0.11027927696704865
# -------- > epoch 50:  taux moyen validation = 0.9718998670578003

# %%
# %matplotlib inline
# -*- coding: utf-8 -*-
"""
Exemple simple de MNIST avec PyTorch
Chargement avec torchvision.datasets
Exemple avec nn.Conv2d et F.cross_entropy
Production de métriques avec graphes
Fonction entrainer
"""
import torch
torch.manual_seed(0) # Pour résultats reproductibles

# Fonction J d'entropie croisée
import torch.nn.functional as F
fonction_cout = F.cross_entropy

def taux_bonnes_predictions(lot_Y_predictions, lot_Y):
    predictions_categorie = torch.argmax(lot_Y_predictions, dim=1)
    return (predictions_categorie == lot_Y).float().mean()

from torch import nn
# Définition de l'architecture du RNA

modele = nn.Sequential(
    nn.Conv2d(1,5,3), # 1 canal, 5 filtres, dimension 3 par 3
    nn.ReLU(),
    nn.Flatten(),
    nn.Linear(26*26*5, 10)
)
    
from torch import optim
optimiseur = optim.SGD(modele.parameters(), lr=0.01)

'''# Chargement des données de MNIST
import torchvision
ds = torchvision.datasets.MNIST(root='/tmp/mnist', train=True, download=True)
# Sous-ensemble pour exécution rapide
donnees_ent_X = ds.data[:5000].reshape(5000, 784).float() / 255.0
donnees_ent_Y = ds.targets[:5000]
donnees_valid_X = ds.data[5000:6000].reshape(1000, 784).float() / 255.0
donnees_valid_Y = ds.targets[5000:6000]

# Création des objets DataLoader pour itérer par lot
from torch.utils.data import TensorDataset
from torch.utils.data import DataLoader
ds_ent = TensorDataset(donnees_ent_X, donnees_ent_Y)
dl_ent = DataLoader(ds_ent, batch_size=100, shuffle=True)
ds_valid = TensorDataset(donnees_valid_X, donnees_valid_Y)
dl_valid = DataLoader(ds_valid, batch_size=100)
'''

# Chargement des données de MNIST
import torchvision
import torchvision.transforms as transforms

ds = torchvision.datasets.MNIST(root = '/tmp/mnist', train = True, download = True, transform = transforms.ToTensor())
ds_ent, ds_valid = torch.utils.data.random_split(ds, [50000, 10000])
ds_test = torchvision.datasets.MNIST(root = '/tmp/mnist', train = False, download = True, transform = transforms.ToTensor())

#Création du DataLoader avec le dataset
dl_ent = torch.utils.data.DataLoader(ds_ent, batch_size=100, shuffle = True)
dl_valid = torch.utils.data.DataLoader(ds_valid, batch_size=100)


def entrainer(modele, dl_ent, dl_valid, optimiseur, nb_epochs=10):

    # Listes pour les métriques par epoch
    liste_cout_moyen_ent = []
    liste_taux_moyen_ent = []
    liste_cout_moyen_valid = []
    liste_taux_moyen_valid = []
    
    # Boucle d'apprentissage
    for epoch in range(nb_epochs):
        cout_total_ent = 0 # pour cumuler les couts par mini-lot
        taux_bonnes_predictions_ent = 0 # pour cumuler les taux par mini-lot
        modele.train() # Pour certains types de couches (nn.BatchNorm2d, nn.Dropout, ...)
        
        # Boucle d'apprentissage par mini-lot pour une epoch
        for lot_X, lot_Y in dl_ent:
            optimiseur.zero_grad() # Remettre les dérivées à zéro
            lot_Y_predictions = modele(lot_X) # Appel de la méthode forward
            cout = fonction_cout(lot_Y_predictions, lot_Y)
            cout.backward() # Calcul des gradiants par rétropropagation
            with torch.no_grad():
                cout_total_ent +=cout
                taux_bonnes_predictions_ent += taux_bonnes_predictions(lot_Y_predictions, lot_Y)
            optimiseur.step() # Mise à jour des paramètres
        # Calculer les moyennes par mini-lot
        with torch.no_grad():
            cout_moyen_ent = cout_total_ent/len(dl_ent)
            taux_moyen_ent = taux_bonnes_predictions_ent/len(dl_ent)
       
        modele.eval() # Pour certains types de couches (nn.BatchNorm2d, nn.Dropout, ...)
        with torch.no_grad():
            cout_valid = sum(fonction_cout(modele(lot_valid_X), lot_valid_Y) for lot_valid_X, lot_valid_Y in dl_valid)
            taux_bons_valid = sum(taux_bonnes_predictions(modele(lot_valid_X), lot_valid_Y) for lot_valid_X, lot_valid_Y in dl_valid)
        cout_moyen_valid = cout_valid/len(dl_valid)
        taux_moyen_valid = taux_bons_valid/len(dl_valid)
        print(f'-------- > epoch {epoch+1}:  coût moyen entraînement = {cout_moyen_ent}')
        print(f'-------- > epoch {epoch+1}:  taux moyen entraînement = {taux_moyen_ent}')
        print(f'-------- > epoch {epoch+1}:  coût moyen validation = {cout_moyen_valid}')
        print(f'-------- > epoch {epoch+1}:  taux moyen validation = {taux_moyen_valid}')
    
        liste_cout_moyen_ent.append(cout_moyen_ent)
        liste_taux_moyen_ent.append(taux_moyen_ent)
        liste_cout_moyen_valid.append(cout_moyen_valid)
        liste_taux_moyen_valid.append(taux_moyen_valid)
    
    # Affichage du graphique d'évolution des métriques par epoch
    import numpy as np
    import matplotlib.pyplot as plt
    plt.plot(np.arange(0,nb_epochs),liste_cout_moyen_ent,label='Erreur entraînement')
    plt.plot(np.arange(0,nb_epochs),liste_cout_moyen_valid,label='Erreur validation')
    plt.title("Evolution du coût")
    plt.xlabel('epoch')
    plt.ylabel('moyenne par observation')
    plt.legend(loc='upper center')
    plt.show()
        
    plt.plot(np.arange(0,nb_epochs),liste_taux_moyen_ent,label='Taux bonnes réponses entraînement')
    plt.plot(np.arange(0,nb_epochs),liste_taux_moyen_valid,label='Taux bonnes réponses validation')
    plt.title("Evolution du taux")
    plt.xlabel('epoch')
    plt.ylabel('moyenne par observation')
    plt.legend(loc='upper center')
    plt.show()

entrainer(modele, dl_ent, dl_valid, optimiseur, nb_epochs=50)
# Out:
# -------- > epoch 1:  coût moyen entraînement = 0.7903032302856445
# -------- > epoch 1:  taux moyen entraînement = 0.8106401562690735
# -------- > epoch 1:  coût moyen validation = 0.38302573561668396
# -------- > epoch 1:  taux moyen validation = 0.8896000385284424
# -------- > epoch 2:  coût moyen entraînement = 0.3436160385608673
# -------- > epoch 2:  taux moyen entraînement = 0.9004204869270325
# -------- > epoch 2:  coût moyen validation = 0.34581878781318665
# -------- > epoch 2:  taux moyen validation = 0.9012001752853394
# -------- > epoch 3:  coût moyen entraînement = 0.3139975070953369
# -------- > epoch 3:  taux moyen entraînement = 0.9082410931587219
# -------- > epoch 3:  coût moyen validation = 0.32490435242652893
# -------- > epoch 3:  taux moyen validation = 0.9089000821113586
# -------- > epoch 4:  coût moyen entraînement = 0.2992253601551056
# -------- > epoch 4:  taux moyen entraînement = 0.9139205813407898
# -------- > epoch 4:  coût moyen validation = 0.31236323714256287
# -------- > epoch 4:  taux moyen validation = 0.9133002758026123
# -------- > epoch 5:  coût moyen entraînement = 0.28981009125709534
# -------- > epoch 5:  taux moyen entraînement = 0.9167009592056274
# -------- > epoch 5:  coût moyen validation = 0.30477774143218994
# -------- > epoch 5:  taux moyen validation = 0.9155001640319824
# -------- > epoch 6:  coût moyen entraînement = 0.2819980978965759
# -------- > epoch 6:  taux moyen entraînement = 0.9197813272476196
# -------- > epoch 6:  coût moyen validation = 0.30148544907569885
# -------- > epoch 6:  taux moyen validation = 0.9172000885009766
# -------- > epoch 7:  coût moyen entraînement = 0.27618351578712463
# -------- > epoch 7:  taux moyen entraînement = 0.9214212894439697
# -------- > epoch 7:  coût moyen validation = 0.29694193601608276
# -------- > epoch 7:  taux moyen validation = 0.9175002574920654
# -------- > epoch 8:  coût moyen entraînement = 0.2698410749435425
# -------- > epoch 8:  taux moyen entraînement = 0.9239804148674011
# -------- > epoch 8:  coût moyen validation = 0.2919081449508667
# -------- > epoch 8:  taux moyen validation = 0.9196000099182129
# -------- > epoch 9:  coût moyen entraînement = 0.2645675241947174
# -------- > epoch 9:  taux moyen entraînement = 0.9254009127616882
# -------- > epoch 9:  coût moyen validation = 0.29156598448753357
# -------- > epoch 9:  taux moyen validation = 0.9211999773979187
# -------- > epoch 10:  coût moyen entraînement = 0.25949332118034363
# -------- > epoch 10:  taux moyen entraînement = 0.9265807271003723
# -------- > epoch 10:  coût moyen validation = 0.28353846073150635
# -------- > epoch 10:  taux moyen validation = 0.9236997961997986
# -------- > epoch 11:  coût moyen entraînement = 0.2543211579322815
# -------- > epoch 11:  taux moyen entraînement = 0.9283811450004578
# -------- > epoch 11:  coût moyen validation = 0.2776556611061096
# -------- > epoch 11:  taux moyen validation = 0.9271997809410095
# -------- > epoch 12:  coût moyen entraînement = 0.24888353049755096
# -------- > epoch 12:  taux moyen entraînement = 0.9296013116836548
# -------- > epoch 12:  coût moyen validation = 0.2759607434272766
# -------- > epoch 12:  taux moyen validation = 0.9261999726295471
# -------- > epoch 13:  coût moyen entraînement = 0.2433086633682251
# -------- > epoch 13:  taux moyen entraînement = 0.9326008558273315
# -------- > epoch 13:  coût moyen validation = 0.26998206973075867
# -------- > epoch 13:  taux moyen validation = 0.9276996850967407
# -------- > epoch 14:  coût moyen entraînement = 0.23802506923675537
# -------- > epoch 14:  taux moyen entraînement = 0.9332004189491272
# -------- > epoch 14:  coût moyen validation = 0.2668014168739319
# -------- > epoch 14:  taux moyen validation = 0.9286999702453613
# -------- > epoch 15:  coût moyen entraînement = 0.23203133046627045
# -------- > epoch 15:  taux moyen entraînement = 0.9350008964538574
# -------- > epoch 15:  coût moyen validation = 0.2598549723625183
# -------- > epoch 15:  taux moyen validation = 0.9304999709129333
# -------- > epoch 16:  coût moyen entraînement = 0.22581569850444794
# -------- > epoch 16:  taux moyen entraînement = 0.9368009567260742
# -------- > epoch 16:  coût moyen validation = 0.2518391013145447
# -------- > epoch 16:  taux moyen validation = 0.9336998462677002
# -------- > epoch 17:  coût moyen entraînement = 0.21884897351264954
# -------- > epoch 17:  taux moyen entraînement = 0.9387011528015137
# -------- > epoch 17:  coût moyen validation = 0.2441742718219757
# -------- > epoch 17:  taux moyen validation = 0.9338000416755676
# -------- > epoch 18:  coût moyen entraînement = 0.21186870336532593
# -------- > epoch 18:  taux moyen entraînement = 0.9417007565498352
# -------- > epoch 18:  coût moyen validation = 0.2413884550333023
# -------- > epoch 18:  taux moyen validation = 0.9337999820709229
# -------- > epoch 19:  coût moyen entraînement = 0.2055496871471405
# -------- > epoch 19:  taux moyen entraînement = 0.9431807398796082
# -------- > epoch 19:  coût moyen validation = 0.24002335965633392
# -------- > epoch 19:  taux moyen validation = 0.9345000982284546
# -------- > epoch 20:  coût moyen entraînement = 0.19875353574752808
# -------- > epoch 20:  taux moyen entraînement = 0.9454610347747803
# -------- > epoch 20:  coût moyen validation = 0.23180538415908813
# -------- > epoch 20:  taux moyen validation = 0.9367997646331787
# -------- > epoch 21:  coût moyen entraînement = 0.1918567270040512
# -------- > epoch 21:  taux moyen entraînement = 0.9469614624977112
# -------- > epoch 21:  coût moyen validation = 0.226260244846344
# -------- > epoch 21:  taux moyen validation = 0.9394997358322144
# -------- > epoch 22:  coût moyen entraînement = 0.18478702008724213
# -------- > epoch 22:  taux moyen entraînement = 0.9495809674263
# -------- > epoch 22:  coût moyen validation = 0.21451729536056519
# -------- > epoch 22:  taux moyen validation = 0.943800151348114
# -------- > epoch 23:  coût moyen entraînement = 0.1785774827003479
# -------- > epoch 23:  taux moyen entraînement = 0.9511411190032959
# -------- > epoch 23:  coût moyen validation = 0.20840850472450256
# -------- > epoch 23:  taux moyen validation = 0.944399893283844
# -------- > epoch 24:  coût moyen entraînement = 0.17282727360725403
# -------- > epoch 24:  taux moyen entraînement = 0.9528408646583557
# -------- > epoch 24:  coût moyen validation = 0.20384609699249268
# -------- > epoch 24:  taux moyen validation = 0.945900022983551
# -------- > epoch 25:  coût moyen entraînement = 0.16658249497413635
# -------- > epoch 25:  taux moyen entraînement = 0.9545007944107056
# -------- > epoch 25:  coût moyen validation = 0.19940859079360962
# -------- > epoch 25:  taux moyen validation = 0.9474000334739685
# -------- > epoch 26:  coût moyen entraînement = 0.1616210639476776
# -------- > epoch 26:  taux moyen entraînement = 0.9559406042098999
# -------- > epoch 26:  coût moyen validation = 0.19236528873443604
# -------- > epoch 26:  taux moyen validation = 0.9478999972343445
# -------- > epoch 27:  coût moyen entraînement = 0.15629304945468903
# -------- > epoch 27:  taux moyen entraînement = 0.9575010538101196
# -------- > epoch 27:  coût moyen validation = 0.18604591488838196
# -------- > epoch 27:  taux moyen validation = 0.9504998922348022
# -------- > epoch 28:  coût moyen entraînement = 0.1511356085538864
# -------- > epoch 28:  taux moyen entraînement = 0.9591602087020874
# -------- > epoch 28:  coût moyen validation = 0.18453098833560944
# -------- > epoch 28:  taux moyen validation = 0.9510999321937561
# -------- > epoch 29:  coût moyen entraînement = 0.14733360707759857
# -------- > epoch 29:  taux moyen entraînement = 0.9598209261894226
# -------- > epoch 29:  coût moyen validation = 0.1793765276670456
# -------- > epoch 29:  taux moyen validation = 0.9513001441955566
# -------- > epoch 30:  coût moyen entraînement = 0.14295674860477448
# -------- > epoch 30:  taux moyen entraînement = 0.9608612656593323
# -------- > epoch 30:  coût moyen validation = 0.1727590411901474
# -------- > epoch 30:  taux moyen validation = 0.953799843788147
# -------- > epoch 31:  coût moyen entraînement = 0.13855724036693573
# -------- > epoch 31:  taux moyen entraînement = 0.9621008634567261
# -------- > epoch 31:  coût moyen validation = 0.1721518188714981
# -------- > epoch 31:  taux moyen validation = 0.953400194644928
# -------- > epoch 32:  coût moyen entraînement = 0.1346801221370697
# -------- > epoch 32:  taux moyen entraînement = 0.963301420211792
# -------- > epoch 32:  coût moyen validation = 0.16646799445152283
# -------- > epoch 32:  taux moyen validation = 0.9558001756668091
# -------- > epoch 33:  coût moyen entraînement = 0.13163220882415771
# -------- > epoch 33:  taux moyen entraînement = 0.9642208814620972
# -------- > epoch 33:  coût moyen validation = 0.1627657115459442
# -------- > epoch 33:  taux moyen validation = 0.9557999968528748
# -------- > epoch 34:  coût moyen entraînement = 0.12802831828594208
# -------- > epoch 34:  taux moyen entraînement = 0.9648006558418274
# -------- > epoch 34:  coût moyen validation = 0.16019028425216675
# -------- > epoch 34:  taux moyen validation = 0.9578001499176025
# -------- > epoch 35:  coût moyen entraînement = 0.12459950894117355
# -------- > epoch 35:  taux moyen entraînement = 0.9656215906143188
# -------- > epoch 35:  coût moyen validation = 0.1597403585910797
# -------- > epoch 35:  taux moyen validation = 0.9559000134468079
# -------- > epoch 36:  coût moyen entraînement = 0.12194597721099854
# -------- > epoch 36:  taux moyen entraînement = 0.9668606519699097
# -------- > epoch 36:  coût moyen validation = 0.1539929360151291
# -------- > epoch 36:  taux moyen validation = 0.9590999484062195
# -------- > epoch 37:  coût moyen entraînement = 0.11933532357215881
# -------- > epoch 37:  taux moyen entraînement = 0.9676609039306641
# -------- > epoch 37:  coût moyen validation = 0.15520760416984558
# -------- > epoch 37:  taux moyen validation = 0.9584999680519104
# -------- > epoch 38:  coût moyen entraînement = 0.11659126728773117
# -------- > epoch 38:  taux moyen entraînement = 0.9684610962867737
# -------- > epoch 38:  coût moyen validation = 0.14988720417022705
# -------- > epoch 38:  taux moyen validation = 0.9593999981880188
# -------- > epoch 39:  coût moyen entraînement = 0.11404035985469818
# -------- > epoch 39:  taux moyen entraînement = 0.9689407348632812
# -------- > epoch 39:  coût moyen validation = 0.15205416083335876
# -------- > epoch 39:  taux moyen validation = 0.9587998986244202
# -------- > epoch 40:  coût moyen entraînement = 0.11185942590236664
# -------- > epoch 40:  taux moyen entraînement = 0.9697807431221008
# -------- > epoch 40:  coût moyen validation = 0.1484263390302658
# -------- > epoch 40:  taux moyen validation = 0.9596998691558838
# -------- > epoch 41:  coût moyen entraînement = 0.10947798192501068
# -------- > epoch 41:  taux moyen entraînement = 0.9705405235290527
# -------- > epoch 41:  coût moyen validation = 0.14432916045188904
# -------- > epoch 41:  taux moyen validation = 0.9605000019073486
# -------- > epoch 42:  coût moyen entraînement = 0.10761329531669617
# -------- > epoch 42:  taux moyen entraînement = 0.9703810214996338
# -------- > epoch 42:  coût moyen validation = 0.1445574164390564
# -------- > epoch 42:  taux moyen validation = 0.9610999822616577
# -------- > epoch 43:  coût moyen entraînement = 0.10536748915910721
# -------- > epoch 43:  taux moyen entraînement = 0.9709410667419434
# -------- > epoch 43:  coût moyen validation = 0.14177197217941284
# -------- > epoch 43:  taux moyen validation = 0.9610000848770142
# -------- > epoch 44:  coût moyen entraînement = 0.10391292721033096
# -------- > epoch 44:  taux moyen entraînement = 0.9714210033416748
# -------- > epoch 44:  coût moyen validation = 0.14135831594467163
# -------- > epoch 44:  taux moyen validation = 0.9627001881599426
# -------- > epoch 45:  coût moyen entraînement = 0.10191991180181503
# -------- > epoch 45:  taux moyen entraînement = 0.972480833530426
# -------- > epoch 45:  coût moyen validation = 0.13866914808750153
# -------- > epoch 45:  taux moyen validation = 0.9625999331474304
# -------- > epoch 46:  coût moyen entraînement = 0.10038091987371445
# -------- > epoch 46:  taux moyen entraînement = 0.9720204472541809
# -------- > epoch 46:  coût moyen validation = 0.1370568871498108
# -------- > epoch 46:  taux moyen validation = 0.9625998735427856
# -------- > epoch 47:  coût moyen entraînement = 0.09853862226009369
# -------- > epoch 47:  taux moyen entraînement = 0.973060667514801
# -------- > epoch 47:  coût moyen validation = 0.13644729554653168
# -------- > epoch 47:  taux moyen validation = 0.9625999331474304
# -------- > epoch 48:  coût moyen entraînement = 0.09692780673503876
# -------- > epoch 48:  taux moyen entraînement = 0.9735807180404663
# -------- > epoch 48:  coût moyen validation = 0.13389120995998383
# -------- > epoch 48:  taux moyen validation = 0.9633999466896057
# -------- > epoch 49:  coût moyen entraînement = 0.09553360939025879
# -------- > epoch 49:  taux moyen entraînement = 0.9735809564590454
# -------- > epoch 49:  coût moyen validation = 0.137076735496521
# -------- > epoch 49:  taux moyen validation = 0.9620000720024109
# -------- > epoch 50:  coût moyen entraînement = 0.09447997808456421
# -------- > epoch 50:  taux moyen entraînement = 0.9743208289146423
# -------- > epoch 50:  coût moyen validation = 0.1341692954301834
# -------- > epoch 50:  taux moyen validation = 0.9639001488685608
