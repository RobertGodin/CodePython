# %%
# %matplotlib inline
# -*- coding: utf-8 -*-
"""
Exemple simple de MNIST avec PyTorch
Exemple avec nn.Conv2d et F.cross_entropy
Production de métriques avec graphes
Fonction entrainer
"""
import torch
torch.manual_seed(0) # Pour résultats reproductibles

# Fonction J d'entropie croisée
import torch.nn.functional as F
fonction_cout = F.cross_entropy

def taux_bonnes_predictions(lot_Y_predictions, lot_Y):
    predictions_categorie = torch.argmax(lot_Y_predictions, dim=1)
    return (predictions_categorie == lot_Y).float().mean()

from torch import nn
# Définition de l'architecture du RNA

modele = nn.Sequential(
    nn.Conv2d(1,32,3),
    nn.ReLU(),
    nn.Conv2d(32,16,3),
    nn.ReLU(),
    nn.Flatten(),
    nn.Linear(24*24*16, 10)
)
    
from torch import optim
optimiseur = optim.SGD(modele.parameters(), lr=0.01, weight_decay = 0.01)

# Chargement des données de MNIST
import pickle, gzip
fichier_donnees = gzip.open(r"mnist.pkl.gz", 'rb')
((donnees_ent_X, donnees_ent_Y),(donnees_valid_X, donnees_valid_Y),(donnees_test_X,donnees_test_Y)) = pickle.load(fichier_donnees, encoding="latin-1")
fichier_donnees.close()

# Conversion des données en type toch.Tensor
import torch
donnees_ent_X,donnees_ent_Y,donnees_valid_X,donnees_valid_Y,donnees_test_X,donnees_test_Y  = map(torch.tensor,
    (donnees_ent_X.reshape((-1,1,28,28)),donnees_ent_Y,donnees_valid_X.reshape((-1,1,28,28)),donnees_valid_Y,donnees_test_X.reshape((-1,1,28,28)),donnees_test_Y))

# Création des objets DataLoader pour itérer par lot
from torch.utils.data import TensorDataset
from torch.utils.data import DataLoader
ds_ent = TensorDataset(donnees_ent_X, donnees_ent_Y)
dl_ent = DataLoader(ds_ent, batch_size=100, shuffle=True)
ds_valid = TensorDataset(donnees_valid_X,donnees_valid_Y)
dl_valid = DataLoader(ds_valid, batch_size=100)

def entrainer(modele, dl_ent, dl_valid, optimiseur, nb_epochs=10):

    # Listes pour les métriques par epoch
    liste_cout_moyen_ent = []
    liste_taux_moyen_ent = []
    liste_cout_moyen_valid = []
    liste_taux_moyen_valid = []
    
    # Boucle d'apprentissage
    for epoch in range(nb_epochs):
        cout_total_ent = 0 # pour cumuler les couts par mini-lot
        taux_bonnes_predictions_ent = 0 # pour cumuler les taux par mini-lot
        modele.train() # Pour certains types de couches (nn.BatchNorm2d, nn.Dropout, ...)
        
        # Boucle d'apprentissage par mini-lot pour une epoch
        for lot_X, lot_Y in dl_ent:
            optimiseur.zero_grad() # Remettre les dérivées à zéro
            lot_Y_predictions = modele(lot_X) # Appel de la méthode forward
            cout = fonction_cout(lot_Y_predictions, lot_Y)
            cout.backward() # Calcul des gradiants par rétropropagation
            with torch.no_grad():
                cout_total_ent +=cout
                taux_bonnes_predictions_ent += taux_bonnes_predictions(lot_Y_predictions, lot_Y)
            optimiseur.step() # Mise à jour des paramètres
        # Calculer les moyennes par mini-lot
        with torch.no_grad():
            cout_moyen_ent = cout_total_ent/len(dl_ent)
            taux_moyen_ent = taux_bonnes_predictions_ent/len(dl_ent)
       
        modele.eval() # Pour certains types de couches (nn.BatchNorm2d, nn.Dropout, ...)
        with torch.no_grad():
            cout_valid = sum(fonction_cout(modele(lot_valid_X), lot_valid_Y) for lot_valid_X, lot_valid_Y in dl_valid)
            taux_bons_valid = sum(taux_bonnes_predictions(modele(lot_valid_X), lot_valid_Y) for lot_valid_X, lot_valid_Y in dl_valid)
        cout_moyen_valid = cout_valid/len(dl_valid)
        taux_moyen_valid = taux_bons_valid/len(dl_valid)
        print(f'-------- > epoch {epoch+1}:  coût moyen entraînement = {cout_moyen_ent}')
        print(f'-------- > epoch {epoch+1}:  taux moyen entraînement = {taux_moyen_ent}')
        print(f'-------- > epoch {epoch+1}:  coût moyen validation = {cout_moyen_valid}')
        print(f'-------- > epoch {epoch+1}:  taux moyen validation = {taux_moyen_valid}')
    
        liste_cout_moyen_ent.append(cout_moyen_ent)
        liste_taux_moyen_ent.append(taux_moyen_ent)
        liste_cout_moyen_valid.append(cout_moyen_valid)
        liste_taux_moyen_valid.append(taux_moyen_valid)
    
    # Affichage du graphique d'évolution des métriques par epoch
    import numpy as np
    import matplotlib.pyplot as plt
    plt.plot(np.arange(0,nb_epochs),liste_cout_moyen_ent,label='Erreur entraînement')
    plt.plot(np.arange(0,nb_epochs),liste_cout_moyen_valid,label='Erreur validation')
    plt.title("Evolution du coût")
    plt.xlabel('epoch')
    plt.ylabel('moyenne par observation')
    plt.legend(loc='upper center')
    plt.show()
        
    plt.plot(np.arange(0,nb_epochs),liste_taux_moyen_ent,label='Taux bonnes réponses entraînement')
    plt.plot(np.arange(0,nb_epochs),liste_taux_moyen_valid,label='Taux bonnes réponses validation')
    plt.title("Evolution du taux")
    plt.xlabel('epoch')
    plt.ylabel('moyenne par observation')
    plt.legend(loc='upper center')
    plt.show()

entrainer(modele, dl_ent, dl_valid, optimiseur, nb_epochs=30)
# Out:
# -------- > epoch 1:  coût moyen entraînement = 0.641925036907196
# -------- > epoch 1:  taux moyen entraînement = 0.8304803967475891
# -------- > epoch 1:  coût moyen validation = 0.3433564007282257
# -------- > epoch 1:  taux moyen validation = 0.9010999202728271
# -------- > epoch 2:  coût moyen entraînement = 0.3410186767578125
# -------- > epoch 2:  taux moyen entraînement = 0.9008206725120544
# -------- > epoch 2:  coût moyen validation = 0.3148929476737976
# -------- > epoch 2:  taux moyen validation = 0.908799946308136
# -------- > epoch 3:  coût moyen entraînement = 0.31667977571487427
# -------- > epoch 3:  taux moyen entraînement = 0.9076405763626099
# -------- > epoch 3:  coût moyen validation = 0.2772698700428009
# -------- > epoch 3:  taux moyen validation = 0.9217998385429382
# -------- > epoch 4:  coût moyen entraînement = 0.29881978034973145
# -------- > epoch 4:  taux moyen entraînement = 0.9143412709236145
# -------- > epoch 4:  coût moyen validation = 0.27422964572906494
# -------- > epoch 4:  taux moyen validation = 0.9199997782707214
# -------- > epoch 5:  coût moyen entraînement = 0.28432872891426086
# -------- > epoch 5:  taux moyen entraînement = 0.9183212518692017
# -------- > epoch 5:  coût moyen validation = 0.2776883542537689
# -------- > epoch 5:  taux moyen validation = 0.9177000522613525
# -------- > epoch 6:  coût moyen entraînement = 0.2672651410102844
# -------- > epoch 6:  taux moyen entraînement = 0.9237807393074036
# -------- > epoch 6:  coût moyen validation = 0.23977497220039368
# -------- > epoch 6:  taux moyen validation = 0.9324000477790833
# -------- > epoch 7:  coût moyen entraînement = 0.2460203766822815
# -------- > epoch 7:  taux moyen entraînement = 0.9300811886787415
# -------- > epoch 7:  coût moyen validation = 0.21227149665355682
# -------- > epoch 7:  taux moyen validation = 0.9442999958992004
# -------- > epoch 8:  coût moyen entraînement = 0.22377227246761322
# -------- > epoch 8:  taux moyen entraînement = 0.9369206428527832
# -------- > epoch 8:  coût moyen validation = 0.19747455418109894
# -------- > epoch 8:  taux moyen validation = 0.9465001821517944
# -------- > epoch 9:  coût moyen entraînement = 0.2004530131816864
# -------- > epoch 9:  taux moyen entraînement = 0.9433809518814087
# -------- > epoch 9:  coût moyen validation = 0.18036003410816193
# -------- > epoch 9:  taux moyen validation = 0.9537002444267273
# -------- > epoch 10:  coût moyen entraînement = 0.17857202887535095
# -------- > epoch 10:  taux moyen entraînement = 0.9500406384468079
# -------- > epoch 10:  coût moyen validation = 0.1565004587173462
# -------- > epoch 10:  taux moyen validation = 0.9616999626159668
# -------- > epoch 11:  coût moyen entraînement = 0.16049440205097198
# -------- > epoch 11:  taux moyen entraînement = 0.9550009369850159
# -------- > epoch 11:  coût moyen validation = 0.14236591756343842
# -------- > epoch 11:  taux moyen validation = 0.9649000763893127
# -------- > epoch 12:  coût moyen entraînement = 0.14631643891334534
# -------- > epoch 12:  taux moyen entraînement = 0.9590405821800232
# -------- > epoch 12:  coût moyen validation = 0.1399376541376114
# -------- > epoch 12:  taux moyen validation = 0.9666997790336609
# -------- > epoch 13:  coût moyen entraînement = 0.1329643875360489
# -------- > epoch 13:  taux moyen entraînement = 0.9636011123657227
# -------- > epoch 13:  coût moyen validation = 0.12590403854846954
# -------- > epoch 13:  taux moyen validation = 0.9686998128890991
# -------- > epoch 14:  coût moyen entraînement = 0.12310958653688431
# -------- > epoch 14:  taux moyen entraînement = 0.9658405184745789
# -------- > epoch 14:  coût moyen validation = 0.12325707077980042
# -------- > epoch 14:  taux moyen validation = 0.9687999486923218
# -------- > epoch 15:  coût moyen entraînement = 0.11534065753221512
# -------- > epoch 15:  taux moyen entraînement = 0.9686407446861267
# -------- > epoch 15:  coût moyen validation = 0.10949046164751053
# -------- > epoch 15:  taux moyen validation = 0.9728999137878418
# -------- > epoch 16:  coût moyen entraînement = 0.10846687108278275
# -------- > epoch 16:  taux moyen entraînement = 0.9701011180877686
# -------- > epoch 16:  coût moyen validation = 0.10643109679222107
# -------- > epoch 16:  taux moyen validation = 0.9726001024246216
# -------- > epoch 17:  coût moyen entraînement = 0.10321769118309021
# -------- > epoch 17:  taux moyen entraînement = 0.9721406102180481
# -------- > epoch 17:  coût moyen validation = 0.10168708860874176
# -------- > epoch 17:  taux moyen validation = 0.9749999046325684
# -------- > epoch 18:  coût moyen entraînement = 0.09854848682880402
# -------- > epoch 18:  taux moyen entraînement = 0.9729411005973816
# -------- > epoch 18:  coût moyen validation = 0.1006067544221878
# -------- > epoch 18:  taux moyen validation = 0.9754999279975891
# -------- > epoch 19:  coût moyen entraînement = 0.09501145035028458
# -------- > epoch 19:  taux moyen entraînement = 0.9739405512809753
# -------- > epoch 19:  coût moyen validation = 0.09797730296850204
# -------- > epoch 19:  taux moyen validation = 0.9749000072479248
# -------- > epoch 20:  coût moyen entraînement = 0.09184141457080841
# -------- > epoch 20:  taux moyen entraînement = 0.9751803874969482
# -------- > epoch 20:  coût moyen validation = 0.0946904644370079
# -------- > epoch 20:  taux moyen validation = 0.976599931716919
# -------- > epoch 21:  coût moyen entraînement = 0.08929165452718735
# -------- > epoch 21:  taux moyen entraînement = 0.9760212898254395
# -------- > epoch 21:  coût moyen validation = 0.09523118287324905
# -------- > epoch 21:  taux moyen validation = 0.9761000275611877
# -------- > epoch 22:  coût moyen entraînement = 0.08755423873662949
# -------- > epoch 22:  taux moyen entraînement = 0.9759003520011902
# -------- > epoch 22:  coût moyen validation = 0.09205875545740128
# -------- > epoch 22:  taux moyen validation = 0.9770002961158752
# -------- > epoch 23:  coût moyen entraînement = 0.085793636739254
# -------- > epoch 23:  taux moyen entraînement = 0.9770207405090332
# -------- > epoch 23:  coût moyen validation = 0.09033670276403427
# -------- > epoch 23:  taux moyen validation = 0.9773000478744507
# -------- > epoch 24:  coût moyen entraînement = 0.0836930200457573
# -------- > epoch 24:  taux moyen entraînement = 0.9776003956794739
# -------- > epoch 24:  coût moyen validation = 0.08650846779346466
# -------- > epoch 24:  taux moyen validation = 0.9783998131752014
# -------- > epoch 25:  coût moyen entraînement = 0.08278731256723404
# -------- > epoch 25:  taux moyen entraînement = 0.9780004024505615
# -------- > epoch 25:  coût moyen validation = 0.08803969621658325
# -------- > epoch 25:  taux moyen validation = 0.9780000448226929
# -------- > epoch 26:  coût moyen entraînement = 0.08120729774236679
# -------- > epoch 26:  taux moyen entraînement = 0.9786806702613831
# -------- > epoch 26:  coût moyen validation = 0.08531621843576431
# -------- > epoch 26:  taux moyen validation = 0.9790000319480896
# -------- > epoch 27:  coût moyen entraînement = 0.08008462935686111
# -------- > epoch 27:  taux moyen entraînement = 0.9786007404327393
# -------- > epoch 27:  coût moyen validation = 0.0863979309797287
# -------- > epoch 27:  taux moyen validation = 0.9784998893737793
# -------- > epoch 28:  coût moyen entraînement = 0.07922513782978058
# -------- > epoch 28:  taux moyen entraînement = 0.9790803790092468
# -------- > epoch 28:  coût moyen validation = 0.08968977630138397
# -------- > epoch 28:  taux moyen validation = 0.9782000780105591
# -------- > epoch 29:  coût moyen entraînement = 0.07860416173934937
# -------- > epoch 29:  taux moyen entraînement = 0.9791005253791809
# -------- > epoch 29:  coût moyen validation = 0.08422953635454178
# -------- > epoch 29:  taux moyen validation = 0.9800999164581299
# -------- > epoch 30:  coût moyen entraînement = 0.07788597792387009
# -------- > epoch 30:  taux moyen entraînement = 0.979320228099823
# -------- > epoch 30:  coût moyen validation = 0.08448164910078049
# -------- > epoch 30:  taux moyen validation = 0.9782999157905579
