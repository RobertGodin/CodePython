# %%
# %matplotlib inline
# -*- coding: utf-8 -*-
"""
Exemple simple de MNIST avec PyTorch
Exemple avec nn.Sequential et F.cross_entropy
Production de métriques avec graphes
Fonction entrainer
"""
import torch
torch.manual_seed(0)  # Pour résultats reproductibles

# Fonction J d'entropie croisée
import torch.nn.functional as F
fonction_cout = F.cross_entropy

def taux_bonnes_predictions(lot_Y_predictions, lot_Y):
    predictions_categorie = torch.argmax(lot_Y_predictions, dim=1)
    return (predictions_categorie == lot_Y).float().mean()

from torch import nn
# Définition de l'architecture du RNA
modele = nn.Sequential(
    nn.Linear(784, 30),
    nn.ReLU(),
    nn.Linear(30, 10)
)

from torch import optim
optimiseur = optim.SGD(modele.parameters(), lr=0.05)

# Chargement des données de MNIST
import torchvision
ds = torchvision.datasets.MNIST(root='/tmp/mnist', train=True, download=True)
# Sous-ensemble pour exécution rapide
donnees_ent_X = ds.data[:5000].reshape(5000, 784).float() / 255.0
donnees_ent_Y = ds.targets[:5000]
donnees_valid_X = ds.data[5000:6000].reshape(1000, 784).float() / 255.0
donnees_valid_Y = ds.targets[5000:6000]

# Création des objets DataLoader pour itérer par lot
from torch.utils.data import TensorDataset
from torch.utils.data import DataLoader
ds_ent = TensorDataset(donnees_ent_X, donnees_ent_Y)
dl_ent = DataLoader(ds_ent, batch_size=100, shuffle=True)
ds_valid = TensorDataset(donnees_valid_X, donnees_valid_Y)
dl_valid = DataLoader(ds_valid, batch_size=100)

def entrainer(modele, dl_ent, dl_valid, optimiseur, nb_epochs=10):

    # Listes pour les métriques par epoch
    liste_cout_moyen_ent = []
    liste_taux_moyen_ent = []
    liste_cout_moyen_valid = []
    liste_taux_moyen_valid = []

    # Boucle d'apprentissage
    for epoch in range(nb_epochs):
        cout_total_ent = 0  # pour cumuler les couts par mini-lot
        taux_bonnes_predictions_ent = 0  # pour cumuler les taux par mini-lot
        modele.train()  # Pour certains types de couches (nn.BatchNorm2d, nn.Dropout, ...)

        # Boucle d'apprentissage par mini-lot pour une epoch
        for lot_X, lot_Y in dl_ent:
            optimiseur.zero_grad()  # Remettre les dérivées à zéro
            lot_Y_predictions = modele(lot_X)  # Appel de la méthode forward
            cout = fonction_cout(lot_Y_predictions, lot_Y)
            cout.backward()  # Calcul des gradients par rétropropagation
            with torch.no_grad():
                cout_total_ent += cout
                taux_bonnes_predictions_ent += taux_bonnes_predictions(lot_Y_predictions, lot_Y)
            optimiseur.step()  # Mise à jour des paramètres
        # Calculer les moyennes par mini-lot
        with torch.no_grad():
            cout_moyen_ent = cout_total_ent/len(dl_ent)
            taux_moyen_ent = taux_bonnes_predictions_ent/len(dl_ent)

        modele.eval()  # Pour certains types de couches (nn.BatchNorm2d, nn.Dropout, ...)
        with torch.no_grad():
            cout_valid = sum(fonction_cout(modele(lot_valid_X), lot_valid_Y) for lot_valid_X, lot_valid_Y in dl_valid)
            taux_bons_valid = sum(taux_bonnes_predictions(modele(lot_valid_X), lot_valid_Y) for lot_valid_X, lot_valid_Y in dl_valid)
        cout_moyen_valid = cout_valid/len(dl_valid)
        taux_moyen_valid = taux_bons_valid/len(dl_valid)
        print(f'-------- > epoch {epoch+1}: coût moyen entraînement = {cout_moyen_ent}')
        print(f'-------- > epoch {epoch+1}: taux moyen entraînement = {taux_moyen_ent}')
        print(f'-------- > epoch {epoch+1}: coût moyen validation = {cout_moyen_valid}')
        print(f'-------- > epoch {epoch+1}: taux moyen validation = {taux_moyen_valid}')

        liste_cout_moyen_ent.append(cout_moyen_ent)
        liste_taux_moyen_ent.append(taux_moyen_ent)
        liste_cout_moyen_valid.append(cout_moyen_valid)
        liste_taux_moyen_valid.append(taux_moyen_valid)

    # Affichage du graphique d'évolution des métriques par epoch
    import numpy as np
    import matplotlib.pyplot as plt
    plt.figure()
    plt.plot(np.arange(0, nb_epochs), liste_cout_moyen_ent, label='Erreur entraînement')
    plt.plot(np.arange(0, nb_epochs), liste_cout_moyen_valid, label='Erreur validation')
    plt.title("Evolution du coût")
    plt.xlabel('epoch')
    plt.ylabel('moyenne par observation')
    plt.legend(loc='upper center')
    plt.show()

    plt.figure()
    plt.plot(np.arange(0, nb_epochs), liste_taux_moyen_ent, label='Taux bonnes réponses entraînement')
    plt.plot(np.arange(0, nb_epochs), liste_taux_moyen_valid, label='Taux bonnes réponses validation')
    plt.title("Evolution du taux")
    plt.xlabel('epoch')
    plt.ylabel('moyenne par observation')
    plt.legend(loc='upper center')
    plt.show()


print("Étape 1: 10 epochs")
entrainer(modele, dl_ent, dl_valid, optimiseur, nb_epochs=10)

print("Étape 2: 30 epochs")
entrainer(modele, dl_ent, dl_valid, optimiseur, nb_epochs=10)

print("Étape 3: réduire le taux d'apprentissage à 0.005 pour 10 epochs")
optimiseur = optim.SGD(modele.parameters(), lr=0.005)
entrainer(modele, dl_ent, dl_valid, optimiseur, nb_epochs=10)

print("Étape 4: sauvegarder le modèle")
CHEMIN = './MNISTSimple10.pth'
torch.save(modele.state_dict(), CHEMIN)

print("Étape 5: charger le modèle et poursuivre l'entraînement")
modele.load_state_dict(torch.load(CHEMIN))
entrainer(modele, dl_ent, dl_valid, optimiseur, nb_epochs=10)

print("Étape 6: métriques sur les données de test")
# Chargement des données de test MNIST
import torchvision
ds_test = torchvision.datasets.MNIST(root='/tmp/mnist', train=False, download=True)
donnees_test_X = ds_test.data[:1000].reshape(1000, 784).float() / 255.0
donnees_test_Y = ds.targets[:1000]
from torch.utils.data import TensorDataset
from torch.utils.data import DataLoader
ds_test = TensorDataset(donnees_test_X, donnees_test_Y)
dl_test = DataLoader(ds_ent, batch_size=100)

with torch.no_grad():
    cout_test = sum(fonction_cout(modele(lot_test_X), lot_test_Y) for lot_test_X, lot_test_Y in dl_test)
    taux_bons_test = sum(taux_bonnes_predictions(modele(lot_test_X), lot_test_Y) for lot_test_X, lot_test_Y in dl_test)
cout_moyen_test = cout_test/len(dl_test)
taux_moyen_test = taux_bons_test/len(dl_test)
print(f'-------- > coût moyen test = {cout_moyen_test}')
print(f'-------- > taux moyen test = {taux_moyen_test}')
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 404: Not Found
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz to /tmp/mnist\MNIST\raw\train-images-idx3-ubyte.gz
# 100%|██████████| 9912422/9912422 [00:00<00:00, 30105991.00it/s]
# Extracting /tmp/mnist\MNIST\raw\train-images-idx3-ubyte.gz to /tmp/mnist\MNIST\raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 404: Not Found
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz to /tmp/mnist\MNIST\raw\train-labels-idx1-ubyte.gz
# 100%|██████████| 28881/28881 [00:00<00:00, 1960505.18it/s]
# Extracting /tmp/mnist\MNIST\raw\train-labels-idx1-ubyte.gz to /tmp/mnist\MNIST\raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 404: Not Found
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz to /tmp/mnist\MNIST\raw\t10k-images-idx3-ubyte.gz
# 100%|██████████| 1648877/1648877 [00:00<00:00, 13773987.14it/s]
# Extracting /tmp/mnist\MNIST\raw\t10k-images-idx3-ubyte.gz to /tmp/mnist\MNIST\raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 404: Not Found
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz to /tmp/mnist\MNIST\raw\t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4542/4542 [00:00<00:00, 4543412.54it/s]
# Extracting /tmp/mnist\MNIST\raw\t10k-labels-idx1-ubyte.gz to /tmp/mnist\MNIST\raw
#
# Étape 1: 10 epochs
# -------- > epoch 1: coût moyen entraînement = 2.0494468212127686
# -------- > epoch 1: taux moyen entraînement = 0.4966000020503998
# -------- > epoch 1: coût moyen validation = 1.6594085693359375
# -------- > epoch 1: taux moyen validation = 0.7039999961853027
# -------- > epoch 2: coût moyen entraînement = 1.3123300075531006
# -------- > epoch 2: taux moyen entraînement = 0.7644001245498657
# -------- > epoch 2: coût moyen validation = 0.9888823628425598
# -------- > epoch 2: taux moyen validation = 0.7950000762939453
# -------- > epoch 3: coût moyen entraînement = 0.8281621336936951
# -------- > epoch 3: taux moyen entraînement = 0.8226000070571899
# -------- > epoch 3: coût moyen validation = 0.7026217579841614
# -------- > epoch 3: taux moyen validation = 0.843000054359436
# -------- > epoch 4: coût moyen entraînement = 0.6223440766334534
# -------- > epoch 4: taux moyen entraînement = 0.8579999804496765
# -------- > epoch 4: coût moyen validation = 0.5798530578613281
# -------- > epoch 4: taux moyen validation = 0.8560000658035278
# -------- > epoch 5: coût moyen entraînement = 0.5190256834030151
# -------- > epoch 5: taux moyen entraînement = 0.8723999857902527
# -------- > epoch 5: coût moyen validation = 0.4979611039161682
# -------- > epoch 5: taux moyen validation = 0.8780000805854797
# -------- > epoch 6: coût moyen entraînement = 0.4565665125846863
# -------- > epoch 6: taux moyen entraînement = 0.8873999118804932
# -------- > epoch 6: coût moyen validation = 0.4555668830871582
# -------- > epoch 6: taux moyen validation = 0.8840000033378601
# -------- > epoch 7: coût moyen entraînement = 0.4152510166168213
# -------- > epoch 7: taux moyen entraînement = 0.8943998217582703
# -------- > epoch 7: coût moyen validation = 0.4247390329837799
# -------- > epoch 7: taux moyen validation = 0.8880000114440918
# -------- > epoch 8: coût moyen entraînement = 0.3838856816291809
# -------- > epoch 8: taux moyen entraînement = 0.9041998982429504
# -------- > epoch 8: coût moyen validation = 0.40933457016944885
# -------- > epoch 8: taux moyen validation = 0.8949999809265137
# -------- > epoch 9: coût moyen entraînement = 0.3629733920097351
# -------- > epoch 9: taux moyen entraînement = 0.9057998657226562
# -------- > epoch 9: coût moyen validation = 0.3874508738517761
# -------- > epoch 9: taux moyen validation = 0.8939999341964722
# -------- > epoch 10: coût moyen entraînement = 0.34415337443351746
# -------- > epoch 10: taux moyen entraînement = 0.9079999327659607
# -------- > epoch 10: coût moyen validation = 0.37683552503585815
# -------- > epoch 10: taux moyen validation = 0.8989999890327454
# Étape 2: 30 epochs
# -------- > epoch 1: coût moyen entraînement = 0.33008506894111633
# -------- > epoch 1: taux moyen entraînement = 0.9095999002456665
# -------- > epoch 1: coût moyen validation = 0.37404972314834595
# -------- > epoch 1: taux moyen validation = 0.9019999504089355
# -------- > epoch 2: coût moyen entraînement = 0.31762567162513733
# -------- > epoch 2: taux moyen entraînement = 0.9157999157905579
# -------- > epoch 2: coût moyen validation = 0.3598567545413971
# -------- > epoch 2: taux moyen validation = 0.9050000309944153
# -------- > epoch 3: coût moyen entraînement = 0.30654242634773254
# -------- > epoch 3: taux moyen entraînement = 0.9159998893737793
# -------- > epoch 3: coût moyen validation = 0.35164767503738403
# -------- > epoch 3: taux moyen validation = 0.9109999537467957
# -------- > epoch 4: coût moyen entraînement = 0.2974802851676941
# -------- > epoch 4: taux moyen entraînement = 0.919999897480011
# -------- > epoch 4: coût moyen validation = 0.35226327180862427
# -------- > epoch 4: taux moyen validation = 0.9010000228881836
# -------- > epoch 5: coût moyen entraînement = 0.2890872061252594
# -------- > epoch 5: taux moyen entraînement = 0.9229998588562012
# -------- > epoch 5: coût moyen validation = 0.3421247601509094
# -------- > epoch 5: taux moyen validation = 0.906999945640564
# -------- > epoch 6: coût moyen entraînement = 0.2815994620323181
# -------- > epoch 6: taux moyen entraînement = 0.9223997592926025
# -------- > epoch 6: coût moyen validation = 0.336935430765152
# -------- > epoch 6: taux moyen validation = 0.9079999923706055
# -------- > epoch 7: coût moyen entraînement = 0.27547281980514526
# -------- > epoch 7: taux moyen entraînement = 0.9232000112533569
# -------- > epoch 7: coût moyen validation = 0.3397454619407654
# -------- > epoch 7: taux moyen validation = 0.903999924659729
# -------- > epoch 8: coût moyen entraînement = 0.26888400316238403
# -------- > epoch 8: taux moyen entraînement = 0.9265998601913452
# -------- > epoch 8: coût moyen validation = 0.3325650691986084
# -------- > epoch 8: taux moyen validation = 0.9129999876022339
# -------- > epoch 9: coût moyen entraînement = 0.26291602849960327
# -------- > epoch 9: taux moyen entraînement = 0.926800012588501
# -------- > epoch 9: coût moyen validation = 0.325318306684494
# -------- > epoch 9: taux moyen validation = 0.9160000085830688
# -------- > epoch 10: coût moyen entraînement = 0.25783026218414307
# -------- > epoch 10: taux moyen entraînement = 0.9285997748374939
# -------- > epoch 10: coût moyen validation = 0.32182225584983826
# -------- > epoch 10: taux moyen validation = 0.9160000085830688
# Étape 3: réduire le taux d'apprentissage à 0.005 pour 10 epochs
# -------- > epoch 1: coût moyen entraînement = 0.24935640394687653
# -------- > epoch 1: taux moyen entraînement = 0.9329997897148132
# -------- > epoch 1: coût moyen validation = 0.3202438950538635
# -------- > epoch 1: taux moyen validation = 0.9169999957084656
# -------- > epoch 2: coût moyen entraînement = 0.2479010373353958
# -------- > epoch 2: taux moyen entraînement = 0.9322000741958618
# -------- > epoch 2: coût moyen validation = 0.32015952467918396
# -------- > epoch 2: taux moyen validation = 0.9169999957084656
# -------- > epoch 3: coût moyen entraînement = 0.24737732112407684
# -------- > epoch 3: taux moyen entraînement = 0.932600200176239
# -------- > epoch 3: coût moyen validation = 0.3199951648712158
# -------- > epoch 3: taux moyen validation = 0.9160000085830688
# -------- > epoch 4: coût moyen entraînement = 0.24679213762283325
# -------- > epoch 4: taux moyen entraînement = 0.9327999353408813
# -------- > epoch 4: coût moyen validation = 0.3195691704750061
# -------- > epoch 4: taux moyen validation = 0.9169999957084656
# -------- > epoch 5: coût moyen entraînement = 0.24635431170463562
# -------- > epoch 5: taux moyen entraînement = 0.9319999814033508
# -------- > epoch 5: coût moyen validation = 0.31950250267982483
# -------- > epoch 5: taux moyen validation = 0.9160000085830688
# -------- > epoch 6: coût moyen entraînement = 0.24585551023483276
# -------- > epoch 6: taux moyen entraînement = 0.9317998290061951
# -------- > epoch 6: coût moyen validation = 0.31915315985679626
# -------- > epoch 6: taux moyen validation = 0.9169999957084656
# -------- > epoch 7: coût moyen entraînement = 0.2453320324420929
# -------- > epoch 7: taux moyen entraînement = 0.9325999617576599
# -------- > epoch 7: coût moyen validation = 0.31859150528907776
# -------- > epoch 7: taux moyen validation = 0.9169999957084656
# -------- > epoch 8: coût moyen entraînement = 0.2448492795228958
# -------- > epoch 8: taux moyen entraînement = 0.9337999820709229
# -------- > epoch 8: coût moyen validation = 0.31848016381263733
# -------- > epoch 8: taux moyen validation = 0.9180000424385071
# -------- > epoch 9: coût moyen entraînement = 0.24441203474998474
# -------- > epoch 9: taux moyen entraînement = 0.9335998296737671
# -------- > epoch 9: coût moyen validation = 0.31828194856643677
# -------- > epoch 9: taux moyen validation = 0.9169999957084656
# -------- > epoch 10: coût moyen entraînement = 0.24390345811843872
# -------- > epoch 10: taux moyen entraînement = 0.9329997301101685
# -------- > epoch 10: coût moyen validation = 0.31809061765670776
# -------- > epoch 10: taux moyen validation = 0.9180000424385071
# Étape 4: sauvegarder le modèle
# Étape 5: charger le modèle et poursuivre l'entraînement
# -------- > epoch 1: coût moyen entraînement = 0.24336498975753784
# -------- > epoch 1: taux moyen entraînement = 0.9323999285697937
# -------- > epoch 1: coût moyen validation = 0.31812959909439087
# -------- > epoch 1: taux moyen validation = 0.9180000424385071
# C:\Users\vango\AppData\Local\Temp\ipykernel_3960\3691845291.py:126: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   modele.load_state_dict(torch.load(CHEMIN))
# -------- > epoch 2: coût moyen entraînement = 0.24299533665180206
# -------- > epoch 2: taux moyen entraînement = 0.9333999156951904
# -------- > epoch 2: coût moyen validation = 0.3173038959503174
# -------- > epoch 2: taux moyen validation = 0.9180000424385071
# -------- > epoch 3: coût moyen entraînement = 0.24249683320522308
# -------- > epoch 3: taux moyen entraînement = 0.9330000281333923
# -------- > epoch 3: coût moyen validation = 0.3170221447944641
# -------- > epoch 3: taux moyen validation = 0.918999969959259
# -------- > epoch 4: coût moyen entraînement = 0.24206529557704926
# -------- > epoch 4: taux moyen entraînement = 0.9333999752998352
# -------- > epoch 4: coût moyen validation = 0.316819965839386
# -------- > epoch 4: taux moyen validation = 0.9169999957084656
# -------- > epoch 5: coût moyen entraînement = 0.2416062355041504
# -------- > epoch 5: taux moyen entraînement = 0.9331998229026794
# -------- > epoch 5: coût moyen validation = 0.31680750846862793
# -------- > epoch 5: taux moyen validation = 0.9169999957084656
# -------- > epoch 6: coût moyen entraînement = 0.24107995629310608
# -------- > epoch 6: taux moyen entraînement = 0.93340003490448
# -------- > epoch 6: coût moyen validation = 0.3166263699531555
# -------- > epoch 6: taux moyen validation = 0.9190000295639038
# -------- > epoch 7: coût moyen entraînement = 0.2406037449836731
# -------- > epoch 7: taux moyen entraînement = 0.9339998364448547
# -------- > epoch 7: coût moyen validation = 0.31606048345565796
# -------- > epoch 7: taux moyen validation = 0.9179999232292175
# -------- > epoch 8: coût moyen entraînement = 0.24008817970752716
# -------- > epoch 8: taux moyen entraînement = 0.9335997700691223
# -------- > epoch 8: coût moyen validation = 0.3158921003341675
# -------- > epoch 8: taux moyen validation = 0.9169999957084656
# -------- > epoch 9: coût moyen entraînement = 0.23970270156860352
# -------- > epoch 9: taux moyen entraînement = 0.9341998100280762
# -------- > epoch 9: coût moyen validation = 0.31545814871788025
# -------- > epoch 9: taux moyen validation = 0.9180000424385071
# -------- > epoch 10: coût moyen entraînement = 0.23924550414085388
# -------- > epoch 10: taux moyen entraînement = 0.9351999759674072
# -------- > epoch 10: coût moyen validation = 0.31508123874664307
# -------- > epoch 10: taux moyen validation = 0.918999969959259

# %%
# Chargement des données de test MNIST
import torchvision
ds_test = torchvision.datasets.MNIST(root='/tmp/mnist', train=False, download=True)
# Sous-ensemble pour exécution rapide
donnees_test_X = ds_test.data[:1000].reshape(1000, 784).float() / 255.0
donnees_test_Y = ds.targets[:1000]

# Création des objets DataLoader pour itérer par lot
from torch.utils.data import TensorDataset
from torch.utils.data import DataLoader
ds_test = TensorDataset(donnees_test_X, donnees_test_Y)
dl_test = DataLoader(ds_ent, batch_size=100)

with torch.no_grad():
    cout_test = sum(fonction_cout(modele(lot_test_X), lot_test_Y) for lot_test_X, lot_test_Y in dl_test)
    taux_bons_test = sum(taux_bonnes_predictions(modele(lot_test_X), lot_test_Y) for lot_test_X, lot_test_Y in dl_test)
cout_moyen_test = cout_test/len(dl_test)
taux_moyen_test = taux_bons_test/len(dl_test)
print(f'-------- > coût moyen test = {cout_moyen_test}')
print(f'-------- > taux moyen test = {taux_moyen_test}')
# Out:
# -------- > coût moyen test = 0.23818907141685486
# -------- > taux moyen test = 0.934400200843811
