# %%
# %matplotlib inline
# -*- coding: utf-8 -*-
"""
Exercice: FashionMNIST avec PyTorch
Exemple avec nn.Sequential et F.cross_entropy
Production de métriques avec graphes
Fonction entrainer
"""
import torch
torch.manual_seed(0) # Pour résultats reproductibles

# Fonction J d'entropie croisée
import torch.nn.functional as F
fonction_cout = F.cross_entropy

def taux_bonnes_predictions(lot_Y_predictions, lot_Y):
    predictions_categorie = torch.argmax(lot_Y_predictions, dim=1)
    return (predictions_categorie == lot_Y).float().mean()

from torch import nn
# Définition de l'architecture du RNA
modele = nn.Sequential(
    nn.Flatten(),
    nn.Linear(784, 30),
    nn.ReLU(),
    nn.Linear(30, 10)
)
    
from torch import optim
optimiseur = optim.SGD(modele.parameters(), lr=0.05)

# Chargement des données de FashionMNIST
import torchvision
ds = torchvision.datasets.FashionMNIST(root='/tmp/mnist', train=True, download=True)
# Sous-ensemble pour exécution rapide
donnees_ent_X = ds.data[:5000].reshape(5000, 784).float() / 255.0
donnees_ent_Y = ds.targets[:5000]
donnees_valid_X = ds.data[5000:6000].reshape(1000, 784).float() / 255.0
donnees_valid_Y = ds.targets[5000:6000]

# Création des objets DataLoader pour itérer par lot
from torch.utils.data import TensorDataset
from torch.utils.data import DataLoader
ds_ent = TensorDataset(donnees_ent_X, donnees_ent_Y)
dl_ent = DataLoader(ds_ent, batch_size=100, shuffle=True)
ds_valid = TensorDataset(donnees_valid_X, donnees_valid_Y)
dl_valid = DataLoader(ds_valid, batch_size=100)

def entrainer(modele, dl_ent, dl_valid, optimiseur, nb_epochs=10):

    # Listes pour les métriques par epoch
    liste_cout_moyen_ent = []
    liste_taux_moyen_ent = []
    liste_cout_moyen_valid = []
    liste_taux_moyen_valid = []
    
    # Boucle d'apprentissage
    for epoch in range(nb_epochs):
        cout_total_ent = 0 # pour cumuler les couts par mini-lot
        taux_bonnes_predictions_ent = 0 # pour cumuler les taux par mini-lot
        modele.train() # Pour certains types de couches (nn.BatchNorm2d, nn.Dropout, ...)
        
        # Boucle d'apprentissage par mini-lot pour une epoch
        for lot_X, lot_Y in dl_ent:
            optimiseur.zero_grad() # Remettre les dérivées à zéro
            lot_Y_predictions = modele(lot_X) # Appel de la méthode forward
            cout = fonction_cout(lot_Y_predictions, lot_Y)
            cout.backward() # Calcul des gradiants par rétropropagation
            with torch.no_grad():
                cout_total_ent +=cout
                taux_bonnes_predictions_ent += taux_bonnes_predictions(lot_Y_predictions, lot_Y)
            optimiseur.step() # Mise à jour des paramètres
        # Calculer les moyennes par mini-lot
        with torch.no_grad():
            cout_moyen_ent = cout_total_ent/len(dl_ent)
            taux_moyen_ent = taux_bonnes_predictions_ent/len(dl_ent)
       
        modele.eval() # Pour certains types de couches (nn.BatchNorm2d, nn.Dropout, ...)
        with torch.no_grad():
            cout_valid = sum(fonction_cout(modele(lot_valid_X), lot_valid_Y) for lot_valid_X, lot_valid_Y in dl_valid)
            taux_bons_valid = sum(taux_bonnes_predictions(modele(lot_valid_X), lot_valid_Y) for lot_valid_X, lot_valid_Y in dl_valid)
        cout_moyen_valid = cout_valid/len(dl_valid)
        taux_moyen_valid = taux_bons_valid/len(dl_valid)
        print(f'-------- > epoch {epoch+1}:  coût moyen entraînement = {cout_moyen_ent}')
        print(f'-------- > epoch {epoch+1}:  taux moyen entraînement = {taux_moyen_ent}')
        print(f'-------- > epoch {epoch+1}:  coût moyen validation = {cout_moyen_valid}')
        print(f'-------- > epoch {epoch+1}:  taux moyen validation = {taux_moyen_valid}')
    
        liste_cout_moyen_ent.append(cout_moyen_ent)
        liste_taux_moyen_ent.append(taux_moyen_ent)
        liste_cout_moyen_valid.append(cout_moyen_valid)
        liste_taux_moyen_valid.append(taux_moyen_valid)
    
    # Affichage du graphique d'évolution des métriques par epoch
    import numpy as np
    import matplotlib.pyplot as plt
    plt.plot(np.arange(0,nb_epochs),liste_cout_moyen_ent,label='Erreur entraînement')
    plt.plot(np.arange(0,nb_epochs),liste_cout_moyen_valid,label='Erreur validation')
    plt.title("Evolution du coût")
    plt.xlabel('epoch')
    plt.ylabel('moyenne par observation')
    plt.legend(loc='upper center')
    plt.show()
        
    plt.plot(np.arange(0,nb_epochs),liste_taux_moyen_ent,label='Taux bonnes réponses entraînement')
    plt.plot(np.arange(0,nb_epochs),liste_taux_moyen_valid,label='Taux bonnes réponses validation')
    plt.title("Evolution du taux")
    plt.xlabel('epoch')
    plt.ylabel('moyenne par observation')
    plt.legend(loc='upper center')
    plt.show()

entrainer(modele, dl_ent, dl_valid, optimiseur, nb_epochs=30)
# Out:
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz to /tmp/mnist\FashionMNIST\raw\train-images-idx3-ubyte.gz
# 100%|██████████| 26421880/26421880 [09:14<00:00, 47634.51it/s]
# Extracting /tmp/mnist\FashionMNIST\raw\train-images-idx3-ubyte.gz to /tmp/mnist\FashionMNIST\raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz to /tmp/mnist\FashionMNIST\raw\train-labels-idx1-ubyte.gz
# 100%|██████████| 29515/29515 [00:00<00:00, 348291.20it/s]
# Extracting /tmp/mnist\FashionMNIST\raw\train-labels-idx1-ubyte.gz to /tmp/mnist\FashionMNIST\raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz to /tmp/mnist\FashionMNIST\raw\t10k-images-idx3-ubyte.gz
# 100%|██████████| 4422102/4422102 [00:00<00:00, 4959811.09it/s]
# Extracting /tmp/mnist\FashionMNIST\raw\t10k-images-idx3-ubyte.gz to /tmp/mnist\FashionMNIST\raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz to /tmp/mnist\FashionMNIST\raw\t10k-labels-idx1-ubyte.gz
# 100%|██████████| 5148/5148 [00:00<00:00, 5668752.16it/s]
# Extracting /tmp/mnist\FashionMNIST\raw\t10k-labels-idx1-ubyte.gz to /tmp/mnist\FashionMNIST\raw
#
# -------- > epoch 1:  coût moyen entraînement = 1.7641242742538452
# -------- > epoch 1:  taux moyen entraînement = 0.48419997096061707
# -------- > epoch 1:  coût moyen validation = 1.303904414176941
# -------- > epoch 1:  taux moyen validation = 0.6389999389648438
# -------- > epoch 2:  coût moyen entraînement = 1.0641489028930664
# -------- > epoch 2:  taux moyen entraînement = 0.6648000478744507
# -------- > epoch 2:  coût moyen validation = 0.9662894010543823
# -------- > epoch 2:  taux moyen validation = 0.6460000276565552
# -------- > epoch 3:  coût moyen entraînement = 0.8545169830322266
# -------- > epoch 3:  taux moyen entraînement = 0.7001999616622925
# -------- > epoch 3:  coût moyen validation = 0.8283317685127258
# -------- > epoch 3:  taux moyen validation = 0.7080000638961792
# -------- > epoch 4:  coût moyen entraînement = 0.7631598711013794
# -------- > epoch 4:  taux moyen entraînement = 0.7337999939918518
# -------- > epoch 4:  coût moyen validation = 0.77190101146698
# -------- > epoch 4:  taux moyen validation = 0.7289999723434448
# -------- > epoch 5:  coût moyen entraînement = 0.7052103281021118
# -------- > epoch 5:  taux moyen entraînement = 0.7518000602722168
# -------- > epoch 5:  coût moyen validation = 0.7275431752204895
# -------- > epoch 5:  taux moyen validation = 0.7400000095367432
# -------- > epoch 6:  coût moyen entraînement = 0.6573539972305298
# -------- > epoch 6:  taux moyen entraînement = 0.7722001075744629
# -------- > epoch 6:  coût moyen validation = 0.6855887770652771
# -------- > epoch 6:  taux moyen validation = 0.7610000371932983
# -------- > epoch 7:  coût moyen entraînement = 0.6247569918632507
# -------- > epoch 7:  taux moyen entraînement = 0.7841999530792236
# -------- > epoch 7:  coût moyen validation = 0.7170203328132629
# -------- > epoch 7:  taux moyen validation = 0.7440000772476196
# -------- > epoch 8:  coût moyen entraînement = 0.5957999229431152
# -------- > epoch 8:  taux moyen entraînement = 0.7922002673149109
# -------- > epoch 8:  coût moyen validation = 0.6792901158332825
# -------- > epoch 8:  taux moyen validation = 0.7749999761581421
# -------- > epoch 9:  coût moyen entraînement = 0.5807634592056274
# -------- > epoch 9:  taux moyen entraînement = 0.7994000315666199
# -------- > epoch 9:  coût moyen validation = 0.6545812487602234
# -------- > epoch 9:  taux moyen validation = 0.7610000371932983
# -------- > epoch 10:  coût moyen entraînement = 0.5575326681137085
# -------- > epoch 10:  taux moyen entraînement = 0.8118000626564026
# -------- > epoch 10:  coût moyen validation = 0.623802125453949
# -------- > epoch 10:  taux moyen validation = 0.777999997138977
# -------- > epoch 11:  coût moyen entraînement = 0.5422257781028748
# -------- > epoch 11:  taux moyen entraînement = 0.8179999589920044
# -------- > epoch 11:  coût moyen validation = 0.6041482090950012
# -------- > epoch 11:  taux moyen validation = 0.7820000648498535
# -------- > epoch 12:  coût moyen entraînement = 0.5265533328056335
# -------- > epoch 12:  taux moyen entraînement = 0.8258001208305359
# -------- > epoch 12:  coût moyen validation = 0.5881847143173218
# -------- > epoch 12:  taux moyen validation = 0.7900000214576721
# -------- > epoch 13:  coût moyen entraînement = 0.518652617931366
# -------- > epoch 13:  taux moyen entraînement = 0.8250000476837158
# -------- > epoch 13:  coût moyen validation = 0.6050141453742981
# -------- > epoch 13:  taux moyen validation = 0.7949999570846558
# -------- > epoch 14:  coût moyen entraînement = 0.5029760599136353
# -------- > epoch 14:  taux moyen entraînement = 0.8306000232696533
# -------- > epoch 14:  coût moyen validation = 0.5927762985229492
# -------- > epoch 14:  taux moyen validation = 0.7879999876022339
# -------- > epoch 15:  coût moyen entraînement = 0.4886110723018646
# -------- > epoch 15:  taux moyen entraînement = 0.8343999981880188
# -------- > epoch 15:  coût moyen validation = 0.5617321133613586
# -------- > epoch 15:  taux moyen validation = 0.8029999732971191
# -------- > epoch 16:  coût moyen entraînement = 0.48442572355270386
# -------- > epoch 16:  taux moyen entraînement = 0.8368001580238342
# -------- > epoch 16:  coût moyen validation = 0.5561619400978088
# -------- > epoch 16:  taux moyen validation = 0.8059999346733093
# -------- > epoch 17:  coût moyen entraînement = 0.47449982166290283
# -------- > epoch 17:  taux moyen entraînement = 0.8398001790046692
# -------- > epoch 17:  coût moyen validation = 0.5920960307121277
# -------- > epoch 17:  taux moyen validation = 0.7920000553131104
# -------- > epoch 18:  coût moyen entraînement = 0.4699404239654541
# -------- > epoch 18:  taux moyen entraînement = 0.839199960231781
# -------- > epoch 18:  coût moyen validation = 0.566964328289032
# -------- > epoch 18:  taux moyen validation = 0.8030000925064087
# -------- > epoch 19:  coût moyen entraînement = 0.46002140641212463
# -------- > epoch 19:  taux moyen entraînement = 0.8424001336097717
# -------- > epoch 19:  coût moyen validation = 0.5394179821014404
# -------- > epoch 19:  taux moyen validation = 0.8079999685287476
# -------- > epoch 20:  coût moyen entraînement = 0.4525584280490875
# -------- > epoch 20:  taux moyen entraînement = 0.8479999303817749
# -------- > epoch 20:  coût moyen validation = 0.5475793480873108
# -------- > epoch 20:  taux moyen validation = 0.8090000152587891
# -------- > epoch 21:  coût moyen entraînement = 0.4432443678379059
# -------- > epoch 21:  taux moyen entraînement = 0.8519999980926514
# -------- > epoch 21:  coût moyen validation = 0.5801475048065186
# -------- > epoch 21:  taux moyen validation = 0.7919999957084656
# -------- > epoch 22:  coût moyen entraînement = 0.4529670476913452
# -------- > epoch 22:  taux moyen entraînement = 0.8438000679016113
# -------- > epoch 22:  coût moyen validation = 0.5515366792678833
# -------- > epoch 22:  taux moyen validation = 0.8029999732971191
# -------- > epoch 23:  coût moyen entraînement = 0.4399110674858093
# -------- > epoch 23:  taux moyen entraînement = 0.8481998443603516
# -------- > epoch 23:  coût moyen validation = 0.5456305742263794
# -------- > epoch 23:  taux moyen validation = 0.809999942779541
# -------- > epoch 24:  coût moyen entraînement = 0.4298916757106781
# -------- > epoch 24:  taux moyen entraînement = 0.8532000780105591
# -------- > epoch 24:  coût moyen validation = 0.5373013615608215
# -------- > epoch 24:  taux moyen validation = 0.8170000314712524
# -------- > epoch 25:  coût moyen entraînement = 0.43297022581100464
# -------- > epoch 25:  taux moyen entraînement = 0.851599931716919
# -------- > epoch 25:  coût moyen validation = 0.5814568996429443
# -------- > epoch 25:  taux moyen validation = 0.8040000200271606
# -------- > epoch 26:  coût moyen entraînement = 0.4188285768032074
# -------- > epoch 26:  taux moyen entraînement = 0.8598000407218933
# -------- > epoch 26:  coût moyen validation = 0.5428429245948792
# -------- > epoch 26:  taux moyen validation = 0.8130000233650208
# -------- > epoch 27:  coût moyen entraînement = 0.4151788353919983
# -------- > epoch 27:  taux moyen entraînement = 0.8613998889923096
# -------- > epoch 27:  coût moyen validation = 0.5240520238876343
# -------- > epoch 27:  taux moyen validation = 0.8119999766349792
# -------- > epoch 28:  coût moyen entraînement = 0.4155435264110565
# -------- > epoch 28:  taux moyen entraînement = 0.8596001267433167
# -------- > epoch 28:  coût moyen validation = 0.5623797178268433
# -------- > epoch 28:  taux moyen validation = 0.8050000071525574
# -------- > epoch 29:  coût moyen entraînement = 0.40794527530670166
# -------- > epoch 29:  taux moyen entraînement = 0.8590002655982971
# -------- > epoch 29:  coût moyen validation = 0.5191984176635742
# -------- > epoch 29:  taux moyen validation = 0.8240000009536743
# -------- > epoch 30:  coût moyen entraînement = 0.4071976840496063
# -------- > epoch 30:  taux moyen entraînement = 0.8629998564720154
# -------- > epoch 30:  coût moyen validation = 0.5315142273902893
# -------- > epoch 30:  taux moyen validation = 0.8220000267028809

# %%
entrainer(modele, dl_ent, dl_valid, optimiseur, nb_epochs=10)
# Out:
# -------- > epoch 1:  coût moyen entraînement = 0.3070470988750458
# -------- > epoch 1:  taux moyen entraînement = 0.8901407718658447
# -------- > epoch 1:  coût moyen validation = 0.37295714020729065
# -------- > epoch 1:  taux moyen validation = 0.8654998540878296
# -------- > epoch 2:  coût moyen entraînement = 0.3053663671016693
# -------- > epoch 2:  taux moyen entraînement = 0.8906404376029968
# -------- > epoch 2:  coût moyen validation = 0.3622247576713562
# -------- > epoch 2:  taux moyen validation = 0.8711998462677002
# -------- > epoch 3:  coût moyen entraînement = 0.3036971390247345
# -------- > epoch 3:  taux moyen entraînement = 0.8909806609153748
# -------- > epoch 3:  coût moyen validation = 0.3567965626716614
# -------- > epoch 3:  taux moyen validation = 0.874000072479248
# -------- > epoch 4:  coût moyen entraînement = 0.30281057953834534
# -------- > epoch 4:  taux moyen entraînement = 0.8909604549407959
# -------- > epoch 4:  coût moyen validation = 0.36479222774505615
# -------- > epoch 4:  taux moyen validation = 0.8698999881744385
# -------- > epoch 5:  coût moyen entraînement = 0.30041027069091797
# -------- > epoch 5:  taux moyen entraînement = 0.8921406269073486
# -------- > epoch 5:  coût moyen validation = 0.3729926347732544
# -------- > epoch 5:  taux moyen validation = 0.8665998578071594
# -------- > epoch 6:  coût moyen entraînement = 0.29898935556411743
# -------- > epoch 6:  taux moyen entraînement = 0.8946605920791626
# -------- > epoch 6:  coût moyen validation = 0.3602498173713684
# -------- > epoch 6:  taux moyen validation = 0.8707000017166138
# -------- > epoch 7:  coût moyen entraînement = 0.29832664132118225
# -------- > epoch 7:  taux moyen entraînement = 0.8935804963111877
# -------- > epoch 7:  coût moyen validation = 0.35566651821136475
# -------- > epoch 7:  taux moyen validation = 0.8747999668121338
# -------- > epoch 8:  coût moyen entraînement = 0.2955925464630127
# -------- > epoch 8:  taux moyen entraînement = 0.8941201567649841
# -------- > epoch 8:  coût moyen validation = 0.3544762134552002
# -------- > epoch 8:  taux moyen validation = 0.8726000785827637
# -------- > epoch 9:  coût moyen entraînement = 0.29298916459083557
# -------- > epoch 9:  taux moyen entraînement = 0.895280659198761
# -------- > epoch 9:  coût moyen validation = 0.3581620454788208
# -------- > epoch 9:  taux moyen validation = 0.8723999857902527
# -------- > epoch 10:  coût moyen entraînement = 0.29148125648498535
# -------- > epoch 10:  taux moyen entraînement = 0.8963409066200256
# -------- > epoch 10:  coût moyen validation = 0.3679620325565338
# -------- > epoch 10:  taux moyen validation = 0.8686997890472412

# %%
optimiseur = optim.SGD(modele.parameters(), lr=0.005)
entrainer(modele, dl_ent, dl_valid, optimiseur, nb_epochs=10)
# Out:
# -------- > epoch 1:  coût moyen entraînement = 0.38185223937034607
# -------- > epoch 1:  taux moyen entraînement = 0.8754000067710876
# -------- > epoch 1:  coût moyen validation = 0.517200767993927
# -------- > epoch 1:  taux moyen validation = 0.8190000653266907
# -------- > epoch 2:  coût moyen entraînement = 0.37913379073143005
# -------- > epoch 2:  taux moyen entraînement = 0.8730000257492065
# -------- > epoch 2:  coût moyen validation = 0.514278769493103
# -------- > epoch 2:  taux moyen validation = 0.8190000653266907
# -------- > epoch 3:  coût moyen entraînement = 0.37875762581825256
# -------- > epoch 3:  taux moyen entraînement = 0.8752000331878662
# -------- > epoch 3:  coût moyen validation = 0.513273298740387
# -------- > epoch 3:  taux moyen validation = 0.8190000653266907
# -------- > epoch 4:  coût moyen entraînement = 0.37837478518486023
# -------- > epoch 4:  taux moyen entraînement = 0.8749998211860657
# -------- > epoch 4:  coût moyen validation = 0.5131725668907166
# -------- > epoch 4:  taux moyen validation = 0.8190000653266907
# -------- > epoch 5:  coût moyen entraînement = 0.3775491714477539
# -------- > epoch 5:  taux moyen entraînement = 0.8746000528335571
# -------- > epoch 5:  coût moyen validation = 0.512712299823761
# -------- > epoch 5:  taux moyen validation = 0.8189999461174011
# -------- > epoch 6:  coût moyen entraînement = 0.3769261837005615
# -------- > epoch 6:  taux moyen entraînement = 0.8757998943328857
# -------- > epoch 6:  coût moyen validation = 0.5149685740470886
# -------- > epoch 6:  taux moyen validation = 0.8209999799728394
# -------- > epoch 7:  coût moyen entraînement = 0.37667274475097656
# -------- > epoch 7:  taux moyen entraînement = 0.8754000663757324
# -------- > epoch 7:  coût moyen validation = 0.5130746364593506
# -------- > epoch 7:  taux moyen validation = 0.8199999928474426
# -------- > epoch 8:  coût moyen entraînement = 0.37641987204551697
# -------- > epoch 8:  taux moyen entraînement = 0.8770000338554382
# -------- > epoch 8:  coût moyen validation = 0.5129684805870056
# -------- > epoch 8:  taux moyen validation = 0.8199999928474426
# -------- > epoch 9:  coût moyen entraînement = 0.3755561113357544
# -------- > epoch 9:  taux moyen entraînement = 0.8772000670433044
# -------- > epoch 9:  coût moyen validation = 0.5133053660392761
# -------- > epoch 9:  taux moyen validation = 0.8190000653266907
# -------- > epoch 10:  coût moyen entraînement = 0.37532564997673035
# -------- > epoch 10:  taux moyen entraînement = 0.8765999674797058
# -------- > epoch 10:  coût moyen validation = 0.5115517973899841
# -------- > epoch 10:  taux moyen validation = 0.8209999799728394

# %%
CHEMIN = './MNISTSimple10.pth'
torch.save(modele.state_dict(), CHEMIN)

# %%
modele.load_state_dict(torch.load(CHEMIN))
entrainer(modele, dl_ent, dl_valid, optimiseur, nb_epochs=10)
# Out:
# C:\Users\vango\AppData\Local\Temp\ipykernel_41460\3595662355.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   modele.load_state_dict(torch.load(CHEMIN))
# -------- > epoch 1:  coût moyen entraînement = 0.3751239776611328
# -------- > epoch 1:  taux moyen entraînement = 0.876800000667572
# -------- > epoch 1:  coût moyen validation = 0.512122392654419
# -------- > epoch 1:  taux moyen validation = 0.8199999928474426
# -------- > epoch 2:  coût moyen entraînement = 0.37480950355529785
# -------- > epoch 2:  taux moyen entraînement = 0.8758000135421753
# -------- > epoch 2:  coût moyen validation = 0.5105454921722412
# -------- > epoch 2:  taux moyen validation = 0.8209999799728394
# -------- > epoch 3:  coût moyen entraînement = 0.37444302439689636
# -------- > epoch 3:  taux moyen entraînement = 0.8766000270843506
# -------- > epoch 3:  coût moyen validation = 0.5137748718261719
# -------- > epoch 3:  taux moyen validation = 0.8220000267028809
# -------- > epoch 4:  coût moyen entraînement = 0.37375083565711975
# -------- > epoch 4:  taux moyen entraînement = 0.8755999803543091
# -------- > epoch 4:  coût moyen validation = 0.5119704008102417
# -------- > epoch 4:  taux moyen validation = 0.8179999589920044
# -------- > epoch 5:  coût moyen entraînement = 0.37285664677619934
# -------- > epoch 5:  taux moyen entraînement = 0.8787999749183655
# -------- > epoch 5:  coût moyen validation = 0.5115402936935425
# -------- > epoch 5:  taux moyen validation = 0.8229999542236328
# -------- > epoch 6:  coût moyen entraînement = 0.37317776679992676
# -------- > epoch 6:  taux moyen entraînement = 0.876000165939331
# -------- > epoch 6:  coût moyen validation = 0.5104853510856628
# -------- > epoch 6:  taux moyen validation = 0.8229999542236328
# -------- > epoch 7:  coût moyen entraînement = 0.3726215660572052
# -------- > epoch 7:  taux moyen entraînement = 0.8763999938964844
# -------- > epoch 7:  coût moyen validation = 0.5109144449234009
# -------- > epoch 7:  taux moyen validation = 0.8209999799728394
# -------- > epoch 8:  coût moyen entraînement = 0.3718719780445099
# -------- > epoch 8:  taux moyen entraînement = 0.8773999810218811
# -------- > epoch 8:  coût moyen validation = 0.5106614232063293
# -------- > epoch 8:  taux moyen validation = 0.8180000185966492
# -------- > epoch 9:  coût moyen entraînement = 0.3717327415943146
# -------- > epoch 9:  taux moyen entraînement = 0.877000093460083
# -------- > epoch 9:  coût moyen validation = 0.511125922203064
# -------- > epoch 9:  taux moyen validation = 0.8170000314712524
# -------- > epoch 10:  coût moyen entraînement = 0.3715745508670807
# -------- > epoch 10:  taux moyen entraînement = 0.8773999810218811
# -------- > epoch 10:  coût moyen validation = 0.5112819075584412
# -------- > epoch 10:  taux moyen validation = 0.8159999847412109

# %%
print("Étape 6: métriques sur les données de test")
# Chargement des données de test MNIST
import torchvision
ds_test = torchvision.datasets.FashionMNIST(root='/tmp/mnist', train=False, download=True)
donnees_test_X = ds_test.data[:1000].reshape(1000, 784).float() / 255.0
donnees_test_Y = ds.targets[:1000]
from torch.utils.data import TensorDataset
from torch.utils.data import DataLoader
ds_test = TensorDataset(donnees_test_X, donnees_test_Y)
dl_test = DataLoader(ds_ent, batch_size=100)

with torch.no_grad():
    cout_test = sum(fonction_cout(modele(lot_test_X), lot_test_Y) for lot_test_X, lot_test_Y in dl_test)
    taux_bons_test = sum(taux_bonnes_predictions(modele(lot_test_X), lot_test_Y) for lot_test_X, lot_test_Y in dl_test)
cout_moyen_test = cout_test/len(dl_test)
taux_moyen_test = taux_bons_test/len(dl_test)
print(f'-------- > coût moyen test = {cout_moyen_test}')
print(f'-------- > taux moyen test = {taux_moyen_test}')
# Out:
# Étape 6: métriques sur les données de test
# -------- > coût moyen test = 0.3694900870323181
# -------- > taux moyen test = 0.8797999620437622
