# %%
# %matplotlib inline
# -*- coding: utf-8 -*-
"""
Exemple simple de MNIST avec PyTorch
Exemple avec nn.Sequential et F.cross_entropy
Production de métriques avec graphes
Fonction entrainer
"""
import torch
torch.manual_seed(0) # Pour résultats reproductibles

# Fonction J d'entropie croisée
import torch.nn.functional as F
fonction_cout = F.cross_entropy

def taux_bonnes_predictions(lot_Y_predictions, lot_Y):
    predictions_categorie = torch.argmax(lot_Y_predictions, dim=1)
    return (predictions_categorie == lot_Y).float().mean()

from torch import nn
# Définition de l'architecture du RNA
modele = nn.Sequential(
    nn.Linear(784, 30),
    nn.ReLU(),
    nn.Linear(30, 10)
)
    
from torch import optim
optimiseur = optim.SGD(modele.parameters(), lr=0.05)

# Chargement des données de MNIST
import pickle, gzip
fichier_donnees = gzip.open(r"mnist.pkl.gz", 'rb')
((donnees_ent_X, donnees_ent_Y),(donnees_valid_X, donnees_valid_Y),(donnees_test_X,donnees_test_Y)) = pickle.load(fichier_donnees, encoding="latin-1")
fichier_donnees.close()

# Conversion des données en type toch.Tensor
import torch
donnees_ent_X,donnees_ent_Y,donnees_valid_X,donnees_valid_Y,donnees_test_X,donnees_test_Y  = map(torch.tensor,(donnees_ent_X,donnees_ent_Y,donnees_valid_X,donnees_valid_Y,donnees_test_X,donnees_test_Y))

# Création des objets DataLoader pour itérer par lot
from torch.utils.data import TensorDataset
from torch.utils.data import DataLoader
ds_ent = TensorDataset(donnees_ent_X, donnees_ent_Y)
dl_ent = DataLoader(ds_ent, batch_size=100, shuffle=True)
ds_valid = TensorDataset(donnees_valid_X,donnees_valid_Y)
dl_valid = DataLoader(ds_valid, batch_size=100)

def entrainer(modele, dl_ent, dl_valid, optimiseur, nb_epochs=10):

    # Listes pour les métriques par epoch
    liste_cout_moyen_ent = []
    liste_taux_moyen_ent = []
    liste_cout_moyen_valid = []
    liste_taux_moyen_valid = []
    
    # Boucle d'apprentissage
    for epoch in range(nb_epochs):
        cout_total_ent = 0 # pour cumuler les couts par mini-lot
        taux_bonnes_predictions_ent = 0 # pour cumuler les taux par mini-lot
        modele.train() # Pour certains types de couches (nn.BatchNorm2d, nn.Dropout, ...)
        
        # Boucle d'apprentissage par mini-lot pour une epoch
        for lot_X, lot_Y in dl_ent:
            optimiseur.zero_grad() # Remettre les dérivées à zéro
            lot_Y_predictions = modele(lot_X) # Appel de la méthode forward
            cout = fonction_cout(lot_Y_predictions, lot_Y)
            cout.backward() # Calcul des gradiants par rétropropagation
            with torch.no_grad():
                cout_total_ent +=cout
                taux_bonnes_predictions_ent += taux_bonnes_predictions(lot_Y_predictions, lot_Y)
            optimiseur.step() # Mise à jour des paramètres
        # Calculer les moyennes par mini-lot
        with torch.no_grad():
            cout_moyen_ent = cout_total_ent/len(dl_ent)
            taux_moyen_ent = taux_bonnes_predictions_ent/len(dl_ent)
       
        modele.eval() # Pour certains types de couches (nn.BatchNorm2d, nn.Dropout, ...)
        with torch.no_grad():
            cout_valid = sum(fonction_cout(modele(lot_valid_X), lot_valid_Y) for lot_valid_X, lot_valid_Y in dl_valid)
            taux_bons_valid = sum(taux_bonnes_predictions(modele(lot_valid_X), lot_valid_Y) for lot_valid_X, lot_valid_Y in dl_valid)
        cout_moyen_valid = cout_valid/len(dl_valid)
        taux_moyen_valid = taux_bons_valid/len(dl_valid)
        print(f'-------- > epoch {epoch+1}:  coût moyen entraînement = {cout_moyen_ent}')
        print(f'-------- > epoch {epoch+1}:  taux moyen entraînement = {taux_moyen_ent}')
        print(f'-------- > epoch {epoch+1}:  coût moyen validation = {cout_moyen_valid}')
        print(f'-------- > epoch {epoch+1}:  taux moyen validation = {taux_moyen_valid}')
    
        liste_cout_moyen_ent.append(cout_moyen_ent)
        liste_taux_moyen_ent.append(taux_moyen_ent)
        liste_cout_moyen_valid.append(cout_moyen_valid)
        liste_taux_moyen_valid.append(taux_moyen_valid)
    
    # Affichage du graphique d'évolution des métriques par epoch
    import numpy as np
    import matplotlib.pyplot as plt
    plt.plot(np.arange(0,nb_epochs),liste_cout_moyen_ent,label='Erreur entraînement')
    plt.plot(np.arange(0,nb_epochs),liste_cout_moyen_valid,label='Erreur validation')
    plt.title("Evolution du coût")
    plt.xlabel('epoch')
    plt.ylabel('moyenne par observation')
    plt.legend(loc='upper center')
    plt.show()
        
    plt.plot(np.arange(0,nb_epochs),liste_taux_moyen_ent,label='Taux bonnes réponses entraînement')
    plt.plot(np.arange(0,nb_epochs),liste_taux_moyen_valid,label='Taux bonnes réponses validation')
    plt.title("Evolution du taux")
    plt.xlabel('epoch')
    plt.ylabel('moyenne par observation')
    plt.legend(loc='upper center')
    plt.show()

entrainer(modele, dl_ent, dl_valid, optimiseur, nb_epochs=30)
# Out:
# -------- > epoch 1:  coût moyen entraînement = 0.7773018479347229
# -------- > epoch 1:  taux moyen entraînement = 0.8121605515480042
# -------- > epoch 1:  coût moyen validation = 0.35756435990333557
# -------- > epoch 1:  taux moyen validation = 0.9037998914718628
# -------- > epoch 2:  coût moyen entraînement = 0.3555574119091034
# -------- > epoch 2:  taux moyen entraînement = 0.8997410535812378
# -------- > epoch 2:  coût moyen validation = 0.3012230396270752
# -------- > epoch 2:  taux moyen validation = 0.9142998456954956
# -------- > epoch 3:  coût moyen entraînement = 0.3118169903755188
# -------- > epoch 3:  taux moyen entraînement = 0.9107611179351807
# -------- > epoch 3:  coût moyen validation = 0.2725439965724945
# -------- > epoch 3:  taux moyen validation = 0.9224998950958252
# -------- > epoch 4:  coût moyen entraînement = 0.2861367166042328
# -------- > epoch 4:  taux moyen entraînement = 0.9181413650512695
# -------- > epoch 4:  coût moyen validation = 0.2573801577091217
# -------- > epoch 4:  taux moyen validation = 0.9259997606277466
# -------- > epoch 5:  coût moyen entraînement = 0.2671203017234802
# -------- > epoch 5:  taux moyen entraînement = 0.9234806895256042
# -------- > epoch 5:  coût moyen validation = 0.24095787107944489
# -------- > epoch 5:  taux moyen validation = 0.9325000643730164
# -------- > epoch 6:  coût moyen entraînement = 0.25060081481933594
# -------- > epoch 6:  taux moyen entraînement = 0.9288210272789001
# -------- > epoch 6:  coût moyen validation = 0.23075510561466217
# -------- > epoch 6:  taux moyen validation = 0.9348002672195435
# -------- > epoch 7:  coût moyen entraînement = 0.2359222024679184
# -------- > epoch 7:  taux moyen entraînement = 0.9327411651611328
# -------- > epoch 7:  coût moyen validation = 0.21673092246055603
# -------- > epoch 7:  taux moyen validation = 0.9391998052597046
# -------- > epoch 8:  coût moyen entraînement = 0.22313708066940308
# -------- > epoch 8:  taux moyen entraînement = 0.9362007975578308
# -------- > epoch 8:  coût moyen validation = 0.20671074092388153
# -------- > epoch 8:  taux moyen validation = 0.9428000450134277
# -------- > epoch 9:  coût moyen entraînement = 0.21126997470855713
# -------- > epoch 9:  taux moyen entraînement = 0.9395607709884644
# -------- > epoch 9:  coût moyen validation = 0.19830159842967987
# -------- > epoch 9:  taux moyen validation = 0.9467998743057251
# -------- > epoch 10:  coût moyen entraînement = 0.20084594190120697
# -------- > epoch 10:  taux moyen entraînement = 0.9423008561134338
# -------- > epoch 10:  coût moyen validation = 0.18874609470367432
# -------- > epoch 10:  taux moyen validation = 0.9487000107765198
# -------- > epoch 11:  coût moyen entraînement = 0.19187389314174652
# -------- > epoch 11:  taux moyen entraînement = 0.9453209042549133
# -------- > epoch 11:  coût moyen validation = 0.1830103099346161
# -------- > epoch 11:  taux moyen validation = 0.9490999579429626
# -------- > epoch 12:  coût moyen entraînement = 0.18292631208896637
# -------- > epoch 12:  taux moyen entraînement = 0.9484012722969055
# -------- > epoch 12:  coût moyen validation = 0.1765482872724533
# -------- > epoch 12:  taux moyen validation = 0.9518999457359314
# -------- > epoch 13:  coût moyen entraînement = 0.17541581392288208
# -------- > epoch 13:  taux moyen entraînement = 0.9498010277748108
# -------- > epoch 13:  coût moyen validation = 0.17264516651630402
# -------- > epoch 13:  taux moyen validation = 0.9525999426841736
# -------- > epoch 14:  coût moyen entraînement = 0.16843008995056152
# -------- > epoch 14:  taux moyen entraînement = 0.9528211951255798
# -------- > epoch 14:  coût moyen validation = 0.16521425545215607
# -------- > epoch 14:  taux moyen validation = 0.9537001848220825
# -------- > epoch 15:  coût moyen entraînement = 0.1622423529624939
# -------- > epoch 15:  taux moyen entraînement = 0.9537011981010437
# -------- > epoch 15:  coût moyen validation = 0.16188426315784454
# -------- > epoch 15:  taux moyen validation = 0.9544001221656799
# -------- > epoch 16:  coût moyen entraînement = 0.15659886598587036
# -------- > epoch 16:  taux moyen entraînement = 0.9553412795066833
# -------- > epoch 16:  coût moyen validation = 0.15972457826137543
# -------- > epoch 16:  taux moyen validation = 0.9558001160621643
# -------- > epoch 17:  coût moyen entraînement = 0.15089094638824463
# -------- > epoch 17:  taux moyen entraînement = 0.9569607973098755
# -------- > epoch 17:  coût moyen validation = 0.15616196393966675
# -------- > epoch 17:  taux moyen validation = 0.9559999108314514
# -------- > epoch 18:  coût moyen entraînement = 0.14603006839752197
# -------- > epoch 18:  taux moyen entraînement = 0.9586209654808044
# -------- > epoch 18:  coût moyen validation = 0.15083687007427216
# -------- > epoch 18:  taux moyen validation = 0.9570002555847168
# -------- > epoch 19:  coût moyen entraînement = 0.1411813348531723
# -------- > epoch 19:  taux moyen entraînement = 0.9602412581443787
# -------- > epoch 19:  coût moyen validation = 0.14882118999958038
# -------- > epoch 19:  taux moyen validation = 0.9583001136779785
# -------- > epoch 20:  coût moyen entraînement = 0.13675600290298462
# -------- > epoch 20:  taux moyen entraînement = 0.9610412120819092
# -------- > epoch 20:  coût moyen validation = 0.1450856477022171
# -------- > epoch 20:  taux moyen validation = 0.9592001438140869
# -------- > epoch 21:  coût moyen entraînement = 0.1328551173210144
# -------- > epoch 21:  taux moyen entraînement = 0.9623415470123291
# -------- > epoch 21:  coût moyen validation = 0.1469230055809021
# -------- > epoch 21:  taux moyen validation = 0.958899974822998
# -------- > epoch 22:  coût moyen entraînement = 0.1290169507265091
# -------- > epoch 22:  taux moyen entraînement = 0.9633008241653442
# -------- > epoch 22:  coût moyen validation = 0.14311496913433075
# -------- > epoch 22:  taux moyen validation = 0.9609002470970154
# -------- > epoch 23:  coût moyen entraînement = 0.1258232593536377
# -------- > epoch 23:  taux moyen entraînement = 0.9645411968231201
# -------- > epoch 23:  coût moyen validation = 0.13800187408924103
# -------- > epoch 23:  taux moyen validation = 0.960500180721283
# -------- > epoch 24:  coût moyen entraînement = 0.12196852266788483
# -------- > epoch 24:  taux moyen entraînement = 0.9653208255767822
# -------- > epoch 24:  coût moyen validation = 0.1382192075252533
# -------- > epoch 24:  taux moyen validation = 0.9618001580238342
# -------- > epoch 25:  coût moyen entraînement = 0.11927372962236404
# -------- > epoch 25:  taux moyen entraînement = 0.965940535068512
# -------- > epoch 25:  coût moyen validation = 0.13629835844039917
# -------- > epoch 25:  taux moyen validation = 0.9619002342224121
# -------- > epoch 26:  coût moyen entraînement = 0.11604989320039749
# -------- > epoch 26:  taux moyen entraînement = 0.967441201210022
# -------- > epoch 26:  coût moyen validation = 0.13438767194747925
# -------- > epoch 26:  taux moyen validation = 0.9617002606391907
# -------- > epoch 27:  coût moyen entraînement = 0.11316870898008347
# -------- > epoch 27:  taux moyen entraînement = 0.9676611423492432
# -------- > epoch 27:  coût moyen validation = 0.13404890894889832
# -------- > epoch 27:  taux moyen validation = 0.9628002047538757
# -------- > epoch 28:  coût moyen entraînement = 0.11042620986700058
# -------- > epoch 28:  taux moyen entraînement = 0.968901515007019
# -------- > epoch 28:  coût moyen validation = 0.13296552002429962
# -------- > epoch 28:  taux moyen validation = 0.9619001150131226
# -------- > epoch 29:  coût moyen entraînement = 0.10824175924062729
# -------- > epoch 29:  taux moyen entraînement = 0.9692407846450806
# -------- > epoch 29:  coût moyen validation = 0.1298505663871765
# -------- > epoch 29:  taux moyen validation = 0.9622001647949219
# -------- > epoch 30:  coût moyen entraînement = 0.10590983927249908
# -------- > epoch 30:  taux moyen entraînement = 0.9697806239128113
# -------- > epoch 30:  coût moyen validation = 0.12733915448188782
# -------- > epoch 30:  taux moyen validation = 0.9639003872871399

# %%
entrainer(modele, dl_ent, dl_valid, optimiseur, nb_epochs=10)
# Out:
# -------- > epoch 1:  coût moyen entraînement = 0.10310441255569458
# -------- > epoch 1:  taux moyen entraînement = 0.9711407423019409
# -------- > epoch 1:  coût moyen validation = 0.1287250965833664
# -------- > epoch 1:  taux moyen validation = 0.9635003805160522
# -------- > epoch 2:  coût moyen entraînement = 0.10097722709178925
# -------- > epoch 2:  taux moyen entraînement = 0.9713809490203857
# -------- > epoch 2:  coût moyen validation = 0.12696987390518188
# -------- > epoch 2:  taux moyen validation = 0.9639003276824951
# -------- > epoch 3:  coût moyen entraînement = 0.09913955628871918
# -------- > epoch 3:  taux moyen entraînement = 0.9721807837486267
# -------- > epoch 3:  coût moyen validation = 0.12515965104103088
# -------- > epoch 3:  taux moyen validation = 0.9639002084732056
# -------- > epoch 4:  coût moyen entraînement = 0.09714992344379425
# -------- > epoch 4:  taux moyen entraînement = 0.9722409844398499
# -------- > epoch 4:  coût moyen validation = 0.12398464977741241
# -------- > epoch 4:  taux moyen validation = 0.9645001292228699
# -------- > epoch 5:  coût moyen entraînement = 0.09514258056879044
# -------- > epoch 5:  taux moyen entraînement = 0.9732808470726013
# -------- > epoch 5:  coût moyen validation = 0.12410300225019455
# -------- > epoch 5:  taux moyen validation = 0.963600218296051
# -------- > epoch 6:  coût moyen entraînement = 0.09343642741441727
# -------- > epoch 6:  taux moyen entraînement = 0.9735205173492432
# -------- > epoch 6:  coût moyen validation = 0.12786376476287842
# -------- > epoch 6:  taux moyen validation = 0.9635003805160522
# -------- > epoch 7:  coût moyen entraînement = 0.09170333296060562
# -------- > epoch 7:  taux moyen entraînement = 0.9742608070373535
# -------- > epoch 7:  coût moyen validation = 0.12293455749750137
# -------- > epoch 7:  taux moyen validation = 0.964600145816803
# -------- > epoch 8:  coût moyen entraînement = 0.09021367877721786
# -------- > epoch 8:  taux moyen entraînement = 0.9743411540985107
# -------- > epoch 8:  coût moyen validation = 0.12074925750494003
# -------- > epoch 8:  taux moyen validation = 0.965300440788269
# -------- > epoch 9:  coût moyen entraînement = 0.08799523115158081
# -------- > epoch 9:  taux moyen entraînement = 0.975040853023529
# -------- > epoch 9:  coût moyen validation = 0.1251516193151474
# -------- > epoch 9:  taux moyen validation = 0.9643001556396484
# -------- > epoch 10:  coût moyen entraînement = 0.08677185326814651
# -------- > epoch 10:  taux moyen entraînement = 0.9755606055259705
# -------- > epoch 10:  coût moyen validation = 0.12181553244590759
# -------- > epoch 10:  taux moyen validation = 0.9657002091407776

# %%
optimiseur = optim.SGD(modele.parameters(), lr=0.005)
entrainer(modele, dl_ent, dl_valid, optimiseur, nb_epochs=10)
# Out:
# -------- > epoch 1:  coût moyen entraînement = 0.08183100074529648
# -------- > epoch 1:  taux moyen entraînement = 0.9772604703903198
# -------- > epoch 1:  coût moyen validation = 0.11893507093191147
# -------- > epoch 1:  taux moyen validation = 0.9661003351211548
# -------- > epoch 2:  coût moyen entraînement = 0.08116219937801361
# -------- > epoch 2:  taux moyen entraînement = 0.977920651435852
# -------- > epoch 2:  coût moyen validation = 0.11896507441997528
# -------- > epoch 2:  taux moyen validation = 0.9655002355575562
# -------- > epoch 3:  coût moyen entraînement = 0.0808834433555603
# -------- > epoch 3:  taux moyen entraînement = 0.9777202606201172
# -------- > epoch 3:  coût moyen validation = 0.1190396249294281
# -------- > epoch 3:  taux moyen validation = 0.9662003517150879
# -------- > epoch 4:  coût moyen entraînement = 0.08071591705083847
# -------- > epoch 4:  taux moyen entraînement = 0.9778199791908264
# -------- > epoch 4:  coût moyen validation = 0.1189088523387909
# -------- > epoch 4:  taux moyen validation = 0.9659003615379333
# -------- > epoch 5:  coût moyen entraînement = 0.08053047955036163
# -------- > epoch 5:  taux moyen entraînement = 0.9777603149414062
# -------- > epoch 5:  coût moyen validation = 0.11895029246807098
# -------- > epoch 5:  taux moyen validation = 0.9662002325057983
# -------- > epoch 6:  coût moyen entraînement = 0.0803917720913887
# -------- > epoch 6:  taux moyen entraînement = 0.9780206680297852
# -------- > epoch 6:  coût moyen validation = 0.11851480603218079
# -------- > epoch 6:  taux moyen validation = 0.9656002521514893
# -------- > epoch 7:  coût moyen entraînement = 0.08022508770227432
# -------- > epoch 7:  taux moyen entraînement = 0.9780009388923645
# -------- > epoch 7:  coût moyen validation = 0.11833272874355316
# -------- > epoch 7:  taux moyen validation = 0.9655002355575562
# -------- > epoch 8:  coût moyen entraînement = 0.0800705999135971
# -------- > epoch 8:  taux moyen entraînement = 0.9779403209686279
# -------- > epoch 8:  coût moyen validation = 0.11837214231491089
# -------- > epoch 8:  taux moyen validation = 0.9661002159118652
# -------- > epoch 9:  coût moyen entraînement = 0.07991104573011398
# -------- > epoch 9:  taux moyen entraînement = 0.9778205752372742
# -------- > epoch 9:  coût moyen validation = 0.1183532327413559
# -------- > epoch 9:  taux moyen validation = 0.9658003449440002
# -------- > epoch 10:  coût moyen entraînement = 0.07976441830396652
# -------- > epoch 10:  taux moyen entraînement = 0.9781807065010071
# -------- > epoch 10:  coût moyen validation = 0.11850901693105698
# -------- > epoch 10:  taux moyen validation = 0.9660003185272217

# %%
CHEMIN = './MNISTSimple10.pth'
torch.save(modele.state_dict(), CHEMIN)

# %%
modele.load_state_dict(torch.load(CHEMIN))
entrainer(modele, dl_ent, dl_valid, optimiseur, nb_epochs=10)
# Out:
# -------- > epoch 1:  coût moyen entraînement = 0.07819783687591553
# -------- > epoch 1:  taux moyen entraînement = 0.9786808490753174
# -------- > epoch 1:  coût moyen validation = 0.11802491545677185
# -------- > epoch 1:  taux moyen validation = 0.9660003781318665
# -------- > epoch 2:  coût moyen entraînement = 0.07803085446357727
# -------- > epoch 2:  taux moyen entraînement = 0.9788404107093811
# -------- > epoch 2:  coût moyen validation = 0.11803194880485535
# -------- > epoch 2:  taux moyen validation = 0.9664003252983093
# -------- > epoch 3:  coût moyen entraînement = 0.07789315283298492
# -------- > epoch 3:  taux moyen entraînement = 0.9786200523376465
# -------- > epoch 3:  coût moyen validation = 0.11738929152488708
# -------- > epoch 3:  taux moyen validation = 0.9660001993179321
# -------- > epoch 4:  coût moyen entraînement = 0.07770983129739761
# -------- > epoch 4:  taux moyen entraînement = 0.9788204431533813
# -------- > epoch 4:  coût moyen validation = 0.11744580417871475
# -------- > epoch 4:  taux moyen validation = 0.9660003185272217
# -------- > epoch 5:  coût moyen entraînement = 0.07757794857025146
# -------- > epoch 5:  taux moyen entraînement = 0.9789002537727356
# -------- > epoch 5:  coût moyen validation = 0.11768164485692978
# -------- > epoch 5:  taux moyen validation = 0.9655003547668457
# -------- > epoch 6:  coût moyen entraînement = 0.07752063870429993
# -------- > epoch 6:  taux moyen entraînement = 0.9789406657218933
# -------- > epoch 6:  coût moyen validation = 0.11752822250127792
# -------- > epoch 6:  taux moyen validation = 0.9658002257347107
# -------- > epoch 7:  coût moyen entraînement = 0.07731471955776215
# -------- > epoch 7:  taux moyen entraînement = 0.9790009260177612
# -------- > epoch 7:  coût moyen validation = 0.11766455322504044
# -------- > epoch 7:  taux moyen validation = 0.9663002490997314
# -------- > epoch 8:  coût moyen entraînement = 0.07723527401685715
# -------- > epoch 8:  taux moyen entraînement = 0.9788603782653809
# -------- > epoch 8:  coût moyen validation = 0.11726560443639755
# -------- > epoch 8:  taux moyen validation = 0.9664002060890198
# -------- > epoch 9:  coût moyen entraînement = 0.07704775780439377
# -------- > epoch 9:  taux moyen entraînement = 0.978920578956604
# -------- > epoch 9:  coût moyen validation = 0.11745152622461319
# -------- > epoch 9:  taux moyen validation = 0.9660003185272217
# -------- > epoch 10:  coût moyen entraînement = 0.07693208754062653
# -------- > epoch 10:  taux moyen entraînement = 0.9791000485420227
# -------- > epoch 10:  coût moyen validation = 0.11753208190202713
# -------- > epoch 10:  taux moyen validation = 0.9662003517150879

# %%
ds_test = TensorDataset(donnees_test_X,donnees_test_Y)
dl_test = DataLoader(ds_test, batch_size=100)
with torch.no_grad():
    cout_test = sum(fonction_cout(modele(lot_test_X), lot_test_Y) for lot_test_X, lot_test_Y in dl_test)
    taux_bons_test = sum(taux_bonnes_predictions(modele(lot_test_X), lot_test_Y) for lot_test_X, lot_test_Y in dl_test)
cout_moyen_test = cout_test/len(dl_test)
taux_moyen_test = taux_bons_test/len(dl_test)
print(f'-------- > coût moyen test = {cout_moyen_test}')
print(f'-------- > taux moyen test = {taux_moyen_test}')
# Out:
# -------- > coût moyen test = 0.11828004568815231
# -------- > taux moyen test = 0.9638999700546265
