# %%
# %matplotlib inline
# -*- coding: utf-8 -*-
"""
Exemple simple de MNIST avec PyTorch
Exemple avec nn.Conv2d et F.cross_entropy
Production de métriques avec graphes
Fonction entrainer
"""
import torch
torch.manual_seed(0) # Pour résultats reproductibles

# Fonction J d'entropie croisée
import torch.nn.functional as F
fonction_cout = F.cross_entropy

def taux_bonnes_predictions(lot_Y_predictions, lot_Y):
    predictions_categorie = torch.argmax(lot_Y_predictions, dim=1)
    return (predictions_categorie == lot_Y).float().mean()

from torch import nn
# Définition de l'architecture du RNA

modele = nn.Sequential(
    nn.Conv2d(1,32,3,padding=1),
    nn.ReLU(),
    nn.MaxPool2d(2),
    nn.Conv2d(32,16,3),
    nn.ReLU(),
    nn.MaxPool2d(2),
    nn.Flatten(),
    nn.Linear(6*6*16,10)
)
    
from torch import optim
optimiseur = optim.SGD(modele.parameters(), lr=0.01)

# Chargement des données de MNIST
import pickle, gzip
fichier_donnees = gzip.open(r"mnist.pkl.gz", 'rb')
((donnees_ent_X, donnees_ent_Y),(donnees_valid_X, donnees_valid_Y),(donnees_test_X,donnees_test_Y)) = pickle.load(fichier_donnees, encoding="latin-1")
fichier_donnees.close()

# Conversion des données en type toch.Tensor
import torch
donnees_ent_X,donnees_ent_Y,donnees_valid_X,donnees_valid_Y,donnees_test_X,donnees_test_Y  = map(torch.tensor,
    (donnees_ent_X.reshape((-1,1,28,28)),donnees_ent_Y,donnees_valid_X.reshape((-1,1,28,28)),donnees_valid_Y,donnees_test_X.reshape((-1,1,28,28)),donnees_test_Y))

# Création des objets DataLoader pour itérer par lot
from torch.utils.data import TensorDataset
from torch.utils.data import DataLoader
ds_ent = TensorDataset(donnees_ent_X, donnees_ent_Y)
dl_ent = DataLoader(ds_ent, batch_size=100, shuffle=True)
ds_valid = TensorDataset(donnees_valid_X,donnees_valid_Y)
dl_valid = DataLoader(ds_valid, batch_size=100)

def entrainer(modele, dl_ent, dl_valid, optimiseur, nb_epochs=10):

    # Listes pour les métriques par epoch
    liste_cout_moyen_ent = []
    liste_taux_moyen_ent = []
    liste_cout_moyen_valid = []
    liste_taux_moyen_valid = []
    
    # Boucle d'apprentissage
    for epoch in range(nb_epochs):
        cout_total_ent = 0 # pour cumuler les couts par mini-lot
        taux_bonnes_predictions_ent = 0 # pour cumuler les taux par mini-lot
        modele.train() # Pour certains types de couches (nn.BatchNorm2d, nn.Dropout, ...)
        
        # Boucle d'apprentissage par mini-lot pour une epoch
        for lot_X, lot_Y in dl_ent:
            optimiseur.zero_grad() # Remettre les dérivées à zéro
            lot_Y_predictions = modele(lot_X) # Appel de la méthode forward
            cout = fonction_cout(lot_Y_predictions, lot_Y)
            cout.backward() # Calcul des gradiants par rétropropagation
            with torch.no_grad():
                cout_total_ent +=cout
                taux_bonnes_predictions_ent += taux_bonnes_predictions(lot_Y_predictions, lot_Y)
            optimiseur.step() # Mise à jour des paramètres
        # Calculer les moyennes par mini-lot
        with torch.no_grad():
            cout_moyen_ent = cout_total_ent/len(dl_ent)
            taux_moyen_ent = taux_bonnes_predictions_ent/len(dl_ent)
       
        modele.eval() # Pour certains types de couches (nn.BatchNorm2d, nn.Dropout, ...)
        with torch.no_grad():
            cout_valid = sum(fonction_cout(modele(lot_valid_X), lot_valid_Y) for lot_valid_X, lot_valid_Y in dl_valid)
            taux_bons_valid = sum(taux_bonnes_predictions(modele(lot_valid_X), lot_valid_Y) for lot_valid_X, lot_valid_Y in dl_valid)
        cout_moyen_valid = cout_valid/len(dl_valid)
        taux_moyen_valid = taux_bons_valid/len(dl_valid)
        print(f'-------- > epoch {epoch+1}:  coût moyen entraînement = {cout_moyen_ent}')
        print(f'-------- > epoch {epoch+1}:  taux moyen entraînement = {taux_moyen_ent}')
        print(f'-------- > epoch {epoch+1}:  coût moyen validation = {cout_moyen_valid}')
        print(f'-------- > epoch {epoch+1}:  taux moyen validation = {taux_moyen_valid}')
    
        liste_cout_moyen_ent.append(cout_moyen_ent)
        liste_taux_moyen_ent.append(taux_moyen_ent)
        liste_cout_moyen_valid.append(cout_moyen_valid)
        liste_taux_moyen_valid.append(taux_moyen_valid)
    
    # Affichage du graphique d'évolution des métriques par epoch
    import numpy as np
    import matplotlib.pyplot as plt
    plt.plot(np.arange(0,nb_epochs),liste_cout_moyen_ent,label='Erreur entraînement')
    plt.plot(np.arange(0,nb_epochs),liste_cout_moyen_valid,label='Erreur validation')
    plt.title("Evolution du coût")
    plt.xlabel('epoch')
    plt.ylabel('moyenne par observation')
    plt.legend(loc='upper center')
    plt.show()
        
    plt.plot(np.arange(0,nb_epochs),liste_taux_moyen_ent,label='Taux bonnes réponses entraînement')
    plt.plot(np.arange(0,nb_epochs),liste_taux_moyen_valid,label='Taux bonnes réponses validation')
    plt.title("Evolution du taux")
    plt.xlabel('epoch')
    plt.ylabel('moyenne par observation')
    plt.legend(loc='upper center')
    plt.show()

entrainer(modele, dl_ent, dl_valid, optimiseur, nb_epochs=30)
# Out:
# -------- > epoch 1:  coût moyen entraînement = 1.2910511493682861
# -------- > epoch 1:  taux moyen entraînement = 0.6595396995544434
# -------- > epoch 1:  coût moyen validation = 0.427992582321167
# -------- > epoch 1:  taux moyen validation = 0.8743000030517578
# -------- > epoch 2:  coût moyen entraînement = 0.4090491235256195
# -------- > epoch 2:  taux moyen entraînement = 0.8783205151557922
# -------- > epoch 2:  coût moyen validation = 0.3197106122970581
# -------- > epoch 2:  taux moyen validation = 0.9095000624656677
# -------- > epoch 3:  coût moyen entraînement = 0.3237866759300232
# -------- > epoch 3:  taux moyen entraînement = 0.9040604829788208
# -------- > epoch 3:  coût moyen validation = 0.26891854405403137
# -------- > epoch 3:  taux moyen validation = 0.921999990940094
# -------- > epoch 4:  coût moyen entraînement = 0.2668708264827728
# -------- > epoch 4:  taux moyen entraînement = 0.9208213090896606
# -------- > epoch 4:  coût moyen validation = 0.21820463240146637
# -------- > epoch 4:  taux moyen validation = 0.9371000528335571
# -------- > epoch 5:  coût moyen entraînement = 0.22130759060382843
# -------- > epoch 5:  taux moyen entraînement = 0.9348608255386353
# -------- > epoch 5:  coût moyen validation = 0.18097057938575745
# -------- > epoch 5:  taux moyen validation = 0.9476999640464783
# -------- > epoch 6:  coût moyen entraînement = 0.18681871891021729
# -------- > epoch 6:  taux moyen entraînement = 0.9454204440116882
# -------- > epoch 6:  coût moyen validation = 0.16153718531131744
# -------- > epoch 6:  taux moyen validation = 0.952700138092041
# -------- > epoch 7:  coût moyen entraînement = 0.1607123464345932
# -------- > epoch 7:  taux moyen entraînement = 0.9535607695579529
# -------- > epoch 7:  coût moyen validation = 0.13648571074008942
# -------- > epoch 7:  taux moyen validation = 0.962300181388855
# -------- > epoch 8:  coût moyen entraînement = 0.1408463716506958
# -------- > epoch 8:  taux moyen entraînement = 0.958361029624939
# -------- > epoch 8:  coût moyen validation = 0.12351299077272415
# -------- > epoch 8:  taux moyen validation = 0.9661000967025757
# -------- > epoch 9:  coût moyen entraînement = 0.1263001561164856
# -------- > epoch 9:  taux moyen entraînement = 0.9631813764572144
# -------- > epoch 9:  coût moyen validation = 0.11063101142644882
# -------- > epoch 9:  taux moyen validation = 0.9687999486923218
# -------- > epoch 10:  coût moyen entraînement = 0.11503848433494568
# -------- > epoch 10:  taux moyen entraînement = 0.9657610058784485
# -------- > epoch 10:  coût moyen validation = 0.1076287105679512
# -------- > epoch 10:  taux moyen validation = 0.9701999425888062
# -------- > epoch 11:  coût moyen entraînement = 0.10622183978557587
# -------- > epoch 11:  taux moyen entraînement = 0.9683811664581299
# -------- > epoch 11:  coût moyen validation = 0.09706152975559235
# -------- > epoch 11:  taux moyen validation = 0.9725003242492676
# -------- > epoch 12:  coût moyen entraînement = 0.09998272359371185
# -------- > epoch 12:  taux moyen entraînement = 0.9706804752349854
# -------- > epoch 12:  coût moyen validation = 0.09278878569602966
# -------- > epoch 12:  taux moyen validation = 0.9750001430511475
# -------- > epoch 13:  coût moyen entraînement = 0.09394703805446625
# -------- > epoch 13:  taux moyen entraînement = 0.9723007678985596
# -------- > epoch 13:  coût moyen validation = 0.09147480130195618
# -------- > epoch 13:  taux moyen validation = 0.9726001620292664
# -------- > epoch 14:  coût moyen entraînement = 0.08893442898988724
# -------- > epoch 14:  taux moyen entraînement = 0.9738408327102661
# -------- > epoch 14:  coût moyen validation = 0.08544498682022095
# -------- > epoch 14:  taux moyen validation = 0.9763002991676331
# -------- > epoch 15:  coût moyen entraînement = 0.08562760055065155
# -------- > epoch 15:  taux moyen entraînement = 0.9747807383537292
# -------- > epoch 15:  coût moyen validation = 0.08196105062961578
# -------- > epoch 15:  taux moyen validation = 0.9766002893447876
# -------- > epoch 16:  coût moyen entraînement = 0.08170730620622635
# -------- > epoch 16:  taux moyen entraînement = 0.9758004546165466
# -------- > epoch 16:  coût moyen validation = 0.0810234323143959
# -------- > epoch 16:  taux moyen validation = 0.9776001572608948
# -------- > epoch 17:  coût moyen entraînement = 0.07912956178188324
# -------- > epoch 17:  taux moyen entraînement = 0.9760808348655701
# -------- > epoch 17:  coût moyen validation = 0.07797551900148392
# -------- > epoch 17:  taux moyen validation = 0.9774000644683838
# -------- > epoch 18:  coût moyen entraînement = 0.07612401992082596
# -------- > epoch 18:  taux moyen entraînement = 0.9773012399673462
# -------- > epoch 18:  coût moyen validation = 0.07603976130485535
# -------- > epoch 18:  taux moyen validation = 0.9789005517959595
# -------- > epoch 19:  coût moyen entraînement = 0.07380599528551102
# -------- > epoch 19:  taux moyen entraînement = 0.9780004620552063
# -------- > epoch 19:  coût moyen validation = 0.07308127731084824
# -------- > epoch 19:  taux moyen validation = 0.9783000349998474
# -------- > epoch 20:  coût moyen entraînement = 0.07151783257722855
# -------- > epoch 20:  taux moyen entraînement = 0.978480339050293
# -------- > epoch 20:  coût moyen validation = 0.07320771366357803
# -------- > epoch 20:  taux moyen validation = 0.9802001118659973
# -------- > epoch 21:  coût moyen entraînement = 0.06990783661603928
# -------- > epoch 21:  taux moyen entraînement = 0.9791604280471802
# -------- > epoch 21:  coût moyen validation = 0.0703124850988388
# -------- > epoch 21:  taux moyen validation = 0.9793000817298889
# -------- > epoch 22:  coût moyen entraînement = 0.06803622841835022
# -------- > epoch 22:  taux moyen entraînement = 0.9796203374862671
# -------- > epoch 22:  coût moyen validation = 0.06842219084501266
# -------- > epoch 22:  taux moyen validation = 0.9806002974510193
# -------- > epoch 23:  coût moyen entraînement = 0.06665043532848358
# -------- > epoch 23:  taux moyen entraînement = 0.9801608324050903
# -------- > epoch 23:  coût moyen validation = 0.07121724635362625
# -------- > epoch 23:  taux moyen validation = 0.9794002771377563
# -------- > epoch 24:  coût moyen entraînement = 0.0651470348238945
# -------- > epoch 24:  taux moyen entraînement = 0.9801403880119324
# -------- > epoch 24:  coût moyen validation = 0.06833185255527496
# -------- > epoch 24:  taux moyen validation = 0.9807002544403076
# -------- > epoch 25:  coût moyen entraînement = 0.06367898732423782
# -------- > epoch 25:  taux moyen entraînement = 0.9803807139396667
# -------- > epoch 25:  coût moyen validation = 0.06694474071264267
# -------- > epoch 25:  taux moyen validation = 0.9810003042221069
# -------- > epoch 26:  coût moyen entraînement = 0.06269847601652145
# -------- > epoch 26:  taux moyen entraînement = 0.98110032081604
# -------- > epoch 26:  coût moyen validation = 0.06430041044950485
# -------- > epoch 26:  taux moyen validation = 0.9810003042221069
# -------- > epoch 27:  coût moyen entraînement = 0.06133526936173439
# -------- > epoch 27:  taux moyen entraînement = 0.9820398092269897
# -------- > epoch 27:  coût moyen validation = 0.06323506683111191
# -------- > epoch 27:  taux moyen validation = 0.981800377368927
# -------- > epoch 28:  coût moyen entraînement = 0.059825602918863297
# -------- > epoch 28:  taux moyen entraînement = 0.9825406074523926
# -------- > epoch 28:  coût moyen validation = 0.0651731938123703
# -------- > epoch 28:  taux moyen validation = 0.9817003607749939
# -------- > epoch 29:  coût moyen entraînement = 0.058825187385082245
# -------- > epoch 29:  taux moyen entraînement = 0.9827209711074829
# -------- > epoch 29:  coût moyen validation = 0.06804315000772476
# -------- > epoch 29:  taux moyen validation = 0.9809002876281738
# -------- > epoch 30:  coût moyen entraînement = 0.0579654760658741
# -------- > epoch 30:  taux moyen entraînement = 0.9829400181770325
# -------- > epoch 30:  coût moyen validation = 0.06324207037687302
# -------- > epoch 30:  taux moyen validation = 0.9813002943992615
