# %%
# %matplotlib inline
# -*- coding: utf-8 -*-
"""
Exemple de MNIST avec PyTorch
Exemple avec connexion distante (BlocResSimple)
"""
import torch
torch.manual_seed(0) # Pour résultats reproductibles

# Fonction J d'entropie croisée
import torch.nn.functional as F
fonction_cout = F.cross_entropy

def taux_bonnes_predictions(lot_Y_predictions, lot_Y):
    predictions_categorie = torch.argmax(lot_Y_predictions, dim=1)
    return (predictions_categorie == lot_Y).float().mean()

from torch import nn
# Définition de l'architecture du RNA

class BlocResSimple(nn.Module):
    def __init__(self, nb_f):
        super().__init__()
        self.convolution = nn.Conv2d(nb_f, nb_f, kernel_size=3, stride=1, padding=1) 
        self.normalisation = nn.BatchNorm2d(nb_f)    

    def forward(self, lot_X):
        lot_Y_predictions = self.convolution(lot_X)
        lot_Y_predictions = self.normalisation(lot_Y_predictions)
        lot_Y_predictions = F.relu(lot_Y_predictions)
        return lot_Y_predictions+lot_X

modele = nn.Sequential(
    nn.Conv2d(1,16,3),
    nn.BatchNorm2d(16),
    nn.ReLU(),
    BlocResSimple(16),
    BlocResSimple(16),
    BlocResSimple(16),
    nn.Flatten(),
    nn.Linear(26*26*16,10)
)

from torch import optim
optimiseur = optim.SGD(modele.parameters(), lr=0.01)

# Chargement des données de MNIST
import pickle, gzip
fichier_donnees = gzip.open(r"mnist.pkl.gz", 'rb')
((donnees_ent_X, donnees_ent_Y),(donnees_valid_X, donnees_valid_Y),(donnees_test_X,donnees_test_Y)) = pickle.load(fichier_donnees, encoding="latin-1")
fichier_donnees.close()

# Conversion des données en type toch.Tensor
import torch
donnees_ent_X,donnees_ent_Y,donnees_valid_X,donnees_valid_Y,donnees_test_X,donnees_test_Y  = map(torch.tensor,
    (donnees_ent_X.reshape((-1,1,28,28)),donnees_ent_Y,donnees_valid_X.reshape((-1,1,28,28)),donnees_valid_Y,donnees_test_X.reshape((-1,1,28,28)),donnees_test_Y))

# Création des objets DataLoader pour itérer par lot
from torch.utils.data import TensorDataset
from torch.utils.data import DataLoader
ds_ent = TensorDataset(donnees_ent_X, donnees_ent_Y)
dl_ent = DataLoader(ds_ent, batch_size=100, shuffle=True)
ds_valid = TensorDataset(donnees_valid_X,donnees_valid_Y)
dl_valid = DataLoader(ds_valid, batch_size=100)

def entrainer(modele, dl_ent, dl_valid, optimiseur, nb_epochs=10):

    # Listes pour les métriques par epoch
    liste_cout_moyen_ent = []
    liste_taux_moyen_ent = []
    liste_cout_moyen_valid = []
    liste_taux_moyen_valid = []
    
    # Boucle d'apprentissage
    for epoch in range(nb_epochs):
        cout_total_ent = 0 # pour cumuler les couts par mini-lot
        taux_bonnes_predictions_ent = 0 # pour cumuler les taux par mini-lot
        modele.train() # Pour certains types de couches (nn.BatchNorm2d, nn.Dropout, ...)
        
        # Boucle d'apprentissage par mini-lot pour une epoch
        for lot_X, lot_Y in dl_ent:
            optimiseur.zero_grad() # Remettre les dérivées à zéro
            lot_Y_predictions = modele(lot_X) # Appel de la méthode forward
            cout = fonction_cout(lot_Y_predictions, lot_Y)
            cout.backward() # Calcul des gradiants par rétropropagation
            with torch.no_grad():
                cout_total_ent +=cout
                taux_bonnes_predictions_ent += taux_bonnes_predictions(lot_Y_predictions, lot_Y)
            optimiseur.step() # Mise à jour des paramètres
        # Calculer les moyennes par mini-lot
        with torch.no_grad():
            cout_moyen_ent = cout_total_ent/len(dl_ent)
            taux_moyen_ent = taux_bonnes_predictions_ent/len(dl_ent)
       
        modele.eval() # Pour certains types de couches (nn.BatchNorm2d, nn.Dropout, ...)
        with torch.no_grad():
            cout_valid = sum(fonction_cout(modele(lot_valid_X), lot_valid_Y) for lot_valid_X, lot_valid_Y in dl_valid)
            taux_bons_valid = sum(taux_bonnes_predictions(modele(lot_valid_X), lot_valid_Y) for lot_valid_X, lot_valid_Y in dl_valid)
        cout_moyen_valid = cout_valid/len(dl_valid)
        taux_moyen_valid = taux_bons_valid/len(dl_valid)
        print(f'-------- > epoch {epoch+1}:  coût moyen entraînement = {cout_moyen_ent}')
        print(f'-------- > epoch {epoch+1}:  taux moyen entraînement = {taux_moyen_ent}')
        print(f'-------- > epoch {epoch+1}:  coût moyen validation = {cout_moyen_valid}')
        print(f'-------- > epoch {epoch+1}:  taux moyen validation = {taux_moyen_valid}')
    
        liste_cout_moyen_ent.append(cout_moyen_ent)
        liste_taux_moyen_ent.append(taux_moyen_ent)
        liste_cout_moyen_valid.append(cout_moyen_valid)
        liste_taux_moyen_valid.append(taux_moyen_valid)
    
    # Affichage du graphique d'évolution des métriques par epoch
    import numpy as np
    import matplotlib.pyplot as plt
    plt.plot(np.arange(0,nb_epochs),liste_cout_moyen_ent,label='Erreur entraînement')
    plt.plot(np.arange(0,nb_epochs),liste_cout_moyen_valid,label='Erreur validation')
    plt.title("Evolution du coût")
    plt.xlabel('epoch')
    plt.ylabel('moyenne par observation')
    plt.legend(loc='upper center')
    plt.show()
        
    plt.plot(np.arange(0,nb_epochs),liste_taux_moyen_ent,label='Taux bonnes réponses entraînement')
    plt.plot(np.arange(0,nb_epochs),liste_taux_moyen_valid,label='Taux bonnes réponses validation')
    plt.title("Evolution du taux")
    plt.xlabel('epoch')
    plt.ylabel('moyenne par observation')
    plt.legend(loc='center')
    plt.show()

entrainer(modele, dl_ent, dl_valid, optimiseur, nb_epochs=30)
# Out:
# -------- > epoch 1:  coût moyen entraînement = 1.053234338760376
# -------- > epoch 1:  taux moyen entraînement = 0.9149609208106995
# -------- > epoch 1:  coût moyen validation = 0.1306927502155304
# -------- > epoch 1:  taux moyen validation = 0.9607002139091492
# -------- > epoch 2:  coût moyen entraînement = 0.08460952341556549
# -------- > epoch 2:  taux moyen entraînement = 0.974840521812439
# -------- > epoch 2:  coût moyen validation = 0.0723026692867279
# -------- > epoch 2:  taux moyen validation = 0.9796001315116882
# -------- > epoch 3:  coût moyen entraînement = 0.05952215939760208
# -------- > epoch 3:  taux moyen entraînement = 0.9813603162765503
# -------- > epoch 3:  coût moyen validation = 0.07159039378166199
# -------- > epoch 3:  taux moyen validation = 0.9803001880645752
# -------- > epoch 4:  coût moyen entraînement = 0.04716978594660759
# -------- > epoch 4:  taux moyen entraînement = 0.9858001470565796
# -------- > epoch 4:  coût moyen validation = 0.05996767058968544
# -------- > epoch 4:  taux moyen validation = 0.982400119304657
# -------- > epoch 5:  coût moyen entraînement = 0.037725429981946945
# -------- > epoch 5:  taux moyen entraînement = 0.9884394407272339
# -------- > epoch 5:  coût moyen validation = 0.06770005077123642
# -------- > epoch 5:  taux moyen validation = 0.9810000658035278
# -------- > epoch 6:  coût moyen entraînement = 0.03185662627220154
# -------- > epoch 6:  taux moyen entraînement = 0.9901390671730042
# -------- > epoch 6:  coût moyen validation = 0.05514703691005707
# -------- > epoch 6:  taux moyen validation = 0.9838001132011414
# -------- > epoch 7:  coût moyen entraînement = 0.027085134759545326
# -------- > epoch 7:  taux moyen entraînement = 0.9920392632484436
# -------- > epoch 7:  coût moyen validation = 0.054800163954496384
# -------- > epoch 7:  taux moyen validation = 0.9834001660346985
# -------- > epoch 8:  coût moyen entraînement = 0.02232939936220646
# -------- > epoch 8:  taux moyen entraînement = 0.9935793876647949
# -------- > epoch 8:  coût moyen validation = 0.0544157512485981
# -------- > epoch 8:  taux moyen validation = 0.9847999811172485
# -------- > epoch 9:  coût moyen entraînement = 0.019639773294329643
# -------- > epoch 9:  taux moyen entraînement = 0.9946594834327698
# -------- > epoch 9:  coût moyen validation = 0.05273408070206642
# -------- > epoch 9:  taux moyen validation = 0.9851998686790466
# -------- > epoch 10:  coût moyen entraînement = 0.016880974173545837
# -------- > epoch 10:  taux moyen entraînement = 0.995359480381012
# -------- > epoch 10:  coût moyen validation = 0.05297159031033516
# -------- > epoch 10:  taux moyen validation = 0.9849001169204712
# -------- > epoch 11:  coût moyen entraînement = 0.014125565066933632
# -------- > epoch 11:  taux moyen entraînement = 0.9967594146728516
# -------- > epoch 11:  coût moyen validation = 0.059925347566604614
# -------- > epoch 11:  taux moyen validation = 0.9833000898361206
# -------- > epoch 12:  coût moyen entraînement = 0.012590798549354076
# -------- > epoch 12:  taux moyen entraînement = 0.9967994093894958
# -------- > epoch 12:  coût moyen validation = 0.05967498943209648
# -------- > epoch 12:  taux moyen validation = 0.9841001629829407
# -------- > epoch 13:  coût moyen entraînement = 0.010636188089847565
# -------- > epoch 13:  taux moyen entraînement = 0.99765944480896
# -------- > epoch 13:  coût moyen validation = 0.053158193826675415
# -------- > epoch 13:  taux moyen validation = 0.9851000905036926
# -------- > epoch 14:  coût moyen entraînement = 0.009248741902410984
# -------- > epoch 14:  taux moyen entraînement = 0.9982396364212036
# -------- > epoch 14:  coût moyen validation = 0.056557830423116684
# -------- > epoch 14:  taux moyen validation = 0.9848003387451172
# -------- > epoch 15:  coût moyen entraînement = 0.008176612667739391
# -------- > epoch 15:  taux moyen entraînement = 0.9983994960784912
# -------- > epoch 15:  coût moyen validation = 0.05470949783921242
# -------- > epoch 15:  taux moyen validation = 0.9854000806808472
# -------- > epoch 16:  coût moyen entraînement = 0.00742915878072381
# -------- > epoch 16:  taux moyen entraînement = 0.9986193776130676
# -------- > epoch 16:  coût moyen validation = 0.055863767862319946
# -------- > epoch 16:  taux moyen validation = 0.9848001003265381
# -------- > epoch 17:  coût moyen entraînement = 0.006110635586082935
# -------- > epoch 17:  taux moyen entraînement = 0.999359667301178
# -------- > epoch 17:  coût moyen validation = 0.057157162576913834
# -------- > epoch 17:  taux moyen validation = 0.983900249004364
# -------- > epoch 18:  coût moyen entraînement = 0.005561955273151398
# -------- > epoch 18:  taux moyen entraînement = 0.9993796944618225
# -------- > epoch 18:  coût moyen validation = 0.05649397522211075
# -------- > epoch 18:  taux moyen validation = 0.9847000241279602
# -------- > epoch 19:  coût moyen entraînement = 0.004940137732774019
# -------- > epoch 19:  taux moyen entraînement = 0.9995999336242676
# -------- > epoch 19:  coût moyen validation = 0.05638767406344414
# -------- > epoch 19:  taux moyen validation = 0.9850001335144043
# -------- > epoch 20:  coût moyen entraînement = 0.004741074051707983
# -------- > epoch 20:  taux moyen entraînement = 0.999539852142334
# -------- > epoch 20:  coût moyen validation = 0.05781722441315651
# -------- > epoch 20:  taux moyen validation = 0.9846002459526062
# -------- > epoch 21:  coût moyen entraînement = 0.004199198447167873
# -------- > epoch 21:  taux moyen entraînement = 0.9996198415756226
# -------- > epoch 21:  coût moyen validation = 0.05960778146982193
# -------- > epoch 21:  taux moyen validation = 0.9843000769615173
# -------- > epoch 22:  coût moyen entraînement = 0.003776183584704995
# -------- > epoch 22:  taux moyen entraînement = 0.999799907207489
# -------- > epoch 22:  coût moyen validation = 0.05920177325606346
# -------- > epoch 22:  taux moyen validation = 0.9848001003265381
# -------- > epoch 23:  coût moyen entraînement = 0.0035544016864150763
# -------- > epoch 23:  taux moyen entraînement = 0.9997398853302002
# -------- > epoch 23:  coût moyen validation = 0.05757972598075867
# -------- > epoch 23:  taux moyen validation = 0.9845001101493835
# -------- > epoch 24:  coût moyen entraînement = 0.0031895663123577833
# -------- > epoch 24:  taux moyen entraînement = 0.9998599290847778
# -------- > epoch 24:  coût moyen validation = 0.058615945279598236
# -------- > epoch 24:  taux moyen validation = 0.985200047492981
# -------- > epoch 25:  coût moyen entraînement = 0.0029402473010122776
# -------- > epoch 25:  taux moyen entraînement = 0.9999199509620667
# -------- > epoch 25:  coût moyen validation = 0.0589628592133522
# -------- > epoch 25:  taux moyen validation = 0.9848001599311829
# -------- > epoch 26:  coût moyen entraînement = 0.0027493068482726812
# -------- > epoch 26:  taux moyen entraînement = 0.9999199509620667
# -------- > epoch 26:  coût moyen validation = 0.060321420431137085
# -------- > epoch 26:  taux moyen validation = 0.984200119972229
# -------- > epoch 27:  coût moyen entraînement = 0.0025107981637120247
# -------- > epoch 27:  taux moyen entraînement = 0.9999799728393555
# -------- > epoch 27:  coût moyen validation = 0.059098146855831146
# -------- > epoch 27:  taux moyen validation = 0.984700083732605
# -------- > epoch 28:  coût moyen entraînement = 0.0023531117476522923
# -------- > epoch 28:  taux moyen entraînement = 0.9999599456787109
# -------- > epoch 28:  coût moyen validation = 0.060097239911556244
# -------- > epoch 28:  taux moyen validation = 0.9852001667022705
# -------- > epoch 29:  coût moyen entraînement = 0.0022551272995769978
# -------- > epoch 29:  taux moyen entraînement = 1.0
# -------- > epoch 29:  coût moyen validation = 0.06102036312222481
# -------- > epoch 29:  taux moyen validation = 0.9842000603675842
# -------- > epoch 30:  coût moyen entraînement = 0.0021306881681084633
# -------- > epoch 30:  taux moyen entraînement = 0.9999799728393555
# -------- > epoch 30:  coût moyen validation = 0.06063181906938553
# -------- > epoch 30:  taux moyen validation = 0.984700083732605
