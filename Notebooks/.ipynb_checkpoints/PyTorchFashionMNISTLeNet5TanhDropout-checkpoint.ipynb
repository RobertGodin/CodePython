# %%
# %matplotlib inline
# -*- coding: utf-8 -*-
"""
Exemple MNIST avec RNA semblable à LeNet-5 (LeCun et al.)
"""
import torch
torch.manual_seed(0) # Pour résultats reproductibles

# Fonction J d'entropie croisée
import torch.nn.functional as F
fonction_cout = F.cross_entropy

def taux_bonnes_predictions(lot_Y_predictions, lot_Y):
    predictions_categorie = torch.argmax(lot_Y_predictions, dim=1)
    return (predictions_categorie == lot_Y).float().mean()

from torch import nn
# Définition de l'architecture du RNA

modele = torch.nn.Sequential(
    nn.Conv2d(1, 6, kernel_size=5, padding=2), nn.Tanh(), #(N, 1, 28, 28) -> (N, 6, 28, 28)
    nn.AvgPool2d(kernel_size=2, stride=2), #(N, 6, 28, 28) -> (N, 6, 14, 14)
    nn.Conv2d(6, 16, kernel_size=5), nn.Tanh(), #(N, 6, 14, 14) -> (N, 16, 10, 10)
    nn.AvgPool2d(kernel_size=2, stride=2), #(N, 16, 10, 10) -> (N, 16, 5, 5)
    nn.Flatten(), #(N, 16, 5, 5) -> (N, 400)
    nn.Linear(16 * 5 * 5, 120), nn.Tanh(), #(N, 400) -> (N, 120)
    nn.Dropout(0.5), #(N, 120) -> (N, 120)
    nn.Linear(120, 84), nn.Tanh(), #(N, 120) -> (N, 84)
    nn.Dropout(0.5), #(N, 84) -> (N, 84)
    nn.Linear(84, 10)) #(N, 84) -> (N, 10)

from torch import optim
optimiseur = optim.SGD(modele.parameters(), lr=0.5)

import torchvision
import torchvision.transforms as transforms

#Chargement des données
ds = torchvision.datasets.MNIST(root = "./data", train = True, download = True, transform = transforms.ToTensor())
ds_ent, ds_valid = torch.utils.data.random_split(ds, [50000, 10000])
ds_test = torchvision.datasets.MNIST(root = "./data", train = False, download = True, transform = transforms.ToTensor())

#Création du DataLoader avec le dataset
dl_ent = torch.utils.data.DataLoader(ds_ent, batch_size=100, shuffle = True)
dl_valid = torch.utils.data.DataLoader(ds_valid, batch_size=100)

def entrainer(modele, dl_ent, dl_valid, optimiseur, nb_epochs=10):

    # Listes pour les métriques par epoch
    liste_cout_moyen_ent = []
    liste_taux_moyen_ent = []
    liste_cout_moyen_valid = []
    liste_taux_moyen_valid = []
    
    # Boucle d'apprentissage
    for epoch in range(nb_epochs):
        cout_total_ent = 0 # pour cumuler les couts par mini-lot
        taux_bonnes_predictions_ent = 0 # pour cumuler les taux par mini-lot
        modele.train() # Pour certains types de couches (nn.BatchNorm2d, nn.Dropout, ...)
        
        # Boucle d'apprentissage par mini-lot pour une epoch
        for lot_X, lot_Y in dl_ent:
            optimiseur.zero_grad() # Remettre les dérivées à zéro
            lot_Y_predictions = modele(lot_X) # Appel de la méthode forward
            cout = fonction_cout(lot_Y_predictions, lot_Y)
            cout.backward() # Calcul des gradiants par rétropropagation
            with torch.no_grad():
                cout_total_ent +=cout
                taux_bonnes_predictions_ent += taux_bonnes_predictions(lot_Y_predictions, lot_Y)
            optimiseur.step() # Mise à jour des paramètres
        # Calculer les moyennes par mini-lot
        with torch.no_grad():
            cout_moyen_ent = cout_total_ent/len(dl_ent)
            taux_moyen_ent = taux_bonnes_predictions_ent/len(dl_ent)
       
        modele.eval() # Pour certains types de couches (nn.BatchNorm2d, nn.Dropout, ...)
        with torch.no_grad():
            cout_valid = sum(fonction_cout(modele(lot_valid_X), lot_valid_Y) for lot_valid_X, lot_valid_Y in dl_valid)
            taux_bons_valid = sum(taux_bonnes_predictions(modele(lot_valid_X), lot_valid_Y) for lot_valid_X, lot_valid_Y in dl_valid)
        cout_moyen_valid = cout_valid/len(dl_valid)
        taux_moyen_valid = taux_bons_valid/len(dl_valid)
        print(f'-------- > epoch {epoch+1}:  coût moyen entraînement = {cout_moyen_ent}')
        print(f'-------- > epoch {epoch+1}:  taux moyen entraînement = {taux_moyen_ent}')
        print(f'-------- > epoch {epoch+1}:  coût moyen validation = {cout_moyen_valid}')
        print(f'-------- > epoch {epoch+1}:  taux moyen validation = {taux_moyen_valid}')
    
        liste_cout_moyen_ent.append(cout_moyen_ent)
        liste_taux_moyen_ent.append(taux_moyen_ent)
        liste_cout_moyen_valid.append(cout_moyen_valid)
        liste_taux_moyen_valid.append(taux_moyen_valid)
    
    # Affichage du graphique d'évolution des métriques par epoch
    import numpy as np
    import matplotlib.pyplot as plt
    plt.plot(np.arange(0,nb_epochs),liste_cout_moyen_ent,label='Erreur entraînement')
    plt.plot(np.arange(0,nb_epochs),liste_cout_moyen_valid,label='Erreur validation')
    plt.title("Evolution du coût")
    plt.xlabel('epoch')
    plt.ylabel('moyenne par observation')
    plt.legend(loc='upper center')
    plt.show()
        
    plt.plot(np.arange(0,nb_epochs),liste_taux_moyen_ent,label='Taux bonnes réponses entraînement')
    plt.plot(np.arange(0,nb_epochs),liste_taux_moyen_valid,label='Taux bonnes réponses validation')
    plt.title("Evolution du taux")
    plt.xlabel('epoch')
    plt.ylabel('moyenne par observation')
    plt.legend(loc='lower center')
    plt.show()

entrainer(modele, dl_ent, dl_valid, optimiseur, nb_epochs=30)
# Out:
# -------- > epoch 1:  coût moyen entraînement = 0.45731642842292786
# -------- > epoch 1:  taux moyen entraînement = 0.8581008911132812
# -------- > epoch 1:  coût moyen validation = 0.15818870067596436
# -------- > epoch 1:  taux moyen validation = 0.9546999335289001
# -------- > epoch 2:  coût moyen entraînement = 0.17644011974334717
# -------- > epoch 2:  taux moyen entraînement = 0.9494205117225647
# -------- > epoch 2:  coût moyen validation = 0.08654642105102539
# -------- > epoch 2:  taux moyen validation = 0.9749001264572144
# -------- > epoch 3:  coût moyen entraînement = 0.13300444185733795
# -------- > epoch 3:  taux moyen entraînement = 0.9629214406013489
# -------- > epoch 3:  coût moyen validation = 0.0735141709446907
# -------- > epoch 3:  taux moyen validation = 0.9788001775741577
# -------- > epoch 4:  coût moyen entraînement = 0.1115112230181694
# -------- > epoch 4:  taux moyen entraînement = 0.9679808616638184
# -------- > epoch 4:  coût moyen validation = 0.0610119067132473
# -------- > epoch 4:  taux moyen validation = 0.982300341129303
# -------- > epoch 5:  coût moyen entraînement = 0.09556616842746735
# -------- > epoch 5:  taux moyen entraînement = 0.9728211760520935
# -------- > epoch 5:  coût moyen validation = 0.05561511591076851
# -------- > epoch 5:  taux moyen validation = 0.9832002520561218
# -------- > epoch 6:  coût moyen entraînement = 0.08714386820793152
# -------- > epoch 6:  taux moyen entraînement = 0.9750606417655945
# -------- > epoch 6:  coût moyen validation = 0.05976684391498566
# -------- > epoch 6:  taux moyen validation = 0.9818000197410583
# -------- > epoch 7:  coût moyen entraînement = 0.07985427975654602
# -------- > epoch 7:  taux moyen entraînement = 0.9771808981895447
# -------- > epoch 7:  coût moyen validation = 0.05207269638776779
# -------- > epoch 7:  taux moyen validation = 0.985500156879425
# -------- > epoch 8:  coût moyen entraînement = 0.07411597669124603
# -------- > epoch 8:  taux moyen entraînement = 0.978660523891449
# -------- > epoch 8:  coût moyen validation = 0.052239399403333664
# -------- > epoch 8:  taux moyen validation = 0.9855002760887146
# -------- > epoch 9:  coût moyen entraînement = 0.06652077287435532
# -------- > epoch 9:  taux moyen entraînement = 0.9805405735969543
# -------- > epoch 9:  coût moyen validation = 0.045198798179626465
# -------- > epoch 9:  taux moyen validation = 0.987400233745575
# -------- > epoch 10:  coût moyen entraînement = 0.06706292182207108
# -------- > epoch 10:  taux moyen entraînement = 0.9812802672386169
# -------- > epoch 10:  coût moyen validation = 0.058653250336647034
# -------- > epoch 10:  taux moyen validation = 0.9841001033782959
# -------- > epoch 11:  coût moyen entraînement = 0.06056612730026245
# -------- > epoch 11:  taux moyen entraînement = 0.9831003546714783
# -------- > epoch 11:  coût moyen validation = 0.04840254411101341
# -------- > epoch 11:  taux moyen validation = 0.9866001009941101
# -------- > epoch 12:  coût moyen entraînement = 0.05860891565680504
# -------- > epoch 12:  taux moyen entraînement = 0.9827803373336792
# -------- > epoch 12:  coût moyen validation = 0.04356594383716583
# -------- > epoch 12:  taux moyen validation = 0.988099992275238
# -------- > epoch 13:  coût moyen entraînement = 0.057662829756736755
# -------- > epoch 13:  taux moyen entraînement = 0.9836804866790771
# -------- > epoch 13:  coût moyen validation = 0.04484787955880165
# -------- > epoch 13:  taux moyen validation = 0.9878000617027283
# -------- > epoch 14:  coût moyen entraînement = 0.05409045144915581
# -------- > epoch 14:  taux moyen entraînement = 0.9845200181007385
# -------- > epoch 14:  coût moyen validation = 0.042157143354415894
# -------- > epoch 14:  taux moyen validation = 0.9888002872467041
# -------- > epoch 15:  coût moyen entraînement = 0.050482288002967834
# -------- > epoch 15:  taux moyen entraînement = 0.986140251159668
# -------- > epoch 15:  coût moyen validation = 0.04346150904893875
# -------- > epoch 15:  taux moyen validation = 0.9883002638816833
# -------- > epoch 16:  coût moyen entraînement = 0.04969857260584831
# -------- > epoch 16:  taux moyen entraînement = 0.9860796332359314
# -------- > epoch 16:  coût moyen validation = 0.04361343011260033
# -------- > epoch 16:  taux moyen validation = 0.9887000918388367
# -------- > epoch 17:  coût moyen entraînement = 0.04746031016111374
# -------- > epoch 17:  taux moyen entraînement = 0.9855800271034241
# -------- > epoch 17:  coût moyen validation = 0.04063969478011131
# -------- > epoch 17:  taux moyen validation = 0.9894001483917236
# -------- > epoch 18:  coût moyen entraînement = 0.04866856709122658
# -------- > epoch 18:  taux moyen entraînement = 0.986560046672821
# -------- > epoch 18:  coût moyen validation = 0.04337605461478233
# -------- > epoch 18:  taux moyen validation = 0.9883999824523926
# -------- > epoch 19:  coût moyen entraînement = 0.044994089752435684
# -------- > epoch 19:  taux moyen entraînement = 0.9872002601623535
# -------- > epoch 19:  coût moyen validation = 0.03794831410050392
# -------- > epoch 19:  taux moyen validation = 0.9899001121520996
# -------- > epoch 20:  coût moyen entraînement = 0.044732946902513504
# -------- > epoch 20:  taux moyen entraînement = 0.9872602224349976
# -------- > epoch 20:  coût moyen validation = 0.04262020066380501
# -------- > epoch 20:  taux moyen validation = 0.9892000555992126
# -------- > epoch 21:  coût moyen entraînement = 0.04128913953900337
# -------- > epoch 21:  taux moyen entraînement = 0.9883396029472351
# -------- > epoch 21:  coût moyen validation = 0.038773465901613235
# -------- > epoch 21:  taux moyen validation = 0.989000141620636
# -------- > epoch 22:  coût moyen entraînement = 0.04060206189751625
# -------- > epoch 22:  taux moyen entraînement = 0.9883196949958801
# -------- > epoch 22:  coût moyen validation = 0.04004960507154465
# -------- > epoch 22:  taux moyen validation = 0.9894998669624329
# -------- > epoch 23:  coût moyen entraînement = 0.03840773180127144
# -------- > epoch 23:  taux moyen entraînement = 0.989200234413147
# -------- > epoch 23:  coût moyen validation = 0.04325733333826065
# -------- > epoch 23:  taux moyen validation = 0.9894000887870789
# -------- > epoch 24:  coût moyen entraînement = 0.03756729140877724
# -------- > epoch 24:  taux moyen entraînement = 0.9881402254104614
# -------- > epoch 24:  coût moyen validation = 0.042388927191495895
# -------- > epoch 24:  taux moyen validation = 0.9874001145362854
# -------- > epoch 25:  coût moyen entraînement = 0.036942675709724426
# -------- > epoch 25:  taux moyen entraînement = 0.9890392422676086
# -------- > epoch 25:  coût moyen validation = 0.04182373359799385
# -------- > epoch 25:  taux moyen validation = 0.989800214767456
# -------- > epoch 26:  coût moyen entraînement = 0.034821830689907074
# -------- > epoch 26:  taux moyen entraînement = 0.9892400503158569
# -------- > epoch 26:  coût moyen validation = 0.04157791659235954
# -------- > epoch 26:  taux moyen validation = 0.9892001152038574
# -------- > epoch 27:  coût moyen entraînement = 0.0353286936879158
# -------- > epoch 27:  taux moyen entraînement = 0.989799439907074
# -------- > epoch 27:  coût moyen validation = 0.038042064756155014
# -------- > epoch 27:  taux moyen validation = 0.9903000593185425
# -------- > epoch 28:  coût moyen entraînement = 0.03598681464791298
# -------- > epoch 28:  taux moyen entraînement = 0.9897795915603638
# -------- > epoch 28:  coût moyen validation = 0.038997799158096313
# -------- > epoch 28:  taux moyen validation = 0.9907001256942749
# -------- > epoch 29:  coût moyen entraînement = 0.0352870337665081
# -------- > epoch 29:  taux moyen entraînement = 0.9897798895835876
# -------- > epoch 29:  coût moyen validation = 0.03726290911436081
# -------- > epoch 29:  taux moyen validation = 0.9907999634742737
# -------- > epoch 30:  coût moyen entraînement = 0.03352954238653183
# -------- > epoch 30:  taux moyen entraînement = 0.9900397658348083
# -------- > epoch 30:  coût moyen validation = 0.03606554865837097
# -------- > epoch 30:  taux moyen validation = 0.9914999604225159

# %%
X = torch.randn(size=(1, 1, 28, 28), dtype=torch.float32)
for une_couche in modele:
    X = une_couche(X)
    print('Type de couche:',une_couche.__class__.__name__,'  Forme de sortie:',X.shape)
# Out:
# Type de couche: Conv2d   Forme de sortie: torch.Size([1, 6, 28, 28])
# Type de couche: Tanh   Forme de sortie: torch.Size([1, 6, 28, 28])
# Type de couche: AvgPool2d   Forme de sortie: torch.Size([1, 6, 14, 14])
# Type de couche: Conv2d   Forme de sortie: torch.Size([1, 16, 10, 10])
# Type de couche: Tanh   Forme de sortie: torch.Size([1, 16, 10, 10])
# Type de couche: AvgPool2d   Forme de sortie: torch.Size([1, 16, 5, 5])
# Type de couche: Flatten   Forme de sortie: torch.Size([1, 400])
# Type de couche: Linear   Forme de sortie: torch.Size([1, 120])
# Type de couche: Tanh   Forme de sortie: torch.Size([1, 120])
# Type de couche: Dropout   Forme de sortie: torch.Size([1, 120])
# Type de couche: Linear   Forme de sortie: torch.Size([1, 84])
# Type de couche: Tanh   Forme de sortie: torch.Size([1, 84])
# Type de couche: Dropout   Forme de sortie: torch.Size([1, 84])
# Type de couche: Linear   Forme de sortie: torch.Size([1, 10])

# %%
optimiseur = optim.SGD(modele.parameters(), lr=0.001)
entrainer(modele, dl_ent, dl_valid, optimiseur, nb_epochs=10)
# Out:
# -------- > epoch 1:  coût moyen entraînement = 0.025599393993616104
# -------- > epoch 1:  taux moyen entraînement = 0.9927592277526855
# -------- > epoch 1:  coût moyen validation = 0.035949066281318665
# -------- > epoch 1:  taux moyen validation = 0.9917999505996704
# -------- > epoch 2:  coût moyen entraînement = 0.026921860873699188
# -------- > epoch 2:  taux moyen entraînement = 0.9924991726875305
# -------- > epoch 2:  coût moyen validation = 0.03581906855106354
# -------- > epoch 2:  taux moyen validation = 0.991899847984314
# -------- > epoch 3:  coût moyen entraînement = 0.027541300281882286
# -------- > epoch 3:  taux moyen entraînement = 0.9917393922805786
# -------- > epoch 3:  coût moyen validation = 0.035726889967918396
# -------- > epoch 3:  taux moyen validation = 0.991899847984314
# -------- > epoch 4:  coût moyen entraînement = 0.023989228531718254
# -------- > epoch 4:  taux moyen entraînement = 0.9929797649383545
# -------- > epoch 4:  coût moyen validation = 0.035635605454444885
# -------- > epoch 4:  taux moyen validation = 0.991899847984314
# -------- > epoch 5:  coût moyen entraînement = 0.025607656687498093
# -------- > epoch 5:  taux moyen entraînement = 0.9927989840507507
# -------- > epoch 5:  coût moyen validation = 0.035553108900785446
# -------- > epoch 5:  taux moyen validation = 0.991899847984314
# -------- > epoch 6:  coût moyen entraînement = 0.02514885552227497
# -------- > epoch 6:  taux moyen entraînement = 0.993179202079773
# -------- > epoch 6:  coût moyen validation = 0.03547482565045357
# -------- > epoch 6:  taux moyen validation = 0.9918999671936035
# -------- > epoch 7:  coût moyen entraînement = 0.02573227696120739
# -------- > epoch 7:  taux moyen entraînement = 0.9924994707107544
# -------- > epoch 7:  coût moyen validation = 0.03542150929570198
# -------- > epoch 7:  taux moyen validation = 0.9918999671936035
# -------- > epoch 8:  coût moyen entraînement = 0.024452751502394676
# -------- > epoch 8:  taux moyen entraînement = 0.9929794669151306
# -------- > epoch 8:  coût moyen validation = 0.035355374217033386
# -------- > epoch 8:  taux moyen validation = 0.9919999837875366
# -------- > epoch 9:  coût moyen entraînement = 0.02606963738799095
# -------- > epoch 9:  taux moyen entraînement = 0.9927794337272644
# -------- > epoch 9:  coût moyen validation = 0.03530792146921158
# -------- > epoch 9:  taux moyen validation = 0.992099940776825
# -------- > epoch 10:  coût moyen entraînement = 0.024271460250020027
# -------- > epoch 10:  taux moyen entraînement = 0.9927195906639099
# -------- > epoch 10:  coût moyen validation = 0.03524084389209747
# -------- > epoch 10:  taux moyen validation = 0.9919998645782471
