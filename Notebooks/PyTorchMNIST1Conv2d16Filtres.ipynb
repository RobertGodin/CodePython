# %%
# %matplotlib inline
# -*- coding: utf-8 -*-
"""
Exemple simple de MNIST avec PyTorch
Exemple avec nn.Conv2d et F.cross_entropy
Production de métriques avec graphes
Fonction entrainer
"""
import torch
torch.manual_seed(0) # Pour résultats reproductibles

# Fonction J d'entropie croisée
import torch.nn.functional as F
fonction_cout = F.cross_entropy

def taux_bonnes_predictions(lot_Y_predictions, lot_Y):
    predictions_categorie = torch.argmax(lot_Y_predictions, dim=1)
    return (predictions_categorie == lot_Y).float().mean()

from torch import nn
# Définition de l'architecture du RNA

modele = nn.Sequential(
    nn.Conv2d(1,16,3), # 1 canal, 16 filtres, dimension 3 par 3
    nn.ReLU(),
    nn.Flatten(),
    nn.Linear(26*26*16, 10)
)
    
from torch import optim
optimiseur = optim.SGD(modele.parameters(), lr=0.01)

# Chargement des données de MNIST
import pickle, gzip
fichier_donnees = gzip.open(r"mnist.pkl.gz", 'rb')
((donnees_ent_X, donnees_ent_Y),(donnees_valid_X, donnees_valid_Y),(donnees_test_X,donnees_test_Y)) = pickle.load(fichier_donnees, encoding="latin-1")
fichier_donnees.close()

# Conversion des données en type toch.Tensor
import torch
donnees_ent_X,donnees_ent_Y,donnees_valid_X,donnees_valid_Y,donnees_test_X,donnees_test_Y  = map(torch.tensor,
    (donnees_ent_X.reshape((-1,1,28,28)),donnees_ent_Y,donnees_valid_X.reshape((-1,1,28,28)),donnees_valid_Y,donnees_test_X.reshape((-1,1,28,28)),donnees_test_Y))

# Création des objets DataLoader pour itérer par lot
from torch.utils.data import TensorDataset
from torch.utils.data import DataLoader
ds_ent = TensorDataset(donnees_ent_X, donnees_ent_Y)
dl_ent = DataLoader(ds_ent, batch_size=100, shuffle=True)
ds_valid = TensorDataset(donnees_valid_X,donnees_valid_Y)
dl_valid = DataLoader(ds_valid, batch_size=100)

def entrainer(modele, dl_ent, dl_valid, optimiseur, nb_epochs=10):

    # Listes pour les métriques par epoch
    liste_cout_moyen_ent = []
    liste_taux_moyen_ent = []
    liste_cout_moyen_valid = []
    liste_taux_moyen_valid = []
    
    # Boucle d'apprentissage
    for epoch in range(nb_epochs):
        cout_total_ent = 0 # pour cumuler les couts par mini-lot
        taux_bonnes_predictions_ent = 0 # pour cumuler les taux par mini-lot
        modele.train() # Pour certains types de couches (nn.BatchNorm2d, nn.Dropout, ...)
        
        # Boucle d'apprentissage par mini-lot pour une epoch
        for lot_X, lot_Y in dl_ent:
            optimiseur.zero_grad() # Remettre les dérivées à zéro
            lot_Y_predictions = modele(lot_X) # Appel de la méthode forward
            cout = fonction_cout(lot_Y_predictions, lot_Y)
            cout.backward() # Calcul des gradiants par rétropropagation
            with torch.no_grad():
                cout_total_ent +=cout
                taux_bonnes_predictions_ent += taux_bonnes_predictions(lot_Y_predictions, lot_Y)
            optimiseur.step() # Mise à jour des paramètres
        # Calculer les moyennes par mini-lot
        with torch.no_grad():
            cout_moyen_ent = cout_total_ent/len(dl_ent)
            taux_moyen_ent = taux_bonnes_predictions_ent/len(dl_ent)
       
        modele.eval() # Pour certains types de couches (nn.BatchNorm2d, nn.Dropout, ...)
        with torch.no_grad():
            cout_valid = sum(fonction_cout(modele(lot_valid_X), lot_valid_Y) for lot_valid_X, lot_valid_Y in dl_valid)
            taux_bons_valid = sum(taux_bonnes_predictions(modele(lot_valid_X), lot_valid_Y) for lot_valid_X, lot_valid_Y in dl_valid)
        cout_moyen_valid = cout_valid/len(dl_valid)
        taux_moyen_valid = taux_bons_valid/len(dl_valid)
        print(f'-------- > epoch {epoch+1}:  coût moyen entraînement = {cout_moyen_ent}')
        print(f'-------- > epoch {epoch+1}:  taux moyen entraînement = {taux_moyen_ent}')
        print(f'-------- > epoch {epoch+1}:  coût moyen validation = {cout_moyen_valid}')
        print(f'-------- > epoch {epoch+1}:  taux moyen validation = {taux_moyen_valid}')
    
        liste_cout_moyen_ent.append(cout_moyen_ent)
        liste_taux_moyen_ent.append(taux_moyen_ent)
        liste_cout_moyen_valid.append(cout_moyen_valid)
        liste_taux_moyen_valid.append(taux_moyen_valid)
    
    # Affichage du graphique d'évolution des métriques par epoch
    import numpy as np
    import matplotlib.pyplot as plt
    plt.plot(np.arange(0,nb_epochs),liste_cout_moyen_ent,label='Erreur entraînement')
    plt.plot(np.arange(0,nb_epochs),liste_cout_moyen_valid,label='Erreur validation')
    plt.title("Evolution du coût")
    plt.xlabel('epoch')
    plt.ylabel('moyenne par observation')
    plt.legend(loc='upper center')
    plt.show()
        
    plt.plot(np.arange(0,nb_epochs),liste_taux_moyen_ent,label='Taux bonnes réponses entraînement')
    plt.plot(np.arange(0,nb_epochs),liste_taux_moyen_valid,label='Taux bonnes réponses validation')
    plt.title("Evolution du taux")
    plt.xlabel('epoch')
    plt.ylabel('moyenne par observation')
    plt.legend(loc='upper center')
    plt.show()

entrainer(modele, dl_ent, dl_valid, optimiseur, nb_epochs=50)
# Out:
# -------- > epoch 1:  coût moyen entraînement = 0.6437620520591736
# -------- > epoch 1:  taux moyen entraînement = 0.8401807546615601
# -------- > epoch 1:  coût moyen validation = 0.3323304057121277
# -------- > epoch 1:  taux moyen validation = 0.9076000452041626
# -------- > epoch 2:  coût moyen entraînement = 0.3440263271331787
# -------- > epoch 2:  taux moyen entraînement = 0.9010206460952759
# -------- > epoch 2:  coût moyen validation = 0.30506661534309387
# -------- > epoch 2:  taux moyen validation = 0.9136998057365417
# -------- > epoch 3:  coût moyen entraînement = 0.3187776803970337
# -------- > epoch 3:  taux moyen entraînement = 0.9084610342979431
# -------- > epoch 3:  coût moyen validation = 0.28768080472946167
# -------- > epoch 3:  taux moyen validation = 0.9164999127388
# -------- > epoch 4:  coût moyen entraînement = 0.30527833104133606
# -------- > epoch 4:  taux moyen entraînement = 0.9128009676933289
# -------- > epoch 4:  coût moyen validation = 0.27873265743255615
# -------- > epoch 4:  taux moyen validation = 0.9190999865531921
# -------- > epoch 5:  coût moyen entraînement = 0.29599323868751526
# -------- > epoch 5:  taux moyen entraînement = 0.9157010316848755
# -------- > epoch 5:  coût moyen validation = 0.2807961404323578
# -------- > epoch 5:  taux moyen validation = 0.9201998114585876
# -------- > epoch 6:  coût moyen entraînement = 0.2893170416355133
# -------- > epoch 6:  taux moyen entraînement = 0.9178808927536011
# -------- > epoch 6:  coût moyen validation = 0.2666804790496826
# -------- > epoch 6:  taux moyen validation = 0.9248000979423523
# -------- > epoch 7:  coût moyen entraînement = 0.2833184003829956
# -------- > epoch 7:  taux moyen entraînement = 0.9193608164787292
# -------- > epoch 7:  coût moyen validation = 0.26686039566993713
# -------- > epoch 7:  taux moyen validation = 0.9238001108169556
# -------- > epoch 8:  coût moyen entraînement = 0.2780979573726654
# -------- > epoch 8:  taux moyen entraînement = 0.9207208752632141
# -------- > epoch 8:  coût moyen validation = 0.25753965973854065
# -------- > epoch 8:  taux moyen validation = 0.9273000955581665
# -------- > epoch 9:  coût moyen entraînement = 0.2720032036304474
# -------- > epoch 9:  taux moyen entraînement = 0.922900915145874
# -------- > epoch 9:  coût moyen validation = 0.2531561255455017
# -------- > epoch 9:  taux moyen validation = 0.9296998381614685
# -------- > epoch 10:  coût moyen entraînement = 0.26619336009025574
# -------- > epoch 10:  taux moyen entraînement = 0.9250609278678894
# -------- > epoch 10:  coût moyen validation = 0.24886807799339294
# -------- > epoch 10:  taux moyen validation = 0.9303001165390015
# -------- > epoch 11:  coût moyen entraînement = 0.25989094376564026
# -------- > epoch 11:  taux moyen entraînement = 0.9265610575675964
# -------- > epoch 11:  coût moyen validation = 0.24042409658432007
# -------- > epoch 11:  taux moyen validation = 0.9355999827384949
# -------- > epoch 12:  coût moyen entraînement = 0.2543362081050873
# -------- > epoch 12:  taux moyen entraînement = 0.9289210438728333
# -------- > epoch 12:  coût moyen validation = 0.23970139026641846
# -------- > epoch 12:  taux moyen validation = 0.9336000084877014
# -------- > epoch 13:  coût moyen entraînement = 0.24820275604724884
# -------- > epoch 13:  taux moyen entraînement = 0.9305617213249207
# -------- > epoch 13:  coût moyen validation = 0.2344057410955429
# -------- > epoch 13:  taux moyen validation = 0.9359000325202942
# -------- > epoch 14:  coût moyen entraînement = 0.24112877249717712
# -------- > epoch 14:  taux moyen entraînement = 0.932701051235199
# -------- > epoch 14:  coût moyen validation = 0.22636865079402924
# -------- > epoch 14:  taux moyen validation = 0.9391999840736389
# -------- > epoch 15:  coût moyen entraînement = 0.23476050794124603
# -------- > epoch 15:  taux moyen entraînement = 0.9343008399009705
# -------- > epoch 15:  coût moyen validation = 0.22127899527549744
# -------- > epoch 15:  taux moyen validation = 0.9400998950004578
# -------- > epoch 16:  coût moyen entraînement = 0.22796544432640076
# -------- > epoch 16:  taux moyen entraînement = 0.9367609620094299
# -------- > epoch 16:  coût moyen validation = 0.21170932054519653
# -------- > epoch 16:  taux moyen validation = 0.9422999024391174
# -------- > epoch 17:  coût moyen entraînement = 0.22090911865234375
# -------- > epoch 17:  taux moyen entraînement = 0.9386207461357117
# -------- > epoch 17:  coût moyen validation = 0.20600861310958862
# -------- > epoch 17:  taux moyen validation = 0.9448001384735107
# -------- > epoch 18:  coût moyen entraînement = 0.21351514756679535
# -------- > epoch 18:  taux moyen entraînement = 0.9399413466453552
# -------- > epoch 18:  coût moyen validation = 0.2018890231847763
# -------- > epoch 18:  taux moyen validation = 0.9476000070571899
# -------- > epoch 19:  coût moyen entraînement = 0.20613251626491547
# -------- > epoch 19:  taux moyen entraînement = 0.9425209164619446
# -------- > epoch 19:  coût moyen validation = 0.1932716965675354
# -------- > epoch 19:  taux moyen validation = 0.9479001760482788
# -------- > epoch 20:  coût moyen entraînement = 0.19846077263355255
# -------- > epoch 20:  taux moyen entraînement = 0.9454408288002014
# -------- > epoch 20:  coût moyen validation = 0.19162102043628693
# -------- > epoch 20:  taux moyen validation = 0.9502000212669373
# -------- > epoch 21:  coût moyen entraînement = 0.19119809567928314
# -------- > epoch 21:  taux moyen entraînement = 0.9474813938140869
# -------- > epoch 21:  coût moyen validation = 0.1809372752904892
# -------- > epoch 21:  taux moyen validation = 0.9533001184463501
# -------- > epoch 22:  coût moyen entraînement = 0.18343445658683777
# -------- > epoch 22:  taux moyen entraînement = 0.9494211673736572
# -------- > epoch 22:  coût moyen validation = 0.1751689463853836
# -------- > epoch 22:  taux moyen validation = 0.9546001553535461
# -------- > epoch 23:  coût moyen entraînement = 0.17671088874340057
# -------- > epoch 23:  taux moyen entraînement = 0.9508007764816284
# -------- > epoch 23:  coût moyen validation = 0.17402096092700958
# -------- > epoch 23:  taux moyen validation = 0.9563998579978943
# -------- > epoch 24:  coût moyen entraînement = 0.16963259875774384
# -------- > epoch 24:  taux moyen entraînement = 0.9527409672737122
# -------- > epoch 24:  coût moyen validation = 0.16376851499080658
# -------- > epoch 24:  taux moyen validation = 0.957599937915802
# -------- > epoch 25:  coût moyen entraînement = 0.1629209965467453
# -------- > epoch 25:  taux moyen entraînement = 0.9546612501144409
# -------- > epoch 25:  coût moyen validation = 0.15872971713542938
# -------- > epoch 25:  taux moyen validation = 0.9612999558448792
# -------- > epoch 26:  coût moyen entraînement = 0.15632528066635132
# -------- > epoch 26:  taux moyen entraînement = 0.9571009874343872
# -------- > epoch 26:  coût moyen validation = 0.15341639518737793
# -------- > epoch 26:  taux moyen validation = 0.9597001671791077
# -------- > epoch 27:  coût moyen entraînement = 0.14983636140823364
# -------- > epoch 27:  taux moyen entraînement = 0.9594011306762695
# -------- > epoch 27:  coût moyen validation = 0.14591504633426666
# -------- > epoch 27:  taux moyen validation = 0.9631000757217407
# -------- > epoch 28:  coût moyen entraînement = 0.14381608366966248
# -------- > epoch 28:  taux moyen entraînement = 0.9605010747909546
# -------- > epoch 28:  coût moyen validation = 0.14178359508514404
# -------- > epoch 28:  taux moyen validation = 0.9637000560760498
# -------- > epoch 29:  coût moyen entraînement = 0.1387595683336258
# -------- > epoch 29:  taux moyen entraînement = 0.9622803926467896
# -------- > epoch 29:  coût moyen validation = 0.13809427618980408
# -------- > epoch 29:  taux moyen validation = 0.9644001126289368
# -------- > epoch 30:  coût moyen entraînement = 0.13321608304977417
# -------- > epoch 30:  taux moyen entraînement = 0.9644412398338318
# -------- > epoch 30:  coût moyen validation = 0.13380104303359985
# -------- > epoch 30:  taux moyen validation = 0.9654998183250427
# -------- > epoch 31:  coût moyen entraînement = 0.12806642055511475
# -------- > epoch 31:  taux moyen entraînement = 0.9654609560966492
# -------- > epoch 31:  coût moyen validation = 0.1284467726945877
# -------- > epoch 31:  taux moyen validation = 0.9668999314308167
# -------- > epoch 32:  coût moyen entraînement = 0.12375122308731079
# -------- > epoch 32:  taux moyen entraînement = 0.9664605855941772
# -------- > epoch 32:  coût moyen validation = 0.12730932235717773
# -------- > epoch 32:  taux moyen validation = 0.9676999449729919
# -------- > epoch 33:  coût moyen entraînement = 0.11929298937320709
# -------- > epoch 33:  taux moyen entraînement = 0.9677610397338867
# -------- > epoch 33:  coût moyen validation = 0.1233893483877182
# -------- > epoch 33:  taux moyen validation = 0.9687999486923218
# -------- > epoch 34:  coût moyen entraînement = 0.11510857939720154
# -------- > epoch 34:  taux moyen entraînement = 0.9691804647445679
# -------- > epoch 34:  coût moyen validation = 0.11936113983392715
# -------- > epoch 34:  taux moyen validation = 0.9696000814437866
# -------- > epoch 35:  coût moyen entraînement = 0.1116451770067215
# -------- > epoch 35:  taux moyen entraînement = 0.9695209860801697
# -------- > epoch 35:  coût moyen validation = 0.11762933433055878
# -------- > epoch 35:  taux moyen validation = 0.9706001281738281
# -------- > epoch 36:  coût moyen entraînement = 0.10785180330276489
# -------- > epoch 36:  taux moyen entraînement = 0.9712607264518738
# -------- > epoch 36:  coût moyen validation = 0.11451941728591919
# -------- > epoch 36:  taux moyen validation = 0.971200168132782
# -------- > epoch 37:  coût moyen entraînement = 0.10450884699821472
# -------- > epoch 37:  taux moyen entraînement = 0.9720406532287598
# -------- > epoch 37:  coût moyen validation = 0.11235299706459045
# -------- > epoch 37:  taux moyen validation = 0.9720001220703125
# -------- > epoch 38:  coût moyen entraînement = 0.10159562528133392
# -------- > epoch 38:  taux moyen entraînement = 0.972501277923584
# -------- > epoch 38:  coût moyen validation = 0.11014928668737411
# -------- > epoch 38:  taux moyen validation = 0.9730001091957092
# -------- > epoch 39:  coût moyen entraînement = 0.09878631681203842
# -------- > epoch 39:  taux moyen entraînement = 0.9731206893920898
# -------- > epoch 39:  coût moyen validation = 0.10940860956907272
# -------- > epoch 39:  taux moyen validation = 0.9713998436927795
# -------- > epoch 40:  coût moyen entraînement = 0.09590563923120499
# -------- > epoch 40:  taux moyen entraînement = 0.9741401076316833
# -------- > epoch 40:  coût moyen validation = 0.10578810423612595
# -------- > epoch 40:  taux moyen validation = 0.9723999500274658
# -------- > epoch 41:  coût moyen entraînement = 0.09334901720285416
# -------- > epoch 41:  taux moyen entraînement = 0.9751806855201721
# -------- > epoch 41:  coût moyen validation = 0.1041802316904068
# -------- > epoch 41:  taux moyen validation = 0.9741001129150391
# -------- > epoch 42:  coût moyen entraînement = 0.0910416767001152
# -------- > epoch 42:  taux moyen entraînement = 0.9752205014228821
# -------- > epoch 42:  coût moyen validation = 0.10224134474992752
# -------- > epoch 42:  taux moyen validation = 0.9735998511314392
# -------- > epoch 43:  coût moyen entraînement = 0.08850492537021637
# -------- > epoch 43:  taux moyen entraînement = 0.9765803813934326
# -------- > epoch 43:  coût moyen validation = 0.10124894976615906
# -------- > epoch 43:  taux moyen validation = 0.9732000231742859
# -------- > epoch 44:  coût moyen entraînement = 0.08635841310024261
# -------- > epoch 44:  taux moyen entraînement = 0.9772812128067017
# -------- > epoch 44:  coût moyen validation = 0.09838537871837616
# -------- > epoch 44:  taux moyen validation = 0.9747001528739929
# -------- > epoch 45:  coût moyen entraînement = 0.08430928736925125
# -------- > epoch 45:  taux moyen entraînement = 0.9776405692100525
# -------- > epoch 45:  coût moyen validation = 0.09674706310033798
# -------- > epoch 45:  taux moyen validation = 0.9743000268936157
# -------- > epoch 46:  coût moyen entraînement = 0.08238010108470917
# -------- > epoch 46:  taux moyen entraînement = 0.978280782699585
# -------- > epoch 46:  coût moyen validation = 0.09675731509923935
# -------- > epoch 46:  taux moyen validation = 0.9750002026557922
# -------- > epoch 47:  coût moyen entraînement = 0.08042024821043015
# -------- > epoch 47:  taux moyen entraînement = 0.9779804944992065
# -------- > epoch 47:  coût moyen validation = 0.09461372345685959
# -------- > epoch 47:  taux moyen validation = 0.9758999347686768
# -------- > epoch 48:  coût moyen entraînement = 0.07882332056760788
# -------- > epoch 48:  taux moyen entraînement = 0.9789000749588013
# -------- > epoch 48:  coût moyen validation = 0.09309165179729462
# -------- > epoch 48:  taux moyen validation = 0.9757000207901001
# -------- > epoch 49:  coût moyen entraînement = 0.0769730657339096
# -------- > epoch 49:  taux moyen entraînement = 0.9793798923492432
# -------- > epoch 49:  coût moyen validation = 0.0938960611820221
# -------- > epoch 49:  taux moyen validation = 0.9754000902175903
# -------- > epoch 50:  coût moyen entraînement = 0.07550917565822601
# -------- > epoch 50:  taux moyen entraînement = 0.9796411395072937
# -------- > epoch 50:  coût moyen validation = 0.09148896485567093
# -------- > epoch 50:  taux moyen validation = 0.9761000871658325
