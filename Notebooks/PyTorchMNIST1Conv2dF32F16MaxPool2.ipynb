# %%
# %matplotlib inline
# -*- coding: utf-8 -*-
"""
Exemple simple de MNIST avec PyTorch
Exemple avec nn.Conv2d et F.cross_entropy
Production de métriques avec graphes
Fonction entrainer
"""
import torch
torch.manual_seed(0) # Pour résultats reproductibles

# Fonction J d'entropie croisée
import torch.nn.functional as F
fonction_cout = F.cross_entropy

def taux_bonnes_predictions(lot_Y_predictions, lot_Y):
    predictions_categorie = torch.argmax(lot_Y_predictions, dim=1)
    return (predictions_categorie == lot_Y).float().mean()

from torch import nn
# Définition de l'architecture du RNA

modele = nn.Sequential(
    nn.Conv2d(1,32,3),
    nn.ReLU(),
    nn.MaxPool2d(2),
    nn.Conv2d(32,16,3),
    nn.ReLU(),
    nn.Flatten(),
    nn.Linear(11*11*16, 10)
)
    
from torch import optim
optimiseur = optim.SGD(modele.parameters(), lr=0.01)

# Chargement des données de MNIST
import pickle, gzip
fichier_donnees = gzip.open(r"mnist.pkl.gz", 'rb')
((donnees_ent_X, donnees_ent_Y),(donnees_valid_X, donnees_valid_Y),(donnees_test_X,donnees_test_Y)) = pickle.load(fichier_donnees, encoding="latin-1")
fichier_donnees.close()

# Conversion des données en type toch.Tensor
import torch
donnees_ent_X,donnees_ent_Y,donnees_valid_X,donnees_valid_Y,donnees_test_X,donnees_test_Y  = map(torch.tensor,
    (donnees_ent_X.reshape((-1,1,28,28)),donnees_ent_Y,donnees_valid_X.reshape((-1,1,28,28)),donnees_valid_Y,donnees_test_X.reshape((-1,1,28,28)),donnees_test_Y))

# Création des objets DataLoader pour itérer par lot
from torch.utils.data import TensorDataset
from torch.utils.data import DataLoader
ds_ent = TensorDataset(donnees_ent_X, donnees_ent_Y)
dl_ent = DataLoader(ds_ent, batch_size=100, shuffle=True)
ds_valid = TensorDataset(donnees_valid_X,donnees_valid_Y)
dl_valid = DataLoader(ds_valid, batch_size=100)

def entrainer(modele, dl_ent, dl_valid, optimiseur, nb_epochs=10):

    # Listes pour les métriques par epoch
    liste_cout_moyen_ent = []
    liste_taux_moyen_ent = []
    liste_cout_moyen_valid = []
    liste_taux_moyen_valid = []
    
    # Boucle d'apprentissage
    for epoch in range(nb_epochs):
        cout_total_ent = 0 # pour cumuler les couts par mini-lot
        taux_bonnes_predictions_ent = 0 # pour cumuler les taux par mini-lot
        modele.train() # Pour certains types de couches (nn.BatchNorm2d, nn.Dropout, ...)
        
        # Boucle d'apprentissage par mini-lot pour une epoch
        for lot_X, lot_Y in dl_ent:
            optimiseur.zero_grad() # Remettre les dérivées à zéro
            lot_Y_predictions = modele(lot_X) # Appel de la méthode forward
            cout = fonction_cout(lot_Y_predictions, lot_Y)
            cout.backward() # Calcul des gradiants par rétropropagation
            with torch.no_grad():
                cout_total_ent +=cout
                taux_bonnes_predictions_ent += taux_bonnes_predictions(lot_Y_predictions, lot_Y)
            optimiseur.step() # Mise à jour des paramètres
        # Calculer les moyennes par mini-lot
        with torch.no_grad():
            cout_moyen_ent = cout_total_ent/len(dl_ent)
            taux_moyen_ent = taux_bonnes_predictions_ent/len(dl_ent)
       
        modele.eval() # Pour certains types de couches (nn.BatchNorm2d, nn.Dropout, ...)
        with torch.no_grad():
            cout_valid = sum(fonction_cout(modele(lot_valid_X), lot_valid_Y) for lot_valid_X, lot_valid_Y in dl_valid)
            taux_bons_valid = sum(taux_bonnes_predictions(modele(lot_valid_X), lot_valid_Y) for lot_valid_X, lot_valid_Y in dl_valid)
        cout_moyen_valid = cout_valid/len(dl_valid)
        taux_moyen_valid = taux_bons_valid/len(dl_valid)
        print(f'-------- > epoch {epoch+1}:  coût moyen entraînement = {cout_moyen_ent}')
        print(f'-------- > epoch {epoch+1}:  taux moyen entraînement = {taux_moyen_ent}')
        print(f'-------- > epoch {epoch+1}:  coût moyen validation = {cout_moyen_valid}')
        print(f'-------- > epoch {epoch+1}:  taux moyen validation = {taux_moyen_valid}')
    
        liste_cout_moyen_ent.append(cout_moyen_ent)
        liste_taux_moyen_ent.append(taux_moyen_ent)
        liste_cout_moyen_valid.append(cout_moyen_valid)
        liste_taux_moyen_valid.append(taux_moyen_valid)
    
    # Affichage du graphique d'évolution des métriques par epoch
    import numpy as np
    import matplotlib.pyplot as plt
    plt.plot(np.arange(0,nb_epochs),liste_cout_moyen_ent,label='Erreur entraînement')
    plt.plot(np.arange(0,nb_epochs),liste_cout_moyen_valid,label='Erreur validation')
    plt.title("Evolution du coût")
    plt.xlabel('epoch')
    plt.ylabel('moyenne par observation')
    plt.legend(loc='upper center')
    plt.show()
        
    plt.plot(np.arange(0,nb_epochs),liste_taux_moyen_ent,label='Taux bonnes réponses entraînement')
    plt.plot(np.arange(0,nb_epochs),liste_taux_moyen_valid,label='Taux bonnes réponses validation')
    plt.title("Evolution du taux")
    plt.xlabel('epoch')
    plt.ylabel('moyenne par observation')
    plt.legend(loc='upper center')
    plt.show()

entrainer(modele, dl_ent, dl_valid, optimiseur, nb_epochs=30)
# Out:
# -------- > epoch 1:  coût moyen entraînement = 0.9345830678939819
# -------- > epoch 1:  taux moyen entraînement = 0.7349998354911804
# -------- > epoch 1:  coût moyen validation = 0.3598161041736603
# -------- > epoch 1:  taux moyen validation = 0.8969999551773071
# -------- > epoch 2:  coût moyen entraînement = 0.37814053893089294
# -------- > epoch 2:  taux moyen entraînement = 0.8871802687644958
# -------- > epoch 2:  coût moyen validation = 0.32678091526031494
# -------- > epoch 2:  taux moyen validation = 0.9052000641822815
# -------- > epoch 3:  coût moyen entraînement = 0.3429689109325409
# -------- > epoch 3:  taux moyen entraînement = 0.8987810611724854
# -------- > epoch 3:  coût moyen validation = 0.2985239624977112
# -------- > epoch 3:  taux moyen validation = 0.9142000079154968
# -------- > epoch 4:  coût moyen entraînement = 0.31708231568336487
# -------- > epoch 4:  taux moyen entraînement = 0.9053812623023987
# -------- > epoch 4:  coût moyen validation = 0.286906361579895
# -------- > epoch 4:  taux moyen validation = 0.9161998629570007
# -------- > epoch 5:  coût moyen entraînement = 0.29284563660621643
# -------- > epoch 5:  taux moyen entraînement = 0.914560854434967
# -------- > epoch 5:  coût moyen validation = 0.25198066234588623
# -------- > epoch 5:  taux moyen validation = 0.9288997054100037
# -------- > epoch 6:  coût moyen entraînement = 0.26670438051223755
# -------- > epoch 6:  taux moyen entraînement = 0.9221612215042114
# -------- > epoch 6:  coût moyen validation = 0.23250219225883484
# -------- > epoch 6:  taux moyen validation = 0.9343997836112976
# -------- > epoch 7:  coût moyen entraînement = 0.2381727397441864
# -------- > epoch 7:  taux moyen entraînement = 0.9304412007331848
# -------- > epoch 7:  coût moyen validation = 0.201939657330513
# -------- > epoch 7:  taux moyen validation = 0.9444997310638428
# -------- > epoch 8:  coût moyen entraînement = 0.21041640639305115
# -------- > epoch 8:  taux moyen entraînement = 0.9391213059425354
# -------- > epoch 8:  coût moyen validation = 0.17918230593204498
# -------- > epoch 8:  taux moyen validation = 0.9520999789237976
# -------- > epoch 9:  coût moyen entraînement = 0.18397417664527893
# -------- > epoch 9:  taux moyen entraînement = 0.9470211863517761
# -------- > epoch 9:  coût moyen validation = 0.15854306519031525
# -------- > epoch 9:  taux moyen validation = 0.9573000073432922
# -------- > epoch 10:  coût moyen entraînement = 0.16266947984695435
# -------- > epoch 10:  taux moyen entraînement = 0.9531612396240234
# -------- > epoch 10:  coût moyen validation = 0.14588405191898346
# -------- > epoch 10:  taux moyen validation = 0.9613001942634583
# -------- > epoch 11:  coût moyen entraînement = 0.14467476308345795
# -------- > epoch 11:  taux moyen entraînement = 0.9584407210350037
# -------- > epoch 11:  coût moyen validation = 0.12781409919261932
# -------- > epoch 11:  taux moyen validation = 0.9671000838279724
# -------- > epoch 12:  coût moyen entraînement = 0.12956583499908447
# -------- > epoch 12:  taux moyen entraînement = 0.9625207781791687
# -------- > epoch 12:  coût moyen validation = 0.11669623106718063
# -------- > epoch 12:  taux moyen validation = 0.9702001214027405
# -------- > epoch 13:  coût moyen entraînement = 0.1180565282702446
# -------- > epoch 13:  taux moyen entraînement = 0.9658010601997375
# -------- > epoch 13:  coût moyen validation = 0.11002499610185623
# -------- > epoch 13:  taux moyen validation = 0.9718000888824463
# -------- > epoch 14:  coût moyen entraînement = 0.10822133719921112
# -------- > epoch 14:  taux moyen entraînement = 0.9682806134223938
# -------- > epoch 14:  coût moyen validation = 0.10151606798171997
# -------- > epoch 14:  taux moyen validation = 0.973300039768219
# -------- > epoch 15:  coût moyen entraînement = 0.10004106909036636
# -------- > epoch 15:  taux moyen entraînement = 0.9709206819534302
# -------- > epoch 15:  coût moyen validation = 0.09791939705610275
# -------- > epoch 15:  taux moyen validation = 0.9732000827789307
# -------- > epoch 16:  coût moyen entraînement = 0.0936616063117981
# -------- > epoch 16:  taux moyen entraînement = 0.9728608131408691
# -------- > epoch 16:  coût moyen validation = 0.09551738947629929
# -------- > epoch 16:  taux moyen validation = 0.9742000699043274
# -------- > epoch 17:  coût moyen entraînement = 0.08814694732427597
# -------- > epoch 17:  taux moyen entraînement = 0.9736807346343994
# -------- > epoch 17:  coût moyen validation = 0.0908924862742424
# -------- > epoch 17:  taux moyen validation = 0.9763001799583435
# -------- > epoch 18:  coût moyen entraînement = 0.08327799290418625
# -------- > epoch 18:  taux moyen entraînement = 0.9758408665657043
# -------- > epoch 18:  coût moyen validation = 0.08451932668685913
# -------- > epoch 18:  taux moyen validation = 0.9769001007080078
# -------- > epoch 19:  coût moyen entraînement = 0.07938782870769501
# -------- > epoch 19:  taux moyen entraînement = 0.9761611819267273
# -------- > epoch 19:  coût moyen validation = 0.08679063618183136
# -------- > epoch 19:  taux moyen validation = 0.9768000841140747
# -------- > epoch 20:  coût moyen entraînement = 0.07589364796876907
# -------- > epoch 20:  taux moyen entraînement = 0.9774805903434753
# -------- > epoch 20:  coût moyen validation = 0.08233769237995148
# -------- > epoch 20:  taux moyen validation = 0.9778001308441162
# -------- > epoch 21:  coût moyen entraînement = 0.07264140993356705
# -------- > epoch 21:  taux moyen entraînement = 0.9781605005264282
# -------- > epoch 21:  coût moyen validation = 0.07958874851465225
# -------- > epoch 21:  taux moyen validation = 0.9780000448226929
# -------- > epoch 22:  coût moyen entraînement = 0.06973016262054443
# -------- > epoch 22:  taux moyen entraînement = 0.9792805910110474
# -------- > epoch 22:  coût moyen validation = 0.07893446832895279
# -------- > epoch 22:  taux moyen validation = 0.9794002771377563
# -------- > epoch 23:  coût moyen entraînement = 0.06736748665571213
# -------- > epoch 23:  taux moyen entraînement = 0.9800805449485779
# -------- > epoch 23:  coût moyen validation = 0.07270558923482895
# -------- > epoch 23:  taux moyen validation = 0.9801000952720642
# -------- > epoch 24:  coût moyen entraînement = 0.06513751298189163
# -------- > epoch 24:  taux moyen entraînement = 0.9805999994277954
# -------- > epoch 24:  coût moyen validation = 0.07279638200998306
# -------- > epoch 24:  taux moyen validation = 0.9801002740859985
# -------- > epoch 25:  coût moyen entraînement = 0.0629466325044632
# -------- > epoch 25:  taux moyen entraînement = 0.9818205237388611
# -------- > epoch 25:  coût moyen validation = 0.08522782474756241
# -------- > epoch 25:  taux moyen validation = 0.9750001430511475
# -------- > epoch 26:  coût moyen entraînement = 0.061735447496175766
# -------- > epoch 26:  taux moyen entraînement = 0.9813804030418396
# -------- > epoch 26:  coût moyen validation = 0.06884124130010605
# -------- > epoch 26:  taux moyen validation = 0.9807000756263733
# -------- > epoch 27:  coût moyen entraînement = 0.059383243322372437
# -------- > epoch 27:  taux moyen entraînement = 0.9821601510047913
# -------- > epoch 27:  coût moyen validation = 0.06955133378505707
# -------- > epoch 27:  taux moyen validation = 0.980500340461731
# -------- > epoch 28:  coût moyen entraînement = 0.05793872848153114
# -------- > epoch 28:  taux moyen entraînement = 0.982460081577301
# -------- > epoch 28:  coût moyen validation = 0.06830079853534698
# -------- > epoch 28:  taux moyen validation = 0.9817003011703491
# -------- > epoch 29:  coût moyen entraînement = 0.056305259466171265
# -------- > epoch 29:  taux moyen entraînement = 0.9829805493354797
# -------- > epoch 29:  coût moyen validation = 0.0662282407283783
# -------- > epoch 29:  taux moyen validation = 0.9816001653671265
# -------- > epoch 30:  coût moyen entraînement = 0.05512194707989693
# -------- > epoch 30:  taux moyen entraînement = 0.9831600189208984
# -------- > epoch 30:  coût moyen validation = 0.06907173991203308
# -------- > epoch 30:  taux moyen validation = 0.9820004105567932
