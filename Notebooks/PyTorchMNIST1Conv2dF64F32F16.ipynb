# %%
# %matplotlib inline
# -*- coding: utf-8 -*-
"""
Exemple simple de MNIST avec PyTorch
Trois couches convolution F64 F32 F16
"""
import torch
torch.manual_seed(0) # Pour résultats reproductibles

# Fonction J d'entropie croisée
import torch.nn.functional as F
fonction_cout = F.cross_entropy

def taux_bonnes_predictions(lot_Y_predictions, lot_Y):
    predictions_categorie = torch.argmax(lot_Y_predictions, dim=1)
    return (predictions_categorie == lot_Y).float().mean()

from torch import nn
# Définition de l'architecture du RNA

modele = nn.Sequential(
    nn.Conv2d(1,64,3),
    nn.ReLU(),
    nn.Conv2d(64,32,3),
    nn.ReLU(),
    nn.Conv2d(32,16,3),
    nn.ReLU(),
    nn.Flatten(),
    nn.Linear(22*22*16, 10)
)
    
from torch import optim
optimiseur = optim.SGD(modele.parameters(), lr=0.01)

# Chargement des données de MNIST
import pickle, gzip
fichier_donnees = gzip.open(r"mnist.pkl.gz", 'rb')
((donnees_ent_X, donnees_ent_Y),(donnees_valid_X, donnees_valid_Y),(donnees_test_X,donnees_test_Y)) = pickle.load(fichier_donnees, encoding="latin-1")
fichier_donnees.close()

# Conversion des données en type toch.Tensor
import torch
donnees_ent_X,donnees_ent_Y,donnees_valid_X,donnees_valid_Y,donnees_test_X,donnees_test_Y  = map(torch.tensor,
    (donnees_ent_X.reshape((-1,1,28,28)),donnees_ent_Y,donnees_valid_X.reshape((-1,1,28,28)),donnees_valid_Y,donnees_test_X.reshape((-1,1,28,28)),donnees_test_Y))

# Création des objets DataLoader pour itérer par lot
from torch.utils.data import TensorDataset
from torch.utils.data import DataLoader
ds_ent = TensorDataset(donnees_ent_X, donnees_ent_Y)
dl_ent = DataLoader(ds_ent, batch_size=100, shuffle=True)
ds_valid = TensorDataset(donnees_valid_X,donnees_valid_Y)
dl_valid = DataLoader(ds_valid, batch_size=100)

def entrainer(modele, dl_ent, dl_valid, optimiseur, nb_epochs=10):

    # Listes pour les métriques par epoch
    liste_cout_moyen_ent = []
    liste_taux_moyen_ent = []
    liste_cout_moyen_valid = []
    liste_taux_moyen_valid = []
    
    # Boucle d'apprentissage
    for epoch in range(nb_epochs):
        cout_total_ent = 0 # pour cumuler les couts par mini-lot
        taux_bonnes_predictions_ent = 0 # pour cumuler les taux par mini-lot
        modele.train() # Pour certains types de couches (nn.BatchNorm2d, nn.Dropout, ...)
        
        # Boucle d'apprentissage par mini-lot pour une epoch
        for lot_X, lot_Y in dl_ent:
            optimiseur.zero_grad() # Remettre les dérivées à zéro
            lot_Y_predictions = modele(lot_X) # Appel de la méthode forward
            cout = fonction_cout(lot_Y_predictions, lot_Y)
            cout.backward() # Calcul des gradiants par rétropropagation
            with torch.no_grad():
                cout_total_ent +=cout
                taux_bonnes_predictions_ent += taux_bonnes_predictions(lot_Y_predictions, lot_Y)
            optimiseur.step() # Mise à jour des paramètres
        # Calculer les moyennes par mini-lot
        with torch.no_grad():
            cout_moyen_ent = cout_total_ent/len(dl_ent)
            taux_moyen_ent = taux_bonnes_predictions_ent/len(dl_ent)
       
        modele.eval() # Pour certains types de couches (nn.BatchNorm2d, nn.Dropout, ...)
        with torch.no_grad():
            cout_valid = sum(fonction_cout(modele(lot_valid_X), lot_valid_Y) for lot_valid_X, lot_valid_Y in dl_valid)
            taux_bons_valid = sum(taux_bonnes_predictions(modele(lot_valid_X), lot_valid_Y) for lot_valid_X, lot_valid_Y in dl_valid)
        cout_moyen_valid = cout_valid/len(dl_valid)
        taux_moyen_valid = taux_bons_valid/len(dl_valid)
        print(f'-------- > epoch {epoch+1}:  coût moyen entraînement = {cout_moyen_ent}')
        print(f'-------- > epoch {epoch+1}:  taux moyen entraînement = {taux_moyen_ent}')
        print(f'-------- > epoch {epoch+1}:  coût moyen validation = {cout_moyen_valid}')
        print(f'-------- > epoch {epoch+1}:  taux moyen validation = {taux_moyen_valid}')
    
        liste_cout_moyen_ent.append(cout_moyen_ent)
        liste_taux_moyen_ent.append(taux_moyen_ent)
        liste_cout_moyen_valid.append(cout_moyen_valid)
        liste_taux_moyen_valid.append(taux_moyen_valid)
    
    # Affichage du graphique d'évolution des métriques par epoch
    import numpy as np
    import matplotlib.pyplot as plt
    plt.plot(np.arange(0,nb_epochs),liste_cout_moyen_ent,label='Erreur entraînement')
    plt.plot(np.arange(0,nb_epochs),liste_cout_moyen_valid,label='Erreur validation')
    plt.title("Evolution du coût")
    plt.xlabel('epoch')
    plt.ylabel('moyenne par observation')
    plt.legend(loc='upper center')
    plt.show()
        
    plt.plot(np.arange(0,nb_epochs),liste_taux_moyen_ent,label='Taux bonnes réponses entraînement')
    plt.plot(np.arange(0,nb_epochs),liste_taux_moyen_valid,label='Taux bonnes réponses validation')
    plt.title("Evolution du taux")
    plt.xlabel('epoch')
    plt.ylabel('moyenne par observation')
    plt.legend(loc='upper center')
    plt.show()

entrainer(modele, dl_ent, dl_valid, optimiseur, nb_epochs=30)
# Out:
# -------- > epoch 1:  coût moyen entraînement = 0.6859339475631714
# -------- > epoch 1:  taux moyen entraînement = 0.7906206846237183
# -------- > epoch 1:  coût moyen validation = 0.33017775416374207
# -------- > epoch 1:  taux moyen validation = 0.9045000672340393
# -------- > epoch 2:  coût moyen entraînement = 0.3388257622718811
# -------- > epoch 2:  taux moyen entraînement = 0.9019210934638977
# -------- > epoch 2:  coût moyen validation = 0.2828671336174011
# -------- > epoch 2:  taux moyen validation = 0.9186000227928162
# -------- > epoch 3:  coût moyen entraînement = 0.29749780893325806
# -------- > epoch 3:  taux moyen entraînement = 0.9144412875175476
# -------- > epoch 3:  coût moyen validation = 0.25131091475486755
# -------- > epoch 3:  taux moyen validation = 0.929900050163269
# -------- > epoch 4:  coût moyen entraînement = 0.24785906076431274
# -------- > epoch 4:  taux moyen entraînement = 0.9290605187416077
# -------- > epoch 4:  coût moyen validation = 0.2104581594467163
# -------- > epoch 4:  taux moyen validation = 0.9447000622749329
# -------- > epoch 5:  coût moyen entraînement = 0.18587304651737213
# -------- > epoch 5:  taux moyen entraînement = 0.9461997747421265
# -------- > epoch 5:  coût moyen validation = 0.15627680718898773
# -------- > epoch 5:  taux moyen validation = 0.9588001370429993
# -------- > epoch 6:  coût moyen entraînement = 0.13676826655864716
# -------- > epoch 6:  taux moyen entraînement = 0.9617608189582825
# -------- > epoch 6:  coût moyen validation = 0.11977256089448929
# -------- > epoch 6:  taux moyen validation = 0.9690999388694763
# -------- > epoch 7:  coût moyen entraînement = 0.10755209624767303
# -------- > epoch 7:  taux moyen entraînement = 0.9701813459396362
# -------- > epoch 7:  coût moyen validation = 0.09387218207120895
# -------- > epoch 7:  taux moyen validation = 0.9761000275611877
# -------- > epoch 8:  coût moyen entraînement = 0.08975381404161453
# -------- > epoch 8:  taux moyen entraînement = 0.9744610786437988
# -------- > epoch 8:  coût moyen validation = 0.08701984584331512
# -------- > epoch 8:  taux moyen validation = 0.9777998924255371
# -------- > epoch 9:  coût moyen entraînement = 0.07858298718929291
# -------- > epoch 9:  taux moyen entraînement = 0.9771208167076111
# -------- > epoch 9:  coût moyen validation = 0.0812770202755928
# -------- > epoch 9:  taux moyen validation = 0.9779000282287598
# -------- > epoch 10:  coût moyen entraînement = 0.06949852406978607
# -------- > epoch 10:  taux moyen entraînement = 0.9797806143760681
# -------- > epoch 10:  coût moyen validation = 0.07940039783716202
# -------- > epoch 10:  taux moyen validation = 0.979300320148468
# -------- > epoch 11:  coût moyen entraînement = 0.06333326548337936
# -------- > epoch 11:  taux moyen entraînement = 0.9807605743408203
# -------- > epoch 11:  coût moyen validation = 0.07819037139415741
# -------- > epoch 11:  taux moyen validation = 0.9784000515937805
# -------- > epoch 12:  coût moyen entraînement = 0.05864845961332321
# -------- > epoch 12:  taux moyen entraînement = 0.9825404286384583
# -------- > epoch 12:  coût moyen validation = 0.07540091127157211
# -------- > epoch 12:  taux moyen validation = 0.979400098323822
# -------- > epoch 13:  coût moyen entraînement = 0.053882334381341934
# -------- > epoch 13:  taux moyen entraînement = 0.9840204119682312
# -------- > epoch 13:  coût moyen validation = 0.07284495234489441
# -------- > epoch 13:  taux moyen validation = 0.9805001020431519
# -------- > epoch 14:  coût moyen entraînement = 0.05104333534836769
# -------- > epoch 14:  taux moyen entraînement = 0.9846594929695129
# -------- > epoch 14:  coût moyen validation = 0.07464035600423813
# -------- > epoch 14:  taux moyen validation = 0.9780998826026917
# -------- > epoch 15:  coût moyen entraînement = 0.0474989116191864
# -------- > epoch 15:  taux moyen entraînement = 0.9853601455688477
# -------- > epoch 15:  coût moyen validation = 0.07836224138736725
# -------- > epoch 15:  taux moyen validation = 0.9775000214576721
# -------- > epoch 16:  coût moyen entraînement = 0.04461800307035446
# -------- > epoch 16:  taux moyen entraînement = 0.9862596988677979
# -------- > epoch 16:  coût moyen validation = 0.06948602944612503
# -------- > epoch 16:  taux moyen validation = 0.9811002612113953
# -------- > epoch 17:  coût moyen entraînement = 0.042352139949798584
# -------- > epoch 17:  taux moyen entraînement = 0.9868999719619751
# -------- > epoch 17:  coût moyen validation = 0.07425566017627716
# -------- > epoch 17:  taux moyen validation = 0.9796001315116882
# -------- > epoch 18:  coût moyen entraînement = 0.04011683538556099
# -------- > epoch 18:  taux moyen entraînement = 0.9877396821975708
# -------- > epoch 18:  coût moyen validation = 0.0739218145608902
# -------- > epoch 18:  taux moyen validation = 0.9803000688552856
# -------- > epoch 19:  coût moyen entraînement = 0.03757316246628761
# -------- > epoch 19:  taux moyen entraînement = 0.9884999990463257
# -------- > epoch 19:  coût moyen validation = 0.07028427720069885
# -------- > epoch 19:  taux moyen validation = 0.9807000756263733
# -------- > epoch 20:  coût moyen entraînement = 0.03557814285159111
# -------- > epoch 20:  taux moyen entraînement = 0.9890798330307007
# -------- > epoch 20:  coût moyen validation = 0.07381144165992737
# -------- > epoch 20:  taux moyen validation = 0.9810001254081726
# -------- > epoch 21:  coût moyen entraînement = 0.03345142677426338
# -------- > epoch 21:  taux moyen entraînement = 0.9897801280021667
# -------- > epoch 21:  coût moyen validation = 0.07223352044820786
# -------- > epoch 21:  taux moyen validation = 0.982200026512146
# -------- > epoch 22:  coût moyen entraînement = 0.031798359006643295
# -------- > epoch 22:  taux moyen entraînement = 0.9902992844581604
# -------- > epoch 22:  coût moyen validation = 0.07429362833499908
# -------- > epoch 22:  taux moyen validation = 0.9809001684188843
# -------- > epoch 23:  coût moyen entraînement = 0.030488276854157448
# -------- > epoch 23:  taux moyen entraînement = 0.9907999634742737
# -------- > epoch 23:  coût moyen validation = 0.07528100162744522
# -------- > epoch 23:  taux moyen validation = 0.9805000424385071
# -------- > epoch 24:  coût moyen entraînement = 0.02972983568906784
# -------- > epoch 24:  taux moyen entraînement = 0.9905797243118286
# -------- > epoch 24:  coût moyen validation = 0.07284056395292282
# -------- > epoch 24:  taux moyen validation = 0.9810000061988831
# -------- > epoch 25:  coût moyen entraînement = 0.026868002489209175
# -------- > epoch 25:  taux moyen entraînement = 0.9919393658638
# -------- > epoch 25:  coût moyen validation = 0.07477245479822159
# -------- > epoch 25:  taux moyen validation = 0.9814001321792603
# -------- > epoch 26:  coût moyen entraînement = 0.02606085129082203
# -------- > epoch 26:  taux moyen entraînement = 0.9921994209289551
# -------- > epoch 26:  coût moyen validation = 0.0735541433095932
# -------- > epoch 26:  taux moyen validation = 0.9823001623153687
# -------- > epoch 27:  coût moyen entraînement = 0.02422790229320526
# -------- > epoch 27:  taux moyen entraînement = 0.9926190972328186
# -------- > epoch 27:  coût moyen validation = 0.0767429769039154
# -------- > epoch 27:  taux moyen validation = 0.9814003109931946
# -------- > epoch 28:  coût moyen entraînement = 0.02420223504304886
# -------- > epoch 28:  taux moyen entraînement = 0.992699146270752
# -------- > epoch 28:  coût moyen validation = 0.07398617267608643
# -------- > epoch 28:  taux moyen validation = 0.9825002551078796
# -------- > epoch 29:  coût moyen entraînement = 0.02243032492697239
# -------- > epoch 29:  taux moyen entraînement = 0.9934993982315063
# -------- > epoch 29:  coût moyen validation = 0.08115917444229126
# -------- > epoch 29:  taux moyen validation = 0.9809001684188843
# -------- > epoch 30:  coût moyen entraînement = 0.02129787765443325
# -------- > epoch 30:  taux moyen entraînement = 0.9935790300369263
# -------- > epoch 30:  coût moyen validation = 0.08386154472827911
# -------- > epoch 30:  taux moyen validation = 0.9784002900123596
