# %%
# %matplotlib inline
# -*- coding: utf-8 -*-
"""
Exemple simple de MNIST avec PyTorch
Exemple avec nn.Sequential et F.cross_entropy
Production de métriques avec graphes
Fonction entrainer
"""
import torch
torch.manual_seed(0)  # Pour résultats reproductibles

# Fonction J d'entropie croisée
import torch.nn.functional as F
fonction_cout = F.cross_entropy

def taux_bonnes_predictions(lot_Y_predictions, lot_Y):
    predictions_categorie = torch.argmax(lot_Y_predictions, dim=1)
    return (predictions_categorie == lot_Y).float().mean()

from torch import nn
# Définition de l'architecture du RNA
modele = nn.Sequential(
    nn.Flatten(),
    nn.Linear(784, 30),
    nn.ReLU(),
    nn.Linear(30, 10)
)

from torch import optim
optimiseur = optim.SGD(modele.parameters(), lr=0.05)

#Chargement des données
import torchvision
import torchvision.transforms as transforms
ds = torchvision.datasets.MNIST(root = "./data", train = True, download = True, transform = transforms.ToTensor())
ds_ent, ds_valid = torch.utils.data.random_split(ds, [50000, 10000])
ds_test = torchvision.datasets.MNIST(root = "./data", train = False, download = True, transform = transforms.ToTensor())

#Création du DataLoader avec le dataset
dl_ent = torch.utils.data.DataLoader(ds_ent, batch_size=100, shuffle = True)
dl_valid = torch.utils.data.DataLoader(ds_valid, batch_size=100)

def entrainer(modele, dl_ent, dl_valid, optimiseur, nb_epochs=10):

    # Listes pour les métriques par epoch
    liste_cout_moyen_ent = []
    liste_taux_moyen_ent = []
    liste_cout_moyen_valid = []
    liste_taux_moyen_valid = []

    # Boucle d'apprentissage
    for epoch in range(nb_epochs):
        cout_total_ent = 0  # pour cumuler les couts par mini-lot
        taux_bonnes_predictions_ent = 0  # pour cumuler les taux par mini-lot
        modele.train()  # Pour certains types de couches (nn.BatchNorm2d, nn.Dropout, ...)

        # Boucle d'apprentissage par mini-lot pour une epoch
        for lot_X, lot_Y in dl_ent:
            optimiseur.zero_grad()  # Remettre les dérivées à zéro
            lot_Y_predictions = modele(lot_X)  # Appel de la méthode forward
            cout = fonction_cout(lot_Y_predictions, lot_Y)
            cout.backward()  # Calcul des gradients par rétropropagation
            with torch.no_grad():
                cout_total_ent += cout
                taux_bonnes_predictions_ent += taux_bonnes_predictions(lot_Y_predictions, lot_Y)
            optimiseur.step()  # Mise à jour des paramètres
        # Calculer les moyennes par mini-lot
        with torch.no_grad():
            cout_moyen_ent = cout_total_ent/len(dl_ent)
            taux_moyen_ent = taux_bonnes_predictions_ent/len(dl_ent)

        modele.eval()  # Pour certains types de couches (nn.BatchNorm2d, nn.Dropout, ...)
        with torch.no_grad():
            cout_valid = sum(fonction_cout(modele(lot_valid_X), lot_valid_Y) for lot_valid_X, lot_valid_Y in dl_valid)
            taux_bons_valid = sum(taux_bonnes_predictions(modele(lot_valid_X), lot_valid_Y) for lot_valid_X, lot_valid_Y in dl_valid)
        cout_moyen_valid = cout_valid/len(dl_valid)
        taux_moyen_valid = taux_bons_valid/len(dl_valid)
        print(f'-------- > epoch {epoch+1}: coût moyen entraînement = {cout_moyen_ent}')
        print(f'-------- > epoch {epoch+1}: taux moyen entraînement = {taux_moyen_ent}')
        print(f'-------- > epoch {epoch+1}: coût moyen validation = {cout_moyen_valid}')
        print(f'-------- > epoch {epoch+1}: taux moyen validation = {taux_moyen_valid}')

        liste_cout_moyen_ent.append(cout_moyen_ent)
        liste_taux_moyen_ent.append(taux_moyen_ent)
        liste_cout_moyen_valid.append(cout_moyen_valid)
        liste_taux_moyen_valid.append(taux_moyen_valid)

    # Affichage du graphique d'évolution des métriques par epoch
    import numpy as np
    import matplotlib.pyplot as plt
    plt.figure()
    plt.plot(np.arange(0, nb_epochs), liste_cout_moyen_ent, label='Erreur entraînement')
    plt.plot(np.arange(0, nb_epochs), liste_cout_moyen_valid, label='Erreur validation')
    plt.title("Evolution du coût")
    plt.xlabel('epoch')
    plt.ylabel('moyenne par observation')
    plt.legend(loc='upper center')
    plt.show()

    plt.figure()
    plt.plot(np.arange(0, nb_epochs), liste_taux_moyen_ent, label='Taux bonnes réponses entraînement')
    plt.plot(np.arange(0, nb_epochs), liste_taux_moyen_valid, label='Taux bonnes réponses validation')
    plt.title("Evolution du taux")
    plt.xlabel('epoch')
    plt.ylabel('moyenne par observation')
    plt.legend(loc='upper center')
    plt.show()


print("Étape 1: 10 epochs")
entrainer(modele, dl_ent, dl_valid, optimiseur, nb_epochs=10)

print("Étape 2: 30 epochs")
entrainer(modele, dl_ent, dl_valid, optimiseur, nb_epochs=10)

print("Étape 3: réduire le taux d'apprentissage à 0.005 pour 10 epochs")
optimiseur = optim.SGD(modele.parameters(), lr=0.005)
entrainer(modele, dl_ent, dl_valid, optimiseur, nb_epochs=10)

print("Étape 4: sauvegarder le modèle")
CHEMIN = './MNISTSimple10.pth'
torch.save(modele.state_dict(), CHEMIN)

print("Étape 5: charger le modèle et poursuivre l'entraînement")
modele.load_state_dict(torch.load(CHEMIN))
entrainer(modele, dl_ent, dl_valid, optimiseur, nb_epochs=10)

print("Étape 6: métriques sur les données de test")
# Chargement des données de test MNIST

ds_test = torchvision.datasets.MNIST(root='./data', train=False, download=True, transform = transforms.ToTensor())
from torch.utils.data import DataLoader
dl_test = DataLoader(ds_test, batch_size=100)

with torch.no_grad():
    cout_test = sum(fonction_cout(modele(lot_test_X), lot_test_Y) for lot_test_X, lot_test_Y in dl_test)
    taux_bons_test = sum(taux_bonnes_predictions(modele(lot_test_X), lot_test_Y) for lot_test_X, lot_test_Y in dl_test)
cout_moyen_test = cout_test/len(dl_test)
taux_moyen_test = taux_bons_test/len(dl_test)
print(f'-------- > coût moyen test = {cout_moyen_test}')
print(f'-------- > taux moyen test = {taux_moyen_test}')
# Out:
# Étape 1: 10 epochs
# -------- > epoch 1: coût moyen entraînement = 0.7716227173805237
# -------- > epoch 1: taux moyen entraînement = 0.8123201131820679
# -------- > epoch 1: coût moyen validation = 0.3955419063568115
# -------- > epoch 1: taux moyen validation = 0.8862999677658081
# -------- > epoch 2: coût moyen entraînement = 0.3499225080013275
# -------- > epoch 2: taux moyen entraînement = 0.9005205631256104
# -------- > epoch 2: coût moyen validation = 0.3298407793045044
# -------- > epoch 2: taux moyen validation = 0.9038000702857971
# -------- > epoch 3: coût moyen entraînement = 0.30645132064819336
# -------- > epoch 3: taux moyen entraînement = 0.9123613238334656
# -------- > epoch 3: coût moyen validation = 0.30566245317459106
# -------- > epoch 3: taux moyen validation = 0.9109000563621521
# -------- > epoch 4: coût moyen entraînement = 0.28073471784591675
# -------- > epoch 4: taux moyen entraînement = 0.9194405674934387
# -------- > epoch 4: coût moyen validation = 0.2844964861869812
# -------- > epoch 4: taux moyen validation = 0.9172003269195557
# -------- > epoch 5: coût moyen entraînement = 0.2615658938884735
# -------- > epoch 5: taux moyen entraînement = 0.9251211285591125
# -------- > epoch 5: coût moyen validation = 0.2685418725013733
# -------- > epoch 5: taux moyen validation = 0.9216001033782959
# -------- > epoch 6: coût moyen entraînement = 0.2456362247467041
# -------- > epoch 6: taux moyen entraînement = 0.9295608401298523
# -------- > epoch 6: coût moyen validation = 0.25804856419563293
# -------- > epoch 6: taux moyen validation = 0.9248999953269958
# -------- > epoch 7: coût moyen entraînement = 0.231550395488739
# -------- > epoch 7: taux moyen entraînement = 0.9342809915542603
# -------- > epoch 7: coût moyen validation = 0.2439560443162918
# -------- > epoch 7: taux moyen validation = 0.9283998608589172
# -------- > epoch 8: coût moyen entraînement = 0.21912021934986115
# -------- > epoch 8: taux moyen entraînement = 0.9378806352615356
# -------- > epoch 8: coût moyen validation = 0.23392358422279358
# -------- > epoch 8: taux moyen validation = 0.9325997829437256
# -------- > epoch 9: coût moyen entraînement = 0.20783661305904388
# -------- > epoch 9: taux moyen entraînement = 0.9403808116912842
# -------- > epoch 9: coût moyen validation = 0.2300681620836258
# -------- > epoch 9: taux moyen validation = 0.9326000809669495
# -------- > epoch 10: coût moyen entraînement = 0.19797565042972565
# -------- > epoch 10: taux moyen entraînement = 0.9433405995368958
# -------- > epoch 10: coût moyen validation = 0.2128177136182785
# -------- > epoch 10: taux moyen validation = 0.9380002617835999
# Étape 2: 30 epochs
# -------- > epoch 1: coût moyen entraînement = 0.18886302411556244
# -------- > epoch 1: taux moyen entraînement = 0.9455013871192932
# -------- > epoch 1: coût moyen validation = 0.2091922163963318
# -------- > epoch 1: taux moyen validation = 0.938700258731842
# -------- > epoch 2: coût moyen entraînement = 0.18032878637313843
# -------- > epoch 2: taux moyen entraînement = 0.9491008520126343
# -------- > epoch 2: coût moyen validation = 0.19716158509254456
# -------- > epoch 2: taux moyen validation = 0.9430002570152283
# -------- > epoch 3: coût moyen entraînement = 0.17324987053871155
# -------- > epoch 3: taux moyen entraînement = 0.9512007236480713
# -------- > epoch 3: coût moyen validation = 0.1940794587135315
# -------- > epoch 3: taux moyen validation = 0.9422999620437622
# -------- > epoch 4: coût moyen entraînement = 0.16633792221546173
# -------- > epoch 4: taux moyen entraînement = 0.9521808624267578
# -------- > epoch 4: coût moyen validation = 0.18696247041225433
# -------- > epoch 4: taux moyen validation = 0.9455001354217529
# -------- > epoch 5: coût moyen entraînement = 0.16015923023223877
# -------- > epoch 5: taux moyen entraînement = 0.9544415473937988
# -------- > epoch 5: coût moyen validation = 0.18289504945278168
# -------- > epoch 5: taux moyen validation = 0.9464000463485718
# -------- > epoch 6: coût moyen entraînement = 0.15445275604724884
# -------- > epoch 6: taux moyen entraînement = 0.9563010334968567
# -------- > epoch 6: coût moyen validation = 0.1781187802553177
# -------- > epoch 6: taux moyen validation = 0.9479999542236328
# -------- > epoch 7: coût moyen entraînement = 0.14901690185070038
# -------- > epoch 7: taux moyen entraînement = 0.9580013751983643
# -------- > epoch 7: coût moyen validation = 0.1741930991411209
# -------- > epoch 7: taux moyen validation = 0.9487002491950989
# -------- > epoch 8: coût moyen entraînement = 0.14413388073444366
# -------- > epoch 8: taux moyen entraînement = 0.9587809443473816
# -------- > epoch 8: coût moyen validation = 0.1711660623550415
# -------- > epoch 8: taux moyen validation = 0.9492000341415405
# -------- > epoch 9: coût moyen entraînement = 0.1398908942937851
# -------- > epoch 9: taux moyen entraînement = 0.9610209465026855
# -------- > epoch 9: coût moyen validation = 0.16621623933315277
# -------- > epoch 9: taux moyen validation = 0.950900137424469
# -------- > epoch 10: coût moyen entraînement = 0.13536052405834198
# -------- > epoch 10: taux moyen entraînement = 0.9618807435035706
# -------- > epoch 10: coût moyen validation = 0.16492822766304016
# -------- > epoch 10: taux moyen validation = 0.9513003826141357
# Étape 3: réduire le taux d'apprentissage à 0.005 pour 10 epochs
# -------- > epoch 1: coût moyen entraînement = 0.12864434719085693
# -------- > epoch 1: taux moyen entraînement = 0.9639011025428772
# -------- > epoch 1: coût moyen validation = 0.1617937833070755
# -------- > epoch 1: taux moyen validation = 0.9523001909255981
# -------- > epoch 2: coût moyen entraînement = 0.12780703604221344
# -------- > epoch 2: taux moyen entraînement = 0.9642612934112549
# -------- > epoch 2: coût moyen validation = 0.1612662822008133
# -------- > epoch 2: taux moyen validation = 0.9525001049041748
# -------- > epoch 3: coût moyen entraînement = 0.12735465168952942
# -------- > epoch 3: taux moyen entraînement = 0.9643610715866089
# -------- > epoch 3: coût moyen validation = 0.16054457426071167
# -------- > epoch 3: taux moyen validation = 0.952400267124176
# -------- > epoch 4: coût moyen entraînement = 0.12696966528892517
# -------- > epoch 4: taux moyen entraînement = 0.964461088180542
# -------- > epoch 4: coût moyen validation = 0.16053137183189392
# -------- > epoch 4: taux moyen validation = 0.9523001313209534
# -------- > epoch 5: coût moyen entraînement = 0.1265312284231186
# -------- > epoch 5: taux moyen entraînement = 0.9647408723831177
# -------- > epoch 5: coût moyen validation = 0.1601802408695221
# -------- > epoch 5: taux moyen validation = 0.9528000354766846
# -------- > epoch 6: coût moyen entraînement = 0.1261432021856308
# -------- > epoch 6: taux moyen entraînement = 0.964460551738739
# -------- > epoch 6: coût moyen validation = 0.15946979820728302
# -------- > epoch 6: taux moyen validation = 0.9533001780509949
# -------- > epoch 7: coût moyen entraînement = 0.12575538456439972
# -------- > epoch 7: taux moyen entraînement = 0.965100884437561
# -------- > epoch 7: coût moyen validation = 0.15956464409828186
# -------- > epoch 7: taux moyen validation = 0.9530001282691956
# -------- > epoch 8: coût moyen entraînement = 0.12536196410655975
# -------- > epoch 8: taux moyen entraînement = 0.9649608135223389
# -------- > epoch 8: coût moyen validation = 0.15922269225120544
# -------- > epoch 8: taux moyen validation = 0.9524000287055969
# -------- > epoch 9: coût moyen entraînement = 0.12499574571847916
# -------- > epoch 9: taux moyen entraînement = 0.9651612639427185
# -------- > epoch 9: coût moyen validation = 0.15912139415740967
# -------- > epoch 9: taux moyen validation = 0.9528001546859741
# -------- > epoch 10: coût moyen entraînement = 0.12459760159254074
# -------- > epoch 10: taux moyen entraînement = 0.9651809334754944
# -------- > epoch 10: coût moyen validation = 0.15835699439048767
# -------- > epoch 10: taux moyen validation = 0.9537002444267273
# Étape 4: sauvegarder le modèle
# Étape 5: charger le modèle et poursuivre l'entraînement
# C:\Users\vango\AppData\Local\Temp\ipykernel_15852\1054235155.py:126: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   modele.load_state_dict(torch.load(CHEMIN))
# -------- > epoch 1: coût moyen entraînement = 0.12423381209373474
# -------- > epoch 1: taux moyen entraînement = 0.9653807878494263
# -------- > epoch 1: coût moyen validation = 0.15807238221168518
# -------- > epoch 1: taux moyen validation = 0.9537000060081482
# -------- > epoch 2: coût moyen entraînement = 0.12382793426513672
# -------- > epoch 2: taux moyen entraînement = 0.9656211137771606
# -------- > epoch 2: coût moyen validation = 0.15840572118759155
# -------- > epoch 2: taux moyen validation = 0.954200029373169
# -------- > epoch 3: coût moyen entraînement = 0.12351217120885849
# -------- > epoch 3: taux moyen entraînement = 0.9653609991073608
# -------- > epoch 3: coût moyen validation = 0.15778474509716034
# -------- > epoch 3: taux moyen validation = 0.9542002081871033
# -------- > epoch 4: coût moyen entraînement = 0.12307466566562653
# -------- > epoch 4: taux moyen entraînement = 0.9657608270645142
# -------- > epoch 4: coût moyen validation = 0.15786588191986084
# -------- > epoch 4: taux moyen validation = 0.9530001282691956
# -------- > epoch 5: coût moyen entraînement = 0.12281585484743118
# -------- > epoch 5: taux moyen entraînement = 0.9656806588172913
# -------- > epoch 5: coût moyen validation = 0.15731316804885864
# -------- > epoch 5: taux moyen validation = 0.9537001848220825
# -------- > epoch 6: coût moyen entraînement = 0.12238296866416931
# -------- > epoch 6: taux moyen entraînement = 0.9659808278083801
# -------- > epoch 6: coût moyen validation = 0.15665392577648163
# -------- > epoch 6: taux moyen validation = 0.9544000029563904
# -------- > epoch 7: coût moyen entraînement = 0.12207827717065811
# -------- > epoch 7: taux moyen entraînement = 0.9662611484527588
# -------- > epoch 7: coût moyen validation = 0.15674228966236115
# -------- > epoch 7: taux moyen validation = 0.9537999629974365
# -------- > epoch 8: coût moyen entraînement = 0.12169923633337021
# -------- > epoch 8: taux moyen entraînement = 0.9659814238548279
# -------- > epoch 8: coût moyen validation = 0.15639589726924896
# -------- > epoch 8: taux moyen validation = 0.9541999697685242
# -------- > epoch 9: coût moyen entraînement = 0.12130039185285568
# -------- > epoch 9: taux moyen entraînement = 0.9660611748695374
# -------- > epoch 9: coût moyen validation = 0.15658099949359894
# -------- > epoch 9: taux moyen validation = 0.9541001319885254
# -------- > epoch 10: coût moyen entraînement = 0.12103389948606491
# -------- > epoch 10: taux moyen entraînement = 0.9663212299346924
# -------- > epoch 10: coût moyen validation = 0.15668298304080963
# -------- > epoch 10: taux moyen validation = 0.9534998536109924
# Étape 6: métriques sur les données de test
# -------- > coût moyen test = 0.1455724835395813
# -------- > taux moyen test = 0.9574999213218689

# %%
# Chargement des données de test MNIST
import torchvision
ds_test = torchvision.datasets.MNIST(root='/tmp/mnist', train=False, download=True)
# Sous-ensemble pour exécution rapide
donnees_test_X = ds_test.data[:1000].reshape(1000, 784).float() / 255.0
donnees_test_Y = ds.targets[:1000]

# Création des objets DataLoader pour itérer par lot
from torch.utils.data import TensorDataset
from torch.utils.data import DataLoader
ds_test = TensorDataset(donnees_test_X, donnees_test_Y)
dl_test = DataLoader(ds_ent, batch_size=100)

with torch.no_grad():
    cout_test = sum(fonction_cout(modele(lot_test_X), lot_test_Y) for lot_test_X, lot_test_Y in dl_test)
    taux_bons_test = sum(taux_bonnes_predictions(modele(lot_test_X), lot_test_Y) for lot_test_X, lot_test_Y in dl_test)
cout_moyen_test = cout_test/len(dl_test)
taux_moyen_test = taux_bons_test/len(dl_test)
print(f'-------- > coût moyen test = {cout_moyen_test}')
print(f'-------- > taux moyen test = {taux_moyen_test}')
# Out:
# -------- > coût moyen test = 0.23818907141685486
# -------- > taux moyen test = 0.934400200843811
