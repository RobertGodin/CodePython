# %%
# %matplotlib inline
# -*- coding: utf-8 -*-
"""
Exemple simple de MNIST avec PyTorch
Exercice : normalisation par lot
"""
import torch
torch.manual_seed(0) # Pour résultats reproductibles

# Fonction J d'entropie croisée
import torch.nn.functional as F
fonction_cout = F.cross_entropy

def taux_bonnes_predictions(lot_Y_predictions, lot_Y):
    predictions_categorie = torch.argmax(lot_Y_predictions, dim=1)
    return (predictions_categorie == lot_Y).float().mean()

from torch import nn
# Définition de l'architecture du RNA

modele = nn.Sequential(
    nn.Conv2d(1,32,3),
    nn.BatchNorm2d(32),
    nn.ReLU(),
    nn.Conv2d(32,16,3),
    nn.BatchNorm2d(16),
    nn.ReLU(),
    nn.Flatten(),
    nn.Linear(24*24*16,10)
)
    
from torch import optim
optimiseur = optim.SGD(modele.parameters(), lr=0.01)

# Chargement des données de MNIST
import pickle, gzip
fichier_donnees = gzip.open(r"mnist.pkl.gz", 'rb')
((donnees_ent_X, donnees_ent_Y),(donnees_valid_X, donnees_valid_Y),(donnees_test_X,donnees_test_Y)) = pickle.load(fichier_donnees, encoding="latin-1")
fichier_donnees.close()

# Conversion des données en type toch.Tensor
import torch
donnees_ent_X,donnees_ent_Y,donnees_valid_X,donnees_valid_Y,donnees_test_X,donnees_test_Y  = map(torch.tensor,
    (donnees_ent_X.reshape((-1,1,28,28)),donnees_ent_Y,donnees_valid_X.reshape((-1,1,28,28)),donnees_valid_Y,donnees_test_X.reshape((-1,1,28,28)),donnees_test_Y))

# Création des objets DataLoader pour itérer par lot
from torch.utils.data import TensorDataset
from torch.utils.data import DataLoader
ds_ent = TensorDataset(donnees_ent_X, donnees_ent_Y)
dl_ent = DataLoader(ds_ent, batch_size=100, shuffle=True)
ds_valid = TensorDataset(donnees_valid_X,donnees_valid_Y)
dl_valid = DataLoader(ds_valid, batch_size=100)

def entrainer(modele, dl_ent, dl_valid, optimiseur, nb_epochs=10):

    # Listes pour les métriques par epoch
    liste_cout_moyen_ent = []
    liste_taux_moyen_ent = []
    liste_cout_moyen_valid = []
    liste_taux_moyen_valid = []
    
    # Boucle d'apprentissage
    for epoch in range(nb_epochs):
        cout_total_ent = 0 # pour cumuler les couts par mini-lot
        taux_bonnes_predictions_ent = 0 # pour cumuler les taux par mini-lot
        modele.train() # Pour certains types de couches (nn.BatchNorm2d, nn.Dropout, ...)
        
        # Boucle d'apprentissage par mini-lot pour une epoch
        for lot_X, lot_Y in dl_ent:
            optimiseur.zero_grad() # Remettre les dérivées à zéro
            lot_Y_predictions = modele(lot_X) # Appel de la méthode forward
            cout = fonction_cout(lot_Y_predictions, lot_Y)
            cout.backward() # Calcul des gradiants par rétropropagation
            with torch.no_grad():
                cout_total_ent +=cout
                taux_bonnes_predictions_ent += taux_bonnes_predictions(lot_Y_predictions, lot_Y)
            optimiseur.step() # Mise à jour des paramètres
        # Calculer les moyennes par mini-lot
        with torch.no_grad():
            cout_moyen_ent = cout_total_ent/len(dl_ent)
            taux_moyen_ent = taux_bonnes_predictions_ent/len(dl_ent)
       
        modele.eval() # Pour certains types de couches (nn.BatchNorm2d, nn.Dropout, ...)
        with torch.no_grad():
            cout_valid = sum(fonction_cout(modele(lot_valid_X), lot_valid_Y) for lot_valid_X, lot_valid_Y in dl_valid)
            taux_bons_valid = sum(taux_bonnes_predictions(modele(lot_valid_X), lot_valid_Y) for lot_valid_X, lot_valid_Y in dl_valid)
        cout_moyen_valid = cout_valid/len(dl_valid)
        taux_moyen_valid = taux_bons_valid/len(dl_valid)
        print(f'-------- > epoch {epoch+1}:  coût moyen entraînement = {cout_moyen_ent}')
        print(f'-------- > epoch {epoch+1}:  taux moyen entraînement = {taux_moyen_ent}')
        print(f'-------- > epoch {epoch+1}:  coût moyen validation = {cout_moyen_valid}')
        print(f'-------- > epoch {epoch+1}:  taux moyen validation = {taux_moyen_valid}')
    
        liste_cout_moyen_ent.append(cout_moyen_ent)
        liste_taux_moyen_ent.append(taux_moyen_ent)
        liste_cout_moyen_valid.append(cout_moyen_valid)
        liste_taux_moyen_valid.append(taux_moyen_valid)
    
    # Affichage du graphique d'évolution des métriques par epoch
    import numpy as np
    import matplotlib.pyplot as plt
    plt.plot(np.arange(0,nb_epochs),liste_cout_moyen_ent,label='Erreur entraînement')
    plt.plot(np.arange(0,nb_epochs),liste_cout_moyen_valid,label='Erreur validation')
    plt.title("Evolution du coût")
    plt.xlabel('epoch')
    plt.ylabel('moyenne par observation')
    plt.legend(loc='upper center')
    plt.show()
        
    plt.plot(np.arange(0,nb_epochs),liste_taux_moyen_ent,label='Taux bonnes réponses entraînement')
    plt.plot(np.arange(0,nb_epochs),liste_taux_moyen_valid,label='Taux bonnes réponses validation')
    plt.title("Evolution du taux")
    plt.xlabel('epoch')
    plt.ylabel('moyenne par observation')
    plt.legend(loc='upper center')
    plt.show()

entrainer(modele, dl_ent, dl_valid, optimiseur, nb_epochs=30)
# Out:
# -------- > epoch 1:  coût moyen entraînement = 0.20170998573303223
# -------- > epoch 1:  taux moyen entraînement = 0.9435405731201172
# -------- > epoch 1:  coût moyen validation = 0.09243996441364288
# -------- > epoch 1:  taux moyen validation = 0.9770001769065857
# -------- > epoch 2:  coût moyen entraînement = 0.07612450420856476
# -------- > epoch 2:  taux moyen entraînement = 0.9784002900123596
# -------- > epoch 2:  coût moyen validation = 0.07335655391216278
# -------- > epoch 2:  taux moyen validation = 0.9798001050949097
# -------- > epoch 3:  coût moyen entraînement = 0.057243261486291885
# -------- > epoch 3:  taux moyen entraînement = 0.9844801425933838
# -------- > epoch 3:  coût moyen validation = 0.0647982656955719
# -------- > epoch 3:  taux moyen validation = 0.9820000529289246
# -------- > epoch 4:  coût moyen entraînement = 0.047407105565071106
# -------- > epoch 4:  taux moyen entraînement = 0.986899733543396
# -------- > epoch 4:  coût moyen validation = 0.05649165064096451
# -------- > epoch 4:  taux moyen validation = 0.9845000505447388
# -------- > epoch 5:  coût moyen entraînement = 0.04120732843875885
# -------- > epoch 5:  taux moyen entraînement = 0.9886999726295471
# -------- > epoch 5:  coût moyen validation = 0.05474388971924782
# -------- > epoch 5:  taux moyen validation = 0.9830998778343201
# -------- > epoch 6:  coût moyen entraînement = 0.03639168292284012
# -------- > epoch 6:  taux moyen entraînement = 0.9902396202087402
# -------- > epoch 6:  coût moyen validation = 0.050705064088106155
# -------- > epoch 6:  taux moyen validation = 0.9853000044822693
# -------- > epoch 7:  coût moyen entraînement = 0.032184042036533356
# -------- > epoch 7:  taux moyen entraînement = 0.9913795590400696
# -------- > epoch 7:  coût moyen validation = 0.04998479038476944
# -------- > epoch 7:  taux moyen validation = 0.9850999712944031
# -------- > epoch 8:  coût moyen entraînement = 0.02902008406817913
# -------- > epoch 8:  taux moyen entraînement = 0.9925191402435303
# -------- > epoch 8:  coût moyen validation = 0.0543278306722641
# -------- > epoch 8:  taux moyen validation = 0.982900083065033
# -------- > epoch 9:  coût moyen entraînement = 0.02629483863711357
# -------- > epoch 9:  taux moyen entraînement = 0.9935193657875061
# -------- > epoch 9:  coût moyen validation = 0.04881865531206131
# -------- > epoch 9:  taux moyen validation = 0.9849998950958252
# -------- > epoch 10:  coût moyen entraînement = 0.023577095940709114
# -------- > epoch 10:  taux moyen entraînement = 0.9944393634796143
# -------- > epoch 10:  coût moyen validation = 0.04646946117281914
# -------- > epoch 10:  taux moyen validation = 0.9864998459815979
# -------- > epoch 11:  coût moyen entraînement = 0.021430708467960358
# -------- > epoch 11:  taux moyen entraînement = 0.9952395558357239
# -------- > epoch 11:  coût moyen validation = 0.05151677504181862
# -------- > epoch 11:  taux moyen validation = 0.9851999878883362
# -------- > epoch 12:  coût moyen entraînement = 0.019640954211354256
# -------- > epoch 12:  taux moyen entraînement = 0.9958792328834534
# -------- > epoch 12:  coût moyen validation = 0.04837571457028389
# -------- > epoch 12:  taux moyen validation = 0.9861999750137329
# -------- > epoch 13:  coût moyen entraînement = 0.018077079206705093
# -------- > epoch 13:  taux moyen entraînement = 0.9963794350624084
# -------- > epoch 13:  coût moyen validation = 0.04674326255917549
# -------- > epoch 13:  taux moyen validation = 0.9864998459815979
# -------- > epoch 14:  coût moyen entraînement = 0.016396598890423775
# -------- > epoch 14:  taux moyen entraînement = 0.9968795776367188
# -------- > epoch 14:  coût moyen validation = 0.04736602306365967
# -------- > epoch 14:  taux moyen validation = 0.9857996106147766
# -------- > epoch 15:  coût moyen entraînement = 0.015223356895148754
# -------- > epoch 15:  taux moyen entraînement = 0.9972192645072937
# -------- > epoch 15:  coût moyen validation = 0.047905996441841125
# -------- > epoch 15:  taux moyen validation = 0.9848999977111816
# -------- > epoch 16:  coût moyen entraînement = 0.013898626901209354
# -------- > epoch 16:  taux moyen entraînement = 0.9977592825889587
# -------- > epoch 16:  coût moyen validation = 0.04964020103216171
# -------- > epoch 16:  taux moyen validation = 0.9846998453140259
# -------- > epoch 17:  coût moyen entraînement = 0.012823169119656086
# -------- > epoch 17:  taux moyen entraînement = 0.9980195164680481
# -------- > epoch 17:  coût moyen validation = 0.04581914469599724
# -------- > epoch 17:  taux moyen validation = 0.9868997931480408
# -------- > epoch 18:  coût moyen entraînement = 0.01175694726407528
# -------- > epoch 18:  taux moyen entraînement = 0.9982993006706238
# -------- > epoch 18:  coût moyen validation = 0.04908193647861481
# -------- > epoch 18:  taux moyen validation = 0.9860000014305115
# -------- > epoch 19:  coût moyen entraînement = 0.010920369997620583
# -------- > epoch 19:  taux moyen entraînement = 0.9985597133636475
# -------- > epoch 19:  coût moyen validation = 0.04558883607387543
# -------- > epoch 19:  taux moyen validation = 0.9867997765541077
# -------- > epoch 20:  coût moyen entraînement = 0.01017938181757927
# -------- > epoch 20:  taux moyen entraînement = 0.9986997246742249
# -------- > epoch 20:  coût moyen validation = 0.046481285244226456
# -------- > epoch 20:  taux moyen validation = 0.9864998459815979
# -------- > epoch 21:  coût moyen entraînement = 0.009344441816210747
# -------- > epoch 21:  taux moyen entraînement = 0.9990997910499573
# -------- > epoch 21:  coût moyen validation = 0.04773043096065521
# -------- > epoch 21:  taux moyen validation = 0.9861998558044434
# -------- > epoch 22:  coût moyen entraînement = 0.008713309653103352
# -------- > epoch 22:  taux moyen entraînement = 0.9989796280860901
# -------- > epoch 22:  coût moyen validation = 0.04755629599094391
# -------- > epoch 22:  taux moyen validation = 0.9859998822212219
# -------- > epoch 23:  coût moyen entraînement = 0.00823588203638792
# -------- > epoch 23:  taux moyen entraînement = 0.9992595911026001
# -------- > epoch 23:  coût moyen validation = 0.04819171130657196
# -------- > epoch 23:  taux moyen validation = 0.9858998656272888
# -------- > epoch 24:  coût moyen entraînement = 0.007634887471795082
# -------- > epoch 24:  taux moyen entraînement = 0.9993998408317566
# -------- > epoch 24:  coût moyen validation = 0.0478874109685421
# -------- > epoch 24:  taux moyen validation = 0.9872998595237732
# -------- > epoch 25:  coût moyen entraînement = 0.007340030744671822
# -------- > epoch 25:  taux moyen entraînement = 0.9994598031044006
# -------- > epoch 25:  coût moyen validation = 0.04693136736750603
# -------- > epoch 25:  taux moyen validation = 0.9861997961997986
# -------- > epoch 26:  coût moyen entraînement = 0.00677138427272439
# -------- > epoch 26:  taux moyen entraînement = 0.9995597004890442
# -------- > epoch 26:  coût moyen validation = 0.04648523032665253
# -------- > epoch 26:  taux moyen validation = 0.9866997003555298
# -------- > epoch 27:  coût moyen entraînement = 0.0064423540607094765
# -------- > epoch 27:  taux moyen entraînement = 0.9995397925376892
# -------- > epoch 27:  coût moyen validation = 0.047955870628356934
# -------- > epoch 27:  taux moyen validation = 0.986599862575531
# -------- > epoch 28:  coût moyen entraînement = 0.006007730029523373
# -------- > epoch 28:  taux moyen entraînement = 0.9996598362922668
# -------- > epoch 28:  coût moyen validation = 0.04687736555933952
# -------- > epoch 28:  taux moyen validation = 0.9866997599601746
# -------- > epoch 29:  coût moyen entraînement = 0.0056837392039597034
# -------- > epoch 29:  taux moyen entraînement = 0.9997198581695557
# -------- > epoch 29:  coût moyen validation = 0.04719865322113037
# -------- > epoch 29:  taux moyen validation = 0.986599862575531
# -------- > epoch 30:  coût moyen entraînement = 0.005440878681838512
# -------- > epoch 30:  taux moyen entraînement = 0.9997599124908447
# -------- > epoch 30:  coût moyen validation = 0.04689270630478859
# -------- > epoch 30:  taux moyen validation = 0.986299991607666
