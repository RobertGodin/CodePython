# %%
# %matplotlib inline
# -*- coding: utf-8 -*-
"""
Exemple simple de MNIST avec PyTorch
Exemple avec nn.Conv2d et F.cross_entropy
Production de métriques avec graphes
Fonction entrainer
"""
import torch
torch.manual_seed(0) # Pour résultats reproductibles

# Fonction J d'entropie croisée
import torch.nn.functional as F
fonction_cout = F.cross_entropy

def taux_bonnes_predictions(lot_Y_predictions, lot_Y):
    predictions_categorie = torch.argmax(lot_Y_predictions, dim=1)
    return (predictions_categorie == lot_Y).float().mean()

from torch import nn
# Définition de l'architecture du RNA

modele = nn.Sequential(
    nn.Conv2d(1,64,3), # 1 canal, 16 filtres, dimension 3 par 3
    nn.ReLU(),
    nn.Flatten(),
    nn.Linear(26*26*64,10)
)
    
from torch import optim
optimiseur = optim.SGD(modele.parameters(), lr=0.01)

# Chargement des données de MNIST
import pickle, gzip
fichier_donnees = gzip.open(r"mnist.pkl.gz", 'rb')
((donnees_ent_X, donnees_ent_Y),(donnees_valid_X, donnees_valid_Y),(donnees_test_X,donnees_test_Y)) = pickle.load(fichier_donnees, encoding="latin-1")
fichier_donnees.close()

# Conversion des données en type toch.Tensor
import torch
donnees_ent_X,donnees_ent_Y,donnees_valid_X,donnees_valid_Y,donnees_test_X,donnees_test_Y  = map(torch.tensor,
    (donnees_ent_X.reshape((-1,1,28,28)),donnees_ent_Y,donnees_valid_X.reshape((-1,1,28,28)),donnees_valid_Y,donnees_test_X.reshape((-1,1,28,28)),donnees_test_Y))

# Création des objets DataLoader pour itérer par lot
from torch.utils.data import TensorDataset
from torch.utils.data import DataLoader
ds_ent = TensorDataset(donnees_ent_X, donnees_ent_Y)
dl_ent = DataLoader(ds_ent, batch_size=100, shuffle=True)
ds_valid = TensorDataset(donnees_valid_X,donnees_valid_Y)
dl_valid = DataLoader(ds_valid, batch_size=100)

def entrainer(modele, dl_ent, dl_valid, optimiseur, nb_epochs=10):

    # Listes pour les métriques par epoch
    liste_cout_moyen_ent = []
    liste_taux_moyen_ent = []
    liste_cout_moyen_valid = []
    liste_taux_moyen_valid = []
    
    # Boucle d'apprentissage
    for epoch in range(nb_epochs):
        cout_total_ent = 0 # pour cumuler les couts par mini-lot
        taux_bonnes_predictions_ent = 0 # pour cumuler les taux par mini-lot
        modele.train() # Pour certains types de couches (nn.BatchNorm2d, nn.Dropout, ...)
        
        # Boucle d'apprentissage par mini-lot pour une epoch
        for lot_X, lot_Y in dl_ent:
            optimiseur.zero_grad() # Remettre les dérivées à zéro
            lot_Y_predictions = modele(lot_X) # Appel de la méthode forward
            cout = fonction_cout(lot_Y_predictions, lot_Y)
            cout.backward() # Calcul des gradiants par rétropropagation
            with torch.no_grad():
                cout_total_ent +=cout
                taux_bonnes_predictions_ent += taux_bonnes_predictions(lot_Y_predictions, lot_Y)
            optimiseur.step() # Mise à jour des paramètres
        # Calculer les moyennes par mini-lot
        with torch.no_grad():
            cout_moyen_ent = cout_total_ent/len(dl_ent)
            taux_moyen_ent = taux_bonnes_predictions_ent/len(dl_ent)
       
        modele.eval() # Pour certains types de couches (nn.BatchNorm2d, nn.Dropout, ...)
        with torch.no_grad():
            cout_valid = sum(fonction_cout(modele(lot_valid_X), lot_valid_Y) for lot_valid_X, lot_valid_Y in dl_valid)
            taux_bons_valid = sum(taux_bonnes_predictions(modele(lot_valid_X), lot_valid_Y) for lot_valid_X, lot_valid_Y in dl_valid)
        cout_moyen_valid = cout_valid/len(dl_valid)
        taux_moyen_valid = taux_bons_valid/len(dl_valid)
        print(f'-------- > epoch {epoch+1}:  coût moyen entraînement = {cout_moyen_ent}')
        print(f'-------- > epoch {epoch+1}:  taux moyen entraînement = {taux_moyen_ent}')
        print(f'-------- > epoch {epoch+1}:  coût moyen validation = {cout_moyen_valid}')
        print(f'-------- > epoch {epoch+1}:  taux moyen validation = {taux_moyen_valid}')
    
        liste_cout_moyen_ent.append(cout_moyen_ent)
        liste_taux_moyen_ent.append(taux_moyen_ent)
        liste_cout_moyen_valid.append(cout_moyen_valid)
        liste_taux_moyen_valid.append(taux_moyen_valid)
    
    # Affichage du graphique d'évolution des métriques par epoch
    import numpy as np
    import matplotlib.pyplot as plt
    plt.plot(np.arange(0,nb_epochs),liste_cout_moyen_ent,label='Erreur entraînement')
    plt.plot(np.arange(0,nb_epochs),liste_cout_moyen_valid,label='Erreur validation')
    plt.title("Evolution du coût")
    plt.xlabel('epoch')
    plt.ylabel('moyenne par observation')
    plt.legend(loc='upper center')
    plt.show()
        
    plt.plot(np.arange(0,nb_epochs),liste_taux_moyen_ent,label='Taux bonnes réponses entraînement')
    plt.plot(np.arange(0,nb_epochs),liste_taux_moyen_valid,label='Taux bonnes réponses validation')
    plt.title("Evolution du taux")
    plt.xlabel('epoch')
    plt.ylabel('moyenne par observation')
    plt.legend(loc='upper center')
    plt.show()

entrainer(modele, dl_ent, dl_valid, optimiseur, nb_epochs=50)
# Out:
# -------- > epoch 1:  coût moyen entraînement = 0.5126889944076538
# -------- > epoch 1:  taux moyen entraînement = 0.8560811877250671
# -------- > epoch 1:  coût moyen validation = 0.31501221656799316
# -------- > epoch 1:  taux moyen validation = 0.9104000329971313
# -------- > epoch 2:  coût moyen entraînement = 0.3236028254032135
# -------- > epoch 2:  taux moyen entraînement = 0.9053812623023987
# -------- > epoch 2:  coût moyen validation = 0.2766697108745575
# -------- > epoch 2:  taux moyen validation = 0.9226000308990479
# -------- > epoch 3:  coût moyen entraînement = 0.2938293218612671
# -------- > epoch 3:  taux moyen entraînement = 0.9160614609718323
# -------- > epoch 3:  coût moyen validation = 0.2587597966194153
# -------- > epoch 3:  taux moyen validation = 0.9262999892234802
# -------- > epoch 4:  coût moyen entraînement = 0.27602890133857727
# -------- > epoch 4:  taux moyen entraînement = 0.9214412569999695
# -------- > epoch 4:  coût moyen validation = 0.2566496729850769
# -------- > epoch 4:  taux moyen validation = 0.9291999936103821
# -------- > epoch 5:  coût moyen entraînement = 0.26092013716697693
# -------- > epoch 5:  taux moyen entraînement = 0.9268409013748169
# -------- > epoch 5:  coût moyen validation = 0.23284555971622467
# -------- > epoch 5:  taux moyen validation = 0.9339001178741455
# -------- > epoch 6:  coût moyen entraînement = 0.248077854514122
# -------- > epoch 6:  taux moyen entraînement = 0.9302611351013184
# -------- > epoch 6:  coût moyen validation = 0.22915446758270264
# -------- > epoch 6:  taux moyen validation = 0.9365000128746033
# -------- > epoch 7:  coût moyen entraînement = 0.23503774404525757
# -------- > epoch 7:  taux moyen entraînement = 0.9338006377220154
# -------- > epoch 7:  coût moyen validation = 0.21650463342666626
# -------- > epoch 7:  taux moyen validation = 0.9403000473976135
# -------- > epoch 8:  coût moyen entraînement = 0.22266653180122375
# -------- > epoch 8:  taux moyen entraînement = 0.9375611543655396
# -------- > epoch 8:  coût moyen validation = 0.21213072538375854
# -------- > epoch 8:  taux moyen validation = 0.9408000111579895
# -------- > epoch 9:  coût moyen entraînement = 0.21107468008995056
# -------- > epoch 9:  taux moyen entraînement = 0.9409609436988831
# -------- > epoch 9:  coût moyen validation = 0.20354098081588745
# -------- > epoch 9:  taux moyen validation = 0.9446000456809998
# -------- > epoch 10:  coût moyen entraînement = 0.1998361200094223
# -------- > epoch 10:  taux moyen entraînement = 0.9437211751937866
# -------- > epoch 10:  coût moyen validation = 0.18909025192260742
# -------- > epoch 10:  taux moyen validation = 0.9493000507354736
# -------- > epoch 11:  coût moyen entraînement = 0.18942596018314362
# -------- > epoch 11:  taux moyen entraînement = 0.9480409622192383
# -------- > epoch 11:  coût moyen validation = 0.17546653747558594
# -------- > epoch 11:  taux moyen validation = 0.9531001448631287
# -------- > epoch 12:  coût moyen entraînement = 0.1795123666524887
# -------- > epoch 12:  taux moyen entraînement = 0.9494406580924988
# -------- > epoch 12:  coût moyen validation = 0.16943904757499695
# -------- > epoch 12:  taux moyen validation = 0.9548999667167664
# -------- > epoch 13:  coût moyen entraînement = 0.16967524588108063
# -------- > epoch 13:  taux moyen entraînement = 0.952860951423645
# -------- > epoch 13:  coût moyen validation = 0.16691426932811737
# -------- > epoch 13:  taux moyen validation = 0.9573001265525818
# -------- > epoch 14:  coût moyen entraînement = 0.16070294380187988
# -------- > epoch 14:  taux moyen entraînement = 0.9559808969497681
# -------- > epoch 14:  coût moyen validation = 0.15271389484405518
# -------- > epoch 14:  taux moyen validation = 0.9604001641273499
# -------- > epoch 15:  coût moyen entraînement = 0.1518784910440445
# -------- > epoch 15:  taux moyen entraînement = 0.9585205912590027
# -------- > epoch 15:  coût moyen validation = 0.14624013006687164
# -------- > epoch 15:  taux moyen validation = 0.9631001949310303
# -------- > epoch 16:  coût moyen entraînement = 0.1443917602300644
# -------- > epoch 16:  taux moyen entraînement = 0.9611608386039734
# -------- > epoch 16:  coût moyen validation = 0.14135754108428955
# -------- > epoch 16:  taux moyen validation = 0.9627001285552979
# -------- > epoch 17:  coût moyen entraînement = 0.13657036423683167
# -------- > epoch 17:  taux moyen entraînement = 0.9631606340408325
# -------- > epoch 17:  coût moyen validation = 0.1347643882036209
# -------- > epoch 17:  taux moyen validation = 0.9676001667976379
# -------- > epoch 18:  coût moyen entraînement = 0.13007499277591705
# -------- > epoch 18:  taux moyen entraînement = 0.9650810956954956
# -------- > epoch 18:  coût moyen validation = 0.12889742851257324
# -------- > epoch 18:  taux moyen validation = 0.9673999547958374
# -------- > epoch 19:  coût moyen entraînement = 0.12403610348701477
# -------- > epoch 19:  taux moyen entraînement = 0.9665212035179138
# -------- > epoch 19:  coût moyen validation = 0.12314460426568985
# -------- > epoch 19:  taux moyen validation = 0.9697999358177185
# -------- > epoch 20:  coût moyen entraînement = 0.11829417943954468
# -------- > epoch 20:  taux moyen entraînement = 0.9680609703063965
# -------- > epoch 20:  coût moyen validation = 0.12002325057983398
# -------- > epoch 20:  taux moyen validation = 0.9700000882148743
# -------- > epoch 21:  coût moyen entraînement = 0.11325480788946152
# -------- > epoch 21:  taux moyen entraînement = 0.9696813225746155
# -------- > epoch 21:  coût moyen validation = 0.11572928726673126
# -------- > epoch 21:  taux moyen validation = 0.9709998369216919
# -------- > epoch 22:  coût moyen entraînement = 0.10855600982904434
# -------- > epoch 22:  taux moyen entraînement = 0.9713809490203857
# -------- > epoch 22:  coût moyen validation = 0.11306437849998474
# -------- > epoch 22:  taux moyen validation = 0.9712001085281372
# -------- > epoch 23:  coût moyen entraînement = 0.10416117310523987
# -------- > epoch 23:  taux moyen entraînement = 0.9725809693336487
# -------- > epoch 23:  coût moyen validation = 0.11178550869226456
# -------- > epoch 23:  taux moyen validation = 0.9719000458717346
# -------- > epoch 24:  coût moyen entraînement = 0.09994520246982574
# -------- > epoch 24:  taux moyen entraînement = 0.9734404683113098
# -------- > epoch 24:  coût moyen validation = 0.10668982565402985
# -------- > epoch 24:  taux moyen validation = 0.9730000495910645
# -------- > epoch 25:  coût moyen entraînement = 0.09630047529935837
# -------- > epoch 25:  taux moyen entraînement = 0.9746808409690857
# -------- > epoch 25:  coût moyen validation = 0.10230346769094467
# -------- > epoch 25:  taux moyen validation = 0.9742001295089722
# -------- > epoch 26:  coût moyen entraînement = 0.0924343392252922
# -------- > epoch 26:  taux moyen entraînement = 0.9767605662345886
# -------- > epoch 26:  coût moyen validation = 0.10480191558599472
# -------- > epoch 26:  taux moyen validation = 0.9729998707771301
# -------- > epoch 27:  coût moyen entraînement = 0.08957454562187195
# -------- > epoch 27:  taux moyen entraînement = 0.9767602682113647
# -------- > epoch 27:  coût moyen validation = 0.09829153120517731
# -------- > epoch 27:  taux moyen validation = 0.9753997921943665
# -------- > epoch 28:  coût moyen entraînement = 0.08687502145767212
# -------- > epoch 28:  taux moyen entraînement = 0.9773003458976746
# -------- > epoch 28:  coût moyen validation = 0.09607000648975372
# -------- > epoch 28:  taux moyen validation = 0.9757000207901001
# -------- > epoch 29:  coût moyen entraînement = 0.08410672843456268
# -------- > epoch 29:  taux moyen entraînement = 0.9780606627464294
# -------- > epoch 29:  coût moyen validation = 0.09509992599487305
# -------- > epoch 29:  taux moyen validation = 0.9755001068115234
# -------- > epoch 30:  coût moyen entraînement = 0.08154772222042084
# -------- > epoch 30:  taux moyen entraînement = 0.9789401888847351
# -------- > epoch 30:  coût moyen validation = 0.09385088086128235
# -------- > epoch 30:  taux moyen validation = 0.9763001203536987
# -------- > epoch 31:  coût moyen entraînement = 0.07910294085741043
# -------- > epoch 31:  taux moyen entraînement = 0.9794402122497559
# -------- > epoch 31:  coût moyen validation = 0.09210709482431412
# -------- > epoch 31:  taux moyen validation = 0.9760999083518982
# -------- > epoch 32:  coût moyen entraînement = 0.07679644227027893
# -------- > epoch 32:  taux moyen entraînement = 0.9801400899887085
# -------- > epoch 32:  coût moyen validation = 0.0893898457288742
# -------- > epoch 32:  taux moyen validation = 0.9780998826026917
# -------- > epoch 33:  coût moyen entraînement = 0.07458723336458206
# -------- > epoch 33:  taux moyen entraînement = 0.9804603457450867
# -------- > epoch 33:  coût moyen validation = 0.08879619836807251
# -------- > epoch 33:  taux moyen validation = 0.9766001105308533
# -------- > epoch 34:  coût moyen entraînement = 0.07290558516979218
# -------- > epoch 34:  taux moyen entraînement = 0.9808207154273987
# -------- > epoch 34:  coût moyen validation = 0.08652500808238983
# -------- > epoch 34:  taux moyen validation = 0.9778000712394714
# -------- > epoch 35:  coût moyen entraînement = 0.07064405083656311
# -------- > epoch 35:  taux moyen entraînement = 0.9817003607749939
# -------- > epoch 35:  coût moyen validation = 0.08607380092144012
# -------- > epoch 35:  taux moyen validation = 0.9780001044273376
# -------- > epoch 36:  coût moyen entraînement = 0.06909427046775818
# -------- > epoch 36:  taux moyen entraînement = 0.9819800853729248
# -------- > epoch 36:  coût moyen validation = 0.08428358286619186
# -------- > epoch 36:  taux moyen validation = 0.9782000780105591
# -------- > epoch 37:  coût moyen entraînement = 0.06738527864217758
# -------- > epoch 37:  taux moyen entraînement = 0.9828999042510986
# -------- > epoch 37:  coût moyen validation = 0.08484445512294769
# -------- > epoch 37:  taux moyen validation = 0.9778000712394714
# -------- > epoch 38:  coût moyen entraînement = 0.06582903116941452
# -------- > epoch 38:  taux moyen entraînement = 0.9831200838088989
# -------- > epoch 38:  coût moyen validation = 0.0840541422367096
# -------- > epoch 38:  taux moyen validation = 0.9786000847816467
# -------- > epoch 39:  coût moyen entraînement = 0.06447626650333405
# -------- > epoch 39:  taux moyen entraînement = 0.9831006526947021
# -------- > epoch 39:  coût moyen validation = 0.08180436491966248
# -------- > epoch 39:  taux moyen validation = 0.9783000349998474
# -------- > epoch 40:  coût moyen entraînement = 0.0629316195845604
# -------- > epoch 40:  taux moyen entraînement = 0.9838398098945618
# -------- > epoch 40:  coût moyen validation = 0.08038990944623947
# -------- > epoch 40:  taux moyen validation = 0.9787001013755798
# -------- > epoch 41:  coût moyen entraînement = 0.06177614629268646
# -------- > epoch 41:  taux moyen entraînement = 0.9840401411056519
# -------- > epoch 41:  coût moyen validation = 0.0794127956032753
# -------- > epoch 41:  taux moyen validation = 0.9794000387191772
# -------- > epoch 42:  coût moyen entraînement = 0.06026941537857056
# -------- > epoch 42:  taux moyen entraînement = 0.9844802021980286
# -------- > epoch 42:  coût moyen validation = 0.07935187220573425
# -------- > epoch 42:  taux moyen validation = 0.9800000786781311
# -------- > epoch 43:  coût moyen entraînement = 0.058943215757608414
# -------- > epoch 43:  taux moyen entraînement = 0.9844201803207397
# -------- > epoch 43:  coût moyen validation = 0.07841049879789352
# -------- > epoch 43:  taux moyen validation = 0.978600025177002
# -------- > epoch 44:  coût moyen entraînement = 0.05792280659079552
# -------- > epoch 44:  taux moyen entraînement = 0.9853200316429138
# -------- > epoch 44:  coût moyen validation = 0.0785999596118927
# -------- > epoch 44:  taux moyen validation = 0.9795001745223999
# -------- > epoch 45:  coût moyen entraînement = 0.05670881271362305
# -------- > epoch 45:  taux moyen entraînement = 0.9851601123809814
# -------- > epoch 45:  coût moyen validation = 0.07641492038965225
# -------- > epoch 45:  taux moyen validation = 0.9800000786781311
# -------- > epoch 46:  coût moyen entraînement = 0.055736396461725235
# -------- > epoch 46:  taux moyen entraînement = 0.9859997034072876
# -------- > epoch 46:  coût moyen validation = 0.07648611813783646
# -------- > epoch 46:  taux moyen validation = 0.979900062084198
# -------- > epoch 47:  coût moyen entraînement = 0.05471291393041611
# -------- > epoch 47:  taux moyen entraînement = 0.9862598776817322
# -------- > epoch 47:  coût moyen validation = 0.07602057605981827
# -------- > epoch 47:  taux moyen validation = 0.980400025844574
# -------- > epoch 48:  coût moyen entraînement = 0.05352003872394562
# -------- > epoch 48:  taux moyen entraînement = 0.9864999055862427
# -------- > epoch 48:  coût moyen validation = 0.07503243535757065
# -------- > epoch 48:  taux moyen validation = 0.9799001216888428
# -------- > epoch 49:  coût moyen entraînement = 0.05271563306450844
# -------- > epoch 49:  taux moyen entraînement = 0.9869399070739746
# -------- > epoch 49:  coût moyen validation = 0.07724536955356598
# -------- > epoch 49:  taux moyen validation = 0.9792001247406006
# -------- > epoch 50:  coût moyen entraînement = 0.051783669739961624
# -------- > epoch 50:  taux moyen entraînement = 0.9870798587799072
# -------- > epoch 50:  coût moyen validation = 0.07410406321287155
# -------- > epoch 50:  taux moyen validation = 0.9805001020431519
