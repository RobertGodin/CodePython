# %%
# %matplotlib inline
# -*- coding: utf-8 -*-
"""
Exemple de MNIST avec PyTorch
Exemple avec connexion distante (BlocResSimple)
"""
import torch
torch.manual_seed(0) # Pour résultats reproductibles

# Fonction J d'entropie croisée
import torch.nn.functional as F
fonction_cout = F.cross_entropy

def taux_bonnes_predictions(lot_Y_predictions, lot_Y):
    predictions_categorie = torch.argmax(lot_Y_predictions, dim=1)
    return (predictions_categorie == lot_Y).float().mean()

from torch import nn
# Définition de l'architecture du RNA

class BlocResSimple(nn.Module):
    def __init__(self, nb_f):
        super().__init__()
        self.convolution = nn.Conv2d(nb_f, nb_f, kernel_size=3, stride=1, padding=1) 
        self.normalisation = nn.BatchNorm2d(nb_f)    

    def forward(self, lot_X):
        lot_Y_predictions = self.convolution(lot_X)
        lot_Y_predictions = self.normalisation(lot_Y_predictions)
        lot_Y_predictions = F.relu(lot_Y_predictions)
        return lot_Y_predictions+lot_X
    
class BlocResNetSimple(nn.Module):
    def __init__(self, nb_f):
        super().__init__()

        self.conv1 = nn.Conv2d(nb_f, nb_f, kernel_size=3, stride=1, padding=1, bias=False) 
        self.bn1 = nn.BatchNorm2d(nb_f)    
        self.relu = nn.ReLU(inplace=True)
        self.conv2 = nn.Conv2d(nb_f, nb_f, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(nb_f)    

    def forward(self, lot_X):
        lot_Y_predictions = self.conv1(lot_X)
        lot_Y_predictions = self.bn1(lot_Y_predictions)
        lot_Y_predictions = self.relu(lot_Y_predictions)
        lot_Y_predictions = self.conv2(lot_Y_predictions)
        lot_Y_predictions = self.bn2(lot_Y_predictions)
        lot_Y_predictions = lot_Y_predictions + lot_X
        lot_Y_predictions = self.relu(lot_Y_predictions)
        return lot_Y_predictions 

modele = nn.Sequential(
    nn.Conv2d(1,8,3,2,1),
    nn.BatchNorm2d(8),
    nn.ReLU(),
    BlocResNetSimple(8),
    nn.Conv2d(8,16,3,2,1),
    nn.BatchNorm2d(16),
    nn.ReLU(),    
    nn.Conv2d(16,10,3,2,1),
    nn.BatchNorm2d(10),
    nn.ReLU(),
    nn.Flatten()
)

from torch import optim
optimiseur = optim.SGD(modele.parameters(), lr=0.01)

# Chargement des données de MNIST
import pickle, gzip
fichier_donnees = gzip.open(r"mnist.pkl.gz", 'rb')
((donnees_ent_X, donnees_ent_Y),(donnees_valid_X, donnees_valid_Y),(donnees_test_X,donnees_test_Y)) = pickle.load(fichier_donnees, encoding="latin-1")
fichier_donnees.close()

# Conversion des données en type toch.Tensor
import torch
donnees_ent_X,donnees_ent_Y,donnees_valid_X,donnees_valid_Y,donnees_test_X,donnees_test_Y  = map(torch.tensor,
    (donnees_ent_X.reshape((-1,1,28,28)),donnees_ent_Y,donnees_valid_X.reshape((-1,1,28,28)),donnees_valid_Y,donnees_test_X.reshape((-1,1,28,28)),donnees_test_Y))

# Création des objets DataLoader pour itérer par lot
from torch.utils.data import TensorDataset
from torch.utils.data import DataLoader
ds_ent = TensorDataset(donnees_ent_X, donnees_ent_Y)
dl_ent = DataLoader(ds_ent, batch_size=100, shuffle=True)
ds_valid = TensorDataset(donnees_valid_X,donnees_valid_Y)
dl_valid = DataLoader(ds_valid, batch_size=100)

def entrainer(modele, dl_ent, dl_valid, optimiseur, nb_epochs=10):

    # Listes pour les métriques par epoch
    liste_cout_moyen_ent = []
    liste_taux_moyen_ent = []
    liste_cout_moyen_valid = []
    liste_taux_moyen_valid = []
    
    # Boucle d'apprentissage
    for epoch in range(nb_epochs):
        cout_total_ent = 0 # pour cumuler les couts par mini-lot
        taux_bonnes_predictions_ent = 0 # pour cumuler les taux par mini-lot
        modele.train() # Pour certains types de couches (nn.BatchNorm2d, nn.Dropout, ...)
        
        # Boucle d'apprentissage par mini-lot pour une epoch
        for lot_X, lot_Y in dl_ent:
            optimiseur.zero_grad() # Remettre les dérivées à zéro
            lot_Y_predictions = modele(lot_X) # Appel de la méthode forward
            cout = fonction_cout(lot_Y_predictions, lot_Y)
            cout.backward() # Calcul des gradiants par rétropropagation
            with torch.no_grad():
                cout_total_ent +=cout
                taux_bonnes_predictions_ent += taux_bonnes_predictions(lot_Y_predictions, lot_Y)
            optimiseur.step() # Mise à jour des paramètres
            # scheduler.step()
        # Calculer les moyennes par mini-lot
        with torch.no_grad():
            cout_moyen_ent = cout_total_ent/len(dl_ent)
            taux_moyen_ent = taux_bonnes_predictions_ent/len(dl_ent)
       
        modele.eval() # Pour certains types de couches (nn.BatchNorm2d, nn.Dropout, ...)
        with torch.no_grad():
            cout_valid = sum(fonction_cout(modele(lot_valid_X), lot_valid_Y) for lot_valid_X, lot_valid_Y in dl_valid)
            taux_bons_valid = sum(taux_bonnes_predictions(modele(lot_valid_X), lot_valid_Y) for lot_valid_X, lot_valid_Y in dl_valid)
        cout_moyen_valid = cout_valid/len(dl_valid)
        taux_moyen_valid = taux_bons_valid/len(dl_valid)
        print(f'-------- > epoch {epoch+1}:  coût moyen entraînement = {cout_moyen_ent}')
        print(f'-------- > epoch {epoch+1}:  taux moyen entraînement = {taux_moyen_ent}')
        print(f'-------- > epoch {epoch+1}:  coût moyen validation = {cout_moyen_valid}')
        print(f'-------- > epoch {epoch+1}:  taux moyen validation = {taux_moyen_valid}')
    
        liste_cout_moyen_ent.append(cout_moyen_ent)
        liste_taux_moyen_ent.append(taux_moyen_ent)
        liste_cout_moyen_valid.append(cout_moyen_valid)
        liste_taux_moyen_valid.append(taux_moyen_valid)
    
    # Affichage du graphique d'évolution des métriques par epoch
    import numpy as np
    import matplotlib.pyplot as plt
    plt.plot(np.arange(0,nb_epochs),liste_cout_moyen_ent,label='Erreur entraînement')
    plt.plot(np.arange(0,nb_epochs),liste_cout_moyen_valid,label='Erreur validation')
    plt.title("Evolution du coût")
    plt.xlabel('epoch')
    plt.ylabel('moyenne par observation')
    plt.legend(loc='upper center')
    plt.show()
        
    plt.plot(np.arange(0,nb_epochs),liste_taux_moyen_ent,label='Taux bonnes réponses entraînement')
    plt.plot(np.arange(0,nb_epochs),liste_taux_moyen_valid,label='Taux bonnes réponses validation')
    plt.title("Evolution du taux")
    plt.xlabel('epoch')
    plt.ylabel('moyenne par observation')
    plt.legend(loc='center')
    plt.show()

entrainer(modele, dl_ent, dl_valid, optimiseur, nb_epochs=30)
# Out:
# -------- > epoch 1:  coût moyen entraînement = 1.8746590614318848
# -------- > epoch 1:  taux moyen entraînement = 0.5752402544021606
# -------- > epoch 1:  coût moyen validation = 0.8920944333076477
# -------- > epoch 1:  taux moyen validation = 0.7514999508857727
# -------- > epoch 2:  coût moyen entraînement = 0.7761270999908447
# -------- > epoch 2:  taux moyen entraînement = 0.7789996266365051
# -------- > epoch 2:  coût moyen validation = 0.6283724308013916
# -------- > epoch 2:  taux moyen validation = 0.8228999972343445
# -------- > epoch 3:  coût moyen entraînement = 0.6218910813331604
# -------- > epoch 3:  taux moyen entraînement = 0.8191596269607544
# -------- > epoch 3:  coût moyen validation = 0.5329985022544861
# -------- > epoch 3:  taux moyen validation = 0.8438999652862549
# -------- > epoch 4:  coût moyen entraînement = 0.5494101643562317
# -------- > epoch 4:  taux moyen entraînement = 0.8365991115570068
# -------- > epoch 4:  coût moyen validation = 0.4768381118774414
# -------- > epoch 4:  taux moyen validation = 0.8555998206138611
# -------- > epoch 5:  coût moyen entraînement = 0.500585675239563
# -------- > epoch 5:  taux moyen entraînement = 0.8488597273826599
# -------- > epoch 5:  coût moyen validation = 0.5554226636886597
# -------- > epoch 5:  taux moyen validation = 0.8205001354217529
# -------- > epoch 6:  coût moyen entraînement = 0.4670071005821228
# -------- > epoch 6:  taux moyen entraînement = 0.8574795126914978
# -------- > epoch 6:  coût moyen validation = 0.4538079798221588
# -------- > epoch 6:  taux moyen validation = 0.8593000769615173
# -------- > epoch 7:  coût moyen entraînement = 0.4414657652378082
# -------- > epoch 7:  taux moyen entraînement = 0.8645598292350769
# -------- > epoch 7:  coût moyen validation = 0.4130747318267822
# -------- > epoch 7:  taux moyen validation = 0.8773999810218811
# -------- > epoch 8:  coût moyen entraînement = 0.42184585332870483
# -------- > epoch 8:  taux moyen entraînement = 0.869159996509552
# -------- > epoch 8:  coût moyen validation = 0.389268696308136
# -------- > epoch 8:  taux moyen validation = 0.8804000020027161
# -------- > epoch 9:  coût moyen entraînement = 0.40774744749069214
# -------- > epoch 9:  taux moyen entraînement = 0.873420000076294
# -------- > epoch 9:  coût moyen validation = 0.38532355427742004
# -------- > epoch 9:  taux moyen validation = 0.8803999423980713
# -------- > epoch 10:  coût moyen entraînement = 0.3949276804924011
# -------- > epoch 10:  taux moyen entraînement = 0.8768402934074402
# -------- > epoch 10:  coût moyen validation = 0.3772120773792267
# -------- > epoch 10:  taux moyen validation = 0.8832002282142639
# -------- > epoch 11:  coût moyen entraînement = 0.38672247529029846
# -------- > epoch 11:  taux moyen entraînement = 0.8794599771499634
# -------- > epoch 11:  coût moyen validation = 0.38011786341667175
# -------- > epoch 11:  taux moyen validation = 0.8845002055168152
# -------- > epoch 12:  coût moyen entraînement = 0.37301310896873474
# -------- > epoch 12:  taux moyen entraînement = 0.882640540599823
# -------- > epoch 12:  coût moyen validation = 0.3652207553386688
# -------- > epoch 12:  taux moyen validation = 0.8860999941825867
# -------- > epoch 13:  coût moyen entraînement = 0.36670902371406555
# -------- > epoch 13:  taux moyen entraînement = 0.8848202228546143
# -------- > epoch 13:  coût moyen validation = 0.35881882905960083
# -------- > epoch 13:  taux moyen validation = 0.889799952507019
# -------- > epoch 14:  coût moyen entraînement = 0.3607707917690277
# -------- > epoch 14:  taux moyen entraînement = 0.8863604068756104
# -------- > epoch 14:  coût moyen validation = 0.3511464297771454
# -------- > epoch 14:  taux moyen validation = 0.8915001153945923
# -------- > epoch 15:  coût moyen entraînement = 0.35548022389411926
# -------- > epoch 15:  taux moyen entraînement = 0.8881405591964722
# -------- > epoch 15:  coût moyen validation = 0.34825900197029114
# -------- > epoch 15:  taux moyen validation = 0.8942002058029175
# -------- > epoch 16:  coût moyen entraînement = 0.34957024455070496
# -------- > epoch 16:  taux moyen entraînement = 0.8882004618644714
# -------- > epoch 16:  coût moyen validation = 0.34896260499954224
# -------- > epoch 16:  taux moyen validation = 0.8921999335289001
# -------- > epoch 17:  coût moyen entraînement = 0.34305453300476074
# -------- > epoch 17:  taux moyen entraînement = 0.8912004828453064
# -------- > epoch 17:  coût moyen validation = 0.3315979838371277
# -------- > epoch 17:  taux moyen validation = 0.8972998857498169
# -------- > epoch 18:  coût moyen entraînement = 0.3395593464374542
# -------- > epoch 18:  taux moyen entraînement = 0.8923407793045044
# -------- > epoch 18:  coût moyen validation = 0.3465096652507782
# -------- > epoch 18:  taux moyen validation = 0.8938001394271851
# -------- > epoch 19:  coût moyen entraînement = 0.33404579758644104
# -------- > epoch 19:  taux moyen entraînement = 0.893620491027832
# -------- > epoch 19:  coût moyen validation = 0.34159350395202637
# -------- > epoch 19:  taux moyen validation = 0.893799901008606
# -------- > epoch 20:  coût moyen entraînement = 0.3294063210487366
# -------- > epoch 20:  taux moyen entraînement = 0.8954007029533386
# -------- > epoch 20:  coût moyen validation = 0.3441082239151001
# -------- > epoch 20:  taux moyen validation = 0.8933999538421631
# -------- > epoch 21:  coût moyen entraînement = 0.32708001136779785
# -------- > epoch 21:  taux moyen entraînement = 0.8959807753562927
# -------- > epoch 21:  coût moyen validation = 0.32936516404151917
# -------- > epoch 21:  taux moyen validation = 0.902199923992157
# -------- > epoch 22:  coût moyen entraînement = 0.3228929936885834
# -------- > epoch 22:  taux moyen entraînement = 0.8971407413482666
# -------- > epoch 22:  coût moyen validation = 0.32438045740127563
# -------- > epoch 22:  taux moyen validation = 0.9003999829292297
# -------- > epoch 23:  coût moyen entraînement = 0.3181345760822296
# -------- > epoch 23:  taux moyen entraînement = 0.8977406024932861
# -------- > epoch 23:  coût moyen validation = 0.3273164629936218
# -------- > epoch 23:  taux moyen validation = 0.9016998410224915
# -------- > epoch 24:  coût moyen entraînement = 0.3159741759300232
# -------- > epoch 24:  taux moyen entraînement = 0.9002206921577454
# -------- > epoch 24:  coût moyen validation = 0.327971875667572
# -------- > epoch 24:  taux moyen validation = 0.9004001617431641
# -------- > epoch 25:  coût moyen entraînement = 0.31252560019493103
# -------- > epoch 25:  taux moyen entraînement = 0.9022608995437622
# -------- > epoch 25:  coût moyen validation = 0.3149482011795044
# -------- > epoch 25:  taux moyen validation = 0.9056999087333679
# -------- > epoch 26:  coût moyen entraînement = 0.3093350827693939
# -------- > epoch 26:  taux moyen entraînement = 0.9008011817932129
# -------- > epoch 26:  coût moyen validation = 0.3115088641643524
# -------- > epoch 26:  taux moyen validation = 0.9042001366615295
# -------- > epoch 27:  coût moyen entraînement = 0.30919745564460754
# -------- > epoch 27:  taux moyen entraînement = 0.9007009267807007
# -------- > epoch 27:  coût moyen validation = 0.3186308741569519
# -------- > epoch 27:  taux moyen validation = 0.9054000377655029
# -------- > epoch 28:  coût moyen entraînement = 0.306342214345932
# -------- > epoch 28:  taux moyen entraînement = 0.9026212692260742
# -------- > epoch 28:  coût moyen validation = 0.32365891337394714
# -------- > epoch 28:  taux moyen validation = 0.8997999429702759
# -------- > epoch 29:  coût moyen entraînement = 0.30335864424705505
# -------- > epoch 29:  taux moyen entraînement = 0.9020807147026062
# -------- > epoch 29:  coût moyen validation = 0.31873658299446106
# -------- > epoch 29:  taux moyen validation = 0.9013999700546265
# -------- > epoch 30:  coût moyen entraînement = 0.300620436668396
# -------- > epoch 30:  taux moyen entraînement = 0.9036010503768921
# -------- > epoch 30:  coût moyen validation = 0.31694284081459045
# -------- > epoch 30:  taux moyen validation = 0.9035999774932861
