# %%
# %matplotlib inline
# -*- coding: utf-8 -*-
"""
Exercice: FashionMNIST avec PyTorch
Exemple avec nn.Sequential et F.cross_entropy
Production de métriques avec graphes
Fonction entrainer
"""
import torch
torch.manual_seed(0) # Pour résultats reproductibles

# Fonction J d'entropie croisée
import torch.nn.functional as F
fonction_cout = F.cross_entropy

def taux_bonnes_predictions(lot_Y_predictions, lot_Y):
    predictions_categorie = torch.argmax(lot_Y_predictions, dim=1)
    return (predictions_categorie == lot_Y).float().mean()

from torch import nn
# Définition de l'architecture du RNA

modele = nn.Sequential(
    nn.Conv2d(1,32,3),
    nn.ReLU(),
    nn.Conv2d(32,16,3),
    nn.ReLU(),
    nn.Flatten(),
    nn.Linear(24*24*16, 10)
)
    
from torch import optim
optimiseur = optim.SGD(modele.parameters(), lr=0.05)

import torchvision
import torchvision.transforms as transforms

#Chargement des données
ds = torchvision.datasets.FashionMNIST(root = "./data", train = True, download = True, transform = transforms.ToTensor())
ds_ent, ds_valid = torch.utils.data.random_split(ds, [50000, 10000])
ds_test = torchvision.datasets.FashionMNIST(root = "./data", train = False, download = True, transform = transforms.ToTensor())

#Création du DataLoader avec le dataset
dl_ent = torch.utils.data.DataLoader(ds_ent, batch_size=100, shuffle = True)
dl_valid = torch.utils.data.DataLoader(ds_valid, batch_size=100)

def entrainer(modele, dl_ent, dl_valid, optimiseur, nb_epochs=10):

    # Listes pour les métriques par epoch
    liste_cout_moyen_ent = []
    liste_taux_moyen_ent = []
    liste_cout_moyen_valid = []
    liste_taux_moyen_valid = []
    
    # Boucle d'apprentissage
    for epoch in range(nb_epochs):
        cout_total_ent = 0 # pour cumuler les couts par mini-lot
        taux_bonnes_predictions_ent = 0 # pour cumuler les taux par mini-lot
        modele.train() # Pour certains types de couches (nn.BatchNorm2d, nn.Dropout, ...)
        
        # Boucle d'apprentissage par mini-lot pour une epoch
        for lot_X, lot_Y in dl_ent:
            optimiseur.zero_grad() # Remettre les dérivées à zéro
            lot_Y_predictions = modele(lot_X) # Appel de la méthode forward
            cout = fonction_cout(lot_Y_predictions, lot_Y)
            cout.backward() # Calcul des gradiants par rétropropagation
            with torch.no_grad():
                cout_total_ent +=cout
                taux_bonnes_predictions_ent += taux_bonnes_predictions(lot_Y_predictions, lot_Y)
            optimiseur.step() # Mise à jour des paramètres
        # Calculer les moyennes par mini-lot
        with torch.no_grad():
            cout_moyen_ent = cout_total_ent/len(dl_ent)
            taux_moyen_ent = taux_bonnes_predictions_ent/len(dl_ent)
       
        modele.eval() # Pour certains types de couches (nn.BatchNorm2d, nn.Dropout, ...)
        with torch.no_grad():
            cout_valid = sum(fonction_cout(modele(lot_valid_X), lot_valid_Y) for lot_valid_X, lot_valid_Y in dl_valid)
            taux_bons_valid = sum(taux_bonnes_predictions(modele(lot_valid_X), lot_valid_Y) for lot_valid_X, lot_valid_Y in dl_valid)
        cout_moyen_valid = cout_valid/len(dl_valid)
        taux_moyen_valid = taux_bons_valid/len(dl_valid)
        print(f'-------- > epoch {epoch+1}:  coût moyen entraînement = {cout_moyen_ent}')
        print(f'-------- > epoch {epoch+1}:  taux moyen entraînement = {taux_moyen_ent}')
        print(f'-------- > epoch {epoch+1}:  coût moyen validation = {cout_moyen_valid}')
        print(f'-------- > epoch {epoch+1}:  taux moyen validation = {taux_moyen_valid}')
    
        liste_cout_moyen_ent.append(cout_moyen_ent)
        liste_taux_moyen_ent.append(taux_moyen_ent)
        liste_cout_moyen_valid.append(cout_moyen_valid)
        liste_taux_moyen_valid.append(taux_moyen_valid)
    
    # Affichage du graphique d'évolution des métriques par epoch
    import numpy as np
    import matplotlib.pyplot as plt
    plt.plot(np.arange(0,nb_epochs),liste_cout_moyen_ent,label='Erreur entraînement')
    plt.plot(np.arange(0,nb_epochs),liste_cout_moyen_valid,label='Erreur validation')
    plt.title("Evolution du coût")
    plt.xlabel('epoch')
    plt.ylabel('moyenne par observation')
    plt.legend(loc='upper center')
    plt.show()
        
    plt.plot(np.arange(0,nb_epochs),liste_taux_moyen_ent,label='Taux bonnes réponses entraînement')
    plt.plot(np.arange(0,nb_epochs),liste_taux_moyen_valid,label='Taux bonnes réponses validation')
    plt.title("Evolution du taux")
    plt.xlabel('epoch')
    plt.ylabel('moyenne par observation')
    plt.legend(loc='lower center')
    plt.show()

entrainer(modele, dl_ent, dl_valid, optimiseur, nb_epochs=30)
# Out:
# -------- > epoch 1:  coût moyen entraînement = 0.6546251177787781
# -------- > epoch 1:  taux moyen entraînement = 0.7698794007301331
# -------- > epoch 1:  coût moyen validation = 0.4773857593536377
# -------- > epoch 1:  taux moyen validation = 0.8297001719474792
# -------- > epoch 2:  coût moyen entraînement = 0.4148024320602417
# -------- > epoch 2:  taux moyen entraînement = 0.8533400893211365
# -------- > epoch 2:  coût moyen validation = 0.38616329431533813
# -------- > epoch 2:  taux moyen validation = 0.8648999929428101
# -------- > epoch 3:  coût moyen entraînement = 0.36665090918540955
# -------- > epoch 3:  taux moyen entraînement = 0.8697398900985718
# -------- > epoch 3:  coût moyen validation = 0.36218756437301636
# -------- > epoch 3:  taux moyen validation = 0.8746000528335571
# -------- > epoch 4:  coût moyen entraînement = 0.3376122713088989
# -------- > epoch 4:  taux moyen entraînement = 0.88092041015625
# -------- > epoch 4:  coût moyen validation = 0.35456278920173645
# -------- > epoch 4:  taux moyen validation = 0.8732000589370728
# -------- > epoch 5:  coût moyen entraînement = 0.3161066174507141
# -------- > epoch 5:  taux moyen entraînement = 0.8884407877922058
# -------- > epoch 5:  coût moyen validation = 0.3097618520259857
# -------- > epoch 5:  taux moyen validation = 0.8906001448631287
# -------- > epoch 6:  coût moyen entraînement = 0.2989231050014496
# -------- > epoch 6:  taux moyen entraînement = 0.8936405777931213
# -------- > epoch 6:  coût moyen validation = 0.3082001805305481
# -------- > epoch 6:  taux moyen validation = 0.889499843120575
# -------- > epoch 7:  coût moyen entraînement = 0.28301796317100525
# -------- > epoch 7:  taux moyen entraînement = 0.900980532169342
# -------- > epoch 7:  coût moyen validation = 0.29880404472351074
# -------- > epoch 7:  taux moyen validation = 0.8938001394271851
# -------- > epoch 8:  coût moyen entraînement = 0.27210286259651184
# -------- > epoch 8:  taux moyen entraînement = 0.9036210179328918
# -------- > epoch 8:  coût moyen validation = 0.29185429215431213
# -------- > epoch 8:  taux moyen validation = 0.8924000263214111
# -------- > epoch 9:  coût moyen entraînement = 0.26212605834007263
# -------- > epoch 9:  taux moyen entraînement = 0.9068804383277893
# -------- > epoch 9:  coût moyen validation = 0.28999871015548706
# -------- > epoch 9:  taux moyen validation = 0.8964001536369324
# -------- > epoch 10:  coût moyen entraînement = 0.25164762139320374
# -------- > epoch 10:  taux moyen entraînement = 0.9103607535362244
# -------- > epoch 10:  coût moyen validation = 0.2884112000465393
# -------- > epoch 10:  taux moyen validation = 0.8950998783111572
# -------- > epoch 11:  coût moyen entraînement = 0.2436901181936264
# -------- > epoch 11:  taux moyen entraînement = 0.9141809344291687
# -------- > epoch 11:  coût moyen validation = 0.28415539860725403
# -------- > epoch 11:  taux moyen validation = 0.8977999091148376
# -------- > epoch 12:  coût moyen entraînement = 0.2362099438905716
# -------- > epoch 12:  taux moyen entraînement = 0.9156408905982971
# -------- > epoch 12:  coût moyen validation = 0.2811140716075897
# -------- > epoch 12:  taux moyen validation = 0.8994999527931213
# -------- > epoch 13:  coût moyen entraînement = 0.22962166368961334
# -------- > epoch 13:  taux moyen entraînement = 0.9174803495407104
# -------- > epoch 13:  coût moyen validation = 0.278090238571167
# -------- > epoch 13:  taux moyen validation = 0.8987998366355896
# -------- > epoch 14:  coût moyen entraînement = 0.22152671217918396
# -------- > epoch 14:  taux moyen entraînement = 0.9202809929847717
# -------- > epoch 14:  coût moyen validation = 0.26748377084732056
# -------- > epoch 14:  taux moyen validation = 0.9061000943183899
# -------- > epoch 15:  coût moyen entraînement = 0.21536757051944733
# -------- > epoch 15:  taux moyen entraînement = 0.9218616485595703
# -------- > epoch 15:  coût moyen validation = 0.2761918604373932
# -------- > epoch 15:  taux moyen validation = 0.9033999443054199
# -------- > epoch 16:  coût moyen entraînement = 0.2077856808900833
# -------- > epoch 16:  taux moyen entraînement = 0.9253413081169128
# -------- > epoch 16:  coût moyen validation = 0.2650902271270752
# -------- > epoch 16:  taux moyen validation = 0.9047001600265503
# -------- > epoch 17:  coût moyen entraînement = 0.20284725725650787
# -------- > epoch 17:  taux moyen entraînement = 0.9269610643386841
# -------- > epoch 17:  coût moyen validation = 0.2660566568374634
# -------- > epoch 17:  taux moyen validation = 0.9067003130912781
# -------- > epoch 18:  coût moyen entraînement = 0.19496271014213562
# -------- > epoch 18:  taux moyen entraînement = 0.9301209449768066
# -------- > epoch 18:  coût moyen validation = 0.28964903950691223
# -------- > epoch 18:  taux moyen validation = 0.8973000049591064
# -------- > epoch 19:  coût moyen entraînement = 0.19032840430736542
# -------- > epoch 19:  taux moyen entraînement = 0.9313814640045166
# -------- > epoch 19:  coût moyen validation = 0.28086206316947937
# -------- > epoch 19:  taux moyen validation = 0.9027999043464661
# -------- > epoch 20:  coût moyen entraînement = 0.18634553253650665
# -------- > epoch 20:  taux moyen entraînement = 0.932580828666687
# -------- > epoch 20:  coût moyen validation = 0.283733606338501
# -------- > epoch 20:  taux moyen validation = 0.9031001329421997
# -------- > epoch 21:  coût moyen entraînement = 0.1808202862739563
# -------- > epoch 21:  taux moyen entraînement = 0.935360848903656
# -------- > epoch 21:  coût moyen validation = 0.26522770524024963
# -------- > epoch 21:  taux moyen validation = 0.9079998731613159
# -------- > epoch 22:  coût moyen entraînement = 0.17733679711818695
# -------- > epoch 22:  taux moyen entraînement = 0.9355214834213257
# -------- > epoch 22:  coût moyen validation = 0.28474485874176025
# -------- > epoch 22:  taux moyen validation = 0.9048001766204834
# -------- > epoch 23:  coût moyen entraînement = 0.17252245545387268
# -------- > epoch 23:  taux moyen entraînement = 0.938380777835846
# -------- > epoch 23:  coût moyen validation = 0.2732522487640381
# -------- > epoch 23:  taux moyen validation = 0.9007999300956726
# -------- > epoch 24:  coût moyen entraînement = 0.16701021790504456
# -------- > epoch 24:  taux moyen entraînement = 0.9399012923240662
# -------- > epoch 24:  coût moyen validation = 0.2728249728679657
# -------- > epoch 24:  taux moyen validation = 0.9096004366874695
# -------- > epoch 25:  coût moyen entraînement = 0.1623631715774536
# -------- > epoch 25:  taux moyen entraînement = 0.942240834236145
# -------- > epoch 25:  coût moyen validation = 0.2700885832309723
# -------- > epoch 25:  taux moyen validation = 0.9079000949859619
# -------- > epoch 26:  coût moyen entraînement = 0.15856105089187622
# -------- > epoch 26:  taux moyen entraînement = 0.9439210891723633
# -------- > epoch 26:  coût moyen validation = 0.2819862365722656
# -------- > epoch 26:  taux moyen validation = 0.9037001729011536
# -------- > epoch 27:  coût moyen entraînement = 0.15393899381160736
# -------- > epoch 27:  taux moyen entraînement = 0.9456010460853577
# -------- > epoch 27:  coût moyen validation = 0.28056600689888
# -------- > epoch 27:  taux moyen validation = 0.9052000641822815
# -------- > epoch 28:  coût moyen entraînement = 0.15016281604766846
# -------- > epoch 28:  taux moyen entraînement = 0.9463008642196655
# -------- > epoch 28:  coût moyen validation = 0.27902930974960327
# -------- > epoch 28:  taux moyen validation = 0.9032003879547119
# -------- > epoch 29:  coût moyen entraînement = 0.14642837643623352
# -------- > epoch 29:  taux moyen entraînement = 0.948440670967102
# -------- > epoch 29:  coût moyen validation = 0.2902194857597351
# -------- > epoch 29:  taux moyen validation = 0.9027001857757568
# -------- > epoch 30:  coût moyen entraînement = 0.14232593774795532
# -------- > epoch 30:  taux moyen entraînement = 0.9488009214401245
# -------- > epoch 30:  coût moyen validation = 0.29974186420440674
# -------- > epoch 30:  taux moyen validation = 0.9014001488685608
