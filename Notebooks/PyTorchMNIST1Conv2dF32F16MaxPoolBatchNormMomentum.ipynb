# %%
# %matplotlib inline
# -*- coding: utf-8 -*-
"""
Exemple simple de MNIST avec PyTorch
Exemple avec nn.Conv2d et F.cross_entropy
Production de métriques avec graphes
Fonction entrainer
"""
import torch
torch.manual_seed(0) # Pour résultats reproductibles

# Fonction J d'entropie croisée
import torch.nn.functional as F
fonction_cout = F.cross_entropy

def taux_bonnes_predictions(lot_Y_predictions, lot_Y):
    predictions_categorie = torch.argmax(lot_Y_predictions, dim=1)
    return (predictions_categorie == lot_Y).float().mean()

from torch import nn
# Définition de l'architecture du RNA

modele = nn.Sequential(
    nn.Conv2d(1,32,3,padding=1),
    nn.BatchNorm2d(32),
    nn.ReLU(),
    nn.MaxPool2d(2),
    nn.Conv2d(32,16,3),
    nn.BatchNorm2d(16),
    nn.ReLU(),
    nn.MaxPool2d(2),
    nn.Flatten(),
    nn.Linear(6*6*16,10)
)
    
from torch import optim
optimiseur = optim.SGD(modele.parameters(), lr=0.01, momentum = 0.5)

# Chargement des données de MNIST
import pickle, gzip
fichier_donnees = gzip.open(r"mnist.pkl.gz", 'rb')
((donnees_ent_X, donnees_ent_Y),(donnees_valid_X, donnees_valid_Y),(donnees_test_X,donnees_test_Y)) = pickle.load(fichier_donnees, encoding="latin-1")
fichier_donnees.close()

# Conversion des données en type toch.Tensor
import torch
donnees_ent_X,donnees_ent_Y,donnees_valid_X,donnees_valid_Y,donnees_test_X,donnees_test_Y  = map(torch.tensor,
    (donnees_ent_X.reshape((-1,1,28,28)),donnees_ent_Y,donnees_valid_X.reshape((-1,1,28,28)),donnees_valid_Y,donnees_test_X.reshape((-1,1,28,28)),donnees_test_Y))

# Création des objets DataLoader pour itérer par lot
from torch.utils.data import TensorDataset
from torch.utils.data import DataLoader
ds_ent = TensorDataset(donnees_ent_X, donnees_ent_Y)
dl_ent = DataLoader(ds_ent, batch_size=100, shuffle=True)
ds_valid = TensorDataset(donnees_valid_X,donnees_valid_Y)
dl_valid = DataLoader(ds_valid, batch_size=100)

def entrainer(modele, dl_ent, dl_valid, optimiseur, nb_epochs=10):

    # Listes pour les métriques par epoch
    liste_cout_moyen_ent = []
    liste_taux_moyen_ent = []
    liste_cout_moyen_valid = []
    liste_taux_moyen_valid = []
    
    # Boucle d'apprentissage
    for epoch in range(nb_epochs):
        cout_total_ent = 0 # pour cumuler les couts par mini-lot
        taux_bonnes_predictions_ent = 0 # pour cumuler les taux par mini-lot
        modele.train() # Pour certains types de couches (nn.BatchNorm2d, nn.Dropout, ...)
        
        # Boucle d'apprentissage par mini-lot pour une epoch
        for lot_X, lot_Y in dl_ent:
            optimiseur.zero_grad() # Remettre les dérivées à zéro
            lot_Y_predictions = modele(lot_X) # Appel de la méthode forward
            cout = fonction_cout(lot_Y_predictions, lot_Y)
            cout.backward() # Calcul des gradiants par rétropropagation
            with torch.no_grad():
                cout_total_ent +=cout
                taux_bonnes_predictions_ent += taux_bonnes_predictions(lot_Y_predictions, lot_Y)
            optimiseur.step() # Mise à jour des paramètres
        # Calculer les moyennes par mini-lot
        with torch.no_grad():
            cout_moyen_ent = cout_total_ent/len(dl_ent)
            taux_moyen_ent = taux_bonnes_predictions_ent/len(dl_ent)
       
        modele.eval() # Pour certains types de couches (nn.BatchNorm2d, nn.Dropout, ...)
        with torch.no_grad():
            cout_valid = sum(fonction_cout(modele(lot_valid_X), lot_valid_Y) for lot_valid_X, lot_valid_Y in dl_valid)
            taux_bons_valid = sum(taux_bonnes_predictions(modele(lot_valid_X), lot_valid_Y) for lot_valid_X, lot_valid_Y in dl_valid)
        cout_moyen_valid = cout_valid/len(dl_valid)
        taux_moyen_valid = taux_bons_valid/len(dl_valid)
        print(f'-------- > epoch {epoch+1}:  coût moyen entraînement = {cout_moyen_ent}')
        print(f'-------- > epoch {epoch+1}:  taux moyen entraînement = {taux_moyen_ent}')
        print(f'-------- > epoch {epoch+1}:  coût moyen validation = {cout_moyen_valid}')
        print(f'-------- > epoch {epoch+1}:  taux moyen validation = {taux_moyen_valid}')
    
        liste_cout_moyen_ent.append(cout_moyen_ent)
        liste_taux_moyen_ent.append(taux_moyen_ent)
        liste_cout_moyen_valid.append(cout_moyen_valid)
        liste_taux_moyen_valid.append(taux_moyen_valid)
    
    # Affichage du graphique d'évolution des métriques par epoch
    import numpy as np
    import matplotlib.pyplot as plt
    plt.plot(np.arange(0,nb_epochs),liste_cout_moyen_ent,label='Erreur entraînement')
    plt.plot(np.arange(0,nb_epochs),liste_cout_moyen_valid,label='Erreur validation')
    plt.title("Evolution du coût")
    plt.xlabel('epoch')
    plt.ylabel('moyenne par observation')
    plt.legend(loc='upper center')
    plt.show()
        
    plt.plot(np.arange(0,nb_epochs),liste_taux_moyen_ent,label='Taux bonnes réponses entraînement')
    plt.plot(np.arange(0,nb_epochs),liste_taux_moyen_valid,label='Taux bonnes réponses validation')
    plt.title("Evolution du taux")
    plt.xlabel('epoch')
    plt.ylabel('moyenne par observation')
    plt.legend(loc='upper center')
    plt.show()

entrainer(modele, dl_ent, dl_valid, optimiseur, nb_epochs=30)
# Out:
# -------- > epoch 1:  coût moyen entraînement = 0.2502087354660034
# -------- > epoch 1:  taux moyen entraînement = 0.9377408623695374
# -------- > epoch 1:  coût moyen validation = 0.10910564661026001
# -------- > epoch 1:  taux moyen validation = 0.9704001545906067
# -------- > epoch 2:  coût moyen entraînement = 0.09145248681306839
# -------- > epoch 2:  taux moyen entraînement = 0.9748209714889526
# -------- > epoch 2:  coût moyen validation = 0.07749021053314209
# -------- > epoch 2:  taux moyen validation = 0.9767001867294312
# -------- > epoch 3:  coût moyen entraînement = 0.07086015492677689
# -------- > epoch 3:  taux moyen entraînement = 0.9797800779342651
# -------- > epoch 3:  coût moyen validation = 0.064176045358181
# -------- > epoch 3:  taux moyen validation = 0.9822002649307251
# -------- > epoch 4:  coût moyen entraînement = 0.059747349470853806
# -------- > epoch 4:  taux moyen entraînement = 0.9825798869132996
# -------- > epoch 4:  coût moyen validation = 0.05781607702374458
# -------- > epoch 4:  taux moyen validation = 0.9836000800132751
# -------- > epoch 5:  coût moyen entraînement = 0.05252372846007347
# -------- > epoch 5:  taux moyen entraînement = 0.9848999381065369
# -------- > epoch 5:  coût moyen validation = 0.05942964553833008
# -------- > epoch 5:  taux moyen validation = 0.9823001623153687
# -------- > epoch 6:  coût moyen entraînement = 0.04749468341469765
# -------- > epoch 6:  taux moyen entraînement = 0.9859198331832886
# -------- > epoch 6:  coût moyen validation = 0.05725117027759552
# -------- > epoch 6:  taux moyen validation = 0.9843001365661621
# -------- > epoch 7:  coût moyen entraînement = 0.04369617626070976
# -------- > epoch 7:  taux moyen entraînement = 0.9872203469276428
# -------- > epoch 7:  coût moyen validation = 0.052957333624362946
# -------- > epoch 7:  taux moyen validation = 0.9851999878883362
# -------- > epoch 8:  coût moyen entraînement = 0.04075247049331665
# -------- > epoch 8:  taux moyen entraînement = 0.988359272480011
# -------- > epoch 8:  coût moyen validation = 0.04936446622014046
# -------- > epoch 8:  taux moyen validation = 0.9861000776290894
# -------- > epoch 9:  coût moyen entraînement = 0.037722863256931305
# -------- > epoch 9:  taux moyen entraînement = 0.9893795251846313
# -------- > epoch 9:  coût moyen validation = 0.04800162836909294
# -------- > epoch 9:  taux moyen validation = 0.98580002784729
# -------- > epoch 10:  coût moyen entraînement = 0.03539494425058365
# -------- > epoch 10:  taux moyen entraînement = 0.9893800020217896
# -------- > epoch 10:  coût moyen validation = 0.04657682403922081
# -------- > epoch 10:  taux moyen validation = 0.9868000745773315
# -------- > epoch 11:  coût moyen entraînement = 0.03343350812792778
# -------- > epoch 11:  taux moyen entraînement = 0.9905400276184082
# -------- > epoch 11:  coût moyen validation = 0.046069931238889694
# -------- > epoch 11:  taux moyen validation = 0.9865000247955322
# -------- > epoch 12:  coût moyen entraînement = 0.03180656209588051
# -------- > epoch 12:  taux moyen entraînement = 0.991219699382782
# -------- > epoch 12:  coût moyen validation = 0.04503192380070686
# -------- > epoch 12:  taux moyen validation = 0.9869000315666199
# -------- > epoch 13:  coût moyen entraînement = 0.029823293909430504
# -------- > epoch 13:  taux moyen entraînement = 0.9916998147964478
# -------- > epoch 13:  coût moyen validation = 0.04965731501579285
# -------- > epoch 13:  taux moyen validation = 0.9854000806808472
# -------- > epoch 14:  coût moyen entraînement = 0.028117474168539047
# -------- > epoch 14:  taux moyen entraînement = 0.9922996163368225
# -------- > epoch 14:  coût moyen validation = 0.04392153397202492
# -------- > epoch 14:  taux moyen validation = 0.9872000813484192
# -------- > epoch 15:  coût moyen entraînement = 0.027178525924682617
# -------- > epoch 15:  taux moyen entraînement = 0.9923592805862427
# -------- > epoch 15:  coût moyen validation = 0.0426286906003952
# -------- > epoch 15:  taux moyen validation = 0.9871000051498413
# -------- > epoch 16:  coût moyen entraînement = 0.025780009105801582
# -------- > epoch 16:  taux moyen entraînement = 0.9926193356513977
# -------- > epoch 16:  coût moyen validation = 0.04740040749311447
# -------- > epoch 16:  taux moyen validation = 0.9862001538276672
# -------- > epoch 17:  coût moyen entraînement = 0.02518611215054989
# -------- > epoch 17:  taux moyen entraînement = 0.9930791258811951
# -------- > epoch 17:  coût moyen validation = 0.047280121594667435
# -------- > epoch 17:  taux moyen validation = 0.9858000874519348
# -------- > epoch 18:  coût moyen entraînement = 0.02386004850268364
# -------- > epoch 18:  taux moyen entraînement = 0.9934790134429932
# -------- > epoch 18:  coût moyen validation = 0.0448434017598629
# -------- > epoch 18:  taux moyen validation = 0.9871000051498413
# -------- > epoch 19:  coût moyen entraînement = 0.022411733865737915
# -------- > epoch 19:  taux moyen entraînement = 0.9938393235206604
# -------- > epoch 19:  coût moyen validation = 0.04197130352258682
# -------- > epoch 19:  taux moyen validation = 0.9884001016616821
# -------- > epoch 20:  coût moyen entraînement = 0.021683210507035255
# -------- > epoch 20:  taux moyen entraînement = 0.9941394329071045
# -------- > epoch 20:  coût moyen validation = 0.052469123154878616
# -------- > epoch 20:  taux moyen validation = 0.9843002557754517
# -------- > epoch 21:  coût moyen entraînement = 0.020790893584489822
# -------- > epoch 21:  taux moyen entraînement = 0.9943593144416809
# -------- > epoch 21:  coût moyen validation = 0.04558723419904709
# -------- > epoch 21:  taux moyen validation = 0.9859000444412231
# -------- > epoch 22:  coût moyen entraînement = 0.019845033064484596
# -------- > epoch 22:  taux moyen entraînement = 0.9945791363716125
# -------- > epoch 22:  coût moyen validation = 0.04530438408255577
# -------- > epoch 22:  taux moyen validation = 0.9873000979423523
# -------- > epoch 23:  coût moyen entraînement = 0.01926925778388977
# -------- > epoch 23:  taux moyen entraînement = 0.9949593544006348
# -------- > epoch 23:  coût moyen validation = 0.041335344314575195
# -------- > epoch 23:  taux moyen validation = 0.9882000088691711
# -------- > epoch 24:  coût moyen entraînement = 0.018167506903409958
# -------- > epoch 24:  taux moyen entraînement = 0.9952793717384338
# -------- > epoch 24:  coût moyen validation = 0.041325733065605164
# -------- > epoch 24:  taux moyen validation = 0.9880002737045288
# -------- > epoch 25:  coût moyen entraînement = 0.017496084794402122
# -------- > epoch 25:  taux moyen entraînement = 0.9955995678901672
# -------- > epoch 25:  coût moyen validation = 0.05192272737622261
# -------- > epoch 25:  taux moyen validation = 0.9850002527236938
# -------- > epoch 26:  coût moyen entraînement = 0.01652989350259304
# -------- > epoch 26:  taux moyen entraînement = 0.9958192110061646
# -------- > epoch 26:  coût moyen validation = 0.04523658752441406
# -------- > epoch 26:  taux moyen validation = 0.9869000911712646
# -------- > epoch 27:  coût moyen entraînement = 0.015743425115942955
# -------- > epoch 27:  taux moyen entraînement = 0.9960793852806091
# -------- > epoch 27:  coût moyen validation = 0.04327353835105896
# -------- > epoch 27:  taux moyen validation = 0.9873000383377075
# -------- > epoch 28:  coût moyen entraînement = 0.015468686819076538
# -------- > epoch 28:  taux moyen entraînement = 0.9960392713546753
# -------- > epoch 28:  coût moyen validation = 0.048100654035806656
# -------- > epoch 28:  taux moyen validation = 0.9868000745773315
# -------- > epoch 29:  coût moyen entraînement = 0.014908084645867348
# -------- > epoch 29:  taux moyen entraînement = 0.9963594079017639
# -------- > epoch 29:  coût moyen validation = 0.04973554611206055
# -------- > epoch 29:  taux moyen validation = 0.9864002466201782
# -------- > epoch 30:  coût moyen entraînement = 0.014067403972148895
# -------- > epoch 30:  taux moyen entraînement = 0.996899425983429
# -------- > epoch 30:  coût moyen validation = 0.04678025096654892
# -------- > epoch 30:  taux moyen validation = 0.9862000942230225
