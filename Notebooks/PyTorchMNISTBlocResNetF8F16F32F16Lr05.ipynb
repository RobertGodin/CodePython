# %%
# %matplotlib inline
# -*- coding: utf-8 -*-
"""
Exemple de MNIST avec PyTorch
Exemple avec connexion distante (BlocResSimple)
"""
import torch
torch.manual_seed(0) # Pour résultats reproductibles

# Fonction J d'entropie croisée
import torch.nn.functional as F
fonction_cout = F.cross_entropy

def taux_bonnes_predictions(lot_Y_predictions, lot_Y):
    predictions_categorie = torch.argmax(lot_Y_predictions, dim=1)
    return (predictions_categorie == lot_Y).float().mean()

from torch import nn
# Définition de l'architecture du RNA

class BlocResSimple(nn.Module):
    def __init__(self, nb_f):
        super().__init__()
        self.convolution = nn.Conv2d(nb_f, nb_f, kernel_size=3, stride=1, padding=1) 
        self.normalisation = nn.BatchNorm2d(nb_f)    

    def forward(self, lot_X):
        lot_Y_predictions = self.convolution(lot_X)
        lot_Y_predictions = self.normalisation(lot_Y_predictions)
        lot_Y_predictions = F.relu(lot_Y_predictions)
        return lot_Y_predictions+lot_X
    
class BlocResNetSimple(nn.Module):
    def __init__(self, nb_f):
        super().__init__()

        self.conv1 = nn.Conv2d(nb_f, nb_f, kernel_size=3, stride=1, padding=1, bias=False) 
        self.bn1 = nn.BatchNorm2d(nb_f)    
        self.relu = nn.ReLU(inplace=True)
        self.conv2 = nn.Conv2d(nb_f, nb_f, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(nb_f)    

    def forward(self, lot_X):
        lot_Y_predictions = self.conv1(lot_X)
        lot_Y_predictions = self.bn1(lot_Y_predictions)
        lot_Y_predictions = self.relu(lot_Y_predictions)
        lot_Y_predictions = self.conv2(lot_Y_predictions)
        lot_Y_predictions = self.bn2(lot_Y_predictions)
        lot_Y_predictions = lot_Y_predictions + lot_X
        lot_Y_predictions = self.relu(lot_Y_predictions)
        return lot_Y_predictions 

modele = nn.Sequential(
    nn.Conv2d(1,8,3,2,1),
    nn.BatchNorm2d(8),
    nn.ReLU(),
    BlocResNetSimple(8),
    nn.Conv2d(8,16,3,2,1),
    nn.BatchNorm2d(16),
    nn.ReLU(),    
    BlocResNetSimple(16),
    nn.Conv2d(16,32,3,2,1),
    nn.BatchNorm2d(32),
    nn.ReLU(),    
    BlocResNetSimple(32),
    nn.Conv2d(32,16,3,2,1),
    nn.BatchNorm2d(16),
    nn.ReLU(),
    nn.Conv2d(16,10,3,2,1),
    nn.BatchNorm2d(10),
    nn.ReLU(),
    nn.Flatten()
#    nn.Linear(20*20*16,10)
)

from torch import optim
optimiseur = optim.SGD(modele.parameters(), lr=0.5)

# Chargement des données de MNIST
import pickle, gzip
fichier_donnees = gzip.open(r"mnist.pkl.gz", 'rb')
((donnees_ent_X, donnees_ent_Y),(donnees_valid_X, donnees_valid_Y),(donnees_test_X,donnees_test_Y)) = pickle.load(fichier_donnees, encoding="latin-1")
fichier_donnees.close()

# Conversion des données en type toch.Tensor
import torch
donnees_ent_X,donnees_ent_Y,donnees_valid_X,donnees_valid_Y,donnees_test_X,donnees_test_Y  = map(torch.tensor,
    (donnees_ent_X.reshape((-1,1,28,28)),donnees_ent_Y,donnees_valid_X.reshape((-1,1,28,28)),donnees_valid_Y,donnees_test_X.reshape((-1,1,28,28)),donnees_test_Y))

# Création des objets DataLoader pour itérer par lot
from torch.utils.data import TensorDataset
from torch.utils.data import DataLoader
ds_ent = TensorDataset(donnees_ent_X, donnees_ent_Y)
dl_ent = DataLoader(ds_ent, batch_size=100, shuffle=True)
ds_valid = TensorDataset(donnees_valid_X,donnees_valid_Y)
dl_valid = DataLoader(ds_valid, batch_size=100)

def entrainer(modele, dl_ent, dl_valid, optimiseur, nb_epochs=10):

    # Listes pour les métriques par epoch
    liste_cout_moyen_ent = []
    liste_taux_moyen_ent = []
    liste_cout_moyen_valid = []
    liste_taux_moyen_valid = []
    
    # Boucle d'apprentissage
    for epoch in range(nb_epochs):
        cout_total_ent = 0 # pour cumuler les couts par mini-lot
        taux_bonnes_predictions_ent = 0 # pour cumuler les taux par mini-lot
        modele.train() # Pour certains types de couches (nn.BatchNorm2d, nn.Dropout, ...)
        
        # Boucle d'apprentissage par mini-lot pour une epoch
        for lot_X, lot_Y in dl_ent:
            optimiseur.zero_grad() # Remettre les dérivées à zéro
            lot_Y_predictions = modele(lot_X) # Appel de la méthode forward
            cout = fonction_cout(lot_Y_predictions, lot_Y)
            cout.backward() # Calcul des gradiants par rétropropagation
            with torch.no_grad():
                cout_total_ent +=cout
                taux_bonnes_predictions_ent += taux_bonnes_predictions(lot_Y_predictions, lot_Y)
            optimiseur.step() # Mise à jour des paramètres
            # scheduler.step()
        # Calculer les moyennes par mini-lot
        with torch.no_grad():
            cout_moyen_ent = cout_total_ent/len(dl_ent)
            taux_moyen_ent = taux_bonnes_predictions_ent/len(dl_ent)
       
        modele.eval() # Pour certains types de couches (nn.BatchNorm2d, nn.Dropout, ...)
        with torch.no_grad():
            cout_valid = sum(fonction_cout(modele(lot_valid_X), lot_valid_Y) for lot_valid_X, lot_valid_Y in dl_valid)
            taux_bons_valid = sum(taux_bonnes_predictions(modele(lot_valid_X), lot_valid_Y) for lot_valid_X, lot_valid_Y in dl_valid)
        cout_moyen_valid = cout_valid/len(dl_valid)
        taux_moyen_valid = taux_bons_valid/len(dl_valid)
        print(f'-------- > epoch {epoch+1}:  coût moyen entraînement = {cout_moyen_ent}')
        print(f'-------- > epoch {epoch+1}:  taux moyen entraînement = {taux_moyen_ent}')
        print(f'-------- > epoch {epoch+1}:  coût moyen validation = {cout_moyen_valid}')
        print(f'-------- > epoch {epoch+1}:  taux moyen validation = {taux_moyen_valid}')
    
        liste_cout_moyen_ent.append(cout_moyen_ent)
        liste_taux_moyen_ent.append(taux_moyen_ent)
        liste_cout_moyen_valid.append(cout_moyen_valid)
        liste_taux_moyen_valid.append(taux_moyen_valid)
    
    # Affichage du graphique d'évolution des métriques par epoch
    import numpy as np
    import matplotlib.pyplot as plt
    plt.plot(np.arange(0,nb_epochs),liste_cout_moyen_ent,label='Erreur entraînement')
    plt.plot(np.arange(0,nb_epochs),liste_cout_moyen_valid,label='Erreur validation')
    plt.title("Evolution du coût")
    plt.xlabel('epoch')
    plt.ylabel('moyenne par observation')
    plt.legend(loc='upper center')
    plt.show()
        
    plt.plot(np.arange(0,nb_epochs),liste_taux_moyen_ent,label='Taux bonnes réponses entraînement')
    plt.plot(np.arange(0,nb_epochs),liste_taux_moyen_valid,label='Taux bonnes réponses validation')
    plt.title("Evolution du taux")
    plt.xlabel('epoch')
    plt.ylabel('moyenne par observation')
    plt.legend(loc='center')
    plt.show()

entrainer(modele, dl_ent, dl_valid, optimiseur, nb_epochs=30)
# Out:
# -------- > epoch 1:  coût moyen entraînement = 0.2097109705209732
# -------- > epoch 1:  taux moyen entraînement = 0.9469404220581055
# -------- > epoch 1:  coût moyen validation = 0.06247769296169281
# -------- > epoch 1:  taux moyen validation = 0.9827001690864563
# -------- > epoch 2:  coût moyen entraînement = 0.06922288239002228
# -------- > epoch 2:  taux moyen entraînement = 0.9806204438209534
# -------- > epoch 2:  coût moyen validation = 0.049839723855257034
# -------- > epoch 2:  taux moyen validation = 0.9860002994537354
# -------- > epoch 3:  coût moyen entraînement = 0.05370298773050308
# -------- > epoch 3:  taux moyen entraînement = 0.9848203659057617
# -------- > epoch 3:  coût moyen validation = 0.045628905296325684
# -------- > epoch 3:  taux moyen validation = 0.9865001440048218
# -------- > epoch 4:  coût moyen entraînement = 0.040059734135866165
# -------- > epoch 4:  taux moyen entraînement = 0.9882599711418152
# -------- > epoch 4:  coût moyen validation = 0.04246364161372185
# -------- > epoch 4:  taux moyen validation = 0.9880001544952393
# -------- > epoch 5:  coût moyen entraînement = 0.0331929512321949
# -------- > epoch 5:  taux moyen entraînement = 0.9902400374412537
# -------- > epoch 5:  coût moyen validation = 0.03784864395856857
# -------- > epoch 5:  taux moyen validation = 0.9887000918388367
# -------- > epoch 6:  coût moyen entraînement = 0.028679896146059036
# -------- > epoch 6:  taux moyen entraînement = 0.9916196465492249
# -------- > epoch 6:  coût moyen validation = 0.04374067485332489
# -------- > epoch 6:  taux moyen validation = 0.9883999824523926
# -------- > epoch 7:  coût moyen entraînement = 0.026662666350603104
# -------- > epoch 7:  taux moyen entraînement = 0.9918997883796692
# -------- > epoch 7:  coût moyen validation = 0.043306488543748856
# -------- > epoch 7:  taux moyen validation = 0.9883003234863281
# -------- > epoch 8:  coût moyen entraînement = 0.019674846902489662
# -------- > epoch 8:  taux moyen entraînement = 0.9940791726112366
# -------- > epoch 8:  coût moyen validation = 0.03469422459602356
# -------- > epoch 8:  taux moyen validation = 0.9904000759124756
# -------- > epoch 9:  coût moyen entraînement = 0.01872941106557846
# -------- > epoch 9:  taux moyen entraînement = 0.9943192005157471
# -------- > epoch 9:  coût moyen validation = 0.04093314707279205
# -------- > epoch 9:  taux moyen validation = 0.9881002306938171
# -------- > epoch 10:  coût moyen entraînement = 0.015256953425705433
# -------- > epoch 10:  taux moyen entraînement = 0.9955995082855225
# -------- > epoch 10:  coût moyen validation = 0.0374254547059536
# -------- > epoch 10:  taux moyen validation = 0.9905002117156982
# -------- > epoch 11:  coût moyen entraînement = 0.013187183998525143
# -------- > epoch 11:  taux moyen entraînement = 0.9961394667625427
# -------- > epoch 11:  coût moyen validation = 0.037891753017902374
# -------- > epoch 11:  taux moyen validation = 0.9894000887870789
# -------- > epoch 12:  coût moyen entraînement = 0.01198506634682417
# -------- > epoch 12:  taux moyen entraînement = 0.9965394139289856
# -------- > epoch 12:  coût moyen validation = 0.040842343121767044
# -------- > epoch 12:  taux moyen validation = 0.990100085735321
# -------- > epoch 13:  coût moyen entraînement = 0.009081006050109863
# -------- > epoch 13:  taux moyen entraînement = 0.9974793791770935
# -------- > epoch 13:  coût moyen validation = 0.043280646204948425
# -------- > epoch 13:  taux moyen validation = 0.9888002276420593
# -------- > epoch 14:  coût moyen entraînement = 0.009303100407123566
# -------- > epoch 14:  taux moyen entraînement = 0.997419536113739
# -------- > epoch 14:  coût moyen validation = 0.04473286122083664
# -------- > epoch 14:  taux moyen validation = 0.9890998601913452
# -------- > epoch 15:  coût moyen entraînement = 0.007562372833490372
# -------- > epoch 15:  taux moyen entraînement = 0.9978593587875366
# -------- > epoch 15:  coût moyen validation = 0.05069972574710846
# -------- > epoch 15:  taux moyen validation = 0.9881002306938171
# -------- > epoch 16:  coût moyen entraînement = 0.009054531343281269
# -------- > epoch 16:  taux moyen entraînement = 0.9973393082618713
# -------- > epoch 16:  coût moyen validation = 0.04078984260559082
# -------- > epoch 16:  taux moyen validation = 0.9901001453399658
# -------- > epoch 17:  coût moyen entraînement = 0.007038642652332783
# -------- > epoch 17:  taux moyen entraînement = 0.9980195164680481
# -------- > epoch 17:  coût moyen validation = 0.03854665905237198
# -------- > epoch 17:  taux moyen validation = 0.9909999966621399
# -------- > epoch 18:  coût moyen entraînement = 0.009618590585887432
# -------- > epoch 18:  taux moyen entraînement = 0.997019350528717
# -------- > epoch 18:  coût moyen validation = 0.041832759976387024
# -------- > epoch 18:  taux moyen validation = 0.9895002245903015
# -------- > epoch 19:  coût moyen entraînement = 0.006869115866720676
# -------- > epoch 19:  taux moyen entraînement = 0.99793940782547
# -------- > epoch 19:  coût moyen validation = 0.04039931669831276
# -------- > epoch 19:  taux moyen validation = 0.9906002283096313
# -------- > epoch 20:  coût moyen entraînement = 0.006348274648189545
# -------- > epoch 20:  taux moyen entraînement = 0.9980393648147583
# -------- > epoch 20:  coût moyen validation = 0.04714222997426987
# -------- > epoch 20:  taux moyen validation = 0.9886001348495483
# -------- > epoch 21:  coût moyen entraînement = 0.006897806655615568
# -------- > epoch 21:  taux moyen entraînement = 0.9979194402694702
# -------- > epoch 21:  coût moyen validation = 0.04689449444413185
# -------- > epoch 21:  taux moyen validation = 0.9894999861717224
# -------- > epoch 22:  coût moyen entraînement = 0.003923228941857815
# -------- > epoch 22:  taux moyen entraînement = 0.999139666557312
# -------- > epoch 22:  coût moyen validation = 0.0402495414018631
# -------- > epoch 22:  taux moyen validation = 0.9907000064849854
# -------- > epoch 23:  coût moyen entraînement = 0.004201096948236227
# -------- > epoch 23:  taux moyen entraînement = 0.9987995624542236
# -------- > epoch 23:  coût moyen validation = 0.04037347808480263
# -------- > epoch 23:  taux moyen validation = 0.9902001023292542
# -------- > epoch 24:  coût moyen entraînement = 0.004402649123221636
# -------- > epoch 24:  taux moyen entraînement = 0.9987995624542236
# -------- > epoch 24:  coût moyen validation = 0.04889333248138428
# -------- > epoch 24:  taux moyen validation = 0.9884001016616821
# -------- > epoch 25:  coût moyen entraînement = 0.003201782237738371
# -------- > epoch 25:  taux moyen entraînement = 0.9990997910499573
# -------- > epoch 25:  coût moyen validation = 0.03836977481842041
# -------- > epoch 25:  taux moyen validation = 0.9911002516746521
# -------- > epoch 26:  coût moyen entraînement = 0.0038448097184300423
# -------- > epoch 26:  taux moyen entraînement = 0.9987594485282898
# -------- > epoch 26:  coût moyen validation = 0.03822387754917145
# -------- > epoch 26:  taux moyen validation = 0.9905000925064087
# -------- > epoch 27:  coût moyen entraînement = 0.0035020296927541494
# -------- > epoch 27:  taux moyen entraînement = 0.9989796876907349
# -------- > epoch 27:  coût moyen validation = 0.0381762757897377
# -------- > epoch 27:  taux moyen validation = 0.9916000962257385
# -------- > epoch 28:  coût moyen entraînement = 0.0029556937515735626
# -------- > epoch 28:  taux moyen entraînement = 0.9992197751998901
# -------- > epoch 28:  coût moyen validation = 0.04134037345647812
# -------- > epoch 28:  taux moyen validation = 0.9912000894546509
# -------- > epoch 29:  coût moyen entraînement = 0.00185966317076236
# -------- > epoch 29:  taux moyen entraînement = 0.9996598362922668
# -------- > epoch 29:  coût moyen validation = 0.041126761585474014
# -------- > epoch 29:  taux moyen validation = 0.9909000396728516
# -------- > epoch 30:  coût moyen entraînement = 0.0018134776037186384
# -------- > epoch 30:  taux moyen entraînement = 0.9996198415756226
# -------- > epoch 30:  coût moyen validation = 0.039264921098947525
# -------- > epoch 30:  taux moyen validation = 0.991300106048584
