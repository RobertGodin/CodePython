# %%
# %matplotlib inline
# -*- coding: utf-8 -*-
"""
Exemple FashionMNIST avec RNA semblable à LeNet-5 (LeCun et al.)
"""
import torch
torch.manual_seed(0) # Pour résultats reproductibles

# Fonction J d'entropie croisée
import torch.nn.functional as F
fonction_cout = F.cross_entropy

def taux_bonnes_predictions(lot_Y_predictions, lot_Y):
    predictions_categorie = torch.argmax(lot_Y_predictions, dim=1)
    return (predictions_categorie == lot_Y).float().mean()

from torch import nn
# Définition de l'architecture du RNA

modele = torch.nn.Sequential(
    nn.Conv2d(1, 6, kernel_size=5, padding=2), nn.Tanh(), #(N, 1, 28, 28) -> (N, 6, 28, 28)
    nn.AvgPool2d(kernel_size=2, stride=2), #(N, 6, 28, 28) -> (N, 6, 14, 14)
    nn.Conv2d(6, 16, kernel_size=5), nn.Tanh(), #(N, 6, 14, 14) -> (N, 16, 10, 10)
    nn.AvgPool2d(kernel_size=2, stride=2), #(N, 16, 10, 10) -> (N, 16, 5, 5)
    nn.Flatten(), #(N, 16, 5, 5) -> (N, 400)
    nn.Linear(16 * 5 * 5, 120), nn.Tanh(), #(N, 400) -> (N, 120)
    nn.Linear(120, 84), nn.Tanh(), #(N, 120) -> (N, 84)
    nn.Linear(84, 10)) #(N, 84) -> (N, 10)

from torch import optim
optimiseur = optim.SGD(modele.parameters(), lr=0.5)

import torchvision
import torchvision.transforms as transforms

#Chargement des données
ds = torchvision.datasets.FashionMNIST(root = "./data", train = True, download = True, transform = transforms.ToTensor())
ds_ent, ds_valid = torch.utils.data.random_split(ds, [50000, 10000])
ds_test = torchvision.datasets.FashionMNIST(root = "./data", train = False, download = True, transform = transforms.ToTensor())

#Création du DataLoader avec le dataset
dl_ent = torch.utils.data.DataLoader(ds_ent, batch_size=100, shuffle = True)
dl_valid = torch.utils.data.DataLoader(ds_valid, batch_size=100)

def entrainer(modele, dl_ent, dl_valid, optimiseur, nb_epochs=10):

    # Listes pour les métriques par epoch
    liste_cout_moyen_ent = []
    liste_taux_moyen_ent = []
    liste_cout_moyen_valid = []
    liste_taux_moyen_valid = []
    
    # Boucle d'apprentissage
    for epoch in range(nb_epochs):
        cout_total_ent = 0 # pour cumuler les couts par mini-lot
        taux_bonnes_predictions_ent = 0 # pour cumuler les taux par mini-lot
        modele.train() # Pour certains types de couches (nn.BatchNorm2d, nn.Dropout, ...)
        
        # Boucle d'apprentissage par mini-lot pour une epoch
        for lot_X, lot_Y in dl_ent:
            optimiseur.zero_grad() # Remettre les dérivées à zéro
            lot_Y_predictions = modele(lot_X) # Appel de la méthode forward
            cout = fonction_cout(lot_Y_predictions, lot_Y)
            cout.backward() # Calcul des gradiants par rétropropagation
            with torch.no_grad():
                cout_total_ent +=cout
                taux_bonnes_predictions_ent += taux_bonnes_predictions(lot_Y_predictions, lot_Y)
            optimiseur.step() # Mise à jour des paramètres
        # Calculer les moyennes par mini-lot
        with torch.no_grad():
            cout_moyen_ent = cout_total_ent/len(dl_ent)
            taux_moyen_ent = taux_bonnes_predictions_ent/len(dl_ent)
       
        modele.eval() # Pour certains types de couches (nn.BatchNorm2d, nn.Dropout, ...)
        with torch.no_grad():
            cout_valid = sum(fonction_cout(modele(lot_valid_X), lot_valid_Y) for lot_valid_X, lot_valid_Y in dl_valid)
            taux_bons_valid = sum(taux_bonnes_predictions(modele(lot_valid_X), lot_valid_Y) for lot_valid_X, lot_valid_Y in dl_valid)
        cout_moyen_valid = cout_valid/len(dl_valid)
        taux_moyen_valid = taux_bons_valid/len(dl_valid)
        print(f'-------- > epoch {epoch+1}:  coût moyen entraînement = {cout_moyen_ent}')
        print(f'-------- > epoch {epoch+1}:  taux moyen entraînement = {taux_moyen_ent}')
        print(f'-------- > epoch {epoch+1}:  coût moyen validation = {cout_moyen_valid}')
        print(f'-------- > epoch {epoch+1}:  taux moyen validation = {taux_moyen_valid}')
    
        liste_cout_moyen_ent.append(cout_moyen_ent)
        liste_taux_moyen_ent.append(taux_moyen_ent)
        liste_cout_moyen_valid.append(cout_moyen_valid)
        liste_taux_moyen_valid.append(taux_moyen_valid)
    
    # Affichage du graphique d'évolution des métriques par epoch
    import numpy as np
    import matplotlib.pyplot as plt
    plt.plot(np.arange(0,nb_epochs),liste_cout_moyen_ent,label='Erreur entraînement')
    plt.plot(np.arange(0,nb_epochs),liste_cout_moyen_valid,label='Erreur validation')
    plt.title("Evolution du coût")
    plt.xlabel('epoch')
    plt.ylabel('moyenne par observation')
    plt.legend(loc='upper center')
    plt.show()
        
    plt.plot(np.arange(0,nb_epochs),liste_taux_moyen_ent,label='Taux bonnes réponses entraînement')
    plt.plot(np.arange(0,nb_epochs),liste_taux_moyen_valid,label='Taux bonnes réponses validation')
    plt.title("Evolution du taux")
    plt.xlabel('epoch')
    plt.ylabel('moyenne par observation')
    plt.legend(loc='lower center')
    plt.show()

entrainer(modele, dl_ent, dl_valid, optimiseur, nb_epochs=30)
# Out:
# -------- > epoch 1:  coût moyen entraînement = 0.635463535785675
# -------- > epoch 1:  taux moyen entraînement = 0.758579432964325
# -------- > epoch 1:  coût moyen validation = 0.41972172260284424
# -------- > epoch 1:  taux moyen validation = 0.8478996753692627
# -------- > epoch 2:  coût moyen entraînement = 0.41063928604125977
# -------- > epoch 2:  taux moyen entraînement = 0.8480393290519714
# -------- > epoch 2:  coût moyen validation = 0.3975668251514435
# -------- > epoch 2:  taux moyen validation = 0.8565998673439026
# -------- > epoch 3:  coût moyen entraînement = 0.3577546179294586
# -------- > epoch 3:  taux moyen entraînement = 0.867680549621582
# -------- > epoch 3:  coût moyen validation = 0.3592805862426758
# -------- > epoch 3:  taux moyen validation = 0.8697001934051514
# -------- > epoch 4:  coût moyen entraînement = 0.32847389578819275
# -------- > epoch 4:  taux moyen entraînement = 0.8765400052070618
# -------- > epoch 4:  coût moyen validation = 0.34276556968688965
# -------- > epoch 4:  taux moyen validation = 0.8759002089500427
# -------- > epoch 5:  coût moyen entraînement = 0.3016074001789093
# -------- > epoch 5:  taux moyen entraînement = 0.8873395919799805
# -------- > epoch 5:  coût moyen validation = 0.331373929977417
# -------- > epoch 5:  taux moyen validation = 0.8799000382423401
# -------- > epoch 6:  coût moyen entraînement = 0.28738459944725037
# -------- > epoch 6:  taux moyen entraînement = 0.8922005891799927
# -------- > epoch 6:  coût moyen validation = 0.31606778502464294
# -------- > epoch 6:  taux moyen validation = 0.8889999389648438
# -------- > epoch 7:  coût moyen entraînement = 0.26940926909446716
# -------- > epoch 7:  taux moyen entraînement = 0.8981802463531494
# -------- > epoch 7:  coût moyen validation = 0.3355260491371155
# -------- > epoch 7:  taux moyen validation = 0.8810000419616699
# -------- > epoch 8:  coût moyen entraînement = 0.25594228506088257
# -------- > epoch 8:  taux moyen entraînement = 0.9036606550216675
# -------- > epoch 8:  coût moyen validation = 0.32856684923171997
# -------- > epoch 8:  taux moyen validation = 0.8895001411437988
# -------- > epoch 9:  coût moyen entraînement = 0.24321649968624115
# -------- > epoch 9:  taux moyen entraînement = 0.9075606465339661
# -------- > epoch 9:  coût moyen validation = 0.31837040185928345
# -------- > epoch 9:  taux moyen validation = 0.8899001479148865
# -------- > epoch 10:  coût moyen entraînement = 0.23100420832633972
# -------- > epoch 10:  taux moyen entraînement = 0.9118210673332214
# -------- > epoch 10:  coût moyen validation = 0.323929101228714
# -------- > epoch 10:  taux moyen validation = 0.8893001675605774
# -------- > epoch 11:  coût moyen entraînement = 0.2205864042043686
# -------- > epoch 11:  taux moyen entraînement = 0.916441023349762
# -------- > epoch 11:  coût moyen validation = 0.30688202381134033
# -------- > epoch 11:  taux moyen validation = 0.8965001106262207
# -------- > epoch 12:  coût moyen entraînement = 0.20845936238765717
# -------- > epoch 12:  taux moyen entraînement = 0.9215013384819031
# -------- > epoch 12:  coût moyen validation = 0.32138288021087646
# -------- > epoch 12:  taux moyen validation = 0.8897001147270203
# -------- > epoch 13:  coût moyen entraînement = 0.1990576982498169
# -------- > epoch 13:  taux moyen entraînement = 0.9247207045555115
# -------- > epoch 13:  coût moyen validation = 0.3137328624725342
# -------- > epoch 13:  taux moyen validation = 0.895799994468689
# -------- > epoch 14:  coût moyen entraînement = 0.19196045398712158
# -------- > epoch 14:  taux moyen entraînement = 0.9270012378692627
# -------- > epoch 14:  coût moyen validation = 0.3173087239265442
# -------- > epoch 14:  taux moyen validation = 0.8951001763343811
# -------- > epoch 15:  coût moyen entraînement = 0.18412359058856964
# -------- > epoch 15:  taux moyen entraînement = 0.9304208159446716
# -------- > epoch 15:  coût moyen validation = 0.327534943819046
# -------- > epoch 15:  taux moyen validation = 0.8950998783111572
# -------- > epoch 16:  coût moyen entraînement = 0.17489317059516907
# -------- > epoch 16:  taux moyen entraînement = 0.9334810972213745
# -------- > epoch 16:  coût moyen validation = 0.3114905059337616
# -------- > epoch 16:  taux moyen validation = 0.9012998342514038
# -------- > epoch 17:  coût moyen entraînement = 0.16706112027168274
# -------- > epoch 17:  taux moyen entraînement = 0.9365205764770508
# -------- > epoch 17:  coût moyen validation = 0.39286091923713684
# -------- > epoch 17:  taux moyen validation = 0.8794002532958984
# -------- > epoch 18:  coût moyen entraînement = 0.15880155563354492
# -------- > epoch 18:  taux moyen entraînement = 0.9394405484199524
# -------- > epoch 18:  coût moyen validation = 0.32326361536979675
# -------- > epoch 18:  taux moyen validation = 0.9012000560760498
# -------- > epoch 19:  coût moyen entraînement = 0.15265561640262604
# -------- > epoch 19:  taux moyen entraînement = 0.9420010447502136
# -------- > epoch 19:  coût moyen validation = 0.3364361822605133
# -------- > epoch 19:  taux moyen validation = 0.8989002704620361
# -------- > epoch 20:  coût moyen entraînement = 0.1427718698978424
# -------- > epoch 20:  taux moyen entraînement = 0.9455210566520691
# -------- > epoch 20:  coût moyen validation = 0.35028010606765747
# -------- > epoch 20:  taux moyen validation = 0.8955000042915344
# -------- > epoch 21:  coût moyen entraînement = 0.13574540615081787
# -------- > epoch 21:  taux moyen entraînement = 0.9487608671188354
# -------- > epoch 21:  coût moyen validation = 0.3840119242668152
# -------- > epoch 21:  taux moyen validation = 0.8866001963615417
# -------- > epoch 22:  coût moyen entraînement = 0.13212771713733673
# -------- > epoch 22:  taux moyen entraînement = 0.9502606391906738
# -------- > epoch 22:  coût moyen validation = 0.37268513441085815
# -------- > epoch 22:  taux moyen validation = 0.8959000110626221
# -------- > epoch 23:  coût moyen entraînement = 0.12621234357357025
# -------- > epoch 23:  taux moyen entraînement = 0.9536011815071106
# -------- > epoch 23:  coût moyen validation = 0.36379432678222656
# -------- > epoch 23:  taux moyen validation = 0.8969001173973083
# -------- > epoch 24:  coût moyen entraînement = 0.11883531510829926
# -------- > epoch 24:  taux moyen entraînement = 0.9557008147239685
# -------- > epoch 24:  coût moyen validation = 0.3706243634223938
# -------- > epoch 24:  taux moyen validation = 0.8977004885673523
# -------- > epoch 25:  coût moyen entraînement = 0.10920025408267975
# -------- > epoch 25:  taux moyen entraînement = 0.9589009284973145
# -------- > epoch 25:  coût moyen validation = 0.3706110417842865
# -------- > epoch 25:  taux moyen validation = 0.9016000628471375
# -------- > epoch 26:  coût moyen entraînement = 0.11006250232458115
# -------- > epoch 26:  taux moyen entraînement = 0.9590609669685364
# -------- > epoch 26:  coût moyen validation = 0.3866412341594696
# -------- > epoch 26:  taux moyen validation = 0.8956001400947571
# -------- > epoch 27:  coût moyen entraînement = 0.10514182597398758
# -------- > epoch 27:  taux moyen entraînement = 0.9608413577079773
# -------- > epoch 27:  coût moyen validation = 0.41158053278923035
# -------- > epoch 27:  taux moyen validation = 0.8898000121116638
# -------- > epoch 28:  coût moyen entraînement = 0.10544722527265549
# -------- > epoch 28:  taux moyen entraînement = 0.9590011239051819
# -------- > epoch 28:  coût moyen validation = 0.42005017399787903
# -------- > epoch 28:  taux moyen validation = 0.892500102519989
# -------- > epoch 29:  coût moyen entraînement = 0.09258412569761276
# -------- > epoch 29:  taux moyen entraînement = 0.965121328830719
# -------- > epoch 29:  coût moyen validation = 0.4553785026073456
# -------- > epoch 29:  taux moyen validation = 0.8855000138282776
# -------- > epoch 30:  coût moyen entraînement = 0.09234277904033661
# -------- > epoch 30:  taux moyen entraînement = 0.9656612277030945
# -------- > epoch 30:  coût moyen validation = 0.4435129165649414
# -------- > epoch 30:  taux moyen validation = 0.8938999772071838

# %%
X = torch.randn(size=(1, 1, 28, 28), dtype=torch.float32)
for une_couche in modele:
    X = une_couche(X)
    print('Type de couche:',une_couche.__class__.__name__,'  Forme de sortie:',X.shape)
# Out:
# Type de couche: Conv2d   Forme de sortie: torch.Size([1, 6, 28, 28])
# Type de couche: Tanh   Forme de sortie: torch.Size([1, 6, 28, 28])
# Type de couche: AvgPool2d   Forme de sortie: torch.Size([1, 6, 14, 14])
# Type de couche: Conv2d   Forme de sortie: torch.Size([1, 16, 10, 10])
# Type de couche: Tanh   Forme de sortie: torch.Size([1, 16, 10, 10])
# Type de couche: AvgPool2d   Forme de sortie: torch.Size([1, 16, 5, 5])
# Type de couche: Flatten   Forme de sortie: torch.Size([1, 400])
# Type de couche: Linear   Forme de sortie: torch.Size([1, 120])
# Type de couche: Tanh   Forme de sortie: torch.Size([1, 120])
# Type de couche: Linear   Forme de sortie: torch.Size([1, 84])
# Type de couche: Tanh   Forme de sortie: torch.Size([1, 84])
# Type de couche: Linear   Forme de sortie: torch.Size([1, 10])

# %%
optimiseur = optim.SGD(modele.parameters(), lr=0.001)
entrainer(modele, dl_ent, dl_valid, optimiseur, nb_epochs=10)
# Out:
# -------- > epoch 1:  coût moyen entraînement = 0.03446153923869133
# -------- > epoch 1:  taux moyen entraînement = 0.9897797107696533
# -------- > epoch 1:  coût moyen validation = 0.047925323247909546
# -------- > epoch 1:  taux moyen validation = 0.9848001599311829
# -------- > epoch 2:  coût moyen entraînement = 0.032589782029390335
# -------- > epoch 2:  taux moyen entraînement = 0.9904400706291199
# -------- > epoch 2:  coût moyen validation = 0.046702370047569275
# -------- > epoch 2:  taux moyen validation = 0.9857003092765808
# -------- > epoch 3:  coût moyen entraînement = 0.03162141516804695
# -------- > epoch 3:  taux moyen entraînement = 0.9906794428825378
# -------- > epoch 3:  coût moyen validation = 0.04602151736617088
# -------- > epoch 3:  taux moyen validation = 0.985900342464447
# -------- > epoch 4:  coût moyen entraînement = 0.031067242845892906
# -------- > epoch 4:  taux moyen entraînement = 0.9907993078231812
# -------- > epoch 4:  coût moyen validation = 0.04559771716594696
# -------- > epoch 4:  taux moyen validation = 0.986000120639801
# -------- > epoch 5:  coût moyen entraînement = 0.030719542875885963
# -------- > epoch 5:  taux moyen entraînement = 0.9911195635795593
# -------- > epoch 5:  coût moyen validation = 0.045308489352464676
# -------- > epoch 5:  taux moyen validation = 0.9856002330780029
# -------- > epoch 6:  coût moyen entraînement = 0.03048531711101532
# -------- > epoch 6:  taux moyen entraînement = 0.9911195039749146
# -------- > epoch 6:  coût moyen validation = 0.045095715671777725
# -------- > epoch 6:  taux moyen validation = 0.9860002994537354
# -------- > epoch 7:  coût moyen entraînement = 0.030320992693305016
# -------- > epoch 7:  taux moyen entraînement = 0.9912799000740051
# -------- > epoch 7:  coût moyen validation = 0.04492877423763275
# -------- > epoch 7:  taux moyen validation = 0.9861002564430237
# -------- > epoch 8:  coût moyen entraînement = 0.03019868955016136
# -------- > epoch 8:  taux moyen entraînement = 0.9912192821502686
# -------- > epoch 8:  coût moyen validation = 0.04479596018791199
# -------- > epoch 8:  taux moyen validation = 0.9860002398490906
# -------- > epoch 9:  coût moyen entraînement = 0.030104702338576317
# -------- > epoch 9:  taux moyen entraînement = 0.9911995530128479
# -------- > epoch 9:  coût moyen validation = 0.04468608275055885
# -------- > epoch 9:  taux moyen validation = 0.9860002398490906
# -------- > epoch 10:  coût moyen entraînement = 0.03002971224486828
# -------- > epoch 10:  taux moyen entraînement = 0.9911995530128479
# -------- > epoch 10:  coût moyen validation = 0.04458840936422348
# -------- > epoch 10:  taux moyen validation = 0.9860002398490906
