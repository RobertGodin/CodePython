# %%
# %matplotlib inline
# -*- coding: utf-8 -*-
"""
Exercice: FashionMNIST avec PyTorch
Exemple avec nn.Sequential et F.cross_entropy
Production de métriques avec graphes
Fonction entrainer
"""
import torch
torch.manual_seed(0) # Pour résultats reproductibles

# Fonction J d'entropie croisée
import torch.nn.functional as F
fonction_cout = F.cross_entropy

def taux_bonnes_predictions(lot_Y_predictions, lot_Y):
    predictions_categorie = torch.argmax(lot_Y_predictions, dim=1)
    return (predictions_categorie == lot_Y).float().mean()

from torch import nn
# Définition de l'architecture du RNA

class BlocResNetSimple(nn.Module):
    def __init__(self, nb_f):
        super().__init__()

        self.conv1 = nn.Conv2d(nb_f, nb_f, kernel_size=3, stride=1, padding=1, bias=False) 
        self.bn1 = nn.BatchNorm2d(nb_f)    
        self.relu = nn.ReLU(inplace=True)
        self.conv2 = nn.Conv2d(nb_f, nb_f, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(nb_f)    

    def forward(self, lot_X):
        lot_Y_predictions = self.conv1(lot_X)
        lot_Y_predictions = self.bn1(lot_Y_predictions)
        lot_Y_predictions = F.relu(lot_Y_predictions)
        lot_Y_predictions = self.conv2(lot_Y_predictions)
        lot_Y_predictions = self.bn2(lot_Y_predictions)
        lot_Y_predictions = lot_Y_predictions + lot_X
        lot_Y_predictions = F.relu(lot_Y_predictions)
        return lot_Y_predictions 

modele = nn.Sequential(
    nn.Conv2d(1,8,3,2,1),
    nn.BatchNorm2d(8),
    nn.ReLU(),
    BlocResNetSimple(8),
    nn.Conv2d(8,16,3,2,1),
    nn.BatchNorm2d(16),
    nn.ReLU(),    
    BlocResNetSimple(16),
    nn.Conv2d(16,32,3,2,1),
    nn.BatchNorm2d(32),
    nn.ReLU(),    
    BlocResNetSimple(32),
    nn.Conv2d(32,16,3,2,1),
    nn.BatchNorm2d(16),
    nn.ReLU(),
    nn.Conv2d(16,10,3,2,1),
    nn.BatchNorm2d(10),
    nn.ReLU(),
    nn.Flatten()
)

from torch import optim
optimiseur = optim.SGD(modele.parameters(), lr=0.01)

import torchvision
import torchvision.transforms as transforms

#Chargement des données
ds = torchvision.datasets.FashionMNIST(root = "./data", train = True, download = True, transform = transforms.ToTensor())
ds_ent, ds_valid = torch.utils.data.random_split(ds, [50000, 10000])
ds_test = torchvision.datasets.FashionMNIST(root = "./data", train = False, download = True, transform = transforms.ToTensor())

#Création du DataLoader avec le dataset
dl_ent = torch.utils.data.DataLoader(ds_ent, batch_size=100, shuffle = True)
dl_valid = torch.utils.data.DataLoader(ds_valid, batch_size=100)

def entrainer(modele, dl_ent, dl_valid, optimiseur, nb_epochs=10):

    # Listes pour les métriques par epoch
    liste_cout_moyen_ent = []
    liste_taux_moyen_ent = []
    liste_cout_moyen_valid = []
    liste_taux_moyen_valid = []
    
    # Boucle d'apprentissage
    for epoch in range(nb_epochs):
        cout_total_ent = 0 # pour cumuler les couts par mini-lot
        taux_bonnes_predictions_ent = 0 # pour cumuler les taux par mini-lot
        modele.train() # Pour certains types de couches (nn.BatchNorm2d, nn.Dropout, ...)
        
        # Boucle d'apprentissage par mini-lot pour une epoch
        for lot_X, lot_Y in dl_ent:
            optimiseur.zero_grad() # Remettre les dérivées à zéro
            lot_Y_predictions = modele(lot_X) # Appel de la méthode forward
            cout = fonction_cout(lot_Y_predictions, lot_Y)
            cout.backward() # Calcul des gradiants par rétropropagation
            with torch.no_grad():
                cout_total_ent +=cout
                taux_bonnes_predictions_ent += taux_bonnes_predictions(lot_Y_predictions, lot_Y)
            optimiseur.step() # Mise à jour des paramètres
        # Calculer les moyennes par mini-lot
        with torch.no_grad():
            cout_moyen_ent = cout_total_ent/len(dl_ent)
            taux_moyen_ent = taux_bonnes_predictions_ent/len(dl_ent)
       
        modele.eval() # Pour certains types de couches (nn.BatchNorm2d, nn.Dropout, ...)
        with torch.no_grad():
            cout_valid = sum(fonction_cout(modele(lot_valid_X), lot_valid_Y) for lot_valid_X, lot_valid_Y in dl_valid)
            taux_bons_valid = sum(taux_bonnes_predictions(modele(lot_valid_X), lot_valid_Y) for lot_valid_X, lot_valid_Y in dl_valid)
        cout_moyen_valid = cout_valid/len(dl_valid)
        taux_moyen_valid = taux_bons_valid/len(dl_valid)
        print(f'-------- > epoch {epoch+1}:  coût moyen entraînement = {cout_moyen_ent}')
        print(f'-------- > epoch {epoch+1}:  taux moyen entraînement = {taux_moyen_ent}')
        print(f'-------- > epoch {epoch+1}:  coût moyen validation = {cout_moyen_valid}')
        print(f'-------- > epoch {epoch+1}:  taux moyen validation = {taux_moyen_valid}')
    
        liste_cout_moyen_ent.append(cout_moyen_ent)
        liste_taux_moyen_ent.append(taux_moyen_ent)
        liste_cout_moyen_valid.append(cout_moyen_valid)
        liste_taux_moyen_valid.append(taux_moyen_valid)
    
    # Affichage du graphique d'évolution des métriques par epoch
    import numpy as np
    import matplotlib.pyplot as plt
    plt.plot(np.arange(0,nb_epochs),liste_cout_moyen_ent,label='Erreur entraînement')
    plt.plot(np.arange(0,nb_epochs),liste_cout_moyen_valid,label='Erreur validation')
    plt.title("Evolution du coût")
    plt.xlabel('epoch')
    plt.ylabel('moyenne par observation')
    plt.legend(loc='upper center')
    plt.show()
        
    plt.plot(np.arange(0,nb_epochs),liste_taux_moyen_ent,label='Taux bonnes réponses entraînement')
    plt.plot(np.arange(0,nb_epochs),liste_taux_moyen_valid,label='Taux bonnes réponses validation')
    plt.title("Evolution du taux")
    plt.xlabel('epoch')
    plt.ylabel('moyenne par observation')
    plt.legend(loc='lower center')
    plt.show()

entrainer(modele, dl_ent, dl_valid, optimiseur, nb_epochs=30)
# Out:
# -------- > epoch 1:  coût moyen entraînement = 0.8514282703399658
# -------- > epoch 1:  taux moyen entraînement = 0.7903590798377991
# -------- > epoch 1:  coût moyen validation = 0.6089906692504883
# -------- > epoch 1:  taux moyen validation = 0.8560000061988831
# -------- > epoch 2:  coût moyen entraînement = 0.5528355836868286
# -------- > epoch 2:  taux moyen entraînement = 0.8603597283363342
# -------- > epoch 2:  coût moyen validation = 0.497549444437027
# -------- > epoch 2:  taux moyen validation = 0.8667997717857361
# -------- > epoch 3:  coût moyen entraînement = 0.4608239233493805
# -------- > epoch 3:  taux moyen entraînement = 0.8759206533432007
# -------- > epoch 3:  coût moyen validation = 0.45073401927948
# -------- > epoch 3:  taux moyen validation = 0.872700035572052
# -------- > epoch 4:  coût moyen entraînement = 0.40780109167099
# -------- > epoch 4:  taux moyen entraînement = 0.8839202523231506
# -------- > epoch 4:  coût moyen validation = 0.41459429264068604
# -------- > epoch 4:  taux moyen validation = 0.8759997487068176
# -------- > epoch 5:  coût moyen entraînement = 0.3722047805786133
# -------- > epoch 5:  taux moyen entraînement = 0.891080379486084
# -------- > epoch 5:  coût moyen validation = 0.37761715054512024
# -------- > epoch 5:  taux moyen validation = 0.8858999609947205
# -------- > epoch 6:  coût moyen entraînement = 0.3484463393688202
# -------- > epoch 6:  taux moyen entraînement = 0.8954811692237854
# -------- > epoch 6:  coût moyen validation = 0.36119166016578674
# -------- > epoch 6:  taux moyen validation = 0.8867997527122498
# -------- > epoch 7:  coût moyen entraînement = 0.32601940631866455
# -------- > epoch 7:  taux moyen entraînement = 0.9018404483795166
# -------- > epoch 7:  coût moyen validation = 0.3611128330230713
# -------- > epoch 7:  taux moyen validation = 0.883999764919281
# -------- > epoch 8:  coût moyen entraînement = 0.3101081848144531
# -------- > epoch 8:  taux moyen entraînement = 0.904080331325531
# -------- > epoch 8:  coût moyen validation = 0.33894237875938416
# -------- > epoch 8:  taux moyen validation = 0.8909999132156372
# -------- > epoch 9:  coût moyen entraînement = 0.2948455810546875
# -------- > epoch 9:  taux moyen entraînement = 0.9093202948570251
# -------- > epoch 9:  coût moyen validation = 0.35279595851898193
# -------- > epoch 9:  taux moyen validation = 0.8849999308586121
# -------- > epoch 10:  coût moyen entraînement = 0.28218647837638855
# -------- > epoch 10:  taux moyen entraînement = 0.9119205474853516
# -------- > epoch 10:  coût moyen validation = 0.32380715012550354
# -------- > epoch 10:  taux moyen validation = 0.8942999839782715
# -------- > epoch 11:  coût moyen entraînement = 0.27058085799217224
# -------- > epoch 11:  taux moyen entraînement = 0.9136209487915039
# -------- > epoch 11:  coût moyen validation = 0.3503227233886719
# -------- > epoch 11:  taux moyen validation = 0.8875002264976501
# -------- > epoch 12:  coût moyen entraînement = 0.2617262899875641
# -------- > epoch 12:  taux moyen entraînement = 0.9168010354042053
# -------- > epoch 12:  coût moyen validation = 0.32880792021751404
# -------- > epoch 12:  taux moyen validation = 0.8938998579978943
# -------- > epoch 13:  coût moyen entraînement = 0.25025588274002075
# -------- > epoch 13:  taux moyen entraînement = 0.9210612177848816
# -------- > epoch 13:  coût moyen validation = 0.3637969493865967
# -------- > epoch 13:  taux moyen validation = 0.8763999342918396
# -------- > epoch 14:  coût moyen entraînement = 0.24314838647842407
# -------- > epoch 14:  taux moyen entraînement = 0.9222007989883423
# -------- > epoch 14:  coût moyen validation = 0.3477462828159332
# -------- > epoch 14:  taux moyen validation = 0.8852998614311218
# -------- > epoch 15:  coût moyen entraînement = 0.2355363368988037
# -------- > epoch 15:  taux moyen entraînement = 0.9260013103485107
# -------- > epoch 15:  coût moyen validation = 0.337829053401947
# -------- > epoch 15:  taux moyen validation = 0.8877002596855164
# -------- > epoch 16:  coût moyen entraînement = 0.2236950695514679
# -------- > epoch 16:  taux moyen entraînement = 0.9295410513877869
# -------- > epoch 16:  coût moyen validation = 0.32393303513526917
# -------- > epoch 16:  taux moyen validation = 0.8958998322486877
# -------- > epoch 17:  coût moyen entraînement = 0.2204056978225708
# -------- > epoch 17:  taux moyen entraînement = 0.9289209246635437
# -------- > epoch 17:  coût moyen validation = 0.3233788013458252
# -------- > epoch 17:  taux moyen validation = 0.8940998911857605
# -------- > epoch 18:  coût moyen entraînement = 0.21090619266033173
# -------- > epoch 18:  taux moyen entraînement = 0.9321610331535339
# -------- > epoch 18:  coût moyen validation = 0.32579556107521057
# -------- > epoch 18:  taux moyen validation = 0.8948997259140015
# -------- > epoch 19:  coût moyen entraînement = 0.2049294263124466
# -------- > epoch 19:  taux moyen entraînement = 0.9346417188644409
# -------- > epoch 19:  coût moyen validation = 0.3342023193836212
# -------- > epoch 19:  taux moyen validation = 0.8925999402999878
# -------- > epoch 20:  coût moyen entraînement = 0.19903036952018738
# -------- > epoch 20:  taux moyen entraînement = 0.9361814260482788
# -------- > epoch 20:  coût moyen validation = 0.3388577401638031
# -------- > epoch 20:  taux moyen validation = 0.8915002346038818
# -------- > epoch 21:  coût moyen entraînement = 0.195558100938797
# -------- > epoch 21:  taux moyen entraînement = 0.9373610019683838
# -------- > epoch 21:  coût moyen validation = 0.33749666810035706
# -------- > epoch 21:  taux moyen validation = 0.8892002105712891
# -------- > epoch 22:  coût moyen entraînement = 0.18914133310317993
# -------- > epoch 22:  taux moyen entraînement = 0.9384812712669373
# -------- > epoch 22:  coût moyen validation = 0.33801060914993286
# -------- > epoch 22:  taux moyen validation = 0.890999972820282
# -------- > epoch 23:  coût moyen entraînement = 0.18444107472896576
# -------- > epoch 23:  taux moyen entraînement = 0.9410414099693298
# -------- > epoch 23:  coût moyen validation = 0.3316311538219452
# -------- > epoch 23:  taux moyen validation = 0.8944000005722046
# -------- > epoch 24:  coût moyen entraînement = 0.1800084114074707
# -------- > epoch 24:  taux moyen entraînement = 0.9417809247970581
# -------- > epoch 24:  coût moyen validation = 0.3402401804924011
# -------- > epoch 24:  taux moyen validation = 0.8888000249862671
# -------- > epoch 25:  coût moyen entraînement = 0.17290303111076355
# -------- > epoch 25:  taux moyen entraînement = 0.9439804553985596
# -------- > epoch 25:  coût moyen validation = 0.3526550531387329
# -------- > epoch 25:  taux moyen validation = 0.8878999352455139
# -------- > epoch 26:  coût moyen entraînement = 0.16597524285316467
# -------- > epoch 26:  taux moyen entraînement = 0.9457412362098694
# -------- > epoch 26:  coût moyen validation = 0.326717346906662
# -------- > epoch 26:  taux moyen validation = 0.895000159740448
# -------- > epoch 27:  coût moyen entraînement = 0.1640690267086029
# -------- > epoch 27:  taux moyen entraînement = 0.9480412602424622
# -------- > epoch 27:  coût moyen validation = 0.3354153335094452
# -------- > epoch 27:  taux moyen validation = 0.8948000073432922
# -------- > epoch 28:  coût moyen entraînement = 0.15869076550006866
# -------- > epoch 28:  taux moyen entraînement = 0.9490408301353455
# -------- > epoch 28:  coût moyen validation = 0.37018710374832153
# -------- > epoch 28:  taux moyen validation = 0.8883001804351807
# -------- > epoch 29:  coût moyen entraînement = 0.1573050618171692
# -------- > epoch 29:  taux moyen entraînement = 0.9488614797592163
# -------- > epoch 29:  coût moyen validation = 0.34093010425567627
# -------- > epoch 29:  taux moyen validation = 0.8918001055717468
# -------- > epoch 30:  coût moyen entraînement = 0.15097761154174805
# -------- > epoch 30:  taux moyen entraînement = 0.9512411952018738
# -------- > epoch 30:  coût moyen validation = 0.3390728831291199
# -------- > epoch 30:  taux moyen validation = 0.8934003710746765
