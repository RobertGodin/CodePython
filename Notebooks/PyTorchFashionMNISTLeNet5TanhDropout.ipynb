# %%
# %matplotlib inline
# -*- coding: utf-8 -*-
"""
Exemple FashionMNIST avec RNA semblable à LeNet-5 (LeCun et al.) plus Dropout
"""
import torch
torch.manual_seed(0) # Pour résultats reproductibles

# Fonction J d'entropie croisée
import torch.nn.functional as F
fonction_cout = F.cross_entropy

def taux_bonnes_predictions(lot_Y_predictions, lot_Y):
    predictions_categorie = torch.argmax(lot_Y_predictions, dim=1)
    return (predictions_categorie == lot_Y).float().mean()

from torch import nn
# Définition de l'architecture du RNA

modele = torch.nn.Sequential(
    nn.Conv2d(1, 6, kernel_size=5, padding=2), nn.Tanh(), #(N, 1, 28, 28) -> (N, 6, 28, 28)
    nn.AvgPool2d(kernel_size=2, stride=2), #(N, 6, 28, 28) -> (N, 6, 14, 14)
    nn.Conv2d(6, 16, kernel_size=5), nn.Tanh(), #(N, 6, 14, 14) -> (N, 16, 10, 10)
    nn.AvgPool2d(kernel_size=2, stride=2), #(N, 16, 10, 10) -> (N, 16, 5, 5)
    nn.Flatten(), #(N, 16, 5, 5) -> (N, 400)
    nn.Linear(16 * 5 * 5, 120), nn.Tanh(), #(N, 400) -> (N, 120)
    nn.Dropout(0.5), #(N, 120) -> (N, 120)
    nn.Linear(120, 84), nn.Tanh(), #(N, 120) -> (N, 84)
    nn.Dropout(0.5), #(N, 84) -> (N, 84)
    nn.Linear(84, 10)) #(N, 84) -> (N, 10)

from torch import optim
optimiseur = optim.SGD(modele.parameters(), lr=0.5)

import torchvision
import torchvision.transforms as transforms

#Chargement des données
ds = torchvision.datasets.FashionMNIST(root = "./data", train = True, download = True, transform = transforms.ToTensor())
ds_ent, ds_valid = torch.utils.data.random_split(ds, [50000, 10000])
ds_test = torchvision.datasets.FashionMNIST(root = "./data", train = False, download = True, transform = transforms.ToTensor())

#Création du DataLoader avec le dataset
dl_ent = torch.utils.data.DataLoader(ds_ent, batch_size=100, shuffle = True)
dl_valid = torch.utils.data.DataLoader(ds_valid, batch_size=100)

def entrainer(modele, dl_ent, dl_valid, optimiseur, nb_epochs=10):

    # Listes pour les métriques par epoch
    liste_cout_moyen_ent = []
    liste_taux_moyen_ent = []
    liste_cout_moyen_valid = []
    liste_taux_moyen_valid = []
    
    # Boucle d'apprentissage
    for epoch in range(nb_epochs):
        cout_total_ent = 0 # pour cumuler les couts par mini-lot
        taux_bonnes_predictions_ent = 0 # pour cumuler les taux par mini-lot
        modele.train() # Pour certains types de couches (nn.BatchNorm2d, nn.Dropout, ...)
        
        # Boucle d'apprentissage par mini-lot pour une epoch
        for lot_X, lot_Y in dl_ent:
            optimiseur.zero_grad() # Remettre les dérivées à zéro
            lot_Y_predictions = modele(lot_X) # Appel de la méthode forward
            cout = fonction_cout(lot_Y_predictions, lot_Y)
            cout.backward() # Calcul des gradiants par rétropropagation
            with torch.no_grad():
                cout_total_ent +=cout
                taux_bonnes_predictions_ent += taux_bonnes_predictions(lot_Y_predictions, lot_Y)
            optimiseur.step() # Mise à jour des paramètres
        # Calculer les moyennes par mini-lot
        with torch.no_grad():
            cout_moyen_ent = cout_total_ent/len(dl_ent)
            taux_moyen_ent = taux_bonnes_predictions_ent/len(dl_ent)
       
        modele.eval() # Pour certains types de couches (nn.BatchNorm2d, nn.Dropout, ...)
        with torch.no_grad():
            cout_valid = sum(fonction_cout(modele(lot_valid_X), lot_valid_Y) for lot_valid_X, lot_valid_Y in dl_valid)
            taux_bons_valid = sum(taux_bonnes_predictions(modele(lot_valid_X), lot_valid_Y) for lot_valid_X, lot_valid_Y in dl_valid)
        cout_moyen_valid = cout_valid/len(dl_valid)
        taux_moyen_valid = taux_bons_valid/len(dl_valid)
        print(f'-------- > epoch {epoch+1}:  coût moyen entraînement = {cout_moyen_ent}')
        print(f'-------- > epoch {epoch+1}:  taux moyen entraînement = {taux_moyen_ent}')
        print(f'-------- > epoch {epoch+1}:  coût moyen validation = {cout_moyen_valid}')
        print(f'-------- > epoch {epoch+1}:  taux moyen validation = {taux_moyen_valid}')
    
        liste_cout_moyen_ent.append(cout_moyen_ent)
        liste_taux_moyen_ent.append(taux_moyen_ent)
        liste_cout_moyen_valid.append(cout_moyen_valid)
        liste_taux_moyen_valid.append(taux_moyen_valid)
    
    # Affichage du graphique d'évolution des métriques par epoch
    import numpy as np
    import matplotlib.pyplot as plt
    plt.plot(np.arange(0,nb_epochs),liste_cout_moyen_ent,label='Erreur entraînement')
    plt.plot(np.arange(0,nb_epochs),liste_cout_moyen_valid,label='Erreur validation')
    plt.title("Evolution du coût")
    plt.xlabel('epoch')
    plt.ylabel('moyenne par observation')
    plt.legend(loc='upper center')
    plt.show()
        
    plt.plot(np.arange(0,nb_epochs),liste_taux_moyen_ent,label='Taux bonnes réponses entraînement')
    plt.plot(np.arange(0,nb_epochs),liste_taux_moyen_valid,label='Taux bonnes réponses validation')
    plt.title("Evolution du taux")
    plt.xlabel('epoch')
    plt.ylabel('moyenne par observation')
    plt.legend(loc='lower center')
    plt.show()

entrainer(modele, dl_ent, dl_valid, optimiseur, nb_epochs=30)
# Out:
# -------- > epoch 1:  coût moyen entraînement = 0.7705245614051819
# -------- > epoch 1:  taux moyen entraînement = 0.7148198485374451
# -------- > epoch 1:  coût moyen validation = 0.4948522448539734
# -------- > epoch 1:  taux moyen validation = 0.8185997009277344
# -------- > epoch 2:  coût moyen entraînement = 0.5561262965202332
# -------- > epoch 2:  taux moyen entraînement = 0.8039394617080688
# -------- > epoch 2:  coût moyen validation = 0.458660364151001
# -------- > epoch 2:  taux moyen validation = 0.8367001414299011
# -------- > epoch 3:  coût moyen entraînement = 0.5099844932556152
# -------- > epoch 3:  taux moyen entraînement = 0.8222591280937195
# -------- > epoch 3:  coût moyen validation = 0.393039345741272
# -------- > epoch 3:  taux moyen validation = 0.8608999848365784
# -------- > epoch 4:  coût moyen entraînement = 0.4732733368873596
# -------- > epoch 4:  taux moyen entraînement = 0.836139440536499
# -------- > epoch 4:  coût moyen validation = 0.4221453368663788
# -------- > epoch 4:  taux moyen validation = 0.851599931716919
# -------- > epoch 5:  coût moyen entraînement = 0.4575391411781311
# -------- > epoch 5:  taux moyen entraînement = 0.8428595066070557
# -------- > epoch 5:  coût moyen validation = 0.37522372603416443
# -------- > epoch 5:  taux moyen validation = 0.8724001049995422
# -------- > epoch 6:  coût moyen entraînement = 0.4388613998889923
# -------- > epoch 6:  taux moyen entraînement = 0.8490794897079468
# -------- > epoch 6:  coût moyen validation = 0.3683224022388458
# -------- > epoch 6:  taux moyen validation = 0.8760998249053955
# -------- > epoch 7:  coût moyen entraînement = 0.4260856807231903
# -------- > epoch 7:  taux moyen entraînement = 0.8542195558547974
# -------- > epoch 7:  coût moyen validation = 0.3709644079208374
# -------- > epoch 7:  taux moyen validation = 0.8757999539375305
# -------- > epoch 8:  coût moyen entraînement = 0.4127328395843506
# -------- > epoch 8:  taux moyen entraînement = 0.8610997796058655
# -------- > epoch 8:  coût moyen validation = 0.3626793324947357
# -------- > epoch 8:  taux moyen validation = 0.8772000074386597
# -------- > epoch 9:  coût moyen entraînement = 0.4032234847545624
# -------- > epoch 9:  taux moyen entraînement = 0.8615602850914001
# -------- > epoch 9:  coût moyen validation = 0.34785953164100647
# -------- > epoch 9:  taux moyen validation = 0.8807002305984497
# -------- > epoch 10:  coût moyen entraînement = 0.39730092883110046
# -------- > epoch 10:  taux moyen entraînement = 0.8645799160003662
# -------- > epoch 10:  coût moyen validation = 0.3338969349861145
# -------- > epoch 10:  taux moyen validation = 0.8886997699737549
# -------- > epoch 11:  coût moyen entraînement = 0.38479769229888916
# -------- > epoch 11:  taux moyen entraînement = 0.8706396222114563
# -------- > epoch 11:  coût moyen validation = 0.3463610112667084
# -------- > epoch 11:  taux moyen validation = 0.8833999633789062
# -------- > epoch 12:  coût moyen entraînement = 0.38100436329841614
# -------- > epoch 12:  taux moyen entraînement = 0.8717602491378784
# -------- > epoch 12:  coût moyen validation = 0.3301484286785126
# -------- > epoch 12:  taux moyen validation = 0.8901001811027527
# -------- > epoch 13:  coût moyen entraînement = 0.37480446696281433
# -------- > epoch 13:  taux moyen entraînement = 0.8729203939437866
# -------- > epoch 13:  coût moyen validation = 0.3330576717853546
# -------- > epoch 13:  taux moyen validation = 0.8885999917984009
# -------- > epoch 14:  coût moyen entraînement = 0.3667807877063751
# -------- > epoch 14:  taux moyen entraînement = 0.8753198385238647
# -------- > epoch 14:  coût moyen validation = 0.3270655870437622
# -------- > epoch 14:  taux moyen validation = 0.8866001963615417
# -------- > epoch 15:  coût moyen entraînement = 0.36448901891708374
# -------- > epoch 15:  taux moyen entraînement = 0.876319944858551
# -------- > epoch 15:  coût moyen validation = 0.32242316007614136
# -------- > epoch 15:  taux moyen validation = 0.8942999839782715
# -------- > epoch 16:  coût moyen entraînement = 0.3570108413696289
# -------- > epoch 16:  taux moyen entraînement = 0.8780608177185059
# -------- > epoch 16:  coût moyen validation = 0.3223345875740051
# -------- > epoch 16:  taux moyen validation = 0.8958001136779785
# -------- > epoch 17:  coût moyen entraînement = 0.3530474901199341
# -------- > epoch 17:  taux moyen entraînement = 0.8800000548362732
# -------- > epoch 17:  coût moyen validation = 0.30850744247436523
# -------- > epoch 17:  taux moyen validation = 0.8957001566886902
# -------- > epoch 18:  coût moyen entraînement = 0.34891748428344727
# -------- > epoch 18:  taux moyen entraînement = 0.8829004764556885
# -------- > epoch 18:  coût moyen validation = 0.3165851831436157
# -------- > epoch 18:  taux moyen validation = 0.8925999402999878
# -------- > epoch 19:  coût moyen entraînement = 0.3459385931491852
# -------- > epoch 19:  taux moyen entraînement = 0.8829198479652405
# -------- > epoch 19:  coût moyen validation = 0.34511443972587585
# -------- > epoch 19:  taux moyen validation = 0.8825997710227966
# -------- > epoch 20:  coût moyen entraînement = 0.33927178382873535
# -------- > epoch 20:  taux moyen entraînement = 0.8843608498573303
# -------- > epoch 20:  coût moyen validation = 0.3364860415458679
# -------- > epoch 20:  taux moyen validation = 0.8886998891830444
# -------- > epoch 21:  coût moyen entraînement = 0.3402251899242401
# -------- > epoch 21:  taux moyen entraînement = 0.8824605941772461
# -------- > epoch 21:  coût moyen validation = 0.30018511414527893
# -------- > epoch 21:  taux moyen validation = 0.8994998931884766
# -------- > epoch 22:  coût moyen entraînement = 0.33549410104751587
# -------- > epoch 22:  taux moyen entraînement = 0.8863600492477417
# -------- > epoch 22:  coût moyen validation = 0.31581100821495056
# -------- > epoch 22:  taux moyen validation = 0.8982999920845032
# -------- > epoch 23:  coût moyen entraînement = 0.33158767223358154
# -------- > epoch 23:  taux moyen entraînement = 0.8874202370643616
# -------- > epoch 23:  coût moyen validation = 0.3049285411834717
# -------- > epoch 23:  taux moyen validation = 0.9016998410224915
# -------- > epoch 24:  coût moyen entraînement = 0.3255506157875061
# -------- > epoch 24:  taux moyen entraînement = 0.8890206217765808
# -------- > epoch 24:  coût moyen validation = 0.31509992480278015
# -------- > epoch 24:  taux moyen validation = 0.8993999361991882
# -------- > epoch 25:  coût moyen entraînement = 0.32786470651626587
# -------- > epoch 25:  taux moyen entraînement = 0.8886206746101379
# -------- > epoch 25:  coût moyen validation = 0.30807942152023315
# -------- > epoch 25:  taux moyen validation = 0.9014002084732056
# -------- > epoch 26:  coût moyen entraînement = 0.32718130946159363
# -------- > epoch 26:  taux moyen entraînement = 0.8896203637123108
# -------- > epoch 26:  coût moyen validation = 0.3089621961116791
# -------- > epoch 26:  taux moyen validation = 0.8973001837730408
# -------- > epoch 27:  coût moyen entraînement = 0.31836453080177307
# -------- > epoch 27:  taux moyen entraînement = 0.8917803764343262
# -------- > epoch 27:  coût moyen validation = 0.3004879653453827
# -------- > epoch 27:  taux moyen validation = 0.9002001285552979
# -------- > epoch 28:  coût moyen entraînement = 0.3155446946620941
# -------- > epoch 28:  taux moyen entraînement = 0.8932011127471924
# -------- > epoch 28:  coût moyen validation = 0.3297850787639618
# -------- > epoch 28:  taux moyen validation = 0.8962999582290649
# -------- > epoch 29:  coût moyen entraînement = 0.31376296281814575
# -------- > epoch 29:  taux moyen entraînement = 0.8949407935142517
# -------- > epoch 29:  coût moyen validation = 0.33243897557258606
# -------- > epoch 29:  taux moyen validation = 0.892799973487854
# -------- > epoch 30:  coût moyen entraînement = 0.3147282600402832
# -------- > epoch 30:  taux moyen entraînement = 0.8935006260871887
# -------- > epoch 30:  coût moyen validation = 0.3103470504283905
# -------- > epoch 30:  taux moyen validation = 0.895099937915802

# %%
X = torch.randn(size=(1, 1, 28, 28), dtype=torch.float32)
for une_couche in modele:
    X = une_couche(X)
    print('Type de couche:',une_couche.__class__.__name__,'  Forme de sortie:',X.shape)
# Out:
# Type de couche: Conv2d   Forme de sortie: torch.Size([1, 6, 28, 28])
# Type de couche: Tanh   Forme de sortie: torch.Size([1, 6, 28, 28])
# Type de couche: AvgPool2d   Forme de sortie: torch.Size([1, 6, 14, 14])
# Type de couche: Conv2d   Forme de sortie: torch.Size([1, 16, 10, 10])
# Type de couche: Tanh   Forme de sortie: torch.Size([1, 16, 10, 10])
# Type de couche: AvgPool2d   Forme de sortie: torch.Size([1, 16, 5, 5])
# Type de couche: Flatten   Forme de sortie: torch.Size([1, 400])
# Type de couche: Linear   Forme de sortie: torch.Size([1, 120])
# Type de couche: Tanh   Forme de sortie: torch.Size([1, 120])
# Type de couche: Dropout   Forme de sortie: torch.Size([1, 120])
# Type de couche: Linear   Forme de sortie: torch.Size([1, 84])
# Type de couche: Tanh   Forme de sortie: torch.Size([1, 84])
# Type de couche: Dropout   Forme de sortie: torch.Size([1, 84])
# Type de couche: Linear   Forme de sortie: torch.Size([1, 10])

# %%
optimiseur = optim.SGD(modele.parameters(), lr=0.001)
entrainer(modele, dl_ent, dl_valid, optimiseur, nb_epochs=10)
# Out:
# -------- > epoch 1:  coût moyen entraînement = 0.025599393993616104
# -------- > epoch 1:  taux moyen entraînement = 0.9927592277526855
# -------- > epoch 1:  coût moyen validation = 0.035949066281318665
# -------- > epoch 1:  taux moyen validation = 0.9917999505996704
# -------- > epoch 2:  coût moyen entraînement = 0.026921860873699188
# -------- > epoch 2:  taux moyen entraînement = 0.9924991726875305
# -------- > epoch 2:  coût moyen validation = 0.03581906855106354
# -------- > epoch 2:  taux moyen validation = 0.991899847984314
# -------- > epoch 3:  coût moyen entraînement = 0.027541300281882286
# -------- > epoch 3:  taux moyen entraînement = 0.9917393922805786
# -------- > epoch 3:  coût moyen validation = 0.035726889967918396
# -------- > epoch 3:  taux moyen validation = 0.991899847984314
# -------- > epoch 4:  coût moyen entraînement = 0.023989228531718254
# -------- > epoch 4:  taux moyen entraînement = 0.9929797649383545
# -------- > epoch 4:  coût moyen validation = 0.035635605454444885
# -------- > epoch 4:  taux moyen validation = 0.991899847984314
# -------- > epoch 5:  coût moyen entraînement = 0.025607656687498093
# -------- > epoch 5:  taux moyen entraînement = 0.9927989840507507
# -------- > epoch 5:  coût moyen validation = 0.035553108900785446
# -------- > epoch 5:  taux moyen validation = 0.991899847984314
# -------- > epoch 6:  coût moyen entraînement = 0.02514885552227497
# -------- > epoch 6:  taux moyen entraînement = 0.993179202079773
# -------- > epoch 6:  coût moyen validation = 0.03547482565045357
# -------- > epoch 6:  taux moyen validation = 0.9918999671936035
# -------- > epoch 7:  coût moyen entraînement = 0.02573227696120739
# -------- > epoch 7:  taux moyen entraînement = 0.9924994707107544
# -------- > epoch 7:  coût moyen validation = 0.03542150929570198
# -------- > epoch 7:  taux moyen validation = 0.9918999671936035
# -------- > epoch 8:  coût moyen entraînement = 0.024452751502394676
# -------- > epoch 8:  taux moyen entraînement = 0.9929794669151306
# -------- > epoch 8:  coût moyen validation = 0.035355374217033386
# -------- > epoch 8:  taux moyen validation = 0.9919999837875366
# -------- > epoch 9:  coût moyen entraînement = 0.02606963738799095
# -------- > epoch 9:  taux moyen entraînement = 0.9927794337272644
# -------- > epoch 9:  coût moyen validation = 0.03530792146921158
# -------- > epoch 9:  taux moyen validation = 0.992099940776825
# -------- > epoch 10:  coût moyen entraînement = 0.024271460250020027
# -------- > epoch 10:  taux moyen entraînement = 0.9927195906639099
# -------- > epoch 10:  coût moyen validation = 0.03524084389209747
# -------- > epoch 10:  taux moyen validation = 0.9919998645782471
