# %%
# %matplotlib inline
# -*- coding: utf-8 -*-
"""
Exemple simple de MNIST avec PyTorch
Exemple avec nn.Conv2d et F.cross_entropy
Production de métriques avec graphes
Fonction entrainer
"""
import torch
torch.manual_seed(0) # Pour résultats reproductibles

# Fonction J d'entropie croisée
import torch.nn.functional as F
fonction_cout = F.cross_entropy

def taux_bonnes_predictions(lot_Y_predictions, lot_Y):
    predictions_categorie = torch.argmax(lot_Y_predictions, dim=1)
    return (predictions_categorie == lot_Y).float().mean()

from torch import nn
# Définition de l'architecture du RNA

modele = nn.Sequential(
    nn.Conv2d(1,32,3), # 1 canal, 16 filtres, dimension 3 par 3
    nn.ReLU(),
    nn.Flatten(),
    nn.Linear(26*26*32,10)
)
    
from torch import optim
optimiseur = optim.SGD(modele.parameters(), lr=0.01)

# Chargement des données de MNIST
import pickle, gzip
fichier_donnees = gzip.open(r"mnist.pkl.gz", 'rb')
((donnees_ent_X, donnees_ent_Y),(donnees_valid_X, donnees_valid_Y),(donnees_test_X,donnees_test_Y)) = pickle.load(fichier_donnees, encoding="latin-1")
fichier_donnees.close()

# Conversion des données en type toch.Tensor
import torch
donnees_ent_X,donnees_ent_Y,donnees_valid_X,donnees_valid_Y,donnees_test_X,donnees_test_Y  = map(torch.tensor,
    (donnees_ent_X.reshape((-1,1,28,28)),donnees_ent_Y,donnees_valid_X.reshape((-1,1,28,28)),donnees_valid_Y,donnees_test_X.reshape((-1,1,28,28)),donnees_test_Y))

# Création des objets DataLoader pour itérer par lot
from torch.utils.data import TensorDataset
from torch.utils.data import DataLoader
ds_ent = TensorDataset(donnees_ent_X, donnees_ent_Y)
dl_ent = DataLoader(ds_ent, batch_size=100, shuffle=True)
ds_valid = TensorDataset(donnees_valid_X,donnees_valid_Y)
dl_valid = DataLoader(ds_valid, batch_size=100)

def entrainer(modele, dl_ent, dl_valid, optimiseur, nb_epochs=10):

    # Listes pour les métriques par epoch
    liste_cout_moyen_ent = []
    liste_taux_moyen_ent = []
    liste_cout_moyen_valid = []
    liste_taux_moyen_valid = []
    
    # Boucle d'apprentissage
    for epoch in range(nb_epochs):
        cout_total_ent = 0 # pour cumuler les couts par mini-lot
        taux_bonnes_predictions_ent = 0 # pour cumuler les taux par mini-lot
        modele.train() # Pour certains types de couches (nn.BatchNorm2d, nn.Dropout, ...)
        
        # Boucle d'apprentissage par mini-lot pour une epoch
        for lot_X, lot_Y in dl_ent:
            optimiseur.zero_grad() # Remettre les dérivées à zéro
            lot_Y_predictions = modele(lot_X) # Appel de la méthode forward
            cout = fonction_cout(lot_Y_predictions, lot_Y)
            cout.backward() # Calcul des gradiants par rétropropagation
            with torch.no_grad():
                cout_total_ent +=cout
                taux_bonnes_predictions_ent += taux_bonnes_predictions(lot_Y_predictions, lot_Y)
            optimiseur.step() # Mise à jour des paramètres
        # Calculer les moyennes par mini-lot
        with torch.no_grad():
            cout_moyen_ent = cout_total_ent/len(dl_ent)
            taux_moyen_ent = taux_bonnes_predictions_ent/len(dl_ent)
       
        modele.eval() # Pour certains types de couches (nn.BatchNorm2d, nn.Dropout, ...)
        with torch.no_grad():
            cout_valid = sum(fonction_cout(modele(lot_valid_X), lot_valid_Y) for lot_valid_X, lot_valid_Y in dl_valid)
            taux_bons_valid = sum(taux_bonnes_predictions(modele(lot_valid_X), lot_valid_Y) for lot_valid_X, lot_valid_Y in dl_valid)
        cout_moyen_valid = cout_valid/len(dl_valid)
        taux_moyen_valid = taux_bons_valid/len(dl_valid)
        print(f'-------- > epoch {epoch+1}:  coût moyen entraînement = {cout_moyen_ent}')
        print(f'-------- > epoch {epoch+1}:  taux moyen entraînement = {taux_moyen_ent}')
        print(f'-------- > epoch {epoch+1}:  coût moyen validation = {cout_moyen_valid}')
        print(f'-------- > epoch {epoch+1}:  taux moyen validation = {taux_moyen_valid}')
    
        liste_cout_moyen_ent.append(cout_moyen_ent)
        liste_taux_moyen_ent.append(taux_moyen_ent)
        liste_cout_moyen_valid.append(cout_moyen_valid)
        liste_taux_moyen_valid.append(taux_moyen_valid)
    
    # Affichage du graphique d'évolution des métriques par epoch
    import numpy as np
    import matplotlib.pyplot as plt
    plt.plot(np.arange(0,nb_epochs),liste_cout_moyen_ent,label='Erreur entraînement')
    plt.plot(np.arange(0,nb_epochs),liste_cout_moyen_valid,label='Erreur validation')
    plt.title("Evolution du coût")
    plt.xlabel('epoch')
    plt.ylabel('moyenne par observation')
    plt.legend(loc='upper center')
    plt.show()
        
    plt.plot(np.arange(0,nb_epochs),liste_taux_moyen_ent,label='Taux bonnes réponses entraînement')
    plt.plot(np.arange(0,nb_epochs),liste_taux_moyen_valid,label='Taux bonnes réponses validation')
    plt.title("Evolution du taux")
    plt.xlabel('epoch')
    plt.ylabel('moyenne par observation')
    plt.legend(loc='upper center')
    plt.show()

entrainer(modele, dl_ent, dl_valid, optimiseur, nb_epochs=50)
# Out:
# -------- > epoch 1:  coût moyen entraînement = 0.5823272466659546
# -------- > epoch 1:  taux moyen entraînement = 0.854460597038269
# -------- > epoch 1:  coût moyen validation = 0.326997846364975
# -------- > epoch 1:  taux moyen validation = 0.9044999480247498
# -------- > epoch 2:  coût moyen entraînement = 0.33170220255851746
# -------- > epoch 2:  taux moyen entraînement = 0.9036409854888916
# -------- > epoch 2:  coût moyen validation = 0.2894449234008789
# -------- > epoch 2:  taux moyen validation = 0.9160000085830688
# -------- > epoch 3:  coût moyen entraînement = 0.30317026376724243
# -------- > epoch 3:  taux moyen entraînement = 0.9126813411712646
# -------- > epoch 3:  coût moyen validation = 0.2707838714122772
# -------- > epoch 3:  taux moyen validation = 0.922700047492981
# -------- > epoch 4:  coût moyen entraînement = 0.28609800338745117
# -------- > epoch 4:  taux moyen entraînement = 0.9180411696434021
# -------- > epoch 4:  coût moyen validation = 0.2585848867893219
# -------- > epoch 4:  taux moyen validation = 0.9257998466491699
# -------- > epoch 5:  coût moyen entraînement = 0.2730863094329834
# -------- > epoch 5:  taux moyen entraînement = 0.9221813082695007
# -------- > epoch 5:  coût moyen validation = 0.24825486540794373
# -------- > epoch 5:  taux moyen validation = 0.9277999997138977
# -------- > epoch 6:  coût moyen entraînement = 0.2616886794567108
# -------- > epoch 6:  taux moyen entraînement = 0.9270212054252625
# -------- > epoch 6:  coût moyen validation = 0.2406083047389984
# -------- > epoch 6:  taux moyen validation = 0.9327998161315918
# -------- > epoch 7:  coût moyen entraînement = 0.25043785572052
# -------- > epoch 7:  taux moyen entraînement = 0.9295814037322998
# -------- > epoch 7:  coût moyen validation = 0.229706808924675
# -------- > epoch 7:  taux moyen validation = 0.9364001750946045
# -------- > epoch 8:  coût moyen entraînement = 0.24001476168632507
# -------- > epoch 8:  taux moyen entraînement = 0.9326611161231995
# -------- > epoch 8:  coût moyen validation = 0.22095146775245667
# -------- > epoch 8:  taux moyen validation = 0.9393999576568604
# -------- > epoch 9:  coût moyen entraînement = 0.22910204529762268
# -------- > epoch 9:  taux moyen entraînement = 0.9360607862472534
# -------- > epoch 9:  coût moyen validation = 0.2126201093196869
# -------- > epoch 9:  taux moyen validation = 0.9415000677108765
# -------- > epoch 10:  coût moyen entraînement = 0.2180355340242386
# -------- > epoch 10:  taux moyen entraînement = 0.9389011263847351
# -------- > epoch 10:  coût moyen validation = 0.20310966670513153
# -------- > epoch 10:  taux moyen validation = 0.9460999369621277
# -------- > epoch 11:  coût moyen entraînement = 0.20739391446113586
# -------- > epoch 11:  taux moyen entraînement = 0.9418008327484131
# -------- > epoch 11:  coût moyen validation = 0.19153593480587006
# -------- > epoch 11:  taux moyen validation = 0.9498001337051392
# -------- > epoch 12:  coût moyen entraînement = 0.1963968575000763
# -------- > epoch 12:  taux moyen entraînement = 0.9453206658363342
# -------- > epoch 12:  coût moyen validation = 0.18327945470809937
# -------- > epoch 12:  taux moyen validation = 0.9527000188827515
# -------- > epoch 13:  coût moyen entraînement = 0.18651926517486572
# -------- > epoch 13:  taux moyen entraînement = 0.9480610489845276
# -------- > epoch 13:  coût moyen validation = 0.1844300627708435
# -------- > epoch 13:  taux moyen validation = 0.9506999850273132
# -------- > epoch 14:  coût moyen entraînement = 0.17706197500228882
# -------- > epoch 14:  taux moyen entraînement = 0.9511803388595581
# -------- > epoch 14:  coût moyen validation = 0.1675868183374405
# -------- > epoch 14:  taux moyen validation = 0.9572001099586487
# -------- > epoch 15:  coût moyen entraînement = 0.1676921397447586
# -------- > epoch 15:  taux moyen entraînement = 0.9537813067436218
# -------- > epoch 15:  coût moyen validation = 0.15799802541732788
# -------- > epoch 15:  taux moyen validation = 0.9600999355316162
# -------- > epoch 16:  coût moyen entraînement = 0.15914449095726013
# -------- > epoch 16:  taux moyen entraînement = 0.9559211134910583
# -------- > epoch 16:  coût moyen validation = 0.15053392946720123
# -------- > epoch 16:  taux moyen validation = 0.9623001217842102
# -------- > epoch 17:  coût moyen entraînement = 0.151283860206604
# -------- > epoch 17:  taux moyen entraînement = 0.9584009647369385
# -------- > epoch 17:  coût moyen validation = 0.14580973982810974
# -------- > epoch 17:  taux moyen validation = 0.9631999135017395
# -------- > epoch 18:  coût moyen entraînement = 0.14408797025680542
# -------- > epoch 18:  taux moyen entraînement = 0.9603813886642456
# -------- > epoch 18:  coût moyen validation = 0.1389353722333908
# -------- > epoch 18:  taux moyen validation = 0.965399980545044
# -------- > epoch 19:  coût moyen entraînement = 0.13704901933670044
# -------- > epoch 19:  taux moyen entraînement = 0.9625614285469055
# -------- > epoch 19:  coût moyen validation = 0.1359415203332901
# -------- > epoch 19:  taux moyen validation = 0.9652000665664673
# -------- > epoch 20:  coût moyen entraînement = 0.1309761106967926
# -------- > epoch 20:  taux moyen entraînement = 0.9644408822059631
# -------- > epoch 20:  coût moyen validation = 0.12804420292377472
# -------- > epoch 20:  taux moyen validation = 0.9673997759819031
# -------- > epoch 21:  coût moyen entraînement = 0.12504777312278748
# -------- > epoch 21:  taux moyen entraînement = 0.9660808444023132
# -------- > epoch 21:  coût moyen validation = 0.1257198005914688
# -------- > epoch 21:  taux moyen validation = 0.9678999185562134
# -------- > epoch 22:  coût moyen entraînement = 0.11993533372879028
# -------- > epoch 22:  taux moyen entraînement = 0.9678208827972412
# -------- > epoch 22:  coût moyen validation = 0.12070666998624802
# -------- > epoch 22:  taux moyen validation = 0.9698998332023621
# -------- > epoch 23:  coût moyen entraînement = 0.11490239202976227
# -------- > epoch 23:  taux moyen entraînement = 0.96940016746521
# -------- > epoch 23:  coût moyen validation = 0.11519885063171387
# -------- > epoch 23:  taux moyen validation = 0.9708998799324036
# -------- > epoch 24:  coût moyen entraînement = 0.11014457792043686
# -------- > epoch 24:  taux moyen entraînement = 0.9706408977508545
# -------- > epoch 24:  coût moyen validation = 0.11254824697971344
# -------- > epoch 24:  taux moyen validation = 0.9713001847267151
# -------- > epoch 25:  coût moyen entraînement = 0.10615048557519913
# -------- > epoch 25:  taux moyen entraînement = 0.9722604155540466
# -------- > epoch 25:  coût moyen validation = 0.11266612261533737
# -------- > epoch 25:  taux moyen validation = 0.972399890422821
# -------- > epoch 26:  coût moyen entraînement = 0.10240843147039413
# -------- > epoch 26:  taux moyen entraînement = 0.9721211791038513
# -------- > epoch 26:  coût moyen validation = 0.10812264680862427
# -------- > epoch 26:  taux moyen validation = 0.9730998873710632
# -------- > epoch 27:  coût moyen entraînement = 0.0987822562456131
# -------- > epoch 27:  taux moyen entraînement = 0.974580705165863
# -------- > epoch 27:  coût moyen validation = 0.10446567833423615
# -------- > epoch 27:  taux moyen validation = 0.9741000533103943
# -------- > epoch 28:  coût moyen entraînement = 0.09546685218811035
# -------- > epoch 28:  taux moyen entraînement = 0.9747807383537292
# -------- > epoch 28:  coût moyen validation = 0.10360490530729294
# -------- > epoch 28:  taux moyen validation = 0.9741000533103943
# -------- > epoch 29:  coût moyen entraînement = 0.09220052510499954
# -------- > epoch 29:  taux moyen entraînement = 0.9757407307624817
# -------- > epoch 29:  coût moyen validation = 0.10143373161554337
# -------- > epoch 29:  taux moyen validation = 0.9741000533103943
# -------- > epoch 30:  coût moyen entraînement = 0.0895153060555458
# -------- > epoch 30:  taux moyen entraînement = 0.9764406681060791
# -------- > epoch 30:  coût moyen validation = 0.09829603135585785
# -------- > epoch 30:  taux moyen validation = 0.9753000140190125
# -------- > epoch 31:  coût moyen entraînement = 0.08709032833576202
# -------- > epoch 31:  taux moyen entraînement = 0.9770405292510986
# -------- > epoch 31:  coût moyen validation = 0.09654893726110458
# -------- > epoch 31:  taux moyen validation = 0.9750999212265015
# -------- > epoch 32:  coût moyen entraînement = 0.08440356701612473
# -------- > epoch 32:  taux moyen entraînement = 0.977780818939209
# -------- > epoch 32:  coût moyen validation = 0.09551350772380829
# -------- > epoch 32:  taux moyen validation = 0.975600004196167
# -------- > epoch 33:  coût moyen entraînement = 0.0824255421757698
# -------- > epoch 33:  taux moyen entraînement = 0.97878098487854
# -------- > epoch 33:  coût moyen validation = 0.0945560559630394
# -------- > epoch 33:  taux moyen validation = 0.9755998849868774
# -------- > epoch 34:  coût moyen entraînement = 0.08001984655857086
# -------- > epoch 34:  taux moyen entraînement = 0.979340672492981
# -------- > epoch 34:  coût moyen validation = 0.09240307658910751
# -------- > epoch 34:  taux moyen validation = 0.9771000146865845
# -------- > epoch 35:  coût moyen entraînement = 0.07814641296863556
# -------- > epoch 35:  taux moyen entraînement = 0.9793808460235596
# -------- > epoch 35:  coût moyen validation = 0.0905703529715538
# -------- > epoch 35:  taux moyen validation = 0.977199912071228
# -------- > epoch 36:  coût moyen entraînement = 0.07612846046686172
# -------- > epoch 36:  taux moyen entraînement = 0.9800400733947754
# -------- > epoch 36:  coût moyen validation = 0.08926323056221008
# -------- > epoch 36:  taux moyen validation = 0.9770000576972961
# -------- > epoch 37:  coût moyen entraînement = 0.07427030056715012
# -------- > epoch 37:  taux moyen entraînement = 0.9805606007575989
# -------- > epoch 37:  coût moyen validation = 0.0894925519824028
# -------- > epoch 37:  taux moyen validation = 0.9768999218940735
# -------- > epoch 38:  coût moyen entraînement = 0.07222917675971985
# -------- > epoch 38:  taux moyen entraînement = 0.9811004400253296
# -------- > epoch 38:  coût moyen validation = 0.08814647793769836
# -------- > epoch 38:  taux moyen validation = 0.9766998291015625
# -------- > epoch 39:  coût moyen entraînement = 0.0709717869758606
# -------- > epoch 39:  taux moyen entraînement = 0.9812803864479065
# -------- > epoch 39:  coût moyen validation = 0.08399374783039093
# -------- > epoch 39:  taux moyen validation = 0.9790000319480896
# -------- > epoch 40:  coût moyen entraînement = 0.06922665238380432
# -------- > epoch 40:  taux moyen entraînement = 0.9815400838851929
# -------- > epoch 40:  coût moyen validation = 0.08480637520551682
# -------- > epoch 40:  taux moyen validation = 0.9778000712394714
# -------- > epoch 41:  coût moyen entraînement = 0.06773436814546585
# -------- > epoch 41:  taux moyen entraînement = 0.9827398061752319
# -------- > epoch 41:  coût moyen validation = 0.08346638083457947
# -------- > epoch 41:  taux moyen validation = 0.9788998961448669
# -------- > epoch 42:  coût moyen entraînement = 0.06644933670759201
# -------- > epoch 42:  taux moyen entraînement = 0.9826197624206543
# -------- > epoch 42:  coût moyen validation = 0.08221469819545746
# -------- > epoch 42:  taux moyen validation = 0.978900134563446
# -------- > epoch 43:  coût moyen entraînement = 0.06503190845251083
# -------- > epoch 43:  taux moyen entraînement = 0.9828404188156128
# -------- > epoch 43:  coût moyen validation = 0.08163398504257202
# -------- > epoch 43:  taux moyen validation = 0.9787999987602234
# -------- > epoch 44:  coût moyen entraînement = 0.06365340203046799
# -------- > epoch 44:  taux moyen entraînement = 0.9832001328468323
# -------- > epoch 44:  coût moyen validation = 0.08162535727024078
# -------- > epoch 44:  taux moyen validation = 0.9783998727798462
# -------- > epoch 45:  coût moyen entraînement = 0.06252467632293701
# -------- > epoch 45:  taux moyen entraînement = 0.9836401343345642
# -------- > epoch 45:  coût moyen validation = 0.08224856108427048
# -------- > epoch 45:  taux moyen validation = 0.9790999889373779
# -------- > epoch 46:  coût moyen entraînement = 0.06128823384642601
# -------- > epoch 46:  taux moyen entraînement = 0.9839199781417847
# -------- > epoch 46:  coût moyen validation = 0.07957876473665237
# -------- > epoch 46:  taux moyen validation = 0.9793000221252441
# -------- > epoch 47:  coût moyen entraînement = 0.06024686247110367
# -------- > epoch 47:  taux moyen entraînement = 0.9838006496429443
# -------- > epoch 47:  coût moyen validation = 0.07833965122699738
# -------- > epoch 47:  taux moyen validation = 0.9796000123023987
# -------- > epoch 48:  coût moyen entraînement = 0.05919157713651657
# -------- > epoch 48:  taux moyen entraînement = 0.9847403764724731
# -------- > epoch 48:  coût moyen validation = 0.07945302128791809
# -------- > epoch 48:  taux moyen validation = 0.9782998561859131
# -------- > epoch 49:  coût moyen entraînement = 0.05801226571202278
# -------- > epoch 49:  taux moyen entraînement = 0.9847602248191833
# -------- > epoch 49:  coût moyen validation = 0.07804057002067566
# -------- > epoch 49:  taux moyen validation = 0.979200005531311
# -------- > epoch 50:  coût moyen entraînement = 0.05702367424964905
# -------- > epoch 50:  taux moyen entraînement = 0.9853001236915588
# -------- > epoch 50:  coût moyen validation = 0.07896542549133301
# -------- > epoch 50:  taux moyen validation = 0.9783000349998474
