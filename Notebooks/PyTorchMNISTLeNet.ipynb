# %%
# %matplotlib inline
# -*- coding: utf-8 -*-
"""
Exemple MNIST avec réseau LeNet (LeCun et al.)
"""
import torch
torch.manual_seed(0) # Pour résultats reproductibles

# Fonction J d'entropie croisée
import torch.nn.functional as F
fonction_cout = F.cross_entropy

def taux_bonnes_predictions(lot_Y_predictions, lot_Y):
    predictions_categorie = torch.argmax(lot_Y_predictions, dim=1)
    return (predictions_categorie == lot_Y).float().mean()

from torch import nn
# Définition de l'architecture du RNA

modele = torch.nn.Sequential(
    nn.Conv2d(1, 6, kernel_size=5, padding=2), nn.Sigmoid(), #(N, 1, 28, 28) -> (N, 6, 28, 28)
    nn.AvgPool2d(kernel_size=2, stride=2), #(N, 6, 28, 28) -> (N, 6, 14, 14)
    nn.Conv2d(6, 16, kernel_size=5), nn.Sigmoid(), #(N, 6, 14, 14) -> (N, 16, 10, 10)
    nn.AvgPool2d(kernel_size=2, stride=2), #(N, 16, 10, 10) -> (N, 16, 5, 5)
    nn.Flatten(), #(N, 16, 5, 5) -> (N, 400)
    nn.Linear(16 * 5 * 5, 120), nn.Sigmoid(), #(N, 400) -> (N, 120)
    nn.Linear(120, 84), nn.Sigmoid(), #(N, 120) -> (N, 84)
    nn.Linear(84, 10)) #(N, 84) -> (N, 10)

from torch import optim
optimiseur = optim.SGD(modele.parameters(), lr=0.5)

import torchvision
import torchvision.transforms as transforms

#Chargement des données
ds = torchvision.datasets.MNIST(root = "./data", train = True, download = True, transform = transforms.ToTensor())
ds_ent, ds_valid = torch.utils.data.random_split(ds, [50000, 10000])
ds_test = torchvision.datasets.MNIST(root = "./data", train = False, download = True, transform = transforms.ToTensor())

#Création du DataLoader avec le dataset
dl_ent = torch.utils.data.DataLoader(ds_ent, batch_size=100, shuffle = True)
dl_valid = torch.utils.data.DataLoader(ds_valid, batch_size=100)

def entrainer(modele, dl_ent, dl_valid, optimiseur, nb_epochs=10):

    # Listes pour les métriques par epoch
    liste_cout_moyen_ent = []
    liste_taux_moyen_ent = []
    liste_cout_moyen_valid = []
    liste_taux_moyen_valid = []
    
    # Boucle d'apprentissage
    for epoch in range(nb_epochs):
        cout_total_ent = 0 # pour cumuler les couts par mini-lot
        taux_bonnes_predictions_ent = 0 # pour cumuler les taux par mini-lot
        modele.train() # Pour certains types de couches (nn.BatchNorm2d, nn.Dropout, ...)
        
        # Boucle d'apprentissage par mini-lot pour une epoch
        for lot_X, lot_Y in dl_ent:
            optimiseur.zero_grad() # Remettre les dérivées à zéro
            lot_Y_predictions = modele(lot_X) # Appel de la méthode forward
            cout = fonction_cout(lot_Y_predictions, lot_Y)
            cout.backward() # Calcul des gradiants par rétropropagation
            with torch.no_grad():
                cout_total_ent +=cout
                taux_bonnes_predictions_ent += taux_bonnes_predictions(lot_Y_predictions, lot_Y)
            optimiseur.step() # Mise à jour des paramètres
        # Calculer les moyennes par mini-lot
        with torch.no_grad():
            cout_moyen_ent = cout_total_ent/len(dl_ent)
            taux_moyen_ent = taux_bonnes_predictions_ent/len(dl_ent)
       
        modele.eval() # Pour certains types de couches (nn.BatchNorm2d, nn.Dropout, ...)
        with torch.no_grad():
            cout_valid = sum(fonction_cout(modele(lot_valid_X), lot_valid_Y) for lot_valid_X, lot_valid_Y in dl_valid)
            taux_bons_valid = sum(taux_bonnes_predictions(modele(lot_valid_X), lot_valid_Y) for lot_valid_X, lot_valid_Y in dl_valid)
        cout_moyen_valid = cout_valid/len(dl_valid)
        taux_moyen_valid = taux_bons_valid/len(dl_valid)
        print(f'-------- > epoch {epoch+1}:  coût moyen entraînement = {cout_moyen_ent}')
        print(f'-------- > epoch {epoch+1}:  taux moyen entraînement = {taux_moyen_ent}')
        print(f'-------- > epoch {epoch+1}:  coût moyen validation = {cout_moyen_valid}')
        print(f'-------- > epoch {epoch+1}:  taux moyen validation = {taux_moyen_valid}')
    
        liste_cout_moyen_ent.append(cout_moyen_ent)
        liste_taux_moyen_ent.append(taux_moyen_ent)
        liste_cout_moyen_valid.append(cout_moyen_valid)
        liste_taux_moyen_valid.append(taux_moyen_valid)
    
    # Affichage du graphique d'évolution des métriques par epoch
    import numpy as np
    import matplotlib.pyplot as plt
    plt.plot(np.arange(0,nb_epochs),liste_cout_moyen_ent,label='Erreur entraînement')
    plt.plot(np.arange(0,nb_epochs),liste_cout_moyen_valid,label='Erreur validation')
    plt.title("Evolution du coût")
    plt.xlabel('epoch')
    plt.ylabel('moyenne par observation')
    plt.legend(loc='upper center')
    plt.show()
        
    plt.plot(np.arange(0,nb_epochs),liste_taux_moyen_ent,label='Taux bonnes réponses entraînement')
    plt.plot(np.arange(0,nb_epochs),liste_taux_moyen_valid,label='Taux bonnes réponses validation')
    plt.title("Evolution du taux")
    plt.xlabel('epoch')
    plt.ylabel('moyenne par observation')
    plt.legend(loc='lower center')
    plt.show()

entrainer(modele, dl_ent, dl_valid, optimiseur, nb_epochs=50)
# Out:
# -------- > epoch 1:  coût moyen entraînement = 2.3127503395080566
# -------- > epoch 1:  taux moyen entraînement = 0.10588002949953079
# -------- > epoch 1:  coût moyen validation = 2.309460163116455
# -------- > epoch 1:  taux moyen validation = 0.10179998725652695
# -------- > epoch 2:  coût moyen entraînement = 2.30346941947937
# -------- > epoch 2:  taux moyen entraînement = 0.1092800423502922
# -------- > epoch 2:  coût moyen validation = 2.3048715591430664
# -------- > epoch 2:  taux moyen validation = 0.10909999161958694
# -------- > epoch 3:  coût moyen entraînement = 2.3025593757629395
# -------- > epoch 3:  taux moyen entraînement = 0.10842005163431168
# -------- > epoch 3:  coût moyen validation = 2.3039252758026123
# -------- > epoch 3:  taux moyen validation = 0.10909999161958694
# -------- > epoch 4:  coût moyen entraînement = 2.3027455806732178
# -------- > epoch 4:  taux moyen entraînement = 0.1089000254869461
# -------- > epoch 4:  coût moyen validation = 2.3032307624816895
# -------- > epoch 4:  taux moyen validation = 0.10909999161958694
# -------- > epoch 5:  coût moyen entraînement = 2.302534818649292
# -------- > epoch 5:  taux moyen entraînement = 0.10870005935430527
# -------- > epoch 5:  coût moyen validation = 2.301525115966797
# -------- > epoch 5:  taux moyen validation = 0.10909999161958694
# -------- > epoch 6:  coût moyen entraînement = 2.302431583404541
# -------- > epoch 6:  taux moyen entraînement = 0.1101800873875618
# -------- > epoch 6:  coût moyen validation = 2.3025646209716797
# -------- > epoch 6:  taux moyen validation = 0.10909999161958694
# -------- > epoch 7:  coût moyen entraînement = 2.302691698074341
# -------- > epoch 7:  taux moyen entraînement = 0.10967997461557388
# -------- > epoch 7:  coût moyen validation = 2.3021183013916016
# -------- > epoch 7:  taux moyen validation = 0.10909999161958694
# -------- > epoch 8:  coût moyen entraînement = 2.302346706390381
# -------- > epoch 8:  taux moyen entraînement = 0.11148007214069366
# -------- > epoch 8:  coût moyen validation = 2.3030850887298584
# -------- > epoch 8:  taux moyen validation = 0.10179998725652695
# -------- > epoch 9:  coût moyen entraînement = 2.3022913932800293
# -------- > epoch 9:  taux moyen entraînement = 0.10954002290964127
# -------- > epoch 9:  coût moyen validation = 2.303427219390869
# -------- > epoch 9:  taux moyen validation = 0.10909999161958694
# -------- > epoch 10:  coût moyen entraînement = 2.3022663593292236
# -------- > epoch 10:  taux moyen entraînement = 0.1096399575471878
# -------- > epoch 10:  coût moyen validation = 2.302351713180542
# -------- > epoch 10:  taux moyen validation = 0.10909999161958694
# -------- > epoch 11:  coût moyen entraînement = 2.3024508953094482
# -------- > epoch 11:  taux moyen entraînement = 0.11030005663633347
# -------- > epoch 11:  coût moyen validation = 2.303107261657715
# -------- > epoch 11:  taux moyen validation = 0.10909999161958694
# -------- > epoch 12:  coût moyen entraînement = 2.302325963973999
# -------- > epoch 12:  taux moyen entraînement = 0.10887998342514038
# -------- > epoch 12:  coût moyen validation = 2.3027377128601074
# -------- > epoch 12:  taux moyen validation = 0.09679999947547913
# -------- > epoch 13:  coût moyen entraînement = 2.302415609359741
# -------- > epoch 13:  taux moyen entraînement = 0.11008001118898392
# -------- > epoch 13:  coût moyen validation = 2.3016357421875
# -------- > epoch 13:  taux moyen validation = 0.10909999161958694
# -------- > epoch 14:  coût moyen entraînement = 2.3023407459259033
# -------- > epoch 14:  taux moyen entraînement = 0.11104007065296173
# -------- > epoch 14:  coût moyen validation = 2.301955461502075
# -------- > epoch 14:  taux moyen validation = 0.10179998725652695
# -------- > epoch 15:  coût moyen entraînement = 2.302363395690918
# -------- > epoch 15:  taux moyen entraînement = 0.10984006524085999
# -------- > epoch 15:  coût moyen validation = 2.302743673324585
# -------- > epoch 15:  taux moyen validation = 0.10909999161958694
# -------- > epoch 16:  coût moyen entraînement = 2.3021795749664307
# -------- > epoch 16:  taux moyen entraînement = 0.1114000529050827
# -------- > epoch 16:  coût moyen validation = 2.3040177822113037
# -------- > epoch 16:  taux moyen validation = 0.10909999161958694
# -------- > epoch 17:  coût moyen entraînement = 2.3022079467773438
# -------- > epoch 17:  taux moyen entraînement = 0.11099997907876968
# -------- > epoch 17:  coût moyen validation = 2.302652359008789
# -------- > epoch 17:  taux moyen validation = 0.10179999470710754
# -------- > epoch 18:  coût moyen entraînement = 2.3023340702056885
# -------- > epoch 18:  taux moyen entraînement = 0.11070002615451813
# -------- > epoch 18:  coût moyen validation = 2.300994396209717
# -------- > epoch 18:  taux moyen validation = 0.10909999161958694
# -------- > epoch 19:  coût moyen entraînement = 2.3017826080322266
# -------- > epoch 19:  taux moyen entraînement = 0.11090002954006195
# -------- > epoch 19:  coût moyen validation = 2.3033385276794434
# -------- > epoch 19:  taux moyen validation = 0.10179999470710754
# -------- > epoch 20:  coût moyen entraînement = 2.301766872406006
# -------- > epoch 20:  taux moyen entraînement = 0.1116800457239151
# -------- > epoch 20:  coût moyen validation = 2.300913095474243
# -------- > epoch 20:  taux moyen validation = 0.10269997268915176
# -------- > epoch 21:  coût moyen entraînement = 2.3018174171447754
# -------- > epoch 21:  taux moyen entraînement = 0.11306004971265793
# -------- > epoch 21:  coût moyen validation = 2.3024938106536865
# -------- > epoch 21:  taux moyen validation = 0.10909999161958694
# -------- > epoch 22:  coût moyen entraînement = 2.3008081912994385
# -------- > epoch 22:  taux moyen entraînement = 0.11572001874446869
# -------- > epoch 22:  coût moyen validation = 2.2996747493743896
# -------- > epoch 22:  taux moyen validation = 0.13819998502731323
# -------- > epoch 23:  coût moyen entraînement = 2.2757511138916016
# -------- > epoch 23:  taux moyen entraînement = 0.14264000952243805
# -------- > epoch 23:  coût moyen validation = 2.117893934249878
# -------- > epoch 23:  taux moyen validation = 0.23479999601840973
# -------- > epoch 24:  coût moyen entraînement = 1.874680757522583
# -------- > epoch 24:  taux moyen entraînement = 0.3062398433685303
# -------- > epoch 24:  coût moyen validation = 1.5438657999038696
# -------- > epoch 24:  taux moyen validation = 0.41519996523857117
# -------- > epoch 25:  coût moyen entraînement = 1.0542117357254028
# -------- > epoch 25:  taux moyen entraînement = 0.6253196001052856
# -------- > epoch 25:  coût moyen validation = 0.6988287568092346
# -------- > epoch 25:  taux moyen validation = 0.758699893951416
# -------- > epoch 26:  coût moyen entraînement = 0.5130352973937988
# -------- > epoch 26:  taux moyen entraînement = 0.8359001278877258
# -------- > epoch 26:  coût moyen validation = 0.42801231145858765
# -------- > epoch 26:  taux moyen validation = 0.8693997859954834
# -------- > epoch 27:  coût moyen entraînement = 0.3036521375179291
# -------- > epoch 27:  taux moyen entraînement = 0.9086015224456787
# -------- > epoch 27:  coût moyen validation = 0.24275194108486176
# -------- > epoch 27:  taux moyen validation = 0.925899863243103
# -------- > epoch 28:  coût moyen entraînement = 0.21262744069099426
# -------- > epoch 28:  taux moyen entraînement = 0.9353408217430115
# -------- > epoch 28:  coût moyen validation = 0.19035299122333527
# -------- > epoch 28:  taux moyen validation = 0.9418001770973206
# -------- > epoch 29:  coût moyen entraînement = 0.1682186722755432
# -------- > epoch 29:  taux moyen entraînement = 0.9483008980751038
# -------- > epoch 29:  coût moyen validation = 0.14263035356998444
# -------- > epoch 29:  taux moyen validation = 0.957399845123291
# -------- > epoch 30:  coût moyen entraînement = 0.13828317821025848
# -------- > epoch 30:  taux moyen entraînement = 0.9576411247253418
# -------- > epoch 30:  coût moyen validation = 0.15622885525226593
# -------- > epoch 30:  taux moyen validation = 0.9521999359130859
# -------- > epoch 31:  coût moyen entraînement = 0.11989443004131317
# -------- > epoch 31:  taux moyen entraînement = 0.9638814330101013
# -------- > epoch 31:  coût moyen validation = 0.10929665714502335
# -------- > epoch 31:  taux moyen validation = 0.9672999382019043
# -------- > epoch 32:  coût moyen entraînement = 0.10475168377161026
# -------- > epoch 32:  taux moyen entraînement = 0.9685611128807068
# -------- > epoch 32:  coût moyen validation = 0.12146832793951035
# -------- > epoch 32:  taux moyen validation = 0.961899995803833
# -------- > epoch 33:  coût moyen entraînement = 0.09486840665340424
# -------- > epoch 33:  taux moyen entraînement = 0.9713602066040039
# -------- > epoch 33:  coût moyen validation = 0.09309908002614975
# -------- > epoch 33:  taux moyen validation = 0.9719003438949585
# -------- > epoch 34:  coût moyen entraînement = 0.08621212840080261
# -------- > epoch 34:  taux moyen entraînement = 0.9739805459976196
# -------- > epoch 34:  coût moyen validation = 0.08626685291528702
# -------- > epoch 34:  taux moyen validation = 0.9732001423835754
# -------- > epoch 35:  coût moyen entraînement = 0.08065152168273926
# -------- > epoch 35:  taux moyen entraînement = 0.9752607941627502
# -------- > epoch 35:  coût moyen validation = 0.07724771648645401
# -------- > epoch 35:  taux moyen validation = 0.9755001068115234
# -------- > epoch 36:  coût moyen entraînement = 0.07348919659852982
# -------- > epoch 36:  taux moyen entraînement = 0.9776204824447632
# -------- > epoch 36:  coût moyen validation = 0.07853983342647552
# -------- > epoch 36:  taux moyen validation = 0.9752002954483032
# -------- > epoch 37:  coût moyen entraînement = 0.06880258768796921
# -------- > epoch 37:  taux moyen entraînement = 0.9792006611824036
# -------- > epoch 37:  coût moyen validation = 0.06658962368965149
# -------- > epoch 37:  taux moyen validation = 0.979300320148468
# -------- > epoch 38:  coût moyen entraînement = 0.06499061733484268
# -------- > epoch 38:  taux moyen entraînement = 0.9803801774978638
# -------- > epoch 38:  coût moyen validation = 0.0699150487780571
# -------- > epoch 38:  taux moyen validation = 0.979499876499176
# -------- > epoch 39:  coût moyen entraînement = 0.06055976077914238
# -------- > epoch 39:  taux moyen entraînement = 0.981660008430481
# -------- > epoch 39:  coût moyen validation = 0.06510158628225327
# -------- > epoch 39:  taux moyen validation = 0.9783003330230713
# -------- > epoch 40:  coût moyen entraînement = 0.05794050544500351
# -------- > epoch 40:  taux moyen entraînement = 0.9819201231002808
# -------- > epoch 40:  coût moyen validation = 0.06431785970926285
# -------- > epoch 40:  taux moyen validation = 0.9800004363059998
# -------- > epoch 41:  coût moyen entraînement = 0.0550898015499115
# -------- > epoch 41:  taux moyen entraînement = 0.9828809499740601
# -------- > epoch 41:  coût moyen validation = 0.06007123365998268
# -------- > epoch 41:  taux moyen validation = 0.9793001413345337
# -------- > epoch 42:  coût moyen entraînement = 0.05258369818329811
# -------- > epoch 42:  taux moyen entraînement = 0.9839402437210083
# -------- > epoch 42:  coût moyen validation = 0.05612365901470184
# -------- > epoch 42:  taux moyen validation = 0.9830001592636108
# -------- > epoch 43:  coût moyen entraînement = 0.04959649592638016
# -------- > epoch 43:  taux moyen entraînement = 0.9854602813720703
# -------- > epoch 43:  coût moyen validation = 0.05232361704111099
# -------- > epoch 43:  taux moyen validation = 0.9838000535964966
# -------- > epoch 44:  coût moyen entraînement = 0.047589126974344254
# -------- > epoch 44:  taux moyen entraînement = 0.9858807325363159
# -------- > epoch 44:  coût moyen validation = 0.05409152805805206
# -------- > epoch 44:  taux moyen validation = 0.9831003546714783
# -------- > epoch 45:  coût moyen entraînement = 0.04619552567601204
# -------- > epoch 45:  taux moyen entraînement = 0.9860199689865112
# -------- > epoch 45:  coût moyen validation = 0.049190059304237366
# -------- > epoch 45:  taux moyen validation = 0.9851000905036926
# -------- > epoch 46:  coût moyen entraînement = 0.0433003231883049
# -------- > epoch 46:  taux moyen entraînement = 0.9870800971984863
# -------- > epoch 46:  coût moyen validation = 0.06036999821662903
# -------- > epoch 46:  taux moyen validation = 0.9821000695228577
# -------- > epoch 47:  coût moyen entraînement = 0.042179174721241
# -------- > epoch 47:  taux moyen entraînement = 0.9870203733444214
# -------- > epoch 47:  coût moyen validation = 0.050047095865011215
# -------- > epoch 47:  taux moyen validation = 0.9832003116607666
# -------- > epoch 48:  coût moyen entraînement = 0.041183315217494965
# -------- > epoch 48:  taux moyen entraînement = 0.9870402216911316
# -------- > epoch 48:  coût moyen validation = 0.052734896540641785
# -------- > epoch 48:  taux moyen validation = 0.9850001335144043
# -------- > epoch 49:  coût moyen entraînement = 0.03880040720105171
# -------- > epoch 49:  taux moyen entraînement = 0.9881396889686584
# -------- > epoch 49:  coût moyen validation = 0.04769197478890419
# -------- > epoch 49:  taux moyen validation = 0.9850001335144043
# -------- > epoch 50:  coût moyen entraînement = 0.037249013781547546
# -------- > epoch 50:  taux moyen entraînement = 0.9889001846313477
# -------- > epoch 50:  coût moyen validation = 0.0504043810069561
# -------- > epoch 50:  taux moyen validation = 0.984600305557251

# %%
X = torch.randn(size=(1, 1, 28, 28), dtype=torch.float32)
for une_couche in modele:
    X = une_couche(X)
    print('Type de couche:',une_couche.__class__.__name__,'  Forme de sortie:',X.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f81bd3f057e4> in <module>
# ----> 1 X = torch.randn(size=(1, 1, 28, 28), dtype=torch.float32)
#       2 for une_couche in modele:
#       3     X = une_couche(X)
#       4     print('Type de couche:',une_couche.__class__.__name__,'  Forme de sortie:',X.shape)
#
# NameError: name 'torch' is not defined

# %%
optimiseur = optim.SGD(modele.parameters(), lr=0.001)
entrainer(modele, dl_ent, dl_valid, optimiseur, nb_epochs=10)
# Out:
# -------- > epoch 1:  coût moyen entraînement = 0.0011730216210708022
# -------- > epoch 1:  taux moyen entraînement = 0.9999599456787109
# -------- > epoch 1:  coût moyen validation = 0.02290450781583786
# -------- > epoch 1:  taux moyen validation = 0.9934998154640198
# -------- > epoch 2:  coût moyen entraînement = 0.0014617282431572676
# -------- > epoch 2:  taux moyen entraînement = 0.9998399019241333
# -------- > epoch 2:  coût moyen validation = 0.02277243696153164
# -------- > epoch 2:  taux moyen validation = 0.9932998418807983
# -------- > epoch 3:  coût moyen entraînement = 0.0011783367954194546
# -------- > epoch 3:  taux moyen entraînement = 0.9999199509620667
# -------- > epoch 3:  coût moyen validation = 0.022699857130646706
# -------- > epoch 3:  taux moyen validation = 0.9931998252868652
# -------- > epoch 4:  coût moyen entraînement = 0.0011863978579640388
# -------- > epoch 4:  taux moyen entraînement = 0.9998999834060669
# -------- > epoch 4:  coût moyen validation = 0.02314028888940811
# -------- > epoch 4:  taux moyen validation = 0.9929998517036438
# -------- > epoch 5:  coût moyen entraînement = 0.0012405578745529056
# -------- > epoch 5:  taux moyen entraînement = 0.9998999238014221
# -------- > epoch 5:  coût moyen validation = 0.022702591493725777
# -------- > epoch 5:  taux moyen validation = 0.9929998517036438
# -------- > epoch 6:  coût moyen entraînement = 0.0011581629514694214
# -------- > epoch 6:  taux moyen entraînement = 0.9999199509620667
# -------- > epoch 6:  coût moyen validation = 0.022594964131712914
# -------- > epoch 6:  taux moyen validation = 0.9932998418807983
# -------- > epoch 7:  coût moyen entraînement = 0.001193463453091681
# -------- > epoch 7:  taux moyen entraînement = 0.9999000430107117
# -------- > epoch 7:  coût moyen validation = 0.022963140159845352
# -------- > epoch 7:  taux moyen validation = 0.992999792098999
# -------- > epoch 8:  coût moyen entraînement = 0.0012271886225789785
# -------- > epoch 8:  taux moyen entraînement = 0.9998999238014221
# -------- > epoch 8:  coût moyen validation = 0.023455046117305756
# -------- > epoch 8:  taux moyen validation = 0.9930998086929321
# -------- > epoch 9:  coût moyen entraînement = 0.0013464142102748156
# -------- > epoch 9:  taux moyen entraînement = 0.9998999238014221
# -------- > epoch 9:  coût moyen validation = 0.02317296899855137
# -------- > epoch 9:  taux moyen validation = 0.9928998351097107
# -------- > epoch 10:  coût moyen entraînement = 0.0013536452315747738
# -------- > epoch 10:  taux moyen entraînement = 0.9998800158500671
# -------- > epoch 10:  coût moyen validation = 0.02357981912791729
# -------- > epoch 10:  taux moyen validation = 0.9933997988700867
